# %% [markdown]
# ### Frequency map generation steps
#
# #1. Create date time seried data of events(start and end date for events)
# #1a. For flood the data of events are manually created
# 2. Read the manually created excel sheet with geoboundary code for each event
# 3. Merge two dataframe and create year wise fequecny plots of geoboundary code

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import pandas as pd
from ast import literal_eval

filepath = r'C:/Users/HP 820/loan_prediction/ea-ibf-climada/impact_catalog/'

filename = f'{filepath}em_dat_ea_drought_adm2_v2.xlsx'

dfb_dr = pd.read_excel(filename, engine='openpyxl')
#dfb_dr['year']= dfb_dr['Dis No'].str[:4]
#dfb_dr

dfb_dr['adm2_list'] = dfb_dr.geob_adm2_list.apply(lambda x: literal_eval(str(x)))
#dfb_dr['disno_list'] = dfb_dr['Dis No'].apply(lambda x: literal_eval(str(x)))

dfb_dr1 = dfb_dr[['Dis No', 'adm2_list']]

dfb_dr2 = dfb_dr1.explode('adm2_list')
dfb_dr2['year'] = dfb_dr2['Dis No'].str.split('-').str[0]
#dfb_dr3=dfb_dr2.groupby('adm2_list').agg({'Dis No':lambda x: list(x)})

df = dfb_dr2.groupby(['adm2_list']).agg(['count'])

df1 = df.reset_index()
df1.columns = ['shapeID', 'count1', 'count2']
df1['count1'].max()

df1['shapeID'].tolist()
# Out:
# ['DJI-ADM2-3_0_0-B1',
#  'DJI-ADM2-3_0_0-B10',
#  'DJI-ADM2-3_0_0-B11',
#  'DJI-ADM2-3_0_0-B2',
#  'DJI-ADM2-3_0_0-B3',
#  'DJI-ADM2-3_0_0-B4',
#  'DJI-ADM2-3_0_0-B5',
#  'DJI-ADM2-3_0_0-B6',
#  'DJI-ADM2-3_0_0-B7',
#  'DJI-ADM2-3_0_0-B8',
#  'DJI-ADM2-3_0_0-B9',
#  'ERI-ADM2-3_0_0-B1',
#  'ERI-ADM2-3_0_0-B10',
#  'ERI-ADM2-3_0_0-B11',
#  'ERI-ADM2-3_0_0-B12',
#  'ERI-ADM2-3_0_0-B13',
#  'ERI-ADM2-3_0_0-B14',
#  'ERI-ADM2-3_0_0-B15',
#  'ERI-ADM2-3_0_0-B16',
#  'ERI-ADM2-3_0_0-B17',
#  'ERI-ADM2-3_0_0-B18',
#  'ERI-ADM2-3_0_0-B19',
#  'ERI-ADM2-3_0_0-B2',
#  'ERI-ADM2-3_0_0-B20',
#  'ERI-ADM2-3_0_0-B21',
#  'ERI-ADM2-3_0_0-B22',
#  'ERI-ADM2-3_0_0-B23',
#  'ERI-ADM2-3_0_0-B24',
#  'ERI-ADM2-3_0_0-B25',
#  'ERI-ADM2-3_0_0-B26',
#  'ERI-ADM2-3_0_0-B27',
#  'ERI-ADM2-3_0_0-B28',
#  'ERI-ADM2-3_0_0-B29',
#  'ERI-ADM2-3_0_0-B3',
#  'ERI-ADM2-3_0_0-B30',
#  'ERI-ADM2-3_0_0-B31',
#  'ERI-ADM2-3_0_0-B32',
#  'ERI-ADM2-3_0_0-B33',
#  'ERI-ADM2-3_0_0-B34',
#  'ERI-ADM2-3_0_0-B35',
#  'ERI-ADM2-3_0_0-B36',
#  'ERI-ADM2-3_0_0-B37',
#  'ERI-ADM2-3_0_0-B38',
#  'ERI-ADM2-3_0_0-B39',
#  'ERI-ADM2-3_0_0-B4',
#  'ERI-ADM2-3_0_0-B40',
#  'ERI-ADM2-3_0_0-B41',
#  'ERI-ADM2-3_0_0-B42',
#  'ERI-ADM2-3_0_0-B43',
#  'ERI-ADM2-3_0_0-B44',
#  'ERI-ADM2-3_0_0-B45',
#  'ERI-ADM2-3_0_0-B46',
#  'ERI-ADM2-3_0_0-B47',
#  'ERI-ADM2-3_0_0-B48',
#  'ERI-ADM2-3_0_0-B49',
#  'ERI-ADM2-3_0_0-B5',
#  'ERI-ADM2-3_0_0-B50',
#  'ERI-ADM2-3_0_0-B51',
#  'ERI-ADM2-3_0_0-B52',
#  'ERI-ADM2-3_0_0-B53',
#  'ERI-ADM2-3_0_0-B54',
#  'ERI-ADM2-3_0_0-B55',
#  'ERI-ADM2-3_0_0-B56',
#  'ERI-ADM2-3_0_0-B57',
#  'ERI-ADM2-3_0_0-B58',
#  'ERI-ADM2-3_0_0-B6',
#  'ERI-ADM2-3_0_0-B7',
#  'ERI-ADM2-3_0_0-B8',
#  'ERI-ADM2-3_0_0-B9',
#  'ETH-ADM1-3_0_0-B10',
#  'ETH-ADM1-3_0_0-B8',
#  'ETH-ADM2-3_0_0-B1',
#  'ETH-ADM2-3_0_0-B10',
#  'ETH-ADM2-3_0_0-B11',
#  'ETH-ADM2-3_0_0-B12',
#  'ETH-ADM2-3_0_0-B13',
#  'ETH-ADM2-3_0_0-B14',
#  'ETH-ADM2-3_0_0-B15',
#  'ETH-ADM2-3_0_0-B16',
#  'ETH-ADM2-3_0_0-B17',
#  'ETH-ADM2-3_0_0-B18',
#  'ETH-ADM2-3_0_0-B19',
#  'ETH-ADM2-3_0_0-B2',
#  'ETH-ADM2-3_0_0-B20',
#  'ETH-ADM2-3_0_0-B21',
#  'ETH-ADM2-3_0_0-B22',
#  'ETH-ADM2-3_0_0-B23',
#  'ETH-ADM2-3_0_0-B24',
#  'ETH-ADM2-3_0_0-B25',
#  'ETH-ADM2-3_0_0-B26',
#  'ETH-ADM2-3_0_0-B27',
#  'ETH-ADM2-3_0_0-B28',
#  'ETH-ADM2-3_0_0-B29',
#  'ETH-ADM2-3_0_0-B3',
#  'ETH-ADM2-3_0_0-B30',
#  'ETH-ADM2-3_0_0-B31',
#  'ETH-ADM2-3_0_0-B32',
#  'ETH-ADM2-3_0_0-B33',
#  'ETH-ADM2-3_0_0-B34',
#  'ETH-ADM2-3_0_0-B35',
#  'ETH-ADM2-3_0_0-B36',
#  'ETH-ADM2-3_0_0-B37',
#  'ETH-ADM2-3_0_0-B38',
#  'ETH-ADM2-3_0_0-B39',
#  'ETH-ADM2-3_0_0-B4',
#  'ETH-ADM2-3_0_0-B40',
#  'ETH-ADM2-3_0_0-B41',
#  'ETH-ADM2-3_0_0-B42',
#  'ETH-ADM2-3_0_0-B43',
#  'ETH-ADM2-3_0_0-B44',
#  'ETH-ADM2-3_0_0-B45',
#  'ETH-ADM2-3_0_0-B46',
#  'ETH-ADM2-3_0_0-B47',
#  'ETH-ADM2-3_0_0-B48',
#  'ETH-ADM2-3_0_0-B49',
#  'ETH-ADM2-3_0_0-B5',
#  'ETH-ADM2-3_0_0-B50',
#  'ETH-ADM2-3_0_0-B51',
#  'ETH-ADM2-3_0_0-B52',
#  'ETH-ADM2-3_0_0-B53',
#  'ETH-ADM2-3_0_0-B54',
#  'ETH-ADM2-3_0_0-B55',
#  'ETH-ADM2-3_0_0-B56',
#  'ETH-ADM2-3_0_0-B57',
#  'ETH-ADM2-3_0_0-B58',
#  'ETH-ADM2-3_0_0-B59',
#  'ETH-ADM2-3_0_0-B6',
#  'ETH-ADM2-3_0_0-B60',
#  'ETH-ADM2-3_0_0-B61',
#  'ETH-ADM2-3_0_0-B62',
#  'ETH-ADM2-3_0_0-B63',
#  'ETH-ADM2-3_0_0-B64',
#  'ETH-ADM2-3_0_0-B65',
#  'ETH-ADM2-3_0_0-B66',
#  'ETH-ADM2-3_0_0-B67',
#  'ETH-ADM2-3_0_0-B68',
#  'ETH-ADM2-3_0_0-B69',
#  'ETH-ADM2-3_0_0-B7',
#  'ETH-ADM2-3_0_0-B70',
#  'ETH-ADM2-3_0_0-B71',
#  'ETH-ADM2-3_0_0-B72',
#  'ETH-ADM2-3_0_0-B73',
#  'ETH-ADM2-3_0_0-B74',
#  'ETH-ADM2-3_0_0-B8',
#  'ETH-ADM2-3_0_0-B9',
#  'KEN-ADM1-3_0_0-B1',
#  'KEN-ADM1-3_0_0-B10',
#  'KEN-ADM1-3_0_0-B11',
#  'KEN-ADM1-3_0_0-B12',
#  'KEN-ADM1-3_0_0-B13',
#  'KEN-ADM1-3_0_0-B17',
#  'KEN-ADM1-3_0_0-B17,KEN-ADM1-3_0_0-B1,KEN-ADM1-3_0_0-B19,KEN-ADM1-3_0_0-B7,KEN-ADM1-3_0_0-B8,KEN-ADM1-3_0_0-B29,KEN-ADM1-3_0_0-B6,KEN-ADM1-3_0_0-B35,KEN-ADM1-3_0_0-B3,KEN-ADM1-3_0_0-B38,KEN-ADM1-3_0_0-B42,KEN-ADM1-3_0_0-B43,KEN-ADM1-3_0_0-B44,KEN-ADM1-3_0_0-B46',
#  'KEN-ADM1-3_0_0-B18',
#  'KEN-ADM1-3_0_0-B19',
#  'KEN-ADM1-3_0_0-B2',
#  'KEN-ADM1-3_0_0-B22',
#  'KEN-ADM1-3_0_0-B23',
#  'KEN-ADM1-3_0_0-B24',
#  'KEN-ADM1-3_0_0-B26',
#  'KEN-ADM1-3_0_0-B29',
#  'KEN-ADM1-3_0_0-B3',
#  'KEN-ADM1-3_0_0-B31',
#  'KEN-ADM1-3_0_0-B32',
#  'KEN-ADM1-3_0_0-B33',
#  'KEN-ADM1-3_0_0-B35',
#  'KEN-ADM1-3_0_0-B36',
#  'KEN-ADM1-3_0_0-B37',
#  'KEN-ADM1-3_0_0-B38',
#  'KEN-ADM1-3_0_0-B39',
#  'KEN-ADM1-3_0_0-B4',
#  'KEN-ADM1-3_0_0-B40',
#  'KEN-ADM1-3_0_0-B42',
#  'KEN-ADM1-3_0_0-B43',
#  'KEN-ADM1-3_0_0-B44',
#  'KEN-ADM1-3_0_0-B45',
#  'KEN-ADM1-3_0_0-B46',
#  'KEN-ADM1-3_0_0-B47',
#  'KEN-ADM1-3_0_0-B5',
#  'KEN-ADM1-3_0_0-B6',
#  'KEN-ADM1-3_0_0-B8',
#  'KEN-ADM1-3_0_0-B9',
#  'KEN-ADM2-3_0_0-B1',
#  'KEN-ADM2-3_0_0-B10',
#  'KEN-ADM2-3_0_0-B12',
#  'KEN-ADM2-3_0_0-B13',
#  'KEN-ADM2-3_0_0-B14',
#  'KEN-ADM2-3_0_0-B16',
#  'KEN-ADM2-3_0_0-B19',
#  'KEN-ADM2-3_0_0-B22',
#  'KEN-ADM2-3_0_0-B25',
#  'KEN-ADM2-3_0_0-B26',
#  'KEN-ADM2-3_0_0-B27',
#  'KEN-ADM2-3_0_0-B29',
#  'KEN-ADM2-3_0_0-B30',
#  'KEN-ADM2-3_0_0-B31',
#  'KEN-ADM2-3_0_0-B32',
#  'KEN-ADM2-3_0_0-B34',
#  'KEN-ADM2-3_0_0-B35',
#  'KEN-ADM2-3_0_0-B36',
#  'KEN-ADM2-3_0_0-B42',
#  'KEN-ADM2-3_0_0-B45',
#  'KEN-ADM2-3_0_0-B48',
#  'KEN-ADM2-3_0_0-B50',
#  'KEN-ADM2-3_0_0-B52',
#  'KEN-ADM2-3_0_0-B53',
#  'KEN-ADM2-3_0_0-B54',
#  'KEN-ADM2-3_0_0-B56',
#  'KEN-ADM2-3_0_0-B57',
#  'KEN-ADM2-3_0_0-B58',
#  'KEN-ADM2-3_0_0-B60',
#  'KEN-ADM2-3_0_0-B62',
#  'KEN-ADM2-3_0_0-B64',
#  'KEN-ADM2-3_0_0-B67',
#  'KEN-ADM2-3_0_0-B68',
#  'KEN-ADM2-3_0_0-B69',
#  'KEN-ADM2-3_0_0-B9',
#  'RWA-ADM2-3_0_0-B1',
#  'RWA-ADM2-3_0_0-B10',
#  'RWA-ADM2-3_0_0-B11',
#  'RWA-ADM2-3_0_0-B14',
#  'RWA-ADM2-3_0_0-B2',
#  'RWA-ADM2-3_0_0-B24',
#  'RWA-ADM2-3_0_0-B25',
#  'RWA-ADM2-3_0_0-B28',
#  'RWA-ADM2-3_0_0-B29',
#  'RWA-ADM2-3_0_0-B3',
#  'RWA-ADM2-3_0_0-B4',
#  'RWA-ADM2-3_0_0-B5',
#  'RWA-ADM2-3_0_0-B6',
#  'RWA-ADM2-3_0_0-B7',
#  'RWA-ADM2-3_0_0-B8',
#  'RWA-ADM2-3_0_0-B9',
#  'SDN-ADM1-3_0_0-B11',
#  'SDN-ADM2-3_0_0-B1',
#  'SDN-ADM2-3_0_0-B10',
#  'SDN-ADM2-3_0_0-B100',
#  'SDN-ADM2-3_0_0-B101',
#  'SDN-ADM2-3_0_0-B102',
#  'SDN-ADM2-3_0_0-B103',
#  'SDN-ADM2-3_0_0-B104',
#  'SDN-ADM2-3_0_0-B105',
#  'SDN-ADM2-3_0_0-B106',
#  'SDN-ADM2-3_0_0-B107',
#  'SDN-ADM2-3_0_0-B108',
#  'SDN-ADM2-3_0_0-B109',
#  'SDN-ADM2-3_0_0-B11',
#  'SDN-ADM2-3_0_0-B110',
#  'SDN-ADM2-3_0_0-B111',
#  'SDN-ADM2-3_0_0-B112',
#  'SDN-ADM2-3_0_0-B113',
#  'SDN-ADM2-3_0_0-B114',
#  'SDN-ADM2-3_0_0-B115',
#  'SDN-ADM2-3_0_0-B116',
#  'SDN-ADM2-3_0_0-B117',
#  'SDN-ADM2-3_0_0-B118',
#  'SDN-ADM2-3_0_0-B119',
#  'SDN-ADM2-3_0_0-B12',
#  'SDN-ADM2-3_0_0-B120',
#  'SDN-ADM2-3_0_0-B121',
#  'SDN-ADM2-3_0_0-B122',
#  'SDN-ADM2-3_0_0-B123',
#  'SDN-ADM2-3_0_0-B124',
#  'SDN-ADM2-3_0_0-B125',
#  'SDN-ADM2-3_0_0-B126',
#  'SDN-ADM2-3_0_0-B127',
#  'SDN-ADM2-3_0_0-B128',
#  'SDN-ADM2-3_0_0-B129',
#  'SDN-ADM2-3_0_0-B13',
#  'SDN-ADM2-3_0_0-B130',
#  'SDN-ADM2-3_0_0-B131',
#  'SDN-ADM2-3_0_0-B132',
#  'SDN-ADM2-3_0_0-B133',
#  'SDN-ADM2-3_0_0-B134',
#  'SDN-ADM2-3_0_0-B135',
#  'SDN-ADM2-3_0_0-B136',
#  'SDN-ADM2-3_0_0-B137',
#  'SDN-ADM2-3_0_0-B138',
#  'SDN-ADM2-3_0_0-B139',
#  'SDN-ADM2-3_0_0-B14',
#  'SDN-ADM2-3_0_0-B140',
#  'SDN-ADM2-3_0_0-B141',
#  'SDN-ADM2-3_0_0-B142',
#  'SDN-ADM2-3_0_0-B143',
#  'SDN-ADM2-3_0_0-B144',
#  'SDN-ADM2-3_0_0-B145',
#  'SDN-ADM2-3_0_0-B146',
#  'SDN-ADM2-3_0_0-B147',
#  'SDN-ADM2-3_0_0-B148',
#  'SDN-ADM2-3_0_0-B149',
#  'SDN-ADM2-3_0_0-B15',
#  'SDN-ADM2-3_0_0-B150',
#  'SDN-ADM2-3_0_0-B151',
#  'SDN-ADM2-3_0_0-B152',
#  'SDN-ADM2-3_0_0-B153',
#  'SDN-ADM2-3_0_0-B154',
#  'SDN-ADM2-3_0_0-B155',
#  'SDN-ADM2-3_0_0-B156',
#  'SDN-ADM2-3_0_0-B157',
#  'SDN-ADM2-3_0_0-B158',
#  'SDN-ADM2-3_0_0-B159',
#  'SDN-ADM2-3_0_0-B16',
#  'SDN-ADM2-3_0_0-B160',
#  'SDN-ADM2-3_0_0-B161',
#  'SDN-ADM2-3_0_0-B162',
#  'SDN-ADM2-3_0_0-B163',
#  'SDN-ADM2-3_0_0-B164',
#  'SDN-ADM2-3_0_0-B165',
#  'SDN-ADM2-3_0_0-B166',
#  'SDN-ADM2-3_0_0-B167',
#  'SDN-ADM2-3_0_0-B168',
#  'SDN-ADM2-3_0_0-B169',
#  'SDN-ADM2-3_0_0-B17',
#  'SDN-ADM2-3_0_0-B170',
#  'SDN-ADM2-3_0_0-B171',
#  'SDN-ADM2-3_0_0-B172',
#  'SDN-ADM2-3_0_0-B18',
#  'SDN-ADM2-3_0_0-B19',
#  'SDN-ADM2-3_0_0-B2',
#  'SDN-ADM2-3_0_0-B20',
#  'SDN-ADM2-3_0_0-B21',
#  'SDN-ADM2-3_0_0-B22',
#  'SDN-ADM2-3_0_0-B23',
#  'SDN-ADM2-3_0_0-B24',
#  'SDN-ADM2-3_0_0-B25',
#  'SDN-ADM2-3_0_0-B26',
#  'SDN-ADM2-3_0_0-B27',
#  'SDN-ADM2-3_0_0-B28',
#  'SDN-ADM2-3_0_0-B29',
#  'SDN-ADM2-3_0_0-B3',
#  'SDN-ADM2-3_0_0-B30',
#  'SDN-ADM2-3_0_0-B31',
#  'SDN-ADM2-3_0_0-B32',
#  'SDN-ADM2-3_0_0-B33',
#  'SDN-ADM2-3_0_0-B34',
#  'SDN-ADM2-3_0_0-B35',
#  'SDN-ADM2-3_0_0-B36',
#  'SDN-ADM2-3_0_0-B37',
#  'SDN-ADM2-3_0_0-B38',
#  'SDN-ADM2-3_0_0-B39',
#  'SDN-ADM2-3_0_0-B4',
#  'SDN-ADM2-3_0_0-B40',
#  'SDN-ADM2-3_0_0-B41',
#  'SDN-ADM2-3_0_0-B42',
#  'SDN-ADM2-3_0_0-B43',
#  'SDN-ADM2-3_0_0-B44',
#  'SDN-ADM2-3_0_0-B45',
#  'SDN-ADM2-3_0_0-B46',
#  'SDN-ADM2-3_0_0-B47',
#  'SDN-ADM2-3_0_0-B48',
#  'SDN-ADM2-3_0_0-B49',
#  'SDN-ADM2-3_0_0-B5',
#  'SDN-ADM2-3_0_0-B50',
#  'SDN-ADM2-3_0_0-B51',
#  'SDN-ADM2-3_0_0-B52',
#  'SDN-ADM2-3_0_0-B53',
#  'SDN-ADM2-3_0_0-B54',
#  'SDN-ADM2-3_0_0-B55',
#  'SDN-ADM2-3_0_0-B56',
#  'SDN-ADM2-3_0_0-B57',
#  'SDN-ADM2-3_0_0-B58',
#  'SDN-ADM2-3_0_0-B59',
#  'SDN-ADM2-3_0_0-B6',
#  'SDN-ADM2-3_0_0-B60',
#  'SDN-ADM2-3_0_0-B61',
#  'SDN-ADM2-3_0_0-B62',
#  'SDN-ADM2-3_0_0-B63',
#  'SDN-ADM2-3_0_0-B64',
#  'SDN-ADM2-3_0_0-B65',
#  'SDN-ADM2-3_0_0-B66',
#  'SDN-ADM2-3_0_0-B67',
#  'SDN-ADM2-3_0_0-B68',
#  'SDN-ADM2-3_0_0-B69',
#  'SDN-ADM2-3_0_0-B7',
#  'SDN-ADM2-3_0_0-B70',
#  'SDN-ADM2-3_0_0-B71',
#  'SDN-ADM2-3_0_0-B72',
#  'SDN-ADM2-3_0_0-B73',
#  'SDN-ADM2-3_0_0-B74',
#  'SDN-ADM2-3_0_0-B75',
#  'SDN-ADM2-3_0_0-B76',
#  'SDN-ADM2-3_0_0-B77',
#  'SDN-ADM2-3_0_0-B78',
#  'SDN-ADM2-3_0_0-B79',
#  'SDN-ADM2-3_0_0-B8',
#  'SDN-ADM2-3_0_0-B80',
#  'SDN-ADM2-3_0_0-B81',
#  'SDN-ADM2-3_0_0-B82',
#  'SDN-ADM2-3_0_0-B83',
#  'SDN-ADM2-3_0_0-B84',
#  'SDN-ADM2-3_0_0-B85',
#  'SDN-ADM2-3_0_0-B86',
#  'SDN-ADM2-3_0_0-B87',
#  'SDN-ADM2-3_0_0-B88',
#  'SDN-ADM2-3_0_0-B89',
#  'SDN-ADM2-3_0_0-B9',
#  'SDN-ADM2-3_0_0-B90',
#  'SDN-ADM2-3_0_0-B91',
#  'SDN-ADM2-3_0_0-B92',
#  'SDN-ADM2-3_0_0-B93',
#  'SDN-ADM2-3_0_0-B94',
#  'SDN-ADM2-3_0_0-B95',
#  'SDN-ADM2-3_0_0-B96',
#  'SDN-ADM2-3_0_0-B97',
#  'SDN-ADM2-3_0_0-B98',
#  'SDN-ADM2-3_0_0-B99',
#  'SOM-ADM2-3_0_0-B1',
#  'SOM-ADM2-3_0_0-B10',
#  'SOM-ADM2-3_0_0-B11',
#  'SOM-ADM2-3_0_0-B12',
#  'SOM-ADM2-3_0_0-B13',
#  'SOM-ADM2-3_0_0-B14',
#  'SOM-ADM2-3_0_0-B15',
#  'SOM-ADM2-3_0_0-B16',
#  'SOM-ADM2-3_0_0-B17',
#  'SOM-ADM2-3_0_0-B18',
#  'SOM-ADM2-3_0_0-B19',
#  'SOM-ADM2-3_0_0-B2',
#  'SOM-ADM2-3_0_0-B20',
#  'SOM-ADM2-3_0_0-B21',
#  'SOM-ADM2-3_0_0-B22',
#  'SOM-ADM2-3_0_0-B23',
#  'SOM-ADM2-3_0_0-B24',
#  'SOM-ADM2-3_0_0-B25',
#  'SOM-ADM2-3_0_0-B26',
#  'SOM-ADM2-3_0_0-B27',
#  'SOM-ADM2-3_0_0-B28',
#  'SOM-ADM2-3_0_0-B29',
#  'SOM-ADM2-3_0_0-B3',
#  'SOM-ADM2-3_0_0-B30',
#  'SOM-ADM2-3_0_0-B31',
#  'SOM-ADM2-3_0_0-B32',
#  'SOM-ADM2-3_0_0-B33',
#  'SOM-ADM2-3_0_0-B34',
#  'SOM-ADM2-3_0_0-B35',
#  'SOM-ADM2-3_0_0-B36',
#  'SOM-ADM2-3_0_0-B37',
#  'SOM-ADM2-3_0_0-B38',
#  'SOM-ADM2-3_0_0-B39',
#  'SOM-ADM2-3_0_0-B4',
#  'SOM-ADM2-3_0_0-B40',
#  'SOM-ADM2-3_0_0-B41',
#  'SOM-ADM2-3_0_0-B42',
#  'SOM-ADM2-3_0_0-B43',
#  'SOM-ADM2-3_0_0-B44',
#  'SOM-ADM2-3_0_0-B45',
#  'SOM-ADM2-3_0_0-B46',
#  'SOM-ADM2-3_0_0-B47',
#  'SOM-ADM2-3_0_0-B48',
#  'SOM-ADM2-3_0_0-B49',
#  'SOM-ADM2-3_0_0-B5',
#  'SOM-ADM2-3_0_0-B50',
#  'SOM-ADM2-3_0_0-B51',
#  'SOM-ADM2-3_0_0-B52',
#  'SOM-ADM2-3_0_0-B53',
#  'SOM-ADM2-3_0_0-B54',
#  'SOM-ADM2-3_0_0-B55',
#  'SOM-ADM2-3_0_0-B56',
#  'SOM-ADM2-3_0_0-B57',
#  'SOM-ADM2-3_0_0-B58',
#  'SOM-ADM2-3_0_0-B59',
#  'SOM-ADM2-3_0_0-B6',
#  'SOM-ADM2-3_0_0-B60',
#  'SOM-ADM2-3_0_0-B61',
#  'SOM-ADM2-3_0_0-B62',
#  'SOM-ADM2-3_0_0-B63',
#  'SOM-ADM2-3_0_0-B64',
#  'SOM-ADM2-3_0_0-B65',
#  'SOM-ADM2-3_0_0-B66',
#  'SOM-ADM2-3_0_0-B67',
#  'SOM-ADM2-3_0_0-B68',
#  'SOM-ADM2-3_0_0-B69',
#  'SOM-ADM2-3_0_0-B7',
#  'SOM-ADM2-3_0_0-B70',
#  'SOM-ADM2-3_0_0-B71',
#  'SOM-ADM2-3_0_0-B72',
#  'SOM-ADM2-3_0_0-B73',
#  'SOM-ADM2-3_0_0-B74',
#  'SOM-ADM2-3_0_0-B8',
#  'SOM-ADM2-3_0_0-B9',
#  'SSD-ADM1-3_0_0-B7',
#  'SSD-ADM2-3_0_0-B1',
#  'SSD-ADM2-3_0_0-B10',
#  'SSD-ADM2-3_0_0-B11',
#  'SSD-ADM2-3_0_0-B12',
#  'SSD-ADM2-3_0_0-B13',
#  'SSD-ADM2-3_0_0-B14',
#  'SSD-ADM2-3_0_0-B15',
#  'SSD-ADM2-3_0_0-B16',
#  'SSD-ADM2-3_0_0-B17',
#  'SSD-ADM2-3_0_0-B18',
#  'SSD-ADM2-3_0_0-B19',
#  'SSD-ADM2-3_0_0-B2',
#  'SSD-ADM2-3_0_0-B20',
#  'SSD-ADM2-3_0_0-B21',
#  'SSD-ADM2-3_0_0-B22',
#  'SSD-ADM2-3_0_0-B23',
#  'SSD-ADM2-3_0_0-B24',
#  'SSD-ADM2-3_0_0-B25',
#  'SSD-ADM2-3_0_0-B26',
#  'SSD-ADM2-3_0_0-B27',
#  'SSD-ADM2-3_0_0-B28',
#  'SSD-ADM2-3_0_0-B29',
#  'SSD-ADM2-3_0_0-B3',
#  'SSD-ADM2-3_0_0-B30',
#  'SSD-ADM2-3_0_0-B31',
#  'SSD-ADM2-3_0_0-B32',
#  'SSD-ADM2-3_0_0-B33',
#  'SSD-ADM2-3_0_0-B34',
#  'SSD-ADM2-3_0_0-B35',
#  'SSD-ADM2-3_0_0-B36',
#  'SSD-ADM2-3_0_0-B37',
#  'SSD-ADM2-3_0_0-B38',
#  'SSD-ADM2-3_0_0-B39',
#  'SSD-ADM2-3_0_0-B4',
#  'SSD-ADM2-3_0_0-B40',
#  'SSD-ADM2-3_0_0-B41',
#  'SSD-ADM2-3_0_0-B42',
#  'SSD-ADM2-3_0_0-B43',
#  'SSD-ADM2-3_0_0-B44',
#  'SSD-ADM2-3_0_0-B45',
#  'SSD-ADM2-3_0_0-B46',
#  'SSD-ADM2-3_0_0-B47',
#  'SSD-ADM2-3_0_0-B48',
#  'SSD-ADM2-3_0_0-B49',
#  'SSD-ADM2-3_0_0-B5',
#  'SSD-ADM2-3_0_0-B50',
#  'SSD-ADM2-3_0_0-B51',
#  'SSD-ADM2-3_0_0-B52',
#  'SSD-ADM2-3_0_0-B53',
#  'SSD-ADM2-3_0_0-B54',
#  'SSD-ADM2-3_0_0-B55',
#  'SSD-ADM2-3_0_0-B56',
#  'SSD-ADM2-3_0_0-B57',
#  'SSD-ADM2-3_0_0-B58',
#  'SSD-ADM2-3_0_0-B59',
#  'SSD-ADM2-3_0_0-B6',
#  'SSD-ADM2-3_0_0-B60',
#  'SSD-ADM2-3_0_0-B61',
#  'SSD-ADM2-3_0_0-B62',
#  'SSD-ADM2-3_0_0-B63',
#  'SSD-ADM2-3_0_0-B64',
#  'SSD-ADM2-3_0_0-B65',
#  'SSD-ADM2-3_0_0-B66',
#  'SSD-ADM2-3_0_0-B67',
#  'SSD-ADM2-3_0_0-B68',
#  'SSD-ADM2-3_0_0-B69',
#  'SSD-ADM2-3_0_0-B7',
#  'SSD-ADM2-3_0_0-B70',
#  'SSD-ADM2-3_0_0-B71',
#  'SSD-ADM2-3_0_0-B72',
#  'SSD-ADM2-3_0_0-B73',
#  'SSD-ADM2-3_0_0-B74',
#  'SSD-ADM2-3_0_0-B75',
#  'SSD-ADM2-3_0_0-B76',
#  'SSD-ADM2-3_0_0-B77',
#  'SSD-ADM2-3_0_0-B78',
#  'SSD-ADM2-3_0_0-B8',
#  'SSD-ADM2-3_0_0-B9',
#  'TZA-ADM1-3_0_0-B1',
#  'TZA-ADM1-3_0_0-B12',
#  'TZA-ADM1-3_0_0-B13',
#  'TZA-ADM1-3_0_0-B15',
#  'TZA-ADM1-3_0_0-B17',
#  'TZA-ADM1-3_0_0-B18',
#  'TZA-ADM1-3_0_0-B19',
#  'TZA-ADM1-3_0_0-B2',
#  'TZA-ADM1-3_0_0-B25',
#  'TZA-ADM1-3_0_0-B27',
#  'TZA-ADM1-3_0_0-B28',
#  'TZA-ADM1-3_0_0-B29',
#  'TZA-ADM1-3_0_0-B3',
#  'TZA-ADM1-3_0_0-B30',
#  'TZA-ADM1-3_0_0-B4',
#  'TZA-ADM1-3_0_0-B5',
#  'TZA-ADM1-3_0_0-B7',
#  'TZA-ADM2-3_0_0-B1',
#  'TZA-ADM2-3_0_0-B101',
#  'TZA-ADM2-3_0_0-B102',
#  'TZA-ADM2-3_0_0-B104',
#  'TZA-ADM2-3_0_0-B105',
#  'TZA-ADM2-3_0_0-B106',
#  'TZA-ADM2-3_0_0-B107',
#  'TZA-ADM2-3_0_0-B108',
#  'TZA-ADM2-3_0_0-B109',
#  'TZA-ADM2-3_0_0-B11',
#  'TZA-ADM2-3_0_0-B110',
#  'TZA-ADM2-3_0_0-B111',
#  'TZA-ADM2-3_0_0-B112',
#  'TZA-ADM2-3_0_0-B113',
#  'TZA-ADM2-3_0_0-B115',
#  'TZA-ADM2-3_0_0-B118',
#  'TZA-ADM2-3_0_0-B119',
#  'TZA-ADM2-3_0_0-B12',
#  'TZA-ADM2-3_0_0-B124',
#  'TZA-ADM2-3_0_0-B126',
#  'TZA-ADM2-3_0_0-B127',
#  'TZA-ADM2-3_0_0-B128',
#  'TZA-ADM2-3_0_0-B129',
#  'TZA-ADM2-3_0_0-B13',
#  'TZA-ADM2-3_0_0-B130',
#  'TZA-ADM2-3_0_0-B131',
#  'TZA-ADM2-3_0_0-B134',
#  'TZA-ADM2-3_0_0-B135',
#  'TZA-ADM2-3_0_0-B136',
#  'TZA-ADM2-3_0_0-B137',
#  'TZA-ADM2-3_0_0-B138',
#  'TZA-ADM2-3_0_0-B139',
#  'TZA-ADM2-3_0_0-B14',
#  'TZA-ADM2-3_0_0-B141',
#  'TZA-ADM2-3_0_0-B143',
#  'TZA-ADM2-3_0_0-B145',
#  'TZA-ADM2-3_0_0-B153',
#  'TZA-ADM2-3_0_0-B154',
#  'TZA-ADM2-3_0_0-B155',
#  'TZA-ADM2-3_0_0-B156',
#  'TZA-ADM2-3_0_0-B157',
#  'TZA-ADM2-3_0_0-B158',
#  'TZA-ADM2-3_0_0-B159',
#  'TZA-ADM2-3_0_0-B161',
#  'TZA-ADM2-3_0_0-B162',
#  'TZA-ADM2-3_0_0-B163',
#  'TZA-ADM2-3_0_0-B165',
#  'TZA-ADM2-3_0_0-B166',
#  'TZA-ADM2-3_0_0-B168',
#  'TZA-ADM2-3_0_0-B17',
#  'TZA-ADM2-3_0_0-B18',
#  'TZA-ADM2-3_0_0-B19',
#  'TZA-ADM2-3_0_0-B22',
#  'TZA-ADM2-3_0_0-B23',
#  'TZA-ADM2-3_0_0-B24',
#  'TZA-ADM2-3_0_0-B25',
#  'TZA-ADM2-3_0_0-B27',
#  'TZA-ADM2-3_0_0-B28',
#  'TZA-ADM2-3_0_0-B29',
#  'TZA-ADM2-3_0_0-B30',
#  'TZA-ADM2-3_0_0-B32',
#  'TZA-ADM2-3_0_0-B34',
#  'TZA-ADM2-3_0_0-B35',
#  'TZA-ADM2-3_0_0-B37',
#  'TZA-ADM2-3_0_0-B41',
#  'TZA-ADM2-3_0_0-B45',
#  'TZA-ADM2-3_0_0-B47',
#  'TZA-ADM2-3_0_0-B48',
#  'TZA-ADM2-3_0_0-B49',
#  'TZA-ADM2-3_0_0-B5',
#  'TZA-ADM2-3_0_0-B52',
#  'TZA-ADM2-3_0_0-B57',
#  'TZA-ADM2-3_0_0-B58',
#  'TZA-ADM2-3_0_0-B62',
#  'TZA-ADM2-3_0_0-B63',
#  'TZA-ADM2-3_0_0-B64',
#  'TZA-ADM2-3_0_0-B65',
#  'TZA-ADM2-3_0_0-B66',
#  'TZA-ADM2-3_0_0-B67',
#  'TZA-ADM2-3_0_0-B70',
#  'TZA-ADM2-3_0_0-B71',
#  'TZA-ADM2-3_0_0-B72',
#  'TZA-ADM2-3_0_0-B74',
#  'TZA-ADM2-3_0_0-B77',
#  'TZA-ADM2-3_0_0-B78',
#  'TZA-ADM2-3_0_0-B8',
#  'TZA-ADM2-3_0_0-B81',
#  'TZA-ADM2-3_0_0-B85',
#  'TZA-ADM2-3_0_0-B87',
#  'TZA-ADM2-3_0_0-B89',
#  'TZA-ADM2-3_0_0-B9',
#  'TZA-ADM2-3_0_0-B90',
#  'TZA-ADM2-3_0_0-B91',
#  'TZA-ADM2-3_0_0-B92',
#  'TZA-ADM2-3_0_0-B96']

# %%
import cartopy.crs as ccrs
import geopandas as gp
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader

shapefile_path = r'C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/'

adm2 = gp.read_file(f'{shapefile_path}ea_adm2_geoboundaries.shp')

db = pd.merge(adm2, df1, on='shapeID', how='right')

#adm2
db.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 670 entries, 0 to 669
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shapeName   613 non-null    object
#  1   shapeISO    613 non-null    object
#  2   shapeID     670 non-null    object
#  3   shapeGroup  613 non-null    object
#  4   shapeType   613 non-null    object
#  5   geometry    613 non-null    geometry
#  6   count1      670 non-null    int64
#  7   count2      670 non-null    int64
# dtypes: geometry(1), int64(2), object(5)
# memory usage: 42.0+ KB

# %%
from matplotlib import colors
from matplotlib import pyplot as plt
import geoplot as gplt
import matplotlib
from matplotlib.colors import LinearSegmentedColormap
import geoplot.crs as gcrs
import numpy as np
import mapclassify as mc
from cartopy.io.shapereader import Reader

def return_colormap():
    """
    Create colormap of matplotlib based on number of class and given colorcode

    Parameters
    ----------
    params : class object
        Input/Output parameter definitions.
        
    Returns
    -------
    c_cmap : Object
        matplotlib colormap.

    """
    c = matplotlib.colors.ColorConverter().to_rgb
    colorlist=[c("#ffffcc"), c("#ffeda0"), c("#fed976"), c("#ffb24b"), c("#fe8d3b"), c("#fd4e2a"), c("#e3181a")]
    color_code=colorlist
    classif= [2, 4, 6, 8, 10, 12,14]
    c_cmap = LinearSegmentedColormap.from_list("my_colormap",color_code, N=len(classif), gamma=1.0)
    return c_cmap


shapefile_path = r'C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/'

global_bg_shapefile = f'{shapefile_path}ea_global_background.shp'
water_body_shapefile = f'{shapefile_path}Africa_Water_Bodies.shp'

norm = colors.LogNorm(vmin=db['count1'].min(), vmax=db['count1'].max())

c_cmap = return_colormap()

year = '1990-2022'
da_plt = plt
plotsize = {'width': 8.0, 'height': 9.5}
mainmappost = {'x': 0.05, 'y': -0.05, 'width': 0.85, 'height': 1.1}

da_plt.figure(figsize=(plotsize['width'], plotsize['height']))
mainmap = da_plt.axes((mainmappost['x'], mainmappost['y'], mainmappost['width'], mainmappost['height']),
                      projection=ccrs.PlateCarree(), zorder=10)

x_min = 21.838949
x_max = 51.415695
y_min = -11.745695
y_max = 23.145147

mainmap.set_extent([x_min, x_max, y_min, y_max])

# Classify data
classif = [2, 4, 6, 8, 10, 12, 14]
scheme = mc.UserDefined(db['count2'], classif)

# Plot choropleth map
gplt.choropleth(db, hue='count2', projection=gcrs.PlateCarree(),
                edgecolor='none', linewidth=.05,
                cmap=c_cmap,
                legend=True, scheme=scheme, ax=mainmap)

# Add features
mainmap.add_feature(cfeature.OCEAN, facecolor=(0.5, 0.5, 0.5))

# Add geometries for background and water bodies
mainmap.add_geometries(Reader(global_bg_shapefile).geometries(), ccrs.PlateCarree(), facecolor='None')
mainmap.add_geometries(Reader(water_body_shapefile).geometries(), ccrs.PlateCarree(), facecolor='grey')

# Add text annotations
mainmap.text(0.62, 0.13, str(year), fontsize=24, fontweight='bold', ha='left', va='center', color='black', transform=mainmap.transAxes)
mainmap.text(0.62, 0.18, 'Drought Events', fontsize=20, fontweight='bold', ha='left', va='center', color='black', transform=mainmap.transAxes)

# Save output map image
output_png_file = f'output/fl/{str(year)}_fl.png'
# da_plt.savefig(output_png_file, transparent=False, bbox_inches='tight')
# da_plt.close()

# Display the plot
da_plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:524, in GeoAxes.draw(self, renderer, **kwargs)
#     519         self.imshow(img, extent=extent, origin=origin,
#     520                     transform=factory.crs, *factory_args[1:],
#     521                     **factory_kwargs)
#     522 self._done_img_factory = True
# --> 524 return super().draw(renderer=renderer, **kwargs)
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\axes\_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\cartopy\mpl\feature_artist.py:208, in FeatureArtist.draw(self, renderer)
#     195 for geom in geoms:
#     196     # As Shapely geometries cannot be relied upon to be
#     197     # hashable, we have to use a WeakValueDictionary to manage
#    (...)
#     205     # cache of transformed geometries. So when the geom-key is
#     206     # garbage collected so are the transformed geometries.
#     207     geom_key = _GeomKey(geom)
# --> 208     FeatureArtist._geom_key_to_geometry_cache.setdefault(
#     209         geom_key, geom)
#     210     mapping = FeatureArtist._geom_key_to_path_cache.setdefault(
#     211         geom_key, {})
#     212     geom_path = mapping.get(key)
#
# File C:\Python313\Lib\weakref.py:284, in WeakValueDictionary.setdefault(self, key, default)
#     282     if self._pending_removals:
#     283         self._commit_removals()
# --> 284     self.data[key] = KeyedRef(default, self._remove, key)
#     285     return default
#     286 else:
#
# File C:\Python313\Lib\weakref.py:348, in KeyedRef.__new__(type, ob, callback, key)
#     347 def __new__(type, ob, callback, key):
# --> 348     self = ref.__new__(type, ob, callback)
#     349     self.key = key
#     350     return self
#
# TypeError: cannot create weak reference to 'NoneType' object

# %% [markdown]
# ## Floods

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import pandas as pd
from ast import literal_eval

filepath='C:/Users/HP 820/loan_prediction/ea-ibf-climada/impact_catalog/'

filename=f'{filepath}em_dat_ea_flood_adm2_v0.xlsx'

dfb_dr=pd.read_excel(filename, engine='openpyxl')
#dfb_dr['year']= dfb_dr['Dis No'].str[:4]
#dfb_dr

dfb_dr['adm2_list'] = dfb_dr.geob_adm2_list.apply(lambda x: literal_eval(str(x)))
#dfb_dr['disno_list'] = dfb_dr['Dis No'].apply(lambda x: literal_eval(str(x)))

dfb_dr1=dfb_dr[['Dis No','adm2_list']]

dfb_dr2=dfb_dr1.explode('adm2_list')
dfb_dr2['year']=dfb_dr2['Dis No'].str.split('-').str[0]
#dfb_dr3=dfb_dr2.groupby('adm2_list').agg({'Dis No':lambda x: list(x)})

df = dfb_dr2.groupby(['adm2_list']).agg([ 'count'])

df1=df.reset_index()
#df1.columns=['adm2_list','count1','count2']
df1.columns=['shapeID','count1','count2']
df1['count1'].max()
# Out:
# np.int64(17)

# %%
import cartopy.crs as ccrs
import geopandas as gp
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader

shapefile_path = r'C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/'

# Adjusted shapefile path
adm2 = gp.read_file(f'{shapefile_path}ea_adm2_geoboundaries.shp')

db = pd.merge(adm2, df1, on='shapeID', how='right')

# Information about the merged DataFrame
db.info()

# Filter rows where geometry is not null
db1 = db[db['geometry'].notnull()]

# Information about the filtered DataFrame
db1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shapeName   609 non-null    object
#  1   shapeISO    609 non-null    object
#  2   shapeID     648 non-null    object
#  3   shapeGroup  609 non-null    object
#  4   shapeType   609 non-null    object
#  5   geometry    609 non-null    geometry
#  6   count1      648 non-null    int64
#  7   count2      648 non-null    int64
# dtypes: geometry(1), int64(2), object(5)
# memory usage: 40.6+ KB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 609 entries, 1 to 645
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shapeName   609 non-null    object
#  1   shapeISO    609 non-null    object
#  2   shapeID     609 non-null    object
#  3   shapeGroup  609 non-null    object
#  4   shapeType   609 non-null    object
#  5   geometry    609 non-null    geometry
#  6   count1      609 non-null    int64
#  7   count2      609 non-null    int64
# dtypes: geometry(1), int64(2), object(5)
# memory usage: 42.8+ KB

# %%
from matplotlib import colors
from matplotlib import pyplot as plt
import geoplot as gplt
import matplotlib
from matplotlib.colors import LinearSegmentedColormap
import geoplot.crs as gcrs
import numpy as np
import mapclassify as mc
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader


def return_colormap():
    """
    Create colormap of matplotlib based on number of class and given colorcode

    Parameters
    ----------
    params : class object
        Input/Output parameter definitions.
        
    Returns
    -------
    c_cmap : Object
        matplotlib colormap.

    """
    c = matplotlib.colors.ColorConverter().to_rgb
    colorlist=[c("#ffffcc"), c("#ffeda0"), c("#fed976"), c("#ffb24b"), c("#fe8d3b"), c("#fd4e2a"), c("#e3181a")]
    color_code=colorlist
    classif= [2, 6, 10, 14, 18, 20, 24]
    c_cmap = LinearSegmentedColormap.from_list("my_colormap", color_code, N=len(classif), gamma=1.0)
    return c_cmap


# Norm for log scaling
norm = colors.LogNorm(vmin=db['count1'].min(), vmax=db['count1'].max())

# Get colormap
c_cmap = return_colormap()

# Define the year for the plot
year = '1990-2022'

# Set up plot size and map projection
plotsize = {'width': 8.0, 'height': 9.5}
mainmappost = {'x': 0.05, 'y': -0.05, 'width': 0.85, 'height': 1.1}
da_plt = plt
da_plt.figure(figsize=(plotsize['width'], plotsize['height']))
mainmap = da_plt.axes((mainmappost['x'], mainmappost['y'], mainmappost['width'], mainmappost['height']), projection=ccrs.PlateCarree(), zorder=10)

# Set map extent
x_min = 21.838949
x_max = 51.415695
y_min = -11.745695
y_max = 23.145147
mainmap.set_extent([x_min, x_max, y_min, y_max])

# Classify the data
classif = [2, 6, 10, 14, 18, 20, 24]
scheme = mc.UserDefined(db['count2'], classif)

# Create choropleth map
gplt.choropleth(db, hue='count2', projection=gcrs.PlateCarree(),
                edgecolor='none', linewidth=.05,
                cmap=c_cmap,
                legend=True, scheme=scheme, ax=mainmap)

# Add map features
mainmap.add_feature(cfeature.OCEAN, facecolor=(0.5, 0.5, 0.5))

# Define shortened shapefile paths
shapefile_path = 'C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/'

# Add geometries for global background and water bodies
fname = f'{shapefile_path}ea_global_background.shp'
mainmap.add_geometries(Reader(fname).geometries(), ccrs.PlateCarree(), facecolor='None')

water_body = f'{shapefile_path}Africa_Water_Bodies.shp'
mainmap.add_geometries(Reader(water_body).geometries(), ccrs.PlateCarree(), facecolor='grey')

# Add text annotations for year and event type
mainmap.text(0.62, 0.13, str(year), fontsize=24, fontweight='bold', ha='left', va='center', color='black', transform=mainmap.transAxes)
mainmap.text(0.62, 0.18, 'Flood Events', fontsize=24, fontweight='bold', ha='left', va='center', color='black', transform=mainmap.transAxes)

# Commented-out lines for saving the plot and closing it
# output_png_file=f'output/fl/{str(year)}_fl.png'
# da_plt.savefig(output_png_file, transparent=False, bbox_inches='tight')
# da_plt.close()

# Show the plot
da_plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 21
#      19 # Verify if db DataFrame has necessary columns
#      20 if 'count1' not in db.columns or 'count2' not in db.columns:
# ---> 21     raise ValueError("The db DataFrame must contain 'count1' and 'count2' columns.")
#      23 # Create colormap and classify data
#      24 c_cmap = return_colormap()
#
# ValueError: The db DataFrame must contain 'count1' and 'count2' columns.

# %% [markdown]
# ## there is missing geeomrty for flood

# %%
import pandas as pd
from datetime import datetime
import numpy as np

base_path= 'C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/ea-impact-events/'
em_data_filepath='emdat_public_2022_08_11_query_uid-IKGfZc.xlsx'

dfb = pd.read_excel(em_data_filepath, engine='openpyxl',skiprows=6,sheet_name = 'emdat data')

dfb_fl=dfb[dfb['Disaster Type']=='Flood']

ea_cntr=['Djibouti', 'Eritrea','Ethiopia','Kenya','Rwanda', 'Somalia','South Sudan','Sudan (the)','Tanzania, United Republic of']

#dfb1_ea=dfb1[dfb1['Country'].str.contains(ea_cntr)]
dfb_fl_ea=dfb_fl[dfb_fl['Country'].isin(ea_cntr)]


#dfb_dr_ea.info()

dfb_fl_ea_time=dfb_fl_ea[['Dis No','Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month','End Day']]

dfb_fl_ea_time.to_csv('em_dat_flood_dates_v0.csv')

db_time=pd.read_csv('C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/dataframes/em_dat_flood_dates_v1.csv')


db_time['Start Year']=db_time["Start Year"].astype(str)
#dfb_dr_ea_time['Start Month']=dfb_dr_ea_time["Start Month"].astype(str)
db_time['Start Month']=db_time["Start Month"].apply(lambda x: str(int(x)).zfill(2))
db_time['End Year']=db_time["End Year"].astype(str)
#dfb_dr_ea_time['End Month']=dfb_dr_ea_time["End Month"].astype(str)
db_time['End Month']=db_time["End Month"].apply(lambda x: str(int(x)).zfill(2))


def create_daterange_list(row):
    start_date_str=row['Start Year']+'-'+row['Start Month']+'-'+str(int(row['Start Day']))
    end_date_str=row['End Year']+'-'+row['End Month']+'-'+str(int(row['End Day']))
    date_str_list=pd.date_range(start_date_str,end_date_str, freq='D').strftime("%Y-%m-%d").tolist()
    return date_str_list


date_str_list_cont=[]
for idx,row in db_time.iterrows():
    #dfb_dr_ea_time.at[idx,'date_str_list'] = create_daterange_list(row)
    #print(idx)
    #print(row)
    date_str_list=create_daterange_list(row)
    date_str_list_cont.append(date_str_list)
    
    
db_time['date_str_list']=date_str_list_cont
db_time1=db_time[['Dis No','date_str_list']]
# #dfb_dr_ea_time

df_fl=db_time1.explode('date_str_list')

df_t=df_fl.groupby('date_str_list').agg({'Dis No':lambda x: list(x)})

# #df_dr1=df_dr.drop_duplicates('date_str_list')
# dfb_fl_ea_time['date_str_list']=date_str_list_cont
# df_fl=dfb_dr_ea_time.explode('date_str_list')
# #df_dr1=df_dr.drop_duplicates('date_str_list')

# df_t=df_fl.groupby('date_str_list').agg({'Dis No':lambda x: list(x)})

dft1=df_t.reset_index()
dft1['date']=dft1['date_str_list'].apply(pd.to_datetime)
dft1['year']=dft1['date'].dt.year
df=dft1.groupby('year').agg({'Dis No': 'sum'})
df['disno1'] = df['Dis No'].apply(lambda x: list(set(x)))
df_year=df.reset_index()
df_year1=df_year[['year','disno1']]
# Out:
# c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
import pandas as pd

filepath='C:/Users/HP 820/loan_prediction/ea-ibf-climada/impact_catalog/'

filename=f'{filepath}em_dat_ea_flood_adm2_v0.xlsx'

dfb_fl=pd.read_excel(filename, engine='openpyxl')
#dfb_dr['year']= dfb_dr['Dis No'].str[:4]
#dfb_dr

dfb_fl['adm2_list'] = dfb_fl.geob_adm2_list.apply(lambda x: literal_eval(str(x)))
#dfb_dr['disno_list'] = dfb_dr['Dis No'].apply(lambda x: literal_eval(str(x)))

dfb_fl1=dfb_fl[['Dis No','adm2_list']]


# df_year3=df_year2[df_year2['year']==1990]
# dis_no_list=df_year3['disno1'].tolist()
# dis_no_flat_list = [item for sublist in dis_no_list for item in sublist]
# df_b2=dfb_dr1[dfb_dr1['Dis No'].isin(dis_no_flat_list)]
# adm2_list0=df_b2['adm2_list'].tolist()
# flat_list = [item for sublist in adm2_list0 for item in sublist]


def get_adm2_list(year,df_year,df_b):
    df_year1=df_year[df_year['year']==year]
    dis_no_list=df_year1['disno1'].tolist()
    dis_no_flat_list = [item for sublist in dis_no_list for item in sublist]
    df_b2=df_b[df_b['Dis No'].isin(dis_no_flat_list)]
    adm2_list0=df_b2['adm2_list'].tolist()
    flat_list = [item for sublist in adm2_list0 for item in sublist]
    return flat_list

def get_geodf(list_adm2_year,adm2):
    adm2_1=adm2[adm2['shapeID'].isin(list_adm2_year)]
    adm2_1a=adm2_1[['shapeID']]
    adm2_1a['event']=1.0
    db=pd.merge(adm2,adm2_1a,on='shapeID',how='right')
    db1=db[['geometry','event','shapeID']]
    return db1

adm2=gp.read_file('C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/ea_adm2_geoboundaries.shp')

year_list=np.arange(1990,2023,1)

db_geodf_cont=[]
for yearl in year_list:
    list_adm2_year=get_adm2_list(yearl,df_year1,dfb_fl1)
    db_geodf=get_geodf(list_adm2_year,adm2)
    db_geodf['year']=yearl
    db_geodf_cont.append(db_geodf)
# Out:
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_15720\1618184305.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adm2_1a['event']=1.0

# %%
shpdb = pd.concat(db_geodf_cont)
#shpdb1=shpdb[shpb['shapeID']=='']
nas = shpdb[shpdb['shapeID'].isna()]['shapeID'].tolist() 
#shpdb[shpdb['shapeID'].isin(nas)]

filtered_shpdb = shpdb[shpdb['shapeID'].isin(nas)]

# %%
import pandas as pd

db=pd.read_csv('em_dat_flood_dates_v0.csv')
db
# Out:
#      Unnamed: 0         Dis No  Start Year  Start Month  Start Day  End Year  \
# 0            33  1993-0503-DJI        1993          1.0       26.0      1993
# 1            41  1990-0582-ETH        1990          8.0       27.0      1990
# 2            44  1990-0352-KEN        1990          4.0       14.0      1990
# 3           125  1993-0519-ETH        1993          8.0        NaN      1993
# 4           126  1993-0520-ETH        1993          8.0        NaN      1993
# ..          ...            ...         ...          ...        ...       ...
# 264        4573  2022-0055-RWA        2022          1.0        1.0      2022
# 265        4577  2022-0232-RWA        2022          4.0       23.0      2022
# 266        4580  2022-0332-SOM        2022          5.0       12.0      2022
# 267        4622  2022-0445-SDN        2022          7.0       10.0      2022
# 268        4631  2022-0258-TZA        2022          4.0        NaN      2022
#
#      End Month  End Day
# 0          1.0     26.0
# 1          9.0      1.0
# 2          4.0     15.0
# 3          8.0      NaN
# 4          8.0      NaN
# ..         ...      ...
# 264        1.0     27.0
# 265        4.0     24.0
# 266        5.0     30.0
# 267        8.0      5.0
# 268        5.0      5.0
#
# [269 rows x 8 columns]
