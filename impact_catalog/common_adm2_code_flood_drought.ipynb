# %%
import pandas as pd
import numpy as np

impact_data_filepath = r'C:\Users\HP 820\loan_prediction\ea-ibf-climada\impact_catalog\impactevents-202408.xlsx'

dfb = pd.read_excel(impact_data_filepath, engine='openpyxl', sheet_name=0)

disaster_types = ['Flood', 'Drought']
dfb_f1 = dfb[dfb['disaster type'].isin(disaster_types)]

ea_cntr = ['Djibouti', 'Eritrea', 'Ethiopia', 'Kenya', 'Rwanda', 'Somalia', 'South Sudan', 'Sudan (the)', 'Tanzania, United Republic of']

dfb_fl_ea = dfb_f1[dfb_f1['country'].isin(ea_cntr)]

dfb_fl_ea_map = dfb_fl_ea[['sno', 'date of event', 'country', 'reported region/places', 'report type']]

dfb_fl_ea_map['loc_str1'] = dfb_fl_ea_map['reported region/places'].str.replace(' and ', ',', regex=False)
dfb_fl_ea_map['loc_str2'] = dfb_fl_ea_map['loc_str1'].str.replace(' & ', ',', regex=False)
dfb_fl_ea_map['loc_str3'] = dfb_fl_ea_map['loc_str2'].str.replace('&', ',', regex=False)
dfb_fl_ea_map['loc_str4'] = dfb_fl_ea_map['loc_str3'].str.replace(';', ',', regex=False)
dfb_fl_ea_map['loc_list'] = dfb_fl_ea_map['loc_str4'].str.split(',')

df_fl = dfb_fl_ea_map.explode('loc_list')

df_fl['row_idx'] = ['fl_' + str(idx) for idx in range(len(df_fl))]

df_fl['loc_list_a'] = df_fl['loc_list'].str.strip()

df3_fl = df_fl[['sno', 'date of event', 'country', 'loc_list', 'loc_list_a', 'reported region/places', 'row_idx', 'report type']]

df3_fl = df3_fl.reset_index(drop=True)

output_filepath = 'ea_flood_drought_location_processed.csv'
df3_fl.to_csv(output_filepath, index=False)

print(f"Processed data saved to: {output_filepath}")


#df3_fl.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_ibf_data_resources/impact/em-dat/ea_flood_location.csv',index=False)
#d
#df3_fl.info()


# db=pd.read_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_ibf_data_resources/impact/em-dat/ea_flood_missing_location.csv')

# db['code']=db['Dis No'].str.split('-').str[-1]

# db['loc_list'] = db['Location'].str.split(',')
# db1=db.explode('loc_list')
# #db2=db1.drop_duplicates('loc_list')

# db2=db1.drop_duplicates('code')
# code_list=db2['code'].tolist()
# db1.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_ibf_data_resources/impact/em-dat/ea_flood_missing_location_v1.csv')
# Out:
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\788320281.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea_map['loc_str1'] = dfb_fl_ea_map['reported region/places'].str.replace(' and ', ',', regex=False)
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\788320281.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea_map['loc_str2'] = dfb_fl_ea_map['loc_str1'].str.replace(' & ', ',', regex=False)
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\788320281.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea_map['loc_str3'] = dfb_fl_ea_map['loc_str2'].str.replace('&', ',', regex=False)
# Processed data saved to: ea_flood_drought_location_processed.csv

# %%
dfb_fl_ea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 62 to 259
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sno                     17 non-null     int64
#  1   date of event           17 non-null     object
#  2   country                 17 non-null     object
#  3   report type             17 non-null     object
#  4   corrected_report_type   17 non-null     int64
#  5   disaster type           17 non-null     object
#  6   reported region/places  17 non-null     object
#  7   reported loss if any    17 non-null     object
#  8   report link             17 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 1.3+ KB

# %%
db = pd.read_csv(r'C:\Users\HP 820\loan_prediction\ea-ibf-climada\impact_catalog\ea_flood_drought_location_processed.csv')

# db['code'] = db['sno'].str.split('-').str[-1]

db['loc_list'] = db['reported region/places'].str.split(',')
db1 = db.explode('loc_list')
db2=db1.drop_duplicates('loc_list')

db2 = db1.drop_duplicates('reported region/places')
code_list = db2['reported region/places'].tolist()

db1.to_csv('ea_flood_drought_missing_location_v1.csv')

# %%
db2
# Out:
#     sno  date of event      country                                  loc_list  \
# 0    63       20241204      Somalia       Lower Shabelle (Juba camp in Weydow
# 2   106       20241117      Somalia                               East Africa
# 3   145       20241026  South Sudan                           Various regions
# 5   174       20241018  South Sudan                               42 counties
# 9   175       20241017  South Sudan                               38 counties
# 15  176       20241019  South Sudan                   Northern Bahr el Ghazal
# 18  178       20241018  South Sudan                               South Sudan
# 19  217       20241001      Somalia                                  National
# 21  231       20241002  South Sudan                               Mangar Ajak
# 23  232       20241001  South Sudan                Akon International Airport
# 26  233       20241001  South Sudan  South Sudan (White Nile and Tributaries)
# 28  234       20241003  South Sudan                       Nationwide (Jonglei
# 34  236       20240919     Ethiopia                               Addis Ababa
# 36  257       20240812     Ethiopia             Gambella Region (4 districts)
# 37  258       20240908        Kenya                                   Kajiado
# 39  259       20240907        Kenya                   Kilifi (Mariakani Ward)
# 40  262         202409  South Sudan                               Lakes State
#
#                              loc_list_a  \
# 0   Lower Shabelle (Juba camp in Weydow
# 2                           East Africa
# 3                       Various regions
# 5                           42 counties
# 9                           38 counties
# 15              Northern Bahr el Ghazal
# 18                          South Sudan
# 19                             National
# 21                          Mangar Ajak
# 23           Akon International Airport
# 26              South Sudan (White Nile
# 28                  Nationwide (Jonglei
# 34                          Addis Ababa
# 36        Gambella Region (4 districts)
# 37                              Kajiado
# 39              Kilifi (Mariakani Ward)
# 40                          Lakes State
#
#                                reported region/places row_idx  \
# 0   Lower Shabelle (Juba camp in Weydow, Garasbale...    fl_0
# 2                                         East Africa    fl_2
# 3       Various regions, communities on higher ground    fl_3
# 5   42 counties, Abyei, Northern Bahr el Ghazal, U...    fl_5
# 9   38 counties, Jonglei, Northern Bahr el Ghazal,...    fl_9
# 15  Northern Bahr el Ghazal, Unity, 42 counties ac...   fl_15
# 18                                        South Sudan   fl_18
# 19                                  National, Somalia   fl_19
# 21                   Mangar Ajak, Gogrial West County   fl_21
# 23  Akon International Airport, Gogrial West Count...   fl_23
# 26           South Sudan (White Nile and Tributaries)   fl_26
# 28  Nationwide (Jonglei, Upper Nile, Unity, Warrap...   fl_28
# 34               Addis Ababa, rural areas of Ethiopia   fl_34
# 36                      Gambella Region (4 districts)   fl_36
# 37                                  Kajiado, Laikipia   fl_37
# 39                            Kilifi (Mariakani Ward)   fl_39
# 40              Lakes State, Unity State, Sudd region   fl_40
#
#                                           report type
# 0                               Drought Impact Report
# 2                                   1 - ongoing event
# 3                                           UN Report
# 5                         South Sudan Floods Snapshot
# 9    South Sudan Floods - Emergency Appeal (MDRSS014)
# 15  Over 1 million people affected by flooding in ...
# 18                             Satellite Image Report
# 19                                       Drought Risk
# 21                                 Flood Displacement
# 23                                             Floods
# 26                                   Flood Assistance
# 28                      National Disaster Declaration
# 34                              Flood Warning Testing
# 36                       Flooding in Western Ethiopia
# 37  Drought affecting Maasai and other cattle herders
# 39                Drought affecting farmers in Kilifi
# 40        Floods causing mass population displacement

# %%
import geopandas as gp

gaul_adm2=gp.read_file('C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/ea_adm2_gaul.shp')

# %%
gaul_adm2
# Out:
#      gml_id    fid  ADM2_CODE        ADM2_NAME  ADM1_CODE    ADM1_NAME  \
# 0      None     20      32854    Al Mahabishah       3418       Hajjah
# 1      None   8004      12847           Ouadda        856  Haute-Kotto
# 2      None   8005      12848          Yalinga        856  Haute-Kotto
# 3      None     57      32877      Al Makhadir       3419          Ibb
# 4      None     59      32853        Al Miftah       3418       Hajjah
# ...     ...    ...        ...              ...        ...          ...
# 1449   None  33989      32849              Abs       3418       Hajjah
# 1450   None  34013      32850   Aflah Al Yaman       3418       Hajjah
# 1451   None  34019      32851  Aflah Ash Shawm       3418       Hajjah
# 1452   None  34039      32852       Al Jamimah       3418       Hajjah
# 1453   None  34141      32855     Al Maghrabah       3418       Hajjah
#
#             STATUS DISP_AREA  ADM0_CODE                 ADM0_NAME  \
# 0     Member State        NO        269                     Yemen
# 1     Member State        NO         49  Central African Republic
# 2     Member State        NO         49  Central African Republic
# 3     Member State        NO        269                     Yemen
# 4     Member State        NO        269                     Yemen
# ...            ...       ...        ...                       ...
# 1449  Member State        NO        269                     Yemen
# 1450  Member State        NO        269                     Yemen
# 1451  Member State        NO        269                     Yemen
# 1452  Member State        NO        269                     Yemen
# 1453  Member State        NO        269                     Yemen
#
#                                                geometry
# 0     MULTIPOLYGON (((43.45552 15.97692, 43.45554 15...
# 1     POLYGON ((23.2875 8.76171, 23.28112 8.75005, 2...
# 2     POLYGON ((24.2722 8.27699, 24.2739 8.27343, 24...
# 3     POLYGON ((44.26976 14.20502, 44.26981 14.20496...
# 4     POLYGON ((43.54572 15.9774, 43.55705 15.97485,...
# ...                                                 ...
# 1449  POLYGON ((43.22042 16.18735, 43.22144 16.18402...
# 1450  POLYGON ((43.44169 15.98401, 43.44304 15.98109...
# 1451  POLYGON ((43.43349 16.07773, 43.43851 16.07462...
# 1452  POLYGON ((43.5759 16.09728, 43.57911 16.09281,...
# 1453  POLYGON ((43.70865 15.93842, 43.70853 15.93832...
#
# [1454 rows x 11 columns]

# %%
import geopandas as gp
import pandas as pd

adm0=gp.read_file(r'C:\Users\HP 820\loan_prediction\ea-ibf-climada\data_sources\202501-impact-events\202501-impact-events\shpfiles\ea_adm0_geoboundaries.shp')
adm1=gp.read_file(r'C:\Users\HP 820\loan_prediction\ea-ibf-climada\data_sources\202501-impact-events\202501-impact-events\shpfiles\ea_adm1_geoboundaries.shp')
adm2=gp.read_file(r'C:\Users\HP 820\loan_prediction\ea-ibf-climada\data_sources\202501-impact-events\202501-impact-events\shpfiles\ea_adm2_geoboundaries.shp')

db=pd.concat([adm0,adm1,adm2])

db1=db.drop_duplicates('shapeID')
db1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1155 entries, 0 to 971
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shapeName   1155 non-null   object
#  1   shapeISO    1151 non-null   object
#  2   shapeID     1155 non-null   object
#  3   shapeGroup  1155 non-null   object
#  4   shapeType   1155 non-null   object
#  5   geometry    1155 non-null   geometry
# dtypes: geometry(1), object(5)
# memory usage: 63.2+ KB

# %%
db1=db[db['shapeGroup']=='SDN']
#db1.shapeName.tolist()
db2=db1.sort_values('shapeName')
db3=db2[['shapeName','shapeType','shapeID']]
pd.set_option('display.max_columns', 4)
pd.set_option('display.max_rows', 200)
print(db3)
# Out:
#                 shapeName shapeType              shapeID
# 522             Abu Hamed      ADM2    SDN-ADM2-3_0_0-B8
# 544            Abu Houjar      ADM2   SDN-ADM2-3_0_0-B30
# 654             Abu Jabra      ADM2  SDN-ADM2-3_0_0-B140
# 576           Abu Jubaiha      ADM2   SDN-ADM2-3_0_0-B62
# 624           Abu Karinka      ADM2  SDN-ADM2-3_0_0-B110
# 650             Abu Zabad      ADM2  SDN-ADM2-3_0_0-B136
# 640        Abyei - Muglad      ADM2  SDN-ADM2-3_0_0-B126
# 584        Abyei PCA Area      ADM2   SDN-ADM2-3_0_0-B70
# 655                 Adila      ADM2  SDN-ADM2-3_0_0-B141
# 567                  Agig      ADM2   SDN-ADM2-3_0_0-B53
# 635               Ailliet      ADM2  SDN-ADM2-3_0_0-B121
# 583              Al Buram      ADM2   SDN-ADM2-3_0_0-B69
# 531               Al Daba      ADM2   SDN-ADM2-3_0_0-B17
# 680             Al Mafaza      ADM2  SDN-ADM2-3_0_0-B166
# 644                Al Qoz      ADM2  SDN-ADM2-3_0_0-B130
# 643              Al Sunut      ADM2  SDN-ADM2-3_0_0-B129
# 588            Al Tadamon      ADM2   SDN-ADM2-3_0_0-B74
# 528              Alborgag      ADM2   SDN-ADM2-3_0_0-B14
# 530               Algolid      ADM2   SDN-ADM2-3_0_0-B16
# 620               Alwehda      ADM2  SDN-ADM2-3_0_0-B106
# 675                 Aroma      ADM2  SDN-ADM2-3_0_0-B161
# 629              Assalaya      ADM2  SDN-ADM2-3_0_0-B115
# 526                Atbara      ADM2   SDN-ADM2-3_0_0-B12
# 676          Atbara River      ADM2  SDN-ADM2-3_0_0-B162
# 589                  Azum      ADM2   SDN-ADM2-3_0_0-B75
# 641              Babanusa      ADM2  SDN-ADM2-3_0_0-B127
# 627          Bahr El Arab      ADM2  SDN-ADM2-3_0_0-B113
# 534                  Bara      ADM2   SDN-ADM2-3_0_0-B20
# 527                Barbar      ADM2   SDN-ADM2-3_0_0-B13
# 570               Basonda      ADM2   SDN-ADM2-3_0_0-B56
# 587                   Bau      ADM2   SDN-ADM2-3_0_0-B73
# 590                 Beida      ADM2   SDN-ADM2-3_0_0-B76
# 628                Bielel      ADM2  SDN-ADM2-3_0_0-B114
# 591               Bindisi      ADM2   SDN-ADM2-3_0_0-B77
# 135       Blue Nile State      ADM1   SDN-ADM1-3_0_0-B16
# 659                 Buram      ADM2  SDN-ADM2-3_0_0-B145
# 129        Central Darfur      ADM1   SDN-ADM1-3_0_0-B10
# 663                 Dalgo      ADM2  SDN-ADM2-3_0_0-B149
# 592          Dar El Salam      ADM2   SDN-ADM2-3_0_0-B78
# 579               Dilling      ADM2   SDN-ADM2-3_0_0-B65
# 638                 Dimsu      ADM2  SDN-ADM2-3_0_0-B124
# 529               Dongola      ADM2   SDN-ADM2-3_0_0-B15
# 674                Dordeb      ADM2  SDN-ADM2-3_0_0-B160
# 128     East Darfur State      ADM1    SDN-ADM1-3_0_0-B9
# 574    Eastern El Galabat      ADM2   SDN-ADM2-3_0_0-B60
# 540     Eastern El Gezira      ADM2   SDN-ADM2-3_0_0-B26
# 548        Eastern Sennar      ADM2   SDN-ADM2-3_0_0-B34
# 616              Ed Daein      ADM2  SDN-ADM2-3_0_0-B102
# 525              Ed Damer      ADM2   SDN-ADM2-3_0_0-B11
# 617          Ed El Fursan      ADM2  SDN-ADM2-3_0_0-B103
# 646           El Abassiya      ADM2  SDN-ADM2-3_0_0-B132
# 678             El Butana      ADM2  SDN-ADM2-3_0_0-B164
# 546               El Dali      ADM2   SDN-ADM2-3_0_0-B32
# 671           El Damazine      ADM2  SDN-ADM2-3_0_0-B157
# 652             El Dindir      ADM2  SDN-ADM2-3_0_0-B138
# 550             El Douiem      ADM2   SDN-ADM2-3_0_0-B36
# 568            El Fashaga      ADM2   SDN-ADM2-3_0_0-B54
# 593             El Fasher      ADM2   SDN-ADM2-3_0_0-B79
# 679                El Faw      ADM2  SDN-ADM2-3_0_0-B165
# 657            El Ferdous      ADM2  SDN-ADM2-3_0_0-B143
# 594            El Geneina      ADM2   SDN-ADM2-3_0_0-B80
# 555            El Gutaina      ADM2   SDN-ADM2-3_0_0-B41
# 541          El Hasaheesa      ADM2   SDN-ADM2-3_0_0-B27
# 556           El Jabalian      ADM2   SDN-ADM2-3_0_0-B42
# 542            El Kamleen      ADM2   SDN-ADM2-3_0_0-B28
# 595               El Kuma      ADM2   SDN-ADM2-3_0_0-B81
# 665             El Kurmuk      ADM2  SDN-ADM2-3_0_0-B151
# 596              El Malha      ADM2   SDN-ADM2-3_0_0-B82
# 543           El Manageel      ADM2   SDN-ADM2-3_0_0-B29
# 523           El Matammah      ADM2    SDN-ADM2-3_0_0-B9
# 651             El Nehoud      ADM2  SDN-ADM2-3_0_0-B137
# 565              El Qaneb      ADM2   SDN-ADM2-3_0_0-B51
# 569            El Quresha      ADM2   SDN-ADM2-3_0_0-B55
# 656             El Radoom      ADM2  SDN-ADM2-3_0_0-B142
# 681              El Rahad      ADM2  SDN-ADM2-3_0_0-B167
# 653           El Roseires      ADM2  SDN-ADM2-3_0_0-B139
# 642              El Salam      ADM2  SDN-ADM2-3_0_0-B128
# 632              El Salam      ADM2  SDN-ADM2-3_0_0-B118
# 647              El Salam      ADM2  SDN-ADM2-3_0_0-B133
# 597             El Sireaf      ADM2   SDN-ADM2-3_0_0-B83
# 547              El Souki      ADM2   SDN-ADM2-3_0_0-B33
# 598           El Taweisha      ADM2   SDN-ADM2-3_0_0-B84
# 637               El Tina      ADM2  SDN-ADM2-3_0_0-B123
# 599          Foro Baranga      ADM2   SDN-ADM2-3_0_0-B85
# 572               Gedaref      ADM2   SDN-ADM2-3_0_0-B58
# 133         Gedarif State      ADM1   SDN-ADM1-3_0_0-B14
# 666               Geissan      ADM2  SDN-ADM2-3_0_0-B152
# 622               Gereida      ADM2  SDN-ADM2-3_0_0-B108
# 132          Gezira State      ADM1   SDN-ADM1-3_0_0-B13
# 639              Ghubaysh      ADM2  SDN-ADM2-3_0_0-B125
# 537    Greater Wad Madani      ADM2   SDN-ADM2-3_0_0-B23
# 586                Habila      ADM2   SDN-ADM2-3_0_0-B72
# 600                Habila      ADM2   SDN-ADM2-3_0_0-B86
# 562               Halayeb      ADM2   SDN-ADM2-3_0_0-B48
# 664                 Halfa      ADM2  SDN-ADM2-3_0_0-B150
# 557      Halfa El Jadeeda      ADM2   SDN-ADM2-3_0_0-B43
# 559          Hamashkoreib      ADM2   SDN-ADM2-3_0_0-B45
# 566                  Haya      ADM2   SDN-ADM2-3_0_0-B52
# 580                Heiban      ADM2   SDN-ADM2-3_0_0-B66
# 515           Jabal Aulia      ADM2    SDN-ADM2-3_0_0-B1
# 563      Jabiet Al Maadin      ADM2   SDN-ADM2-3_0_0-B49
# 601            Jebel Moon      ADM2   SDN-ADM2-3_0_0-B87
# 535      Jebrat El Sheikh      ADM2   SDN-ADM2-3_0_0-B21
# 582               Kadugli      ADM2   SDN-ADM2-3_0_0-B68
# 604             Kalimendo      ADM2   SDN-ADM2-3_0_0-B90
# 519                Karari      ADM2    SDN-ADM2-3_0_0-B5
# 618                  Kass      ADM2  SDN-ADM2-3_0_0-B104
# 683               Kassala      ADM2  SDN-ADM2-3_0_0-B169
# 123         Kassala State      ADM1    SDN-ADM1-3_0_0-B4
# 626               Katayla      ADM2  SDN-ADM2-3_0_0-B112
# 602             Kebkabiya      ADM2   SDN-ADM2-3_0_0-B88
# 575                Keilak      ADM2   SDN-ADM2-3_0_0-B61
# 521              Khartoum      ADM2    SDN-ADM2-3_0_0-B7
# 517        Khartoum North      ADM2    SDN-ADM2-3_0_0-B3
# 131        Khartoum State      ADM1   SDN-ADM1-3_0_0-B12
# 677         Khashm Ghirba      ADM2  SDN-ADM2-3_0_0-B163
# 634                Kornoi      ADM2  SDN-ADM2-3_0_0-B120
# 553                 Kosti      ADM2   SDN-ADM2-3_0_0-B39
# 603               Kreinik      ADM2   SDN-ADM2-3_0_0-B89
# 625                 Kubum      ADM2  SDN-ADM2-3_0_0-B111
# 605                Kulbus      ADM2   SDN-ADM2-3_0_0-B91
# 606                 Kutum      ADM2   SDN-ADM2-3_0_0-B92
# 585                Lagawa      ADM2   SDN-ADM2-3_0_0-B71
# 668              Marshang      ADM2  SDN-ADM2-3_0_0-B154
# 607                Mellit      ADM2   SDN-ADM2-3_0_0-B93
# 532                Merawi      ADM2   SDN-ADM2-3_0_0-B18
# 573        Middle Gedaref      ADM2   SDN-ADM2-3_0_0-B59
# 608                Mukjar      ADM2   SDN-ADM2-3_0_0-B94
# 609               Nertiti      ADM2   SDN-ADM2-3_0_0-B95
# 621               Niteaga      ADM2  SDN-ADM2-3_0_0-B107
# 126    North Darfur State      ADM1    SDN-ADM1-3_0_0-B7
# 673           North Delta      ADM2  SDN-ADM2-3_0_0-B159
# 127  North Kordofan State      ADM1    SDN-ADM1-3_0_0-B8
# 136        Northern State      ADM1   SDN-ADM1-3_0_0-B17
# 633                 Nyala      ADM2  SDN-ADM2-3_0_0-B119
# 630           Nyala North      ADM2  SDN-ADM2-3_0_0-B116
# 560            Port Sudan      ADM2   SDN-ADM2-3_0_0-B46
# 571         Qala El Nahal      ADM2   SDN-ADM2-3_0_0-B57
# 552                 Rabak      ADM2   SDN-ADM2-3_0_0-B38
# 667        Rahad El Berdi      ADM2  SDN-ADM2-3_0_0-B153
# 645                Rashad      ADM2  SDN-ADM2-3_0_0-B131
# 130         Red Sea State      ADM1   SDN-ADM1-3_0_0-B11
# 581          Reif Ashargi      ADM2   SDN-ADM2-3_0_0-B67
# 124      River Nile State      ADM1    SDN-ADM1-3_0_0-B5
# 610                Rokoro      ADM2   SDN-ADM2-3_0_0-B96
# 558         Rural Kassala      ADM2   SDN-ADM2-3_0_0-B44
# 611            Saraf Omra      ADM2   SDN-ADM2-3_0_0-B97
# 545                Sennar      ADM2   SDN-ADM2-3_0_0-B31
# 125          Sennar State      ADM1    SDN-ADM1-3_0_0-B6
# 619     Sharg Jabel Marra      ADM2  SDN-ADM2-3_0_0-B105
# 518         Sharq El Nile      ADM2    SDN-ADM2-3_0_0-B4
# 623               Shattai      ADM2  SDN-ADM2-3_0_0-B109
# 669               Sheiria      ADM2  SDN-ADM2-3_0_0-B155
# 524                Shendi      ADM2   SDN-ADM2-3_0_0-B10
# 649               Shiekan      ADM2  SDN-ADM2-3_0_0-B135
# 549                 Singa      ADM2   SDN-ADM2-3_0_0-B35
# 672                Sinkat      ADM2  SDN-ADM2-3_0_0-B158
# 612                 Sirba      ADM2   SDN-ADM2-3_0_0-B98
# 533                Sodari      ADM2   SDN-ADM2-3_0_0-B19
# 120    South Darfur State      ADM1    SDN-ADM1-3_0_0-B1
# 121  South Kordofan State      ADM1    SDN-ADM1-3_0_0-B2
# 538    Southern El Gezira      ADM2   SDN-ADM2-3_0_0-B24
# 564                Suakin      ADM2   SDN-ADM2-3_0_0-B50
# 8                   Sudan      ADM0    SDN-ADM0-3_0_0-B1
# 658                 Sunta      ADM2  SDN-ADM2-3_0_0-B144
# 577                Talodi      ADM2   SDN-ADM2-3_0_0-B63
# 636               Tawilla      ADM2  SDN-ADM2-3_0_0-B122
# 686                Telkok      ADM2  SDN-ADM2-3_0_0-B172
# 554              Tendalti      ADM2   SDN-ADM2-3_0_0-B40
# 561                 Tokar      ADM2   SDN-ADM2-3_0_0-B47
# 670                Tullus      ADM2  SDN-ADM2-3_0_0-B156
# 662               Um Buru      ADM2  SDN-ADM2-3_0_0-B148
# 660              Um Dafug      ADM2  SDN-ADM2-3_0_0-B146
# 520             Um Durman      ADM2    SDN-ADM2-3_0_0-B6
# 539            Um El Qura      ADM2   SDN-ADM2-3_0_0-B25
# 648             Um Rawaba      ADM2  SDN-ADM2-3_0_0-B134
# 516             Umm Badda      ADM2    SDN-ADM2-3_0_0-B2
# 661            Umm Dukhun      ADM2  SDN-ADM2-3_0_0-B147
# 578            Umm Durein      ADM2   SDN-ADM2-3_0_0-B64
# 613           Umm Keddada      ADM2   SDN-ADM2-3_0_0-B99
# 551            Umm Ramtta      ADM2   SDN-ADM2-3_0_0-B37
# 536             Wad Banda      ADM2   SDN-ADM2-3_0_0-B22
# 684          Wad El Helew      ADM2  SDN-ADM2-3_0_0-B170
# 614            Wadi Salih      ADM2  SDN-ADM2-3_0_0-B100
# 122     West Darfur State      ADM1    SDN-ADM1-3_0_0-B3
# 137         West Kurdufan      ADM1   SDN-ADM1-3_0_0-B18
# 682    Western El Galabat      ADM2  SDN-ADM2-3_0_0-B168
# 685       Western Kassala      ADM2  SDN-ADM2-3_0_0-B171
# 134      White Nile State      ADM1   SDN-ADM1-3_0_0-B15
# 631                Yassin      ADM2  SDN-ADM2-3_0_0-B117
# 615              Zalingei      ADM2  SDN-ADM2-3_0_0-B101

# %%
dfb_fl_ea['reported_region_places_count'] = dfb_fl_ea['reported region/places'].str.count(',')
# Out:
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\1349256036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea['reported_region_places_count'] = dfb_fl_ea['reported region/places'].str.count(',')

# %% [markdown]
# ## replacing GAUL Admin1 Code into GEOB admin2 codes

# %%
impact_data_path = './'

gaul_adm1_dict_db = pd.read_csv(f'{impact_data_path}ea_gaul_geob_admin1_codeshare.csv')
gaul_adm1_dict = dict(zip(gaul_adm1_dict_db.gaul_adm1_code, gaul_adm1_dict_db.geob_adm1_shapeID))

dfb_fl_ea['gaul_adm1_list'] = dfb_fl_ea['reported region/places'].str.split(';')

dfb_fl_ea_adm1 = dfb_fl_ea[dfb_fl_ea['gaul_adm1_list'].notna()]

dfb_fl_ea_adm1.loc[:, 'gaul_adm1_list_int'] = dfb_fl_ea_adm1['gaul_adm1_list'].apply(lambda x: [int(i.strip()) for i in x if i.strip().isdigit()])

dfb_fl_ea_adm1.loc[:, 'gaul_adm1_geob'] = dfb_fl_ea_adm1['gaul_adm1_list_int'].apply(lambda x: [gaul_adm1_dict.get(i, None) for i in x])

dfb_fl_ea_adm1_a = dfb_fl_ea_adm1[['sno', 'gaul_adm1_geob']]
dfb_fl_ea_adm1_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 62 to 259
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sno             17 non-null     int64
#  1   gaul_adm1_geob  17 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 408.0+ bytes
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\1514437891.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea['gaul_adm1_list'] = dfb_fl_ea['reported region/places'].str.split(';')

# %% [markdown]
#  ## replace adm1 code with adm2 sub codes

# %%
import geopandas as gp
import numpy as np

geob_adm1_adm2_filepath = 'C:/Users/HP 820/loan_prediction/202501-impact-events/202501-impact-events/shpfiles/ea_adm2_geoboundaries_adm1_code.shp'

geob_db = gp.read_file(geob_adm1_adm2_filepath)

print(geob_db.columns)

geob_db1 = geob_db[['adm1_shape', 'shapeID']]
geob_db2 = geob_db1.groupby('adm1_shape').agg({'shapeID': lambda x: list(x)})
geob_db3 = geob_db2.reset_index()
geob_db3.columns = ['gaul_adm1_geob', 'shapeID']

geob_db3_dict = dict(zip(geob_db3.gaul_adm1_geob, geob_db3.shapeID))

dfb_fl_ea_adm1_a['geob_adm2'] = dfb_fl_ea_adm1_a['gaul_adm1_geob'].apply(lambda x: [geob_db3_dict[i] for i in x if i in geob_db3_dict])

def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list = []
for idx, row in dfb_fl_ea_adm1_a.iterrows():
    aa = flatten(row['geob_adm2'])
    aa_list.append(aa)

dfb_fl_ea_adm1_a['geob_adm2_list'] = aa_list

dfb_fl_part1 = dfb_fl_ea_adm1_a[['sno', 'geob_adm2_list']]
print(dfb_fl_part1)
# Out:
# c:\Users\HP 820\loan_prediction\ea-ibf-climada\venv\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: C:/Users/HP 820/loan_prediction/202501-impact-events/202501-impact-events/shpfiles/ea_adm2_geoboundaries_adm1_code.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# Index(['shapeName', 'shapeISO', 'shapeID', 'shapeGroup', 'shapeType',
#        'adm1_shape', 'geometry'],
#       dtype='object')
#      sno geob_adm2_list
# 62    63             []
# 105  106             []
# 144  145             []
# 173  174             []
# 174  175             []
# 175  176             []
# 177  178             []
# 215  217             []
# 229  231             []
# 230  232             []
# 231  233             []
# 232  234             []
# 234  236             []
# 254  257             []
# 255  258             []
# 256  259             []
# 259  262             []
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\3021882481.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea_adm1_a['geob_adm2'] = dfb_fl_ea_adm1_a['gaul_adm1_geob'].apply(lambda x: [geob_db3_dict[i] for i in x if i in geob_db3_dict])
# C:\Users\HP 820\AppData\Local\Temp\ipykernel_12752\3021882481.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfb_fl_ea_adm1_a['geob_adm2_list'] = aa_list

# %% [markdown]
# ## replacing GAUL Admin2 Code into GEOB admin2 codes

# %%
dfb_fl_ea['gaul_adm2_list']=dfb_fl_ea['reported region/places'].str.split(';')


impactevents_path='./'

gaul_adm2_dict_db=pd.read_excel(f'{impactevents_path}ea_gaul_geob_adm2_codeshare_v1.xlsx', engine='openpyxl')
gaul_adm2_dict = dict(zip(gaul_adm2_dict_db.gaul_adm2_code, gaul_adm2_dict_db.geob_adm2_shapeID))

gaul_adm2_dict[48481]='TZA-ADM1-3_0_0-B2'
gaul_adm2_dict[48451]='TZA-ADM1-3_0_0-B8'

#48481:TZA-ADM1-3_0_0-B2
#48451:TZA-ADM1-3_0_0-B8

dfb_fl_adm2=dfb_fl_ea[dfb_fl_ea['gaul_adm2_list'].notna()]
dfb_fl_adm2['gaul_adm2_list_int']=dfb_fl_adm2['gaul_adm2_list'].apply(lambda x: [int(i) for i in x])

#dfb_fl_adm2a=dfb_fl_adm2[dfb_fl_adm2['gaul_adm2_list_int']==48481]

dfb_fl_adm2['gaul_adm2_geob'] = dfb_fl_adm2['gaul_adm2_list_int'].apply(lambda x: [gaul_adm2_dict[i] for i in x])

# _b_dict={1:'TZA-ADM1-3_0_0-B2',2:'TZA-ADM1-3_0_0-B8'}

# dfb_fl_adm2['gaul_adm2_geob'] = dfb_fl_adm2['gaul_adm2_geob'].apply(lambda x: [_b_dict[i] for i in x])
# #dfb_dr_a

dfb_fl_part2=dfb_fl_adm2[['Dis No','gaul_adm2_geob']]
dfb_fl_part2.columns=['Dis No','geob_adm2_list']


dfb_fl_part2

# %%
import geopandas as gp
import glob

shpfiles=glob.glob('C:/Users/HP 820/loan_prediction/ea-ibf-climada/data_sources/202501-impact-events/202501-impact-events/shpfiles/geoboundary_code_flood/*.shp')

for shpfl in shpfiles:
    db=gp.read_file(shpfl)
    db

# %%
db

# %% [markdown]
# ## replacing manually added GEOB admin 1 and admin2 codes into common admin2 codes

# %%
import pandas as pd


dfb_fl=pd.read_excel(f'{em_dat_path}ea_flood_missing_location_v2.xlsx', engine='openpyxl')

dfb_fl1=dfb_fl[dfb_fl['geob'].isna()]

dfb_fl2=dfb_fl[dfb_fl['geob'].notna()]
dfb_fl2['geob_list']=dfb_fl2['geob'].str.split(',')

#dfb_dr1['geob_list']=dfb_dr1['geob'].str.split(',')

_ken=gp.read_file(f'geoboundary_code_flood/1998-0443-KEN.shp')

_ken_list=_ken['shapeID'].tolist()

_som94=gp.read_file(f'geoboundary_code_flood/1994-0573-SOM.shp')
_som94_list=_som94['shapeID'].tolist()

_som97=gp.read_file(f'geoboundary_code_flood/1997-0106-SOM.shp')
_som97_list=_som97['shapeID'].tolist()

dfb_fl1.at[38,'geob']=_ken_list
dfb_fl1.at[78,'geob']=_som94_list
dfb_fl1.at[81,'geob']=_som97_list

dfb_fl1a=dfb_fl1.rename(columns={"geob": "geob_list"})

dfb_fl_a=pd.concat([dfb_fl2,dfb_fl1a])
dfb_fl_a


def get_adm1_list(my_list):
    keys = ['ADM1','ADM2']
    aa=[[value for value in my_list if key in value] for key in set(keys)][0]
    bb=[[value for value in my_list if key in value] for key in set(keys)][1]
    #if not aa:
    #    bb=['']
    #else:
    #    bb=aa
    return aa,bb


aa_list=[]
bb_list=[]
for idx,row in dfb_fl_a.iterrows():
    #dfb_dr1.loc[idx,'geob_adm2_list'] = get_adm1_list(row['geob_list'])
    aa,bb=get_adm1_list(row['geob_list'])
    #dfb_dr1.loc[idx,'geob_adm2_list'] =aa
    #print(aa)
    aa_list.append(aa)
    bb_list.append(bb)

dfb_fl_a['geob_adm2_list']=bb_list
dfb_fl_a['geob_adm1_list']=aa_list


# dfb_dr1['geob_adm2'] = dfb_dr1['geob_list'].apply(lambda x: [geob_db3_dict[i] for i in x])
dfb_fl_adm1=dfb_fl_a[['Dis No','geob_adm1_list']]
#dfb_dr1_adm1_a=dfb_dr1_adm1[dfb_dr1_adm1['geob_adm1_list'].notna()]
dfb_fl_adm1_a=dfb_fl_adm1[dfb_fl_adm1['geob_adm1_list'].map(lambda d: len(d)) > 0]
dfb_fl_adm1_a['geob_adm2_list'] = dfb_fl_adm1_a['geob_adm1_list'].apply(lambda x: [geob_db3_dict[i] for i in x])


def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list=[]
for idx,row in dfb_fl_adm1_a.iterrows():
    aa=flatten(row['geob_adm2_list'])
    aa_list.append(aa)
    #dfb_dr1_adm1_a.loc[idx,'geob_adm2_list_a'] = flatten(row['geob_adm2_list'])

dfb_fl_adm1_a['geob_adm2_list_a']=aa_list

dfb_fl_adm1_b=dfb_fl_adm1_a[['Dis No','geob_adm2_list_a']]

dfb_fl2=pd.merge(dfb_fl_a,dfb_fl_adm1_b,on='Dis No',how='left')

dfb_fl2['geob_adm2_list_a'] = dfb_fl2['geob_adm2_list_a'].apply(lambda d: d if isinstance(d, list) else [])

dfb_fl2['geob_adm2_list_a']=(dfb_fl2.geob_adm2_list+dfb_fl2.geob_adm2_list_a).map(set).map(list)

dfb_fl_part3=dfb_fl2[['sno,'geob_adm2_list_a']]

dfb_fl_part3.columns=['sno','geob_adm2_list']

# %%
dfb_parts=pd.concat([dfb_fl_part1,dfb_fl_part2,dfb_fl_part3],axis=0)
dfb_parts1=dfb_parts.drop_duplicates('Dis No')

# %%
df=dfb_parts.groupby('Dis No').agg({'geob_adm2_list': 'sum'})

# %%
df_a=df[df['geob_adm2_list'].map(lambda d: len(d)) > 0]
adisno=df_a.index.tolist()

# %%
#df.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/test.csv')

# %%
dfb_fl_ea1=dfb_fl_ea[~dfb_fl_ea['Dis No'].isin(adisno)]
df1=dfb_fl_ea1[['Dis No','Location']]
df1
#df1.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/fl_part4_missing_location.csv')

# %% [markdown]
# # part4 missing admins
# 1990-0352-KEN - http://erepository.uonbi.ac.ke/bitstream/handle/11295/66135/Alfred%20Opere.pdf?sequence
#
# 1996-0473-SOM - https://reliefweb.int/report/somalia/fews-bulletin-july-24-1996
#
# 2018-0477-RWA - https://reliefweb.int/disaster/fl-2018-000029-rwa
#
# 2021-0343-ETH - https://floodlist.com/tag/ethiopia
#
# Flood catalogs for EA from 1985
#
# https://drought.unl.edu/archive/Documents/NDMC/Workshops/539/Pres/GHA2_Policelli-floods-1.pdf

# %%
import geopandas as gp

_ken=gp.read_file('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/geoboundary_code_flood/1990-0352-KEN.shp')

print(_ken['shapeID'].tolist())

# %%
_som=gp.read_file('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/geoboundary_code_flood/1996-0473-SOM.shp')

print(_som['shapeID'].tolist())

# %%
_ken1=gp.read_file('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/geoboundary_code_flood/1996-0474-KEN.shp')

print(_ken1['shapeID'].tolist())

# %% [markdown]
# ## part4 repalce

# %%
import pandas as pd
import geopandas as gp


geob_db=gp.read_file(f'ea_adm2_geoboundaries_adm1_code.shp')
#https://stackoverflow.com/a/54137935/2501953
geob_db1=geob_db[['adm1_shape','shapeID']]
#geob_db2=geob_db1.set_index('adm1_shape')
#geob_db_dict=geob_db1['adm1_shape'].groupby(level=0).apply(lambda x: x.to_dict('shapeID')).to_dict()
geob_db2=geob_db1.groupby('adm1_shape').agg({'shapeID':lambda x: list(x)})
geob_db3=geob_db2.reset_index()
geob_db3.columns=['gaul_adm1_geob','shapeID']
geob_db3_dict = dict(zip(geob_db3.gaul_adm1_geob, geob_db3.shapeID))


dfb_fl=pd.read_csv(f'fl_part4_missing_location_v1.csv')



dfb_fl1=dfb_fl[dfb_fl['geob'].notna()]
dfb_fl1['geob_list']=dfb_fl1['geob'].str.split(',').replace(' ','')



def get_adm1_list(my_list):
    keys = ['ADM1','ADM2']
    aa=[[value for value in my_list if key in value] for key in set(keys)][0]
    bb=[[value for value in my_list if key in value] for key in set(keys)][1]
    #if not aa:
    #    bb=['']
    #else:
    #    bb=aa
    return aa,bb


aa_list=[]
bb_list=[]
for idx,row in dfb_fl1.iterrows():
    #dfb_dr1.loc[idx,'geob_adm2_list'] = get_adm1_list(row['geob_list'])
    aa,bb=get_adm1_list(row['geob_list'])
    #dfb_dr1.loc[idx,'geob_adm2_list'] =aa
    #print(aa)
    aa_list.append(aa)
    bb_list.append(bb)

dfb_fl1['geob_adm2_list']=bb_list
dfb_fl1['geob_adm1_list']=aa_list


# dfb_dr1['geob_adm2'] = dfb_dr1['geob_list'].apply(lambda x: [geob_db3_dict[i] for i in x])
dfb_fl_adm1=dfb_fl1[['Dis No','geob_adm1_list']]
#dfb_dr1_adm1_a=dfb_dr1_adm1[dfb_dr1_adm1['geob_adm1_list'].notna()]
dfb_fl_adm1_a=dfb_fl_adm1[dfb_fl_adm1['geob_adm1_list'].map(lambda d: len(d)) > 0]
dfb_fl_adm1_a['geob_adm2_list'] = dfb_fl_adm1_a['geob_adm1_list'].apply(lambda x: [geob_db3_dict[i] for i in x])


def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list=[]
for idx,row in dfb_fl_adm1_a.iterrows():
    aa=flatten(row['geob_adm2_list'])
    aa_list.append(aa)
    #dfb_dr1_adm1_a.loc[idx,'geob_adm2_list_a'] = flatten(row['geob_adm2_list'])

dfb_fl_adm1_a['geob_adm2_list_a']=aa_list

dfb_fl_adm1_b=dfb_fl_adm1_a[['Dis No','geob_adm2_list_a']]

dfb_fl2=pd.merge(dfb_fl1,dfb_fl_adm1_b,on='Dis No',how='left')

dfb_fl2['geob_adm2_list_a'] = dfb_fl2['geob_adm2_list_a'].apply(lambda d: d if isinstance(d, list) else [])

dfb_fl2['geob_adm2_list_a']=(dfb_fl2.geob_adm2_list+dfb_fl2.geob_adm2_list_a).map(set).map(list)

dfb_fl_part4=dfb_fl2[['Dis No','geob_adm2_list_a']]

dfb_fl_part4.columns=['Dis No','geob_adm2_list']

# %%
dfb_fl_part4

# %%
dfb_parts=pd.concat([dfb_fl_part1,dfb_fl_part2,dfb_fl_part3,dfb_fl_part4],axis=0)
#dfb_parts1=dfb_parts.drop_duplicates('Dis No')
df=dfb_parts.groupby('Dis No').agg({'geob_adm2_list': 'sum'})
df['len_of_list'] = df.geob_adm2_list.agg([len])
df['geob_adm2_list1'] = df['geob_adm2_list'].apply(lambda x: list(set(x)))
#df['len_of_list1'] = df.geob_un.agg([len])
df1=df[['geob_adm2_list1']]
df2=df1.reset_index()
df2.columns=['Dis No','geob_adm2_list']
df2.to_excel("em_dat_ea_flood_adm2_v0.xlsx",index=False)

# %%
df2
