# %%
import glob
import geopandas as gp
import pandas as pd
import numpy as np

shpfiles=glob.glob('/home/data_folder/karamoja_shapefiles/*/*.shp')

dist_shp=gp.read_file(shpfiles[0])
#dist_shp.plot()
#dist_shp.info()

kara_shp=gp.read_file(shpfiles[1])
#kara_shp.plot()

lh_shp=gp.read_file(shpfiles[2])
#lh_shp.plot()

sc_shp=gp.read_file(shpfiles[3])
#sc_shp.plot()

dist_shp1=dist_shp[['admin2Name','geometry']]
dist_shp1.columns=['admin_name','geometry']
lh_shp1=lh_shp[['livelihood','geometry']]
lh_shp1.columns=['admin_name','geometry']
kara_shp1=kara_shp[['geometry']]
kara_shp1['admin_name']='karamoja'
#kara_shp1.columns=['admin_name','geometry']

geo_db=pd.concat([dist_shp1,lh_shp1,kara_shp1])
geo_db1=geo_db.reset_index()
geo_db2=geo_db1[['admin_name','geometry']]
geo_db2['admin_name1']=geo_db2['admin_name'].str.lower()
admin_bound_list=geo_db2['admin_name1'].tolist()
admin_bound_list
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# ['abim',
#  'napak',
#  'nabilatuk',
#  'kotido',
#  'moroto',
#  'nakapiripirit',
#  'kaabong',
#  'karenga',
#  'amudat',
#  'nab_nak_napak',
#  'abi_kar_kaboong',
#  'mor_kot_amudat',
#  'karamoja']

# %%
lh_shp1
# Out:
#         admin_name                                           geometry
# 0    Nab_Nak_Napak  POLYGON ((34.22907 1.63980, 34.22907 1.63980, ...
# 1  Abi_Kar_Kaboong  MULTIPOLYGON (((33.94424 2.63034, 33.95916 2.6...
# 2   Mor_Kot_Amudat  POLYGON ((34.27117 2.82791, 34.27038 2.81984, ...

# %%
month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}

start_month_index=2
end_month_index=9


m_ind_list=np.arange(start_month_index,end_month_index+1,1)
m_cnt=[]
for m_ind in m_ind_list:
    mstr=month_index_dict[m_ind]
    m_cnt.append(mstr)
jmstr=''.join(m_cnt)

# %%
import rioxarray



def get_month_index_str(start_month_index,end_month_index):
    month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
    m_ind_list=np.arange(start_month_index,end_month_index+1,1)
    m_cnt=[]
    for m_ind in m_ind_list:
        mstr=month_index_dict[m_ind]
        m_cnt.append(mstr)
    jmstr=''.join(m_cnt)
    return jmstr


def region_shp_averager_season(single_row_shp,xds,var_str,start_month_index,end_month_index):
    clipped = xds.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)
    year_xds=xds.indexes['time'].to_datetimeindex()
    year_str=str(year_xds[0].year)
    da=clipped.loc[dict(time=slice(year_str))]
    da1=da[var_str]
    aa=da1.values
    aa1=aa[start_month_index:end_month_index,:,:]
    aa2=aa1.ravel()
    aa3 = aa2[(aa2 >=-9000)]
    cont_mean=np.mean(aa3)
    return cont_mean,year_str



def make_csv_season(geo_db2,admin_bound_list,folder_str,var_str,start_month_index,end_month_index):
    ncfiles=glob.glob(f'/home/data_folder/icpac_data/data/{folder_str}/CHIRPS/*.nc')
    month_index_str=get_month_index_str(start_month_index,end_month_index)
    mdb_cont=[]
    for ncfile_path in ncfiles:
        xds = rioxarray.open_rasterio(ncfile_path)
        db_cont=[]
        year_cont=[]
        for ab_str in admin_bound_list:
            geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
            single_row_shp=geo_db3        
            cont_mean,year_str=region_shp_averager_season(single_row_shp,xds,var_str,start_month_index,end_month_index)
            year_month_index_str=f'{year_str}_{month_index_str}'
            ab_dict={}
            ab_dict['year_month']=year_month_index_str
            ab_dict['bound_name']=ab_str
            ab_dict['mean']=cont_mean
            db_cont.append(ab_dict)
        print(year_cont)
        print(db_cont)
        db=pd.DataFrame(db_cont)
        print(db)
        db1=pd.pivot_table(db, values='mean', index=['year_month'], columns=['bound_name'])
        db2=db1.reset_index()
        mdb_cont.append(db2)
        db=[]
        db1=[]
        db2=[]
    mdb1=pd.concat(mdb_cont,axis=0)
    mdb1.to_csv(f'/home/data_folder/seasonal/{folder_str}_{month_index_str}_CHRIPS.csv',index=False)
    mdb1=[]
    #return db

# %%
folder_list=['IGAD_Standardized_Precipitation_Index_SPI1','IGAD_Standardized_Precipitation_Index_SPI3',
            'IGAD_Standardized_Precipitation_Index_SPI6','IGAD_Standardized_Precipitation_Index_SPI9',
            'IGAD_Standardized_Precipitation_Index_SPI12','IGAD_Standardized_Precipitation_Index_SPI24',
            'IGAD_Standardized_Precipitation_Index_SPI48']

var_list=['spg01','spg03','spg06','spg09','spg12','spg24','spg48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for mar to october
start_month_index=2
end_month_index=9
    
for folder_str,var_str in zip(folder_list,var_list):
    mdb1=make_csv_season(geo_db2,admin_bound_list,folder_str,var_str,start_month_index,end_month_index)
# Out:
# bound_name     abi_kar_kaboong      abim    amudat   kaabong  karamoja  \
# year_month
# 2021_MAMJJASO        -0.211082 -0.497553  0.156461 -0.129047 -0.083487
#
# bound_name      karenga    kotido  mor_kot_amudat    moroto  nab_nak_napak  \
# year_month
# 2021_MAMJJASO -0.040663 -0.204423        -0.04938  0.014288       0.027726
#
# bound_name     nabilatuk  nakapiripirit     napak
# year_month
# 2021_MAMJJASO    0.06378       0.212193 -0.087153

# %%
folder_list=['IGAD_Standardized_Precipitation_Index_SPI1','IGAD_Standardized_Precipitation_Index_SPI3',
            'IGAD_Standardized_Precipitation_Index_SPI6','IGAD_Standardized_Precipitation_Index_SPI9',
            'IGAD_Standardized_Precipitation_Index_SPI12','IGAD_Standardized_Precipitation_Index_SPI24',
            'IGAD_Standardized_Precipitation_Index_SPI48']

var_list=['spg01','spg03','spg06','spg09','spg12','spg24','spg48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for JJAS
start_month_index=5
end_month_index=8
    
for folder_str,var_str in zip(folder_list,var_list):
    mdb1=make_csv_season(geo_db2,admin_bound_list,folder_str,var_str,start_month_index,end_month_index)
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2000_JJAS', 'bound_name': 'abim', 'mean': 0.8933117}, {'year_month': '2000_JJAS', 'bound_name': 'napak', 'mean': 0.40687212}, {'year_month': '2000_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.01213661}, {'year_month': '2000_JJAS', 'bound_name': 'kotido', 'mean': 0.5693305}, {'year_month': '2000_JJAS', 'bound_name': 'moroto', 'mean': -0.03919828}, {'year_month': '2000_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.07801688}, {'year_month': '2000_JJAS', 'bound_name': 'kaabong', 'mean': -0.066006534}, {'year_month': '2000_JJAS', 'bound_name': 'karenga', 'mean': 0.13393414}, {'year_month': '2000_JJAS', 'bound_name': 'amudat', 'mean': 0.04861005}, {'year_month': '2000_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.18356526}, {'year_month': '2000_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.2543998}, {'year_month': '2000_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.2272137}, {'year_month': '2000_JJAS', 'bound_name': 'karamoja', 'mean': 0.22318612}]
#    year_month       bound_name      mean
# 0   2000_JJAS             abim  0.893312
# 1   2000_JJAS            napak  0.406872
# 2   2000_JJAS        nabilatuk -0.012137
# 3   2000_JJAS           kotido  0.569331
# 4   2000_JJAS           moroto -0.039198
# 5   2000_JJAS    nakapiripirit -0.078017
# 6   2000_JJAS          kaabong -0.066007
# 7   2000_JJAS          karenga  0.133934
# 8   2000_JJAS           amudat  0.048610
# 9   2000_JJAS    nab_nak_napak  0.183565
# 10  2000_JJAS  abi_kar_kaboong  0.254400
# 11  2000_JJAS   mor_kot_amudat  0.227214
# 12  2000_JJAS         karamoja  0.223186
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2001_JJAS', 'bound_name': 'abim', 'mean': 0.6405145}, {'year_month': '2001_JJAS', 'bound_name': 'napak', 'mean': 1.1202877}, {'year_month': '2001_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.1315192}, {'year_month': '2001_JJAS', 'bound_name': 'kotido', 'mean': 0.42896897}, {'year_month': '2001_JJAS', 'bound_name': 'moroto', 'mean': 0.47872415}, {'year_month': '2001_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.95673}, {'year_month': '2001_JJAS', 'bound_name': 'kaabong', 'mean': 0.16493681}, {'year_month': '2001_JJAS', 'bound_name': 'karenga', 'mean': 0.29966256}, {'year_month': '2001_JJAS', 'bound_name': 'amudat', 'mean': 0.8259057}, {'year_month': '2001_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.0775046}, {'year_month': '2001_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.33262372}, {'year_month': '2001_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.52238095}, {'year_month': '2001_JJAS', 'bound_name': 'karamoja', 'mean': 0.6301724}]
#    year_month       bound_name      mean
# 0   2001_JJAS             abim  0.640514
# 1   2001_JJAS            napak  1.120288
# 2   2001_JJAS        nabilatuk  1.131519
# 3   2001_JJAS           kotido  0.428969
# 4   2001_JJAS           moroto  0.478724
# 5   2001_JJAS    nakapiripirit  0.956730
# 6   2001_JJAS          kaabong  0.164937
# 7   2001_JJAS          karenga  0.299663
# 8   2001_JJAS           amudat  0.825906
# 9   2001_JJAS    nab_nak_napak  1.077505
# 10  2001_JJAS  abi_kar_kaboong  0.332624
# 11  2001_JJAS   mor_kot_amudat  0.522381
# 12  2001_JJAS         karamoja  0.630172
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2002_JJAS', 'bound_name': 'abim', 'mean': -0.8578551}, {'year_month': '2002_JJAS', 'bound_name': 'napak', 'mean': -0.91043836}, {'year_month': '2002_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.9038251}, {'year_month': '2002_JJAS', 'bound_name': 'kotido', 'mean': -1.0481949}, {'year_month': '2002_JJAS', 'bound_name': 'moroto', 'mean': -0.8937069}, {'year_month': '2002_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.86813927}, {'year_month': '2002_JJAS', 'bound_name': 'kaabong', 'mean': -0.87125707}, {'year_month': '2002_JJAS', 'bound_name': 'karenga', 'mean': -0.75897944}, {'year_month': '2002_JJAS', 'bound_name': 'amudat', 'mean': -0.8268112}, {'year_month': '2002_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.8973439}, {'year_month': '2002_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.8395776}, {'year_month': '2002_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.944871}, {'year_month': '2002_JJAS', 'bound_name': 'karamoja', 'mean': -0.89156914}]
#    year_month       bound_name      mean
# 0   2002_JJAS             abim -0.857855
# 1   2002_JJAS            napak -0.910438
# 2   2002_JJAS        nabilatuk -0.903825
# 3   2002_JJAS           kotido -1.048195
# 4   2002_JJAS           moroto -0.893707
# 5   2002_JJAS    nakapiripirit -0.868139
# 6   2002_JJAS          kaabong -0.871257
# 7   2002_JJAS          karenga -0.758979
# 8   2002_JJAS           amudat -0.826811
# 9   2002_JJAS    nab_nak_napak -0.897344
# 10  2002_JJAS  abi_kar_kaboong -0.839578
# 11  2002_JJAS   mor_kot_amudat -0.944871
# 12  2002_JJAS         karamoja -0.891569
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2003_JJAS', 'bound_name': 'abim', 'mean': 0.5640471}, {'year_month': '2003_JJAS', 'bound_name': 'napak', 'mean': 0.67702055}, {'year_month': '2003_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.94482523}, {'year_month': '2003_JJAS', 'bound_name': 'kotido', 'mean': 0.28991243}, {'year_month': '2003_JJAS', 'bound_name': 'moroto', 'mean': 0.31647417}, {'year_month': '2003_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.7630422}, {'year_month': '2003_JJAS', 'bound_name': 'kaabong', 'mean': 0.064610034}, {'year_month': '2003_JJAS', 'bound_name': 'karenga', 'mean': -0.02127572}, {'year_month': '2003_JJAS', 'bound_name': 'amudat', 'mean': 0.8267736}, {'year_month': '2003_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.757901}, {'year_month': '2003_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.18421575}, {'year_month': '2003_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.39978978}, {'year_month': '2003_JJAS', 'bound_name': 'karamoja', 'mean': 0.43554357}]
#    year_month       bound_name      mean
# 0   2003_JJAS             abim  0.564047
# 1   2003_JJAS            napak  0.677021
# 2   2003_JJAS        nabilatuk  0.944825
# 3   2003_JJAS           kotido  0.289912
# 4   2003_JJAS           moroto  0.316474
# 5   2003_JJAS    nakapiripirit  0.763042
# 6   2003_JJAS          kaabong  0.064610
# 7   2003_JJAS          karenga -0.021276
# 8   2003_JJAS           amudat  0.826774
# 9   2003_JJAS    nab_nak_napak  0.757901
# 10  2003_JJAS  abi_kar_kaboong  0.184216
# 11  2003_JJAS   mor_kot_amudat  0.399790
# 12  2003_JJAS         karamoja  0.435544
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2004_JJAS', 'bound_name': 'abim', 'mean': -0.38968116}, {'year_month': '2004_JJAS', 'bound_name': 'napak', 'mean': -0.23021233}, {'year_month': '2004_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.749295}, {'year_month': '2004_JJAS', 'bound_name': 'kotido', 'mean': -0.35669214}, {'year_month': '2004_JJAS', 'bound_name': 'moroto', 'mean': -0.53102297}, {'year_month': '2004_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.9795822}, {'year_month': '2004_JJAS', 'bound_name': 'kaabong', 'mean': -0.4292462}, {'year_month': '2004_JJAS', 'bound_name': 'karenga', 'mean': -0.11055558}, {'year_month': '2004_JJAS', 'bound_name': 'amudat', 'mean': -0.89098114}, {'year_month': '2004_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.54791963}, {'year_month': '2004_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.3388967}, {'year_month': '2004_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.52582}, {'year_month': '2004_JJAS', 'bound_name': 'karamoja', 'mean': -0.46506754}]
#    year_month       bound_name      mean
# 0   2004_JJAS             abim -0.389681
# 1   2004_JJAS            napak -0.230212
# 2   2004_JJAS        nabilatuk -0.749295
# 3   2004_JJAS           kotido -0.356692
# 4   2004_JJAS           moroto -0.531023
# 5   2004_JJAS    nakapiripirit -0.979582
# 6   2004_JJAS          kaabong -0.429246
# 7   2004_JJAS          karenga -0.110556
# 8   2004_JJAS           amudat -0.890981
# 9   2004_JJAS    nab_nak_napak -0.547920
# 10  2004_JJAS  abi_kar_kaboong -0.338897
# 11  2004_JJAS   mor_kot_amudat -0.525820
# 12  2004_JJAS         karamoja -0.465068
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2005_JJAS', 'bound_name': 'abim', 'mean': -1.0639457}, {'year_month': '2005_JJAS', 'bound_name': 'napak', 'mean': -0.63602513}, {'year_month': '2005_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.48563385}, {'year_month': '2005_JJAS', 'bound_name': 'kotido', 'mean': -0.79235303}, {'year_month': '2005_JJAS', 'bound_name': 'moroto', 'mean': -0.30451724}, {'year_month': '2005_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.60064554}, {'year_month': '2005_JJAS', 'bound_name': 'kaabong', 'mean': -0.34852722}, {'year_month': '2005_JJAS', 'bound_name': 'karenga', 'mean': -0.46913993}, {'year_month': '2005_JJAS', 'bound_name': 'amudat', 'mean': -0.6359371}, {'year_month': '2005_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.594176}, {'year_month': '2005_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.58039266}, {'year_month': '2005_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.56629384}, {'year_month': '2005_JJAS', 'bound_name': 'karamoja', 'mean': -0.58027667}]
#    year_month       bound_name      mean
# 0   2005_JJAS             abim -1.063946
# 1   2005_JJAS            napak -0.636025
# 2   2005_JJAS        nabilatuk -0.485634
# 3   2005_JJAS           kotido -0.792353
# 4   2005_JJAS           moroto -0.304517
# 5   2005_JJAS    nakapiripirit -0.600646
# 6   2005_JJAS          kaabong -0.348527
# 7   2005_JJAS          karenga -0.469140
# 8   2005_JJAS           amudat -0.635937
# 9   2005_JJAS    nab_nak_napak -0.594176
# 10  2005_JJAS  abi_kar_kaboong -0.580393
# 11  2005_JJAS   mor_kot_amudat -0.566294
# 12  2005_JJAS         karamoja -0.580277
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2006_JJAS', 'bound_name': 'abim', 'mean': -0.17404714}, {'year_month': '2006_JJAS', 'bound_name': 'napak', 'mean': -0.51193607}, {'year_month': '2006_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.5680929}, {'year_month': '2006_JJAS', 'bound_name': 'kotido', 'mean': -0.18278253}, {'year_month': '2006_JJAS', 'bound_name': 'moroto', 'mean': -0.10406321}, {'year_month': '2006_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.76238817}, {'year_month': '2006_JJAS', 'bound_name': 'kaabong', 'mean': -0.10195426}, {'year_month': '2006_JJAS', 'bound_name': 'karenga', 'mean': -0.008827162}, {'year_month': '2006_JJAS', 'bound_name': 'amudat', 'mean': -0.37576732}, {'year_month': '2006_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.59309435}, {'year_month': '2006_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.09916054}, {'year_month': '2006_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.18660395}, {'year_month': '2006_JJAS', 'bound_name': 'karamoja', 'mean': -0.28421208}]
#    year_month       bound_name      mean
# 0   2006_JJAS             abim -0.174047
# 1   2006_JJAS            napak -0.511936
# 2   2006_JJAS        nabilatuk -0.568093
# 3   2006_JJAS           kotido -0.182783
# 4   2006_JJAS           moroto -0.104063
# 5   2006_JJAS    nakapiripirit -0.762388
# 6   2006_JJAS          kaabong -0.101954
# 7   2006_JJAS          karenga -0.008827
# 8   2006_JJAS           amudat -0.375767
# 9   2006_JJAS    nab_nak_napak -0.593094
# 10  2006_JJAS  abi_kar_kaboong -0.099161
# 11  2006_JJAS   mor_kot_amudat -0.186604
# 12  2006_JJAS         karamoja -0.284212
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2007_JJAS', 'bound_name': 'abim', 'mean': 1.1186992}, {'year_month': '2007_JJAS', 'bound_name': 'napak', 'mean': 1.5369977}, {'year_month': '2007_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.3871422}, {'year_month': '2007_JJAS', 'bound_name': 'kotido', 'mean': 1.6119378}, {'year_month': '2007_JJAS', 'bound_name': 'moroto', 'mean': 2.0549195}, {'year_month': '2007_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.2244769}, {'year_month': '2007_JJAS', 'bound_name': 'kaabong', 'mean': 2.0180805}, {'year_month': '2007_JJAS', 'bound_name': 'karenga', 'mean': 1.8169754}, {'year_month': '2007_JJAS', 'bound_name': 'amudat', 'mean': 1.4819056}, {'year_month': '2007_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.4187098}, {'year_month': '2007_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.7142996}, {'year_month': '2007_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.7669698}, {'year_month': '2007_JJAS', 'bound_name': 'karamoja', 'mean': 1.6370778}]
#    year_month       bound_name      mean
# 0   2007_JJAS             abim  1.118699
# 1   2007_JJAS            napak  1.536998
# 2   2007_JJAS        nabilatuk  1.387142
# 3   2007_JJAS           kotido  1.611938
# 4   2007_JJAS           moroto  2.054919
# 5   2007_JJAS    nakapiripirit  1.224477
# 6   2007_JJAS          kaabong  2.018080
# 7   2007_JJAS          karenga  1.816975
# 8   2007_JJAS           amudat  1.481906
# 9   2007_JJAS    nab_nak_napak  1.418710
# 10  2007_JJAS  abi_kar_kaboong  1.714300
# 11  2007_JJAS   mor_kot_amudat  1.766970
# 12  2007_JJAS         karamoja  1.637078
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2008_JJAS', 'bound_name': 'abim', 'mean': 0.30743477}, {'year_month': '2008_JJAS', 'bound_name': 'napak', 'mean': 0.3401233}, {'year_month': '2008_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.5268142}, {'year_month': '2008_JJAS', 'bound_name': 'kotido', 'mean': 0.1165678}, {'year_month': '2008_JJAS', 'bound_name': 'moroto', 'mean': -0.10020403}, {'year_month': '2008_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.4731519}, {'year_month': '2008_JJAS', 'bound_name': 'kaabong', 'mean': -0.28949457}, {'year_month': '2008_JJAS', 'bound_name': 'karenga', 'mean': -0.20293827}, {'year_month': '2008_JJAS', 'bound_name': 'amudat', 'mean': 0.3493522}, {'year_month': '2008_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.41668764}, {'year_month': '2008_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.099529654}, {'year_month': '2008_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.07194078}, {'year_month': '2008_JJAS', 'bound_name': 'karamoja', 'mean': 0.11943605}]
#    year_month       bound_name      mean
# 0   2008_JJAS             abim  0.307435
# 1   2008_JJAS            napak  0.340123
# 2   2008_JJAS        nabilatuk  0.526814
# 3   2008_JJAS           kotido  0.116568
# 4   2008_JJAS           moroto -0.100204
# 5   2008_JJAS    nakapiripirit  0.473152
# 6   2008_JJAS          kaabong -0.289495
# 7   2008_JJAS          karenga -0.202938
# 8   2008_JJAS           amudat  0.349352
# 9   2008_JJAS    nab_nak_napak  0.416688
# 10  2008_JJAS  abi_kar_kaboong -0.099530
# 11  2008_JJAS   mor_kot_amudat  0.071941
# 12  2008_JJAS         karamoja  0.119436
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2009_JJAS', 'bound_name': 'abim', 'mean': -1.5274819}, {'year_month': '2009_JJAS', 'bound_name': 'napak', 'mean': -1.6461302}, {'year_month': '2009_JJAS', 'bound_name': 'nabilatuk', 'mean': -1.2991202}, {'year_month': '2009_JJAS', 'bound_name': 'kotido', 'mean': -1.6982118}, {'year_month': '2009_JJAS', 'bound_name': 'moroto', 'mean': -1.4380833}, {'year_month': '2009_JJAS', 'bound_name': 'nakapiripirit', 'mean': -1.1623291}, {'year_month': '2009_JJAS', 'bound_name': 'kaabong', 'mean': -1.2348648}, {'year_month': '2009_JJAS', 'bound_name': 'karenga', 'mean': -1.2111235}, {'year_month': '2009_JJAS', 'bound_name': 'amudat', 'mean': -1.1105723}, {'year_month': '2009_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -1.4384801}, {'year_month': '2009_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -1.311545}, {'year_month': '2009_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -1.4845539}, {'year_month': '2009_JJAS', 'bound_name': 'karamoja', 'mean': -1.4071591}]
#    year_month       bound_name      mean
# 0   2009_JJAS             abim -1.527482
# 1   2009_JJAS            napak -1.646130
# 2   2009_JJAS        nabilatuk -1.299120
# 3   2009_JJAS           kotido -1.698212
# 4   2009_JJAS           moroto -1.438083
# 5   2009_JJAS    nakapiripirit -1.162329
# 6   2009_JJAS          kaabong -1.234865
# 7   2009_JJAS          karenga -1.211123
# 8   2009_JJAS           amudat -1.110572
# 9   2009_JJAS    nab_nak_napak -1.438480
# 10  2009_JJAS  abi_kar_kaboong -1.311545
# 11  2009_JJAS   mor_kot_amudat -1.484554
# 12  2009_JJAS         karamoja -1.407159
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# ...
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2018_JJAS', 'bound_name': 'abim', 'mean': 2.0310762}, {'year_month': '2018_JJAS', 'bound_name': 'napak', 'mean': 2.6304085}, {'year_month': '2018_JJAS', 'bound_name': 'nabilatuk', 'mean': 2.5336666}, {'year_month': '2018_JJAS', 'bound_name': 'kotido', 'mean': 1.988469}, {'year_month': '2018_JJAS', 'bound_name': 'moroto', 'mean': 2.0978189}, {'year_month': '2018_JJAS', 'bound_name': 'nakapiripirit', 'mean': 2.819439}, {'year_month': '2018_JJAS', 'bound_name': 'kaabong', 'mean': 2.0827167}, {'year_month': '2018_JJAS', 'bound_name': 'karenga', 'mean': 2.4221768}, {'year_month': '2018_JJAS', 'bound_name': 'amudat', 'mean': 3.1991384}, {'year_month': '2018_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 2.6619892}, {'year_month': '2018_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 2.1524878}, {'year_month': '2018_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 2.256239}, {'year_month': '2018_JJAS', 'bound_name': 'karamoja', 'mean': 2.3476982}]
#    year_month       bound_name      mean
# 0   2018_JJAS             abim  2.031076
# 1   2018_JJAS            napak  2.630409
# 2   2018_JJAS        nabilatuk  2.533667
# 3   2018_JJAS           kotido  1.988469
# 4   2018_JJAS           moroto  2.097819
# 5   2018_JJAS    nakapiripirit  2.819439
# 6   2018_JJAS          kaabong  2.082717
# 7   2018_JJAS          karenga  2.422177
# 8   2018_JJAS           amudat  3.199138
# 9   2018_JJAS    nab_nak_napak  2.661989
# 10  2018_JJAS  abi_kar_kaboong  2.152488
# 11  2018_JJAS   mor_kot_amudat  2.256239
# 12  2018_JJAS         karamoja  2.347698
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2019_JJAS', 'bound_name': 'abim', 'mean': 1.5456377}, {'year_month': '2019_JJAS', 'bound_name': 'napak', 'mean': 2.1346622}, {'year_month': '2019_JJAS', 'bound_name': 'nabilatuk', 'mean': 2.0700603}, {'year_month': '2019_JJAS', 'bound_name': 'kotido', 'mean': 1.5177402}, {'year_month': '2019_JJAS', 'bound_name': 'moroto', 'mean': 1.7964165}, {'year_month': '2019_JJAS', 'bound_name': 'nakapiripirit', 'mean': 2.435405}, {'year_month': '2019_JJAS', 'bound_name': 'kaabong', 'mean': 1.7095097}, {'year_month': '2019_JJAS', 'bound_name': 'karenga', 'mean': 2.033309}, {'year_month': '2019_JJAS', 'bound_name': 'amudat', 'mean': 2.79417}, {'year_month': '2019_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 2.2039557}, {'year_month': '2019_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.7437167}, {'year_month': '2019_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.8660929}, {'year_month': '2019_JJAS', 'bound_name': 'karamoja', 'mean': 1.929201}]
#    year_month       bound_name      mean
# 0   2019_JJAS             abim  1.545638
# 1   2019_JJAS            napak  2.134662
# 2   2019_JJAS        nabilatuk  2.070060
# 3   2019_JJAS           kotido  1.517740
# 4   2019_JJAS           moroto  1.796417
# 5   2019_JJAS    nakapiripirit  2.435405
# 6   2019_JJAS          kaabong  1.709510
# 7   2019_JJAS          karenga  2.033309
# 8   2019_JJAS           amudat  2.794170
# 9   2019_JJAS    nab_nak_napak  2.203956
# 10  2019_JJAS  abi_kar_kaboong  1.743717
# 11  2019_JJAS   mor_kot_amudat  1.866093
# 12  2019_JJAS         karamoja  1.929201
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2020_JJAS', 'bound_name': 'abim', 'mean': 2.4405544}, {'year_month': '2020_JJAS', 'bound_name': 'napak', 'mean': 3.3399334}, {'year_month': '2020_JJAS', 'bound_name': 'nabilatuk', 'mean': 3.4450984}, {'year_month': '2020_JJAS', 'bound_name': 'kotido', 'mean': 2.8628645}, {'year_month': '2020_JJAS', 'bound_name': 'moroto', 'mean': 3.5096724}, {'year_month': '2020_JJAS', 'bound_name': 'nakapiripirit', 'mean': 4.058996}, {'year_month': '2020_JJAS', 'bound_name': 'kaabong', 'mean': 3.3012788}, {'year_month': '2020_JJAS', 'bound_name': 'karenga', 'mean': 3.5930123}, {'year_month': '2020_JJAS', 'bound_name': 'amudat', 'mean': 4.715296}, {'year_month': '2020_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 3.560986}, {'year_month': '2020_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 3.1308608}, {'year_month': '2020_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 3.4663785}, {'year_month': '2020_JJAS', 'bound_name': 'karamoja', 'mean': 3.3748093}]
#    year_month       bound_name      mean
# 0   2020_JJAS             abim  2.440554
# 1   2020_JJAS            napak  3.339933
# 2   2020_JJAS        nabilatuk  3.445098
# 3   2020_JJAS           kotido  2.862864
# 4   2020_JJAS           moroto  3.509672
# 5   2020_JJAS    nakapiripirit  4.058996
# 6   2020_JJAS          kaabong  3.301279
# 7   2020_JJAS          karenga  3.593012
# 8   2020_JJAS           amudat  4.715296
# 9   2020_JJAS    nab_nak_napak  3.560986
# 10  2020_JJAS  abi_kar_kaboong  3.130861
# 11  2020_JJAS   mor_kot_amudat  3.466378
# 12  2020_JJAS         karamoja  3.374809
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2021_JJAS', 'bound_name': 'abim', 'mean': 3.1877644}, {'year_month': '2021_JJAS', 'bound_name': 'napak', 'mean': 4.330523}, {'year_month': '2021_JJAS', 'bound_name': 'nabilatuk', 'mean': 4.611858}, {'year_month': '2021_JJAS', 'bound_name': 'kotido', 'mean': 3.8148193}, {'year_month': '2021_JJAS', 'bound_name': 'moroto', 'mean': 4.74569}, {'year_month': '2021_JJAS', 'bound_name': 'nakapiripirit', 'mean': 5.342405}, {'year_month': '2021_JJAS', 'bound_name': 'kaabong', 'mean': 4.2743354}, {'year_month': '2021_JJAS', 'bound_name': 'karenga', 'mean': 4.857453}, {'year_month': '2021_JJAS', 'bound_name': 'amudat', 'mean': 5.9569063}, {'year_month': '2021_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 4.670034}, {'year_month': '2021_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 4.112581}, {'year_month': '2021_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 4.5866365}, {'year_month': '2021_JJAS', 'bound_name': 'karamoja', 'mean': 4.441263}]
#    year_month       bound_name      mean
# 0   2021_JJAS             abim  3.187764
# 1   2021_JJAS            napak  4.330523
# 2   2021_JJAS        nabilatuk  4.611858
# 3   2021_JJAS           kotido  3.814819
# 4   2021_JJAS           moroto  4.745690
# 5   2021_JJAS    nakapiripirit  5.342405
# 6   2021_JJAS          kaabong  4.274335
# 7   2021_JJAS          karenga  4.857453
# 8   2021_JJAS           amudat  5.956906
# 9   2021_JJAS    nab_nak_napak  4.670034
# 10  2021_JJAS  abi_kar_kaboong  4.112581
# 11  2021_JJAS   mor_kot_amudat  4.586637
# 12  2021_JJAS         karamoja  4.441263
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]

# %%
folder_list=['IGAD_Standardized_Precipitation_Index_SPI1','IGAD_Standardized_Precipitation_Index_SPI3',
            'IGAD_Standardized_Precipitation_Index_SPI6','IGAD_Standardized_Precipitation_Index_SPI9',
            'IGAD_Standardized_Precipitation_Index_SPI12','IGAD_Standardized_Precipitation_Index_SPI24',
            'IGAD_Standardized_Precipitation_Index_SPI48']

var_list=['spg01','spg03','spg06','spg09','spg12','spg24','spg48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for MAM
start_month_index=2
end_month_index=4
    
for folder_str,var_str in zip(folder_list,var_list):
    mdb1=make_csv_season(geo_db2,admin_bound_list,folder_str,var_str,start_month_index,end_month_index)
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2000_MAM', 'bound_name': 'abim', 'mean': -1.0173641}, {'year_month': '2000_MAM', 'bound_name': 'napak', 'mean': -0.90197945}, {'year_month': '2000_MAM', 'bound_name': 'nabilatuk', 'mean': -0.96031964}, {'year_month': '2000_MAM', 'bound_name': 'kotido', 'mean': -0.7701611}, {'year_month': '2000_MAM', 'bound_name': 'moroto', 'mean': -1.0824914}, {'year_month': '2000_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.90704435}, {'year_month': '2000_MAM', 'bound_name': 'kaabong', 'mean': -1.1770197}, {'year_month': '2000_MAM', 'bound_name': 'karenga', 'mean': -0.68138885}, {'year_month': '2000_MAM', 'bound_name': 'amudat', 'mean': -1.255953}, {'year_month': '2000_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.9158216}, {'year_month': '2000_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -1.0088159}, {'year_month': '2000_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.98610973}, {'year_month': '2000_MAM', 'bound_name': 'karamoja', 'mean': -0.9719828}]
#    year_month       bound_name      mean
# 0    2000_MAM             abim -1.017364
# 1    2000_MAM            napak -0.901979
# 2    2000_MAM        nabilatuk -0.960320
# 3    2000_MAM           kotido -0.770161
# 4    2000_MAM           moroto -1.082491
# 5    2000_MAM    nakapiripirit -0.907044
# 6    2000_MAM          kaabong -1.177020
# 7    2000_MAM          karenga -0.681389
# 8    2000_MAM           amudat -1.255953
# 9    2000_MAM    nab_nak_napak -0.915822
# 10   2000_MAM  abi_kar_kaboong -1.008816
# 11   2000_MAM   mor_kot_amudat -0.986110
# 12   2000_MAM         karamoja -0.971983
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2001_MAM', 'bound_name': 'abim', 'mean': 0.7985218}, {'year_month': '2001_MAM', 'bound_name': 'napak', 'mean': 0.5663151}, {'year_month': '2001_MAM', 'bound_name': 'nabilatuk', 'mean': 0.601041}, {'year_month': '2001_MAM', 'bound_name': 'kotido', 'mean': 0.6448263}, {'year_month': '2001_MAM', 'bound_name': 'moroto', 'mean': 0.61915517}, {'year_month': '2001_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.3776012}, {'year_month': '2001_MAM', 'bound_name': 'kaabong', 'mean': 0.5610784}, {'year_month': '2001_MAM', 'bound_name': 'karenga', 'mean': 0.82720983}, {'year_month': '2001_MAM', 'bound_name': 'amudat', 'mean': 0.33673584}, {'year_month': '2001_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.5215944}, {'year_month': '2001_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.69421166}, {'year_month': '2001_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.5775558}, {'year_month': '2001_MAM', 'bound_name': 'karamoja', 'mean': 0.6020551}]
#    year_month       bound_name      mean
# 0    2001_MAM             abim  0.798522
# 1    2001_MAM            napak  0.566315
# 2    2001_MAM        nabilatuk  0.601041
# 3    2001_MAM           kotido  0.644826
# 4    2001_MAM           moroto  0.619155
# 5    2001_MAM    nakapiripirit  0.377601
# 6    2001_MAM          kaabong  0.561078
# 7    2001_MAM          karenga  0.827210
# 8    2001_MAM           amudat  0.336736
# 9    2001_MAM    nab_nak_napak  0.521594
# 10   2001_MAM  abi_kar_kaboong  0.694212
# 11   2001_MAM   mor_kot_amudat  0.577556
# 12   2001_MAM         karamoja  0.602055
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2002_MAM', 'bound_name': 'abim', 'mean': -0.48747826}, {'year_month': '2002_MAM', 'bound_name': 'napak', 'mean': -0.32434586}, {'year_month': '2002_MAM', 'bound_name': 'nabilatuk', 'mean': -0.109860644}, {'year_month': '2002_MAM', 'bound_name': 'kotido', 'mean': -0.19744489}, {'year_month': '2002_MAM', 'bound_name': 'moroto', 'mean': 0.38430175}, {'year_month': '2002_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.42502537}, {'year_month': '2002_MAM', 'bound_name': 'kaabong', 'mean': 0.46553922}, {'year_month': '2002_MAM', 'bound_name': 'karenga', 'mean': 0.36694446}, {'year_month': '2002_MAM', 'bound_name': 'amudat', 'mean': -0.16522643}, {'year_month': '2002_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.30640906}, {'year_month': '2002_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.17209202}, {'year_month': '2002_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.043635882}, {'year_month': '2002_MAM', 'bound_name': 'karamoja', 'mean': -0.021142945}]
#    year_month       bound_name      mean
# 0    2002_MAM             abim -0.487478
# 1    2002_MAM            napak -0.324346
# 2    2002_MAM        nabilatuk -0.109861
# 3    2002_MAM           kotido -0.197445
# 4    2002_MAM           moroto  0.384302
# 5    2002_MAM    nakapiripirit -0.425025
# 6    2002_MAM          kaabong  0.465539
# 7    2002_MAM          karenga  0.366944
# 8    2002_MAM           amudat -0.165226
# 9    2002_MAM    nab_nak_napak -0.306409
# 10   2002_MAM  abi_kar_kaboong  0.172092
# 11   2002_MAM   mor_kot_amudat  0.043636
# 12   2002_MAM         karamoja -0.021143
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2003_MAM', 'bound_name': 'abim', 'mean': -0.031836923}, {'year_month': '2003_MAM', 'bound_name': 'napak', 'mean': 0.20470546}, {'year_month': '2003_MAM', 'bound_name': 'nabilatuk', 'mean': 0.56811476}, {'year_month': '2003_MAM', 'bound_name': 'kotido', 'mean': 0.16180517}, {'year_month': '2003_MAM', 'bound_name': 'moroto', 'mean': 0.75496113}, {'year_month': '2003_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.6060316}, {'year_month': '2003_MAM', 'bound_name': 'kaabong', 'mean': 0.6483987}, {'year_month': '2003_MAM', 'bound_name': 'karenga', 'mean': 0.32875928}, {'year_month': '2003_MAM', 'bound_name': 'amudat', 'mean': 0.7884434}, {'year_month': '2003_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.39307168}, {'year_month': '2003_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.37701073}, {'year_month': '2003_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.5172683}, {'year_month': '2003_MAM', 'bound_name': 'karamoja', 'mean': 0.42689657}]
#    year_month       bound_name      mean
# 0    2003_MAM             abim -0.031837
# 1    2003_MAM            napak  0.204705
# 2    2003_MAM        nabilatuk  0.568115
# 3    2003_MAM           kotido  0.161805
# 4    2003_MAM           moroto  0.754961
# 5    2003_MAM    nakapiripirit  0.606032
# 6    2003_MAM          kaabong  0.648399
# 7    2003_MAM          karenga  0.328759
# 8    2003_MAM           amudat  0.788443
# 9    2003_MAM    nab_nak_napak  0.393072
# 10   2003_MAM  abi_kar_kaboong  0.377011
# 11   2003_MAM   mor_kot_amudat  0.517268
# 12   2003_MAM         karamoja  0.426897
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2004_MAM', 'bound_name': 'abim', 'mean': -0.5875108}, {'year_month': '2004_MAM', 'bound_name': 'napak', 'mean': -0.3185857}, {'year_month': '2004_MAM', 'bound_name': 'nabilatuk', 'mean': -0.12072952}, {'year_month': '2004_MAM', 'bound_name': 'kotido', 'mean': -0.27681777}, {'year_month': '2004_MAM', 'bound_name': 'moroto', 'mean': 0.07864226}, {'year_month': '2004_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.037088636}, {'year_month': '2004_MAM', 'bound_name': 'kaabong', 'mean': -0.1852451}, {'year_month': '2004_MAM', 'bound_name': 'karenga', 'mean': -0.20478398}, {'year_month': '2004_MAM', 'bound_name': 'amudat', 'mean': 0.039047174}, {'year_month': '2004_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.19862936}, {'year_month': '2004_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.30362266}, {'year_month': '2004_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.07481703}, {'year_month': '2004_MAM', 'bound_name': 'karamoja', 'mean': -0.19717628}]
#    year_month       bound_name      mean
# 0    2004_MAM             abim -0.587511
# 1    2004_MAM            napak -0.318586
# 2    2004_MAM        nabilatuk -0.120730
# 3    2004_MAM           kotido -0.276818
# 4    2004_MAM           moroto  0.078642
# 5    2004_MAM    nakapiripirit -0.037089
# 6    2004_MAM          kaabong -0.185245
# 7    2004_MAM          karenga -0.204784
# 8    2004_MAM           amudat  0.039047
# 9    2004_MAM    nab_nak_napak -0.198629
# 10   2004_MAM  abi_kar_kaboong -0.303623
# 11   2004_MAM   mor_kot_amudat -0.074817
# 12   2004_MAM         karamoja -0.197176
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2005_MAM', 'bound_name': 'abim', 'mean': -0.77552176}, {'year_month': '2005_MAM', 'bound_name': 'napak', 'mean': -0.4936918}, {'year_month': '2005_MAM', 'bound_name': 'nabilatuk', 'mean': -0.69229513}, {'year_month': '2005_MAM', 'bound_name': 'kotido', 'mean': -0.6849576}, {'year_month': '2005_MAM', 'bound_name': 'moroto', 'mean': -0.7049957}, {'year_month': '2005_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.8708354}, {'year_month': '2005_MAM', 'bound_name': 'kaabong', 'mean': -0.188}, {'year_month': '2005_MAM', 'bound_name': 'karenga', 'mean': -0.09427162}, {'year_month': '2005_MAM', 'bound_name': 'amudat', 'mean': -1.1062453}, {'year_month': '2005_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.64022726}, {'year_month': '2005_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.33051535}, {'year_month': '2005_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.7708554}, {'year_month': '2005_MAM', 'bound_name': 'karamoja', 'mean': -0.56962013}]
#    year_month       bound_name      mean
# 0    2005_MAM             abim -0.775522
# 1    2005_MAM            napak -0.493692
# 2    2005_MAM        nabilatuk -0.692295
# 3    2005_MAM           kotido -0.684958
# 4    2005_MAM           moroto -0.704996
# 5    2005_MAM    nakapiripirit -0.870835
# 6    2005_MAM          kaabong -0.188000
# 7    2005_MAM          karenga -0.094272
# 8    2005_MAM           amudat -1.106245
# 9    2005_MAM    nab_nak_napak -0.640227
# 10   2005_MAM  abi_kar_kaboong -0.330515
# 11   2005_MAM   mor_kot_amudat -0.770855
# 12   2005_MAM         karamoja -0.569620
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2006_MAM', 'bound_name': 'abim', 'mean': 1.6092826}, {'year_month': '2006_MAM', 'bound_name': 'napak', 'mean': 1.8389863}, {'year_month': '2006_MAM', 'bound_name': 'nabilatuk', 'mean': 1.694246}, {'year_month': '2006_MAM', 'bound_name': 'kotido', 'mean': 1.2095762}, {'year_month': '2006_MAM', 'bound_name': 'moroto', 'mean': 0.9224568}, {'year_month': '2006_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.2981583}, {'year_month': '2006_MAM', 'bound_name': 'kaabong', 'mean': 0.7159869}, {'year_month': '2006_MAM', 'bound_name': 'karenga', 'mean': 0.8097037}, {'year_month': '2006_MAM', 'bound_name': 'amudat', 'mean': 0.8515472}, {'year_month': '2006_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.6587255}, {'year_month': '2006_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.991368}, {'year_month': '2006_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.0274112}, {'year_month': '2006_MAM', 'bound_name': 'karamoja', 'mean': 1.2151818}]
#    year_month       bound_name      mean
# 0    2006_MAM             abim  1.609283
# 1    2006_MAM            napak  1.838986
# 2    2006_MAM        nabilatuk  1.694246
# 3    2006_MAM           kotido  1.209576
# 4    2006_MAM           moroto  0.922457
# 5    2006_MAM    nakapiripirit  1.298158
# 6    2006_MAM          kaabong  0.715987
# 7    2006_MAM          karenga  0.809704
# 8    2006_MAM           amudat  0.851547
# 9    2006_MAM    nab_nak_napak  1.658726
# 10   2006_MAM  abi_kar_kaboong  0.991368
# 11   2006_MAM   mor_kot_amudat  1.027411
# 12   2006_MAM         karamoja  1.215182
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2007_MAM', 'bound_name': 'abim', 'mean': 0.13122828}, {'year_month': '2007_MAM', 'bound_name': 'napak', 'mean': -0.09157536}, {'year_month': '2007_MAM', 'bound_name': 'nabilatuk', 'mean': -0.13981968}, {'year_month': '2007_MAM', 'bound_name': 'kotido', 'mean': -0.11868645}, {'year_month': '2007_MAM', 'bound_name': 'moroto', 'mean': 0.14025863}, {'year_month': '2007_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.2544114}, {'year_month': '2007_MAM', 'bound_name': 'kaabong', 'mean': 0.13558497}, {'year_month': '2007_MAM', 'bound_name': 'karenga', 'mean': -0.0739136}, {'year_month': '2007_MAM', 'bound_name': 'amudat', 'mean': -0.06275472}, {'year_month': '2007_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.14684442}, {'year_month': '2007_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.08230216}, {'year_month': '2007_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.0036968803}, {'year_month': '2007_MAM', 'bound_name': 'karamoja', 'mean': -0.018051164}]
#    year_month       bound_name      mean
# 0    2007_MAM             abim  0.131228
# 1    2007_MAM            napak -0.091575
# 2    2007_MAM        nabilatuk -0.139820
# 3    2007_MAM           kotido -0.118686
# 4    2007_MAM           moroto  0.140259
# 5    2007_MAM    nakapiripirit -0.254411
# 6    2007_MAM          kaabong  0.135585
# 7    2007_MAM          karenga -0.073914
# 8    2007_MAM           amudat -0.062755
# 9    2007_MAM    nab_nak_napak -0.146844
# 10   2007_MAM  abi_kar_kaboong  0.082302
# 11   2007_MAM   mor_kot_amudat -0.003697
# 12   2007_MAM         karamoja -0.018051
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2008_MAM', 'bound_name': 'abim', 'mean': -1.0377392}, {'year_month': '2008_MAM', 'bound_name': 'napak', 'mean': -0.9543527}, {'year_month': '2008_MAM', 'bound_name': 'nabilatuk', 'mean': -1.0107378}, {'year_month': '2008_MAM', 'bound_name': 'kotido', 'mean': -0.7574789}, {'year_month': '2008_MAM', 'bound_name': 'moroto', 'mean': -0.82537067}, {'year_month': '2008_MAM', 'bound_name': 'nakapiripirit', 'mean': -1.1063987}, {'year_month': '2008_MAM', 'bound_name': 'kaabong', 'mean': -0.6880326}, {'year_month': '2008_MAM', 'bound_name': 'karenga', 'mean': -0.49462965}, {'year_month': '2008_MAM', 'bound_name': 'amudat', 'mean': -0.9514152}, {'year_month': '2008_MAM', 'bound_name': 'nab_nak_napak', 'mean': -1.0083776}, {'year_month': '2008_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.7386686}, {'year_month': '2008_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.8207335}, {'year_month': '2008_MAM', 'bound_name': 'karamoja', 'mean': -0.8506702}]
#    year_month       bound_name      mean
# 0    2008_MAM             abim -1.037739
# 1    2008_MAM            napak -0.954353
# 2    2008_MAM        nabilatuk -1.010738
# 3    2008_MAM           kotido -0.757479
# 4    2008_MAM           moroto -0.825371
# 5    2008_MAM    nakapiripirit -1.106399
# 6    2008_MAM          kaabong -0.688033
# 7    2008_MAM          karenga -0.494630
# 8    2008_MAM           amudat -0.951415
# 9    2008_MAM    nab_nak_napak -1.008378
# 10   2008_MAM  abi_kar_kaboong -0.738669
# 11   2008_MAM   mor_kot_amudat -0.820733
# 12   2008_MAM         karamoja -0.850670
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2009_MAM', 'bound_name': 'abim', 'mean': -0.3417065}, {'year_month': '2009_MAM', 'bound_name': 'napak', 'mean': -0.2527329}, {'year_month': '2009_MAM', 'bound_name': 'nabilatuk', 'mean': -0.3022541}, {'year_month': '2009_MAM', 'bound_name': 'kotido', 'mean': -0.4106356}, {'year_month': '2009_MAM', 'bound_name': 'moroto', 'mean': -0.7104871}, {'year_month': '2009_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.2698481}, {'year_month': '2009_MAM', 'bound_name': 'kaabong', 'mean': -0.7798659}, {'year_month': '2009_MAM', 'bound_name': 'karenga', 'mean': -0.7064136}, {'year_month': '2009_MAM', 'bound_name': 'amudat', 'mean': -0.5358113}, {'year_month': '2009_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.26802272}, {'year_month': '2009_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.6379632}, {'year_month': '2009_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.554946}, {'year_month': '2009_MAM', 'bound_name': 'karamoja', 'mean': -0.49377084}]
#    year_month       bound_name      mean
# 0    2009_MAM             abim -0.341707
# 1    2009_MAM            napak -0.252733
# 2    2009_MAM        nabilatuk -0.302254
# 3    2009_MAM           kotido -0.410636
# 4    2009_MAM           moroto -0.710487
# 5    2009_MAM    nakapiripirit -0.269848
# 6    2009_MAM          kaabong -0.779866
# 7    2009_MAM          karenga -0.706414
# 8    2009_MAM           amudat -0.535811
# 9    2009_MAM    nab_nak_napak -0.268023
# 10   2009_MAM  abi_kar_kaboong -0.637963
# 11   2009_MAM   mor_kot_amudat -0.554946
# 12   2009_MAM         karamoja -0.493771
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# ...
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2018_MAM', 'bound_name': 'abim', 'mean': 1.0932609}, {'year_month': '2018_MAM', 'bound_name': 'napak', 'mean': 1.2746301}, {'year_month': '2018_MAM', 'bound_name': 'nabilatuk', 'mean': 1.0732296}, {'year_month': '2018_MAM', 'bound_name': 'kotido', 'mean': 0.65856785}, {'year_month': '2018_MAM', 'bound_name': 'moroto', 'mean': 0.29293963}, {'year_month': '2018_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.3159493}, {'year_month': '2018_MAM', 'bound_name': 'kaabong', 'mean': 0.41156211}, {'year_month': '2018_MAM', 'bound_name': 'karenga', 'mean': 0.39992595}, {'year_month': '2018_MAM', 'bound_name': 'amudat', 'mean': 1.410264}, {'year_month': '2018_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.2430874}, {'year_month': '2018_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.6010521}, {'year_month': '2018_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.64960283}, {'year_month': '2018_MAM', 'bound_name': 'karamoja', 'mean': 0.82080317}]
#    year_month       bound_name      mean
# 0    2018_MAM             abim  1.093261
# 1    2018_MAM            napak  1.274630
# 2    2018_MAM        nabilatuk  1.073230
# 3    2018_MAM           kotido  0.658568
# 4    2018_MAM           moroto  0.292940
# 5    2018_MAM    nakapiripirit  1.315949
# 6    2018_MAM          kaabong  0.411562
# 7    2018_MAM          karenga  0.399926
# 8    2018_MAM           amudat  1.410264
# 9    2018_MAM    nab_nak_napak  1.243087
# 10   2018_MAM  abi_kar_kaboong  0.601052
# 11   2018_MAM   mor_kot_amudat  0.649603
# 12   2018_MAM         karamoja  0.820803
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2019_MAM', 'bound_name': 'abim', 'mean': 1.484413}, {'year_month': '2019_MAM', 'bound_name': 'napak', 'mean': 2.024154}, {'year_month': '2019_MAM', 'bound_name': 'nabilatuk', 'mean': 1.8831805}, {'year_month': '2019_MAM', 'bound_name': 'kotido', 'mean': 1.257055}, {'year_month': '2019_MAM', 'bound_name': 'moroto', 'mean': 1.4364828}, {'year_month': '2019_MAM', 'bound_name': 'nakapiripirit', 'mean': 2.2464874}, {'year_month': '2019_MAM', 'bound_name': 'kaabong', 'mean': 1.3716372}, {'year_month': '2019_MAM', 'bound_name': 'karenga', 'mean': 1.594074}, {'year_month': '2019_MAM', 'bound_name': 'amudat', 'mean': 2.593481}, {'year_month': '2019_MAM', 'bound_name': 'nab_nak_napak', 'mean': 2.0555}, {'year_month': '2019_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.4587317}, {'year_month': '2019_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.5763729}, {'year_month': '2019_MAM', 'bound_name': 'karamoja', 'mean': 1.6861385}]
#    year_month       bound_name      mean
# 0    2019_MAM             abim  1.484413
# 1    2019_MAM            napak  2.024154
# 2    2019_MAM        nabilatuk  1.883180
# 3    2019_MAM           kotido  1.257055
# 4    2019_MAM           moroto  1.436483
# 5    2019_MAM    nakapiripirit  2.246487
# 6    2019_MAM          kaabong  1.371637
# 7    2019_MAM          karenga  1.594074
# 8    2019_MAM           amudat  2.593481
# 9    2019_MAM    nab_nak_napak  2.055500
# 10   2019_MAM  abi_kar_kaboong  1.458732
# 11   2019_MAM   mor_kot_amudat  1.576373
# 12   2019_MAM         karamoja  1.686139
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2020_MAM', 'bound_name': 'abim', 'mean': 2.2126195}, {'year_month': '2020_MAM', 'bound_name': 'napak', 'mean': 2.969993}, {'year_month': '2020_MAM', 'bound_name': 'nabilatuk', 'mean': 2.9830983}, {'year_month': '2020_MAM', 'bound_name': 'kotido', 'mean': 2.2769957}, {'year_month': '2020_MAM', 'bound_name': 'moroto', 'mean': 2.9697242}, {'year_month': '2020_MAM', 'bound_name': 'nakapiripirit', 'mean': 3.5449367}, {'year_month': '2020_MAM', 'bound_name': 'kaabong', 'mean': 2.58732}, {'year_month': '2020_MAM', 'bound_name': 'karenga', 'mean': 2.6186543}, {'year_month': '2020_MAM', 'bound_name': 'amudat', 'mean': 4.189094}, {'year_month': '2020_MAM', 'bound_name': 'nab_nak_napak', 'mean': 3.131601}, {'year_month': '2020_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 2.489362}, {'year_month': '2020_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 2.9100888}, {'year_month': '2020_MAM', 'bound_name': 'karamoja', 'mean': 2.8279927}]
#    year_month       bound_name      mean
# 0    2020_MAM             abim  2.212620
# 1    2020_MAM            napak  2.969993
# 2    2020_MAM        nabilatuk  2.983098
# 3    2020_MAM           kotido  2.276996
# 4    2020_MAM           moroto  2.969724
# 5    2020_MAM    nakapiripirit  3.544937
# 6    2020_MAM          kaabong  2.587320
# 7    2020_MAM          karenga  2.618654
# 8    2020_MAM           amudat  4.189094
# 9    2020_MAM    nab_nak_napak  3.131601
# 10   2020_MAM  abi_kar_kaboong  2.489362
# 11   2020_MAM   mor_kot_amudat  2.910089
# 12   2020_MAM         karamoja  2.827993
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2021_MAM', 'bound_name': 'abim', 'mean': 3.460913}, {'year_month': '2021_MAM', 'bound_name': 'napak', 'mean': 4.357305}, {'year_month': '2021_MAM', 'bound_name': 'nabilatuk', 'mean': 4.4885006}, {'year_month': '2021_MAM', 'bound_name': 'kotido', 'mean': 3.7101693}, {'year_month': '2021_MAM', 'bound_name': 'moroto', 'mean': 4.368142}, {'year_month': '2021_MAM', 'bound_name': 'nakapiripirit', 'mean': 5.2801647}, {'year_month': '2021_MAM', 'bound_name': 'kaabong', 'mean': 4.078611}, {'year_month': '2021_MAM', 'bound_name': 'karenga', 'mean': 4.270574}, {'year_month': '2021_MAM', 'bound_name': 'amudat', 'mean': 5.9467645}, {'year_month': '2021_MAM', 'bound_name': 'nab_nak_napak', 'mean': 4.640203}, {'year_month': '2021_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 3.9519875}, {'year_month': '2021_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 4.389139}, {'year_month': '2021_MAM', 'bound_name': 'karamoja', 'mean': 4.3104887}]
#    year_month       bound_name      mean
# 0    2021_MAM             abim  3.460913
# 1    2021_MAM            napak  4.357305
# 2    2021_MAM        nabilatuk  4.488501
# 3    2021_MAM           kotido  3.710169
# 4    2021_MAM           moroto  4.368142
# 5    2021_MAM    nakapiripirit  5.280165
# 6    2021_MAM          kaabong  4.078611
# 7    2021_MAM          karenga  4.270574
# 8    2021_MAM           amudat  5.946764
# 9    2021_MAM    nab_nak_napak  4.640203
# 10   2021_MAM  abi_kar_kaboong  3.951988
# 11   2021_MAM   mor_kot_amudat  4.389139
# 12   2021_MAM         karamoja  4.310489

# %%
folder_list=['IGAD_Standardized_Precipitation_Index_SPI1','IGAD_Standardized_Precipitation_Index_SPI3',
            'IGAD_Standardized_Precipitation_Index_SPI6','IGAD_Standardized_Precipitation_Index_SPI9',
            'IGAD_Standardized_Precipitation_Index_SPI12','IGAD_Standardized_Precipitation_Index_SPI24',
            'IGAD_Standardized_Precipitation_Index_SPI48']

var_list=['spg01','spg03','spg06','spg09','spg12','spg24','spg48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for OND
start_month_index=9
end_month_index=11
    
for folder_str,var_str in zip(folder_list,var_list):
    mdb1=make_csv_season(geo_db2,admin_bound_list,folder_str,var_str,start_month_index,end_month_index)
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2000_OND', 'bound_name': 'abim', 'mean': 0.56602174}, {'year_month': '2000_OND', 'bound_name': 'napak', 'mean': 0.7012774}, {'year_month': '2000_OND', 'bound_name': 'nabilatuk', 'mean': 0.62853277}, {'year_month': '2000_OND', 'bound_name': 'kotido', 'mean': 0.645572}, {'year_month': '2000_OND', 'bound_name': 'moroto', 'mean': 0.63843536}, {'year_month': '2000_OND', 'bound_name': 'nakapiripirit', 'mean': 0.5327152}, {'year_month': '2000_OND', 'bound_name': 'kaabong', 'mean': 0.5241144}, {'year_month': '2000_OND', 'bound_name': 'karenga', 'mean': 0.42306176}, {'year_month': '2000_OND', 'bound_name': 'amudat', 'mean': 0.5130848}, {'year_month': '2000_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.63920105}, {'year_month': '2000_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.51083285}, {'year_month': '2000_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.6182213}, {'year_month': '2000_OND', 'bound_name': 'karamoja', 'mean': 0.5859539}]
#    year_month       bound_name      mean
# 0    2000_OND             abim  0.566022
# 1    2000_OND            napak  0.701277
# 2    2000_OND        nabilatuk  0.628533
# 3    2000_OND           kotido  0.645572
# 4    2000_OND           moroto  0.638435
# 5    2000_OND    nakapiripirit  0.532715
# 6    2000_OND          kaabong  0.524114
# 7    2000_OND          karenga  0.423062
# 8    2000_OND           amudat  0.513085
# 9    2000_OND    nab_nak_napak  0.639201
# 10   2000_OND  abi_kar_kaboong  0.510833
# 11   2000_OND   mor_kot_amudat  0.618221
# 12   2000_OND         karamoja  0.585954
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2001_OND', 'bound_name': 'abim', 'mean': 1.1044837}, {'year_month': '2001_OND', 'bound_name': 'napak', 'mean': 1.0357945}, {'year_month': '2001_OND', 'bound_name': 'nabilatuk', 'mean': 0.8613032}, {'year_month': '2001_OND', 'bound_name': 'kotido', 'mean': 1.1496907}, {'year_month': '2001_OND', 'bound_name': 'moroto', 'mean': 0.888444}, {'year_month': '2001_OND', 'bound_name': 'nakapiripirit', 'mean': 0.99867713}, {'year_month': '2001_OND', 'bound_name': 'kaabong', 'mean': 0.9713039}, {'year_month': '2001_OND', 'bound_name': 'karenga', 'mean': 1.0699074}, {'year_month': '2001_OND', 'bound_name': 'amudat', 'mean': 0.92353785}, {'year_month': '2001_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.98832524}, {'year_month': '2001_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.0333881}, {'year_month': '2001_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.0023364}, {'year_month': '2001_OND', 'bound_name': 'karamoja', 'mean': 1.0091391}]
#    year_month       bound_name      mean
# 0    2001_OND             abim  1.104484
# 1    2001_OND            napak  1.035794
# 2    2001_OND        nabilatuk  0.861303
# 3    2001_OND           kotido  1.149691
# 4    2001_OND           moroto  0.888444
# 5    2001_OND    nakapiripirit  0.998677
# 6    2001_OND          kaabong  0.971304
# 7    2001_OND          karenga  1.069907
# 8    2001_OND           amudat  0.923538
# 9    2001_OND    nab_nak_napak  0.988325
# 10   2001_OND  abi_kar_kaboong  1.033388
# 11   2001_OND   mor_kot_amudat  1.002336
# 12   2001_OND         karamoja  1.009139
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2002_OND', 'bound_name': 'abim', 'mean': 0.24115218}, {'year_month': '2002_OND', 'bound_name': 'napak', 'mean': 0.2354452}, {'year_month': '2002_OND', 'bound_name': 'nabilatuk', 'mean': 0.36518028}, {'year_month': '2002_OND', 'bound_name': 'kotido', 'mean': 0.100406766}, {'year_month': '2002_OND', 'bound_name': 'moroto', 'mean': -0.16161206}, {'year_month': '2002_OND', 'bound_name': 'nakapiripirit', 'mean': 0.49134174}, {'year_month': '2002_OND', 'bound_name': 'kaabong', 'mean': -0.22738563}, {'year_month': '2002_OND', 'bound_name': 'karenga', 'mean': -0.16351235}, {'year_month': '2002_OND', 'bound_name': 'amudat', 'mean': 0.19188678}, {'year_month': '2002_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.3338007}, {'year_month': '2002_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.079289876}, {'year_month': '2002_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.011397199}, {'year_month': '2002_OND', 'bound_name': 'karamoja', 'mean': 0.08107842}]
#    year_month       bound_name      mean
# 0    2002_OND             abim  0.241152
# 1    2002_OND            napak  0.235445
# 2    2002_OND        nabilatuk  0.365180
# 3    2002_OND           kotido  0.100407
# 4    2002_OND           moroto -0.161612
# 5    2002_OND    nakapiripirit  0.491342
# 6    2002_OND          kaabong -0.227386
# 7    2002_OND          karenga -0.163512
# 8    2002_OND           amudat  0.191887
# 9    2002_OND    nab_nak_napak  0.333801
# 10   2002_OND  abi_kar_kaboong -0.079290
# 11   2002_OND   mor_kot_amudat  0.011397
# 12   2002_OND         karamoja  0.081078
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2003_OND', 'bound_name': 'abim', 'mean': -0.67858696}, {'year_month': '2003_OND', 'bound_name': 'napak', 'mean': -0.7054281}, {'year_month': '2003_OND', 'bound_name': 'nabilatuk', 'mean': -0.65200007}, {'year_month': '2003_OND', 'bound_name': 'kotido', 'mean': -0.7631991}, {'year_month': '2003_OND', 'bound_name': 'moroto', 'mean': -0.90293103}, {'year_month': '2003_OND', 'bound_name': 'nakapiripirit', 'mean': -0.6125949}, {'year_month': '2003_OND', 'bound_name': 'kaabong', 'mean': -0.77536273}, {'year_month': '2003_OND', 'bound_name': 'karenga', 'mean': -0.56433946}, {'year_month': '2003_OND', 'bound_name': 'amudat', 'mean': -0.8211886}, {'year_month': '2003_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.66838986}, {'year_month': '2003_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.69561964}, {'year_month': '2003_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.830385}, {'year_month': '2003_OND', 'bound_name': 'karamoja', 'mean': -0.72998}]
#    year_month       bound_name      mean
# 0    2003_OND             abim -0.678587
# 1    2003_OND            napak -0.705428
# 2    2003_OND        nabilatuk -0.652000
# 3    2003_OND           kotido -0.763199
# 4    2003_OND           moroto -0.902931
# 5    2003_OND    nakapiripirit -0.612595
# 6    2003_OND          kaabong -0.775363
# 7    2003_OND          karenga -0.564339
# 8    2003_OND           amudat -0.821189
# 9    2003_OND    nab_nak_napak -0.668390
# 10   2003_OND  abi_kar_kaboong -0.695620
# 11   2003_OND   mor_kot_amudat -0.830385
# 12   2003_OND         karamoja -0.729980
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2004_OND', 'bound_name': 'abim', 'mean': -0.15052171}, {'year_month': '2004_OND', 'bound_name': 'napak', 'mean': 0.07771918}, {'year_month': '2004_OND', 'bound_name': 'nabilatuk', 'mean': 0.112540975}, {'year_month': '2004_OND', 'bound_name': 'kotido', 'mean': 0.12706779}, {'year_month': '2004_OND', 'bound_name': 'moroto', 'mean': 0.28153878}, {'year_month': '2004_OND', 'bound_name': 'nakapiripirit', 'mean': 0.20829122}, {'year_month': '2004_OND', 'bound_name': 'kaabong', 'mean': 0.3602451}, {'year_month': '2004_OND', 'bound_name': 'karenga', 'mean': 0.2154938}, {'year_month': '2004_OND', 'bound_name': 'amudat', 'mean': 0.49573582}, {'year_month': '2004_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.12121331}, {'year_month': '2004_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.18013652}, {'year_month': '2004_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.25758365}, {'year_month': '2004_OND', 'bound_name': 'karamoja', 'mean': 0.18611564}]
#    year_month       bound_name      mean
# 0    2004_OND             abim -0.150522
# 1    2004_OND            napak  0.077719
# 2    2004_OND        nabilatuk  0.112541
# 3    2004_OND           kotido  0.127068
# 4    2004_OND           moroto  0.281539
# 5    2004_OND    nakapiripirit  0.208291
# 6    2004_OND          kaabong  0.360245
# 7    2004_OND          karenga  0.215494
# 8    2004_OND           amudat  0.495736
# 9    2004_OND    nab_nak_napak  0.121213
# 10   2004_OND  abi_kar_kaboong  0.180137
# 11   2004_OND   mor_kot_amudat  0.257584
# 12   2004_OND         karamoja  0.186116
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2005_OND', 'bound_name': 'abim', 'mean': -1.2573532}, {'year_month': '2005_OND', 'bound_name': 'napak', 'mean': -1.0164452}, {'year_month': '2005_OND', 'bound_name': 'nabilatuk', 'mean': -0.66518855}, {'year_month': '2005_OND', 'bound_name': 'kotido', 'mean': -1.1792754}, {'year_month': '2005_OND', 'bound_name': 'moroto', 'mean': -0.83928007}, {'year_month': '2005_OND', 'bound_name': 'nakapiripirit', 'mean': -0.36460128}, {'year_month': '2005_OND', 'bound_name': 'kaabong', 'mean': -1.0000197}, {'year_month': '2005_OND', 'bound_name': 'karenga', 'mean': -0.9270741}, {'year_month': '2005_OND', 'bound_name': 'amudat', 'mean': -0.50581133}, {'year_month': '2005_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.76147205}, {'year_month': '2005_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -1.0545169}, {'year_month': '2005_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.9174878}, {'year_month': '2005_OND', 'bound_name': 'karamoja', 'mean': -0.9175445}]
#    year_month       bound_name      mean
# 0    2005_OND             abim -1.257353
# 1    2005_OND            napak -1.016445
# 2    2005_OND        nabilatuk -0.665189
# 3    2005_OND           kotido -1.179275
# 4    2005_OND           moroto -0.839280
# 5    2005_OND    nakapiripirit -0.364601
# 6    2005_OND          kaabong -1.000020
# 7    2005_OND          karenga -0.927074
# 8    2005_OND           amudat -0.505811
# 9    2005_OND    nab_nak_napak -0.761472
# 10   2005_OND  abi_kar_kaboong -1.054517
# 11   2005_OND   mor_kot_amudat -0.917488
# 12   2005_OND         karamoja -0.917544
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2006_OND', 'bound_name': 'abim', 'mean': 1.4445653}, {'year_month': '2006_OND', 'bound_name': 'napak', 'mean': 1.5768493}, {'year_month': '2006_OND', 'bound_name': 'nabilatuk', 'mean': 1.5789508}, {'year_month': '2006_OND', 'bound_name': 'kotido', 'mean': 1.5196102}, {'year_month': '2006_OND', 'bound_name': 'moroto', 'mean': 1.8405346}, {'year_month': '2006_OND', 'bound_name': 'nakapiripirit', 'mean': 1.4068861}, {'year_month': '2006_OND', 'bound_name': 'kaabong', 'mean': 1.8100097}, {'year_month': '2006_OND', 'bound_name': 'karenga', 'mean': 1.3393271}, {'year_month': '2006_OND', 'bound_name': 'amudat', 'mean': 1.6026319}, {'year_month': '2006_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.5303496}, {'year_month': '2006_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.5899295}, {'year_month': '2006_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.6646533}, {'year_month': '2006_OND', 'bound_name': 'karamoja', 'mean': 1.5948304}]
#    year_month       bound_name      mean
# 0    2006_OND             abim  1.444565
# 1    2006_OND            napak  1.576849
# 2    2006_OND        nabilatuk  1.578951
# 3    2006_OND           kotido  1.519610
# 4    2006_OND           moroto  1.840535
# 5    2006_OND    nakapiripirit  1.406886
# 6    2006_OND          kaabong  1.810010
# 7    2006_OND          karenga  1.339327
# 8    2006_OND           amudat  1.602632
# 9    2006_OND    nab_nak_napak  1.530350
# 10   2006_OND  abi_kar_kaboong  1.589929
# 11   2006_OND   mor_kot_amudat  1.664653
# 12   2006_OND         karamoja  1.594830
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2007_OND', 'bound_name': 'abim', 'mean': -1.7348641}, {'year_month': '2007_OND', 'bound_name': 'napak', 'mean': -1.4622467}, {'year_month': '2007_OND', 'bound_name': 'nabilatuk', 'mean': -1.4658278}, {'year_month': '2007_OND', 'bound_name': 'kotido', 'mean': -1.116784}, {'year_month': '2007_OND', 'bound_name': 'moroto', 'mean': -1.1068664}, {'year_month': '2007_OND', 'bound_name': 'nakapiripirit', 'mean': -1.5232469}, {'year_month': '2007_OND', 'bound_name': 'kaabong', 'mean': -0.5377647}, {'year_month': '2007_OND', 'bound_name': 'karenga', 'mean': -0.60334563}, {'year_month': '2007_OND', 'bound_name': 'amudat', 'mean': -1.343736}, {'year_month': '2007_OND', 'bound_name': 'nab_nak_napak', 'mean': -1.4798601}, {'year_month': '2007_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.8918911}, {'year_month': '2007_OND', 'bound_name': 'mor_kot_amudat', 'mean': -1.1546865}, {'year_month': '2007_OND', 'bound_name': 'karamoja', 'mean': -1.1628381}]
#    year_month       bound_name      mean
# 0    2007_OND             abim -1.734864
# 1    2007_OND            napak -1.462247
# 2    2007_OND        nabilatuk -1.465828
# 3    2007_OND           kotido -1.116784
# 4    2007_OND           moroto -1.106866
# 5    2007_OND    nakapiripirit -1.523247
# 6    2007_OND          kaabong -0.537765
# 7    2007_OND          karenga -0.603346
# 8    2007_OND           amudat -1.343736
# 9    2007_OND    nab_nak_napak -1.479860
# 10   2007_OND  abi_kar_kaboong -0.891891
# 11   2007_OND   mor_kot_amudat -1.154686
# 12   2007_OND         karamoja -1.162838
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2008_OND', 'bound_name': 'abim', 'mean': 0.111706495}, {'year_month': '2008_OND', 'bound_name': 'napak', 'mean': 0.63525337}, {'year_month': '2008_OND', 'bound_name': 'nabilatuk', 'mean': 0.7092623}, {'year_month': '2008_OND', 'bound_name': 'kotido', 'mean': 0.37413135}, {'year_month': '2008_OND', 'bound_name': 'moroto', 'mean': 0.79595256}, {'year_month': '2008_OND', 'bound_name': 'nakapiripirit', 'mean': 0.69023424}, {'year_month': '2008_OND', 'bound_name': 'kaabong', 'mean': 0.6455915}, {'year_month': '2008_OND', 'bound_name': 'karenga', 'mean': 0.515463}, {'year_month': '2008_OND', 'bound_name': 'amudat', 'mean': 0.9091227}, {'year_month': '2008_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.66622555}, {'year_month': '2008_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.46259204}, {'year_month': '2008_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.64341986}, {'year_month': '2008_OND', 'bound_name': 'karamoja', 'mean': 0.5851024}]
#    year_month       bound_name      mean
# 0    2008_OND             abim  0.111706
# 1    2008_OND            napak  0.635253
# 2    2008_OND        nabilatuk  0.709262
# 3    2008_OND           kotido  0.374131
# 4    2008_OND           moroto  0.795953
# 5    2008_OND    nakapiripirit  0.690234
# 6    2008_OND          kaabong  0.645591
# 7    2008_OND          karenga  0.515463
# 8    2008_OND           amudat  0.909123
# 9    2008_OND    nab_nak_napak  0.666226
# 10   2008_OND  abi_kar_kaboong  0.462592
# 11   2008_OND   mor_kot_amudat  0.643420
# 12   2008_OND         karamoja  0.585102
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2009_OND', 'bound_name': 'abim', 'mean': -0.10933696}, {'year_month': '2009_OND', 'bound_name': 'napak', 'mean': 0.08344179}, {'year_month': '2009_OND', 'bound_name': 'nabilatuk', 'mean': 0.052901637}, {'year_month': '2009_OND', 'bound_name': 'kotido', 'mean': -0.5081907}, {'year_month': '2009_OND', 'bound_name': 'moroto', 'mean': -0.34887928}, {'year_month': '2009_OND', 'bound_name': 'nakapiripirit', 'mean': -0.0899367}, {'year_month': '2009_OND', 'bound_name': 'kaabong', 'mean': -0.110137254}, {'year_month': '2009_OND', 'bound_name': 'karenga', 'mean': -0.3239877}, {'year_month': '2009_OND', 'bound_name': 'amudat', 'mean': -0.23761319}, {'year_month': '2009_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.029036716}, {'year_month': '2009_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.16304602}, {'year_month': '2009_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.39383274}, {'year_month': '2009_OND', 'bound_name': 'karamoja', 'mean': -0.1756157}]
#    year_month       bound_name      mean
# 0    2009_OND             abim -0.109337
# 1    2009_OND            napak  0.083442
# 2    2009_OND        nabilatuk  0.052902
# 3    2009_OND           kotido -0.508191
# 4    2009_OND           moroto -0.348879
# 5    2009_OND    nakapiripirit -0.089937
# 6    2009_OND          kaabong -0.110137
# 7    2009_OND          karenga -0.323988
# 8    2009_OND           amudat -0.237613
# 9    2009_OND    nab_nak_napak  0.029037
# 10   2009_OND  abi_kar_kaboong -0.163046
# 11   2009_OND   mor_kot_amudat -0.393833
# 12   2009_OND         karamoja -0.175616
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# ...
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2018_OND', 'bound_name': 'abim', 'mean': 1.4867661}, {'year_month': '2018_OND', 'bound_name': 'napak', 'mean': 1.9374862}, {'year_month': '2018_OND', 'bound_name': 'nabilatuk', 'mean': 1.7588359}, {'year_month': '2018_OND', 'bound_name': 'kotido', 'mean': 1.2724959}, {'year_month': '2018_OND', 'bound_name': 'moroto', 'mean': 1.3619612}, {'year_month': '2018_OND', 'bound_name': 'nakapiripirit', 'mean': 1.9954429}, {'year_month': '2018_OND', 'bound_name': 'kaabong', 'mean': 1.3543432}, {'year_month': '2018_OND', 'bound_name': 'karenga', 'mean': 1.5307283}, {'year_month': '2018_OND', 'bound_name': 'amudat', 'mean': 2.292047}, {'year_month': '2018_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.9153916}, {'year_month': '2018_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.4355398}, {'year_month': '2018_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.4969355}, {'year_month': '2018_OND', 'bound_name': 'karamoja', 'mean': 1.6077958}]
#    year_month       bound_name      mean
# 0    2018_OND             abim  1.486766
# 1    2018_OND            napak  1.937486
# 2    2018_OND        nabilatuk  1.758836
# 3    2018_OND           kotido  1.272496
# 4    2018_OND           moroto  1.361961
# 5    2018_OND    nakapiripirit  1.995443
# 6    2018_OND          kaabong  1.354343
# 7    2018_OND          karenga  1.530728
# 8    2018_OND           amudat  2.292047
# 9    2018_OND    nab_nak_napak  1.915392
# 10   2018_OND  abi_kar_kaboong  1.435540
# 11   2018_OND   mor_kot_amudat  1.496935
# 12   2018_OND         karamoja  1.607796
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2019_OND', 'bound_name': 'abim', 'mean': 1.4889566}, {'year_month': '2019_OND', 'bound_name': 'napak', 'mean': 2.3692944}, {'year_month': '2019_OND', 'bound_name': 'nabilatuk', 'mean': 2.413836}, {'year_month': '2019_OND', 'bound_name': 'kotido', 'mean': 1.7039449}, {'year_month': '2019_OND', 'bound_name': 'moroto', 'mean': 2.3761768}, {'year_month': '2019_OND', 'bound_name': 'nakapiripirit', 'mean': 2.908095}, {'year_month': '2019_OND', 'bound_name': 'kaabong', 'mean': 2.1192548}, {'year_month': '2019_OND', 'bound_name': 'karenga', 'mean': 2.180926}, {'year_month': '2019_OND', 'bound_name': 'amudat', 'mean': 3.4394057}, {'year_month': '2019_OND', 'bound_name': 'nab_nak_napak', 'mean': 2.5276241}, {'year_month': '2019_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.9567025}, {'year_month': '2019_OND', 'bound_name': 'mor_kot_amudat', 'mean': 2.296134}, {'year_month': '2019_OND', 'bound_name': 'karamoja', 'mean': 2.246692}]
#    year_month       bound_name      mean
# 0    2019_OND             abim  1.488957
# 1    2019_OND            napak  2.369294
# 2    2019_OND        nabilatuk  2.413836
# 3    2019_OND           kotido  1.703945
# 4    2019_OND           moroto  2.376177
# 5    2019_OND    nakapiripirit  2.908095
# 6    2019_OND          kaabong  2.119255
# 7    2019_OND          karenga  2.180926
# 8    2019_OND           amudat  3.439406
# 9    2019_OND    nab_nak_napak  2.527624
# 10   2019_OND  abi_kar_kaboong  1.956702
# 11   2019_OND   mor_kot_amudat  2.296134
# 12   2019_OND         karamoja  2.246692
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# []
# [{'year_month': '2020_OND', 'bound_name': 'abim', 'mean': 3.0687554}, {'year_month': '2020_OND', 'bound_name': 'napak', 'mean': 3.9143183}, {'year_month': '2020_OND', 'bound_name': 'nabilatuk', 'mean': 4.030598}, {'year_month': '2020_OND', 'bound_name': 'kotido', 'mean': 3.4486694}, {'year_month': '2020_OND', 'bound_name': 'moroto', 'mean': 4.2100773}, {'year_month': '2020_OND', 'bound_name': 'nakapiripirit', 'mean': 4.7747912}, {'year_month': '2020_OND', 'bound_name': 'kaabong', 'mean': 3.9007876}, {'year_month': '2020_OND', 'bound_name': 'karenga', 'mean': 4.07221}, {'year_month': '2020_OND', 'bound_name': 'amudat', 'mean': 5.5623493}, {'year_month': '2020_OND', 'bound_name': 'nab_nak_napak', 'mean': 4.176802}, {'year_month': '2020_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 3.7085736}, {'year_month': '2020_OND', 'bound_name': 'mor_kot_amudat', 'mean': 4.146747}, {'year_month': '2020_OND', 'bound_name': 'karamoja', 'mean': 3.997416}]
#    year_month       bound_name      mean
# 0    2020_OND             abim  3.068755
# 1    2020_OND            napak  3.914318
# 2    2020_OND        nabilatuk  4.030598
# 3    2020_OND           kotido  3.448669
# 4    2020_OND           moroto  4.210077
# 5    2020_OND    nakapiripirit  4.774791
# 6    2020_OND          kaabong  3.900788
# 7    2020_OND          karenga  4.072210
# 8    2020_OND           amudat  5.562349
# 9    2020_OND    nab_nak_napak  4.176802
# 10   2020_OND  abi_kar_kaboong  3.708574
# 11   2020_OND   mor_kot_amudat  4.146747
# 12   2020_OND         karamoja  3.997416
# []
# [{'year_month': '2021_OND', 'bound_name': 'abim', 'mean': 1.2513044}, {'year_month': '2021_OND', 'bound_name': 'napak', 'mean': 2.3105686}, {'year_month': '2021_OND', 'bound_name': 'nabilatuk', 'mean': 2.3822951}, {'year_month': '2021_OND', 'bound_name': 'kotido', 'mean': 1.7381145}, {'year_month': '2021_OND', 'bound_name': 'moroto', 'mean': 2.4354913}, {'year_month': '2021_OND', 'bound_name': 'nakapiripirit', 'mean': 2.6580002}, {'year_month': '2021_OND', 'bound_name': 'kaabong', 'mean': 2.2131734}, {'year_month': '2021_OND', 'bound_name': 'karenga', 'mean': 2.6035557}, {'year_month': '2021_OND', 'bound_name': 'amudat', 'mean': 3.206}, {'year_month': '2021_OND', 'bound_name': 'nab_nak_napak', 'mean': 2.421836}, {'year_month': '2021_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 2.0387223}, {'year_month': '2021_OND', 'bound_name': 'mor_kot_amudat', 'mean': 2.291054}, {'year_month': '2021_OND', 'bound_name': 'karamoja', 'mean': 2.241158}]
#    year_month       bound_name      mean
# 0    2021_OND             abim  1.251304
# 1    2021_OND            napak  2.310569
# 2    2021_OND        nabilatuk  2.382295
# 3    2021_OND           kotido  1.738114
# 4    2021_OND           moroto  2.435491
# 5    2021_OND    nakapiripirit  2.658000
# 6    2021_OND          kaabong  2.213173
# 7    2021_OND          karenga  2.603556
# 8    2021_OND           amudat  3.206000
# 9    2021_OND    nab_nak_napak  2.421836
# 10   2021_OND  abi_kar_kaboong  2.038722
# 11   2021_OND   mor_kot_amudat  2.291054
# 12   2021_OND         karamoja  2.241158
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/xarray/coding/times.py:360: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   sample = dates.ravel()[0]

# %% [markdown]
# # SPEI seasonal
#
#
# Data source
#
# https://catalogue.ceda.ac.uk/uuid/bbdfd09a04304158b366777eba0d2aeb

# %% [markdown]
# ## very slow

# %%
import glob
import geopandas as gp
import pandas as pd
import numpy as np

import xarray as xr
import rioxarray

shpfiles=glob.glob('/home/data_folder/karamoja_shapefiles/*/*.shp')

dist_shp=gp.read_file(shpfiles[0])
#dist_shp.plot()
#dist_shp.info()

kara_shp=gp.read_file(shpfiles[1])
#kara_shp.plot()

lh_shp=gp.read_file(shpfiles[2])
#lh_shp.plot()

sc_shp=gp.read_file(shpfiles[3])
#sc_shp.plot()

dist_shp1=dist_shp[['admin2Name','geometry']]
dist_shp1.columns=['admin_name','geometry']
lh_shp1=lh_shp[['livelihood','geometry']]
lh_shp1.columns=['admin_name','geometry']
kara_shp1=kara_shp[['geometry']]
kara_shp1['admin_name']='karamoja'
#kara_shp1.columns=['admin_name','geometry']

geo_db=pd.concat([dist_shp1,lh_shp1,kara_shp1])
geo_db1=geo_db.reset_index()
geo_db2=geo_db1[['admin_name','geometry']]
geo_db2['admin_name1']=geo_db2['admin_name'].str.lower()
admin_bound_list=geo_db2['admin_name1'].tolist()


def region_shp_spei_averager_season(single_row_shp,xds,var_str,start_month_index,end_month_index):
    clipped = xds.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)
    da1=clipped[var_str]
    aa=da1.values
    aa1=aa[start_month_index:end_month_index,:,:]
    aa2=aa1.ravel()
    aa3 = aa2[(aa2 >=-9000)]
    cont_mean=np.mean(aa3)
    return cont_mean



def make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index):
    ncfile_path=f'/home/data_folder/ceda_spei/{ncfilename}.nc'
    month_index_str=get_month_index_str(start_month_index,end_month_index)
    #xds = rioxarray.open_rasterio(ncfile_path)
    xds=xr.open_dataset(ncfile_path)
    xds.rio.write_crs("epsg:4326", inplace=True)
    year_list=np.arange(1981,2016+1,1)
    mdb_cont=[]
    for year_int in year_list:
        #xds_year=xds.loc[dict(time=slice(str(year_int)))]
        xds_year=xds.sel(time=slice(str(year_int),str(year_int)))
        db_cont=[]
        year_cont=[]
        year_str=str(year_int)
        for ab_str in admin_bound_list:
            geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
            single_row_shp=geo_db3        
            cont_mean=region_shp_spei_averager_season(single_row_shp,xds_year,var_str,start_month_index,end_month_index)
            year_month_index_str=f'{year_str}_{month_index_str}'
            ab_dict={}
            ab_dict['year_month']=year_month_index_str
            ab_dict['bound_name']=ab_str
            ab_dict['mean']=cont_mean
            db_cont.append(ab_dict)
        print(year_cont)
        print(db_cont)
        db=pd.DataFrame(db_cont)
        print(db)
        db1=pd.pivot_table(db, values='mean', index=['year_month'], columns=['bound_name'])
        db2=db1.reset_index()
        mdb_cont.append(db2)
        db=[]
        db1=[]
        db2=[]
    mdb1=pd.concat(mdb_cont,axis=0)
    mdb1.to_csv(f'/home/data_folder/spei_seasonal/{ncfilename}_{month_index_str}.csv',index=False)
    mdb1=[]
    #return db
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
ncfile_list=['spei01','spei03','spei06','spei09','spei12','spei24','spei48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for mar to october
start_month_index=2
end_month_index=9

var_str='spei'

for ncfilename in ncfile_list:
    make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index)
# Out:
# []
# [{'year_month': '1981_MAMJJASO', 'bound_name': 'abim', 'mean': 0.2655135}, {'year_month': '1981_MAMJJASO', 'bound_name': 'napak', 'mean': 0.18792722}, {'year_month': '1981_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.12997538}, {'year_month': '1981_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.3579538}, {'year_month': '1981_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.2577894}, {'year_month': '1981_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.15465875}, {'year_month': '1981_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.3404912}, {'year_month': '1981_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.29594105}, {'year_month': '1981_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.13698271}, {'year_month': '1981_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.16637734}, {'year_month': '1981_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.30826268}, {'year_month': '1981_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.27666268}, {'year_month': '1981_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.2530364}]
#        year_month       bound_name      mean
# 0   1981_MAMJJASO             abim  0.265514
# 1   1981_MAMJJASO            napak  0.187927
# 2   1981_MAMJJASO        nabilatuk  0.129975
# 3   1981_MAMJJASO           kotido  0.357954
# 4   1981_MAMJJASO           moroto  0.257789
# 5   1981_MAMJJASO    nakapiripirit  0.154659
# 6   1981_MAMJJASO          kaabong  0.340491
# 7   1981_MAMJJASO          karenga  0.295941
# 8   1981_MAMJJASO           amudat  0.136983
# 9   1981_MAMJJASO    nab_nak_napak  0.166377
# 10  1981_MAMJJASO  abi_kar_kaboong  0.308263
# 11  1981_MAMJJASO   mor_kot_amudat  0.276663
# 12  1981_MAMJJASO         karamoja  0.253036
# []
# [{'year_month': '1982_MAMJJASO', 'bound_name': 'abim', 'mean': 0.05077933}, {'year_month': '1982_MAMJJASO', 'bound_name': 'napak', 'mean': -0.2801493}, {'year_month': '1982_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.33767426}, {'year_month': '1982_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.029538004}, {'year_month': '1982_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.25162995}, {'year_month': '1982_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.33196437}, {'year_month': '1982_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.064389996}, {'year_month': '1982_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.012218872}, {'year_month': '1982_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.39864746}, {'year_month': '1982_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.30673116}, {'year_month': '1982_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.012853504}, {'year_month': '1982_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.16317737}, {'year_month': '1982_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.15433508}]
#        year_month       bound_name      mean
# 0   1982_MAMJJASO             abim  0.050779
# 1   1982_MAMJJASO            napak -0.280149
# 2   1982_MAMJJASO        nabilatuk -0.337674
# 3   1982_MAMJJASO           kotido  0.029538
# 4   1982_MAMJJASO           moroto -0.251630
# 5   1982_MAMJJASO    nakapiripirit -0.331964
# 6   1982_MAMJJASO          kaabong -0.064390
# 7   1982_MAMJJASO          karenga  0.012219
# 8   1982_MAMJJASO           amudat -0.398647
# 9   1982_MAMJJASO    nab_nak_napak -0.306731
# 10  1982_MAMJJASO  abi_kar_kaboong -0.012854
# 11  1982_MAMJJASO   mor_kot_amudat -0.163177
# 12  1982_MAMJJASO         karamoja -0.154335
# []
# [{'year_month': '1983_MAMJJASO', 'bound_name': 'abim', 'mean': -0.19489115}, {'year_month': '1983_MAMJJASO', 'bound_name': 'napak', 'mean': -0.13750431}, {'year_month': '1983_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.19704027}, {'year_month': '1983_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.101313055}, {'year_month': '1983_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.13375048}, {'year_month': '1983_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.23636363}, {'year_month': '1983_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.08435295}, {'year_month': '1983_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.14835063}, {'year_month': '1983_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.21539679}, {'year_month': '1983_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.17750984}, {'year_month': '1983_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.13144906}, {'year_month': '1983_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.13549136}, {'year_month': '1983_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.14739293}]
#        year_month       bound_name      mean
# 0   1983_MAMJJASO             abim -0.194891
# 1   1983_MAMJJASO            napak -0.137504
# 2   1983_MAMJJASO        nabilatuk -0.197040
# 3   1983_MAMJJASO           kotido -0.101313
# 4   1983_MAMJJASO           moroto -0.133750
# 5   1983_MAMJJASO    nakapiripirit -0.236364
# 6   1983_MAMJJASO          kaabong -0.084353
# 7   1983_MAMJJASO          karenga -0.148351
# 8   1983_MAMJJASO           amudat -0.215397
# 9   1983_MAMJJASO    nab_nak_napak -0.177510
# 10  1983_MAMJJASO  abi_kar_kaboong -0.131449
# 11  1983_MAMJJASO   mor_kot_amudat -0.135491
# 12  1983_MAMJJASO         karamoja -0.147393
# []
# [{'year_month': '1984_MAMJJASO', 'bound_name': 'abim', 'mean': -0.4886126}, {'year_month': '1984_MAMJJASO', 'bound_name': 'napak', 'mean': -0.65074897}, {'year_month': '1984_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.7070218}, {'year_month': '1984_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.7608001}, {'year_month': '1984_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.77763706}, {'year_month': '1984_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.83936113}, {'year_month': '1984_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.8917775}, {'year_month': '1984_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.9874186}, {'year_month': '1984_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.8436528}, {'year_month': '1984_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.7148504}, {'year_month': '1984_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.8017645}, {'year_month': '1984_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.7829056}, {'year_month': '1984_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.7680938}]
#        year_month       bound_name      mean
# 0   1984_MAMJJASO             abim -0.488613
# 1   1984_MAMJJASO            napak -0.650749
# 2   1984_MAMJJASO        nabilatuk -0.707022
# 3   1984_MAMJJASO           kotido -0.760800
# 4   1984_MAMJJASO           moroto -0.777637
# 5   1984_MAMJJASO    nakapiripirit -0.839361
# 6   1984_MAMJJASO          kaabong -0.891778
# 7   1984_MAMJJASO          karenga -0.987419
# 8   1984_MAMJJASO           amudat -0.843653
# 9   1984_MAMJJASO    nab_nak_napak -0.714850
# 10  1984_MAMJJASO  abi_kar_kaboong -0.801764
# 11  1984_MAMJJASO   mor_kot_amudat -0.782906
# 12  1984_MAMJJASO         karamoja -0.768094
# []
# [{'year_month': '1985_MAMJJASO', 'bound_name': 'abim', 'mean': 0.13243899}, {'year_month': '1985_MAMJJASO', 'bound_name': 'napak', 'mean': -0.08293238}, {'year_month': '1985_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.015653374}, {'year_month': '1985_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.067687765}, {'year_month': '1985_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.041230377}, {'year_month': '1985_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.23937936}, {'year_month': '1985_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.13361233}, {'year_month': '1985_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.21399416}, {'year_month': '1985_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.12225039}, {'year_month': '1985_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.027124822}, {'year_month': '1985_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.15325339}, {'year_month': '1985_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.011410567}, {'year_month': '1985_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.06784557}]
#        year_month       bound_name      mean
# 0   1985_MAMJJASO             abim  0.132439
# 1   1985_MAMJJASO            napak -0.082932
# 2   1985_MAMJJASO        nabilatuk  0.015653
# 3   1985_MAMJJASO           kotido -0.067688
# 4   1985_MAMJJASO           moroto  0.041230
# 5   1985_MAMJJASO    nakapiripirit  0.239379
# 6   1985_MAMJJASO          kaabong  0.133612
# 7   1985_MAMJJASO          karenga  0.213994
# 8   1985_MAMJJASO           amudat  0.122250
# 9   1985_MAMJJASO    nab_nak_napak  0.027125
# 10  1985_MAMJJASO  abi_kar_kaboong  0.153253
# 11  1985_MAMJJASO   mor_kot_amudat  0.011411
# 12  1985_MAMJJASO         karamoja  0.067846
# []
# [{'year_month': '1986_MAMJJASO', 'bound_name': 'abim', 'mean': -0.69649446}, {'year_month': '1986_MAMJJASO', 'bound_name': 'napak', 'mean': -0.54947865}, {'year_month': '1986_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.5960866}, {'year_month': '1986_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.36746418}, {'year_month': '1986_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.24789767}, {'year_month': '1986_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.49478194}, {'year_month': '1986_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.14365949}, {'year_month': '1986_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.22974214}, {'year_month': '1986_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.32365015}, {'year_month': '1986_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.544311}, {'year_month': '1986_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.32106286}, {'year_month': '1986_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.31104654}, {'year_month': '1986_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.38888744}]
#        year_month       bound_name      mean
# 0   1986_MAMJJASO             abim -0.696494
# 1   1986_MAMJJASO            napak -0.549479
# 2   1986_MAMJJASO        nabilatuk -0.596087
# 3   1986_MAMJJASO           kotido -0.367464
# 4   1986_MAMJJASO           moroto -0.247898
# 5   1986_MAMJJASO    nakapiripirit -0.494782
# 6   1986_MAMJJASO          kaabong -0.143659
# 7   1986_MAMJJASO          karenga -0.229742
# 8   1986_MAMJJASO           amudat -0.323650
# 9   1986_MAMJJASO    nab_nak_napak -0.544311
# 10  1986_MAMJJASO  abi_kar_kaboong -0.321063
# 11  1986_MAMJJASO   mor_kot_amudat -0.311047
# 12  1986_MAMJJASO         karamoja -0.388887
# []
# [{'year_month': '1987_MAMJJASO', 'bound_name': 'abim', 'mean': -0.09109007}, {'year_month': '1987_MAMJJASO', 'bound_name': 'napak', 'mean': -0.08070305}, {'year_month': '1987_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.042860195}, {'year_month': '1987_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.086498074}, {'year_month': '1987_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.058345333}, {'year_month': '1987_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.05836473}, {'year_month': '1987_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.083702266}, {'year_month': '1987_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.07925377}, {'year_month': '1987_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.16561778}, {'year_month': '1987_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.048178278}, {'year_month': '1987_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.08468187}, {'year_month': '1987_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.042566083}, {'year_month': '1987_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.059623726}]
#        year_month       bound_name      mean
# 0   1987_MAMJJASO             abim -0.091090
# 1   1987_MAMJJASO            napak -0.080703
# 2   1987_MAMJJASO        nabilatuk  0.042860
# 3   1987_MAMJJASO           kotido -0.086498
# 4   1987_MAMJJASO           moroto  0.058345
# 5   1987_MAMJJASO    nakapiripirit -0.058365
# 6   1987_MAMJJASO          kaabong -0.083702
# 7   1987_MAMJJASO          karenga -0.079254
# 8   1987_MAMJJASO           amudat -0.165618
# 9   1987_MAMJJASO    nab_nak_napak -0.048178
# 10  1987_MAMJJASO  abi_kar_kaboong -0.084682
# 11  1987_MAMJJASO   mor_kot_amudat -0.042566
# 12  1987_MAMJJASO         karamoja -0.059624
# []
# [{'year_month': '1988_MAMJJASO', 'bound_name': 'abim', 'mean': 0.22039875}, {'year_month': '1988_MAMJJASO', 'bound_name': 'napak', 'mean': 0.26704538}, {'year_month': '1988_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.6844393}, {'year_month': '1988_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.46887666}, {'year_month': '1988_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.48766515}, {'year_month': '1988_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.74843204}, {'year_month': '1988_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.48542634}, {'year_month': '1988_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.34361556}, {'year_month': '1988_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.7114968}, {'year_month': '1988_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.48904043}, {'year_month': '1988_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.37539807}, {'year_month': '1988_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.521275}, {'year_month': '1988_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.45812148}]
#        year_month       bound_name      mean
# 0   1988_MAMJJASO             abim  0.220399
# 1   1988_MAMJJASO            napak  0.267045
# 2   1988_MAMJJASO        nabilatuk  0.684439
# 3   1988_MAMJJASO           kotido  0.468877
# 4   1988_MAMJJASO           moroto  0.487665
# 5   1988_MAMJJASO    nakapiripirit  0.748432
# 6   1988_MAMJJASO          kaabong  0.485426
# 7   1988_MAMJJASO          karenga  0.343616
# 8   1988_MAMJJASO           amudat  0.711497
# 9   1988_MAMJJASO    nab_nak_napak  0.489040
# 10  1988_MAMJJASO  abi_kar_kaboong  0.375398
# 11  1988_MAMJJASO   mor_kot_amudat  0.521275
# 12  1988_MAMJJASO         karamoja  0.458121
# []
# [{'year_month': '1989_MAMJJASO', 'bound_name': 'abim', 'mean': -0.20236102}, {'year_month': '1989_MAMJJASO', 'bound_name': 'napak', 'mean': 0.049163207}, {'year_month': '1989_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.23339084}, {'year_month': '1989_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.24040644}, {'year_month': '1989_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.36832958}, {'year_month': '1989_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.4227568}, {'year_month': '1989_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.3289222}, {'year_month': '1989_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.35172206}, {'year_month': '1989_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.25544634}, {'year_month': '1989_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.19165194}, {'year_month': '1989_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.1846545}, {'year_month': '1989_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.29488793}, {'year_month': '1989_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.22207193}]
#        year_month       bound_name      mean
# 0   1989_MAMJJASO             abim -0.202361
# 1   1989_MAMJJASO            napak  0.049163
# 2   1989_MAMJJASO        nabilatuk  0.233391
# 3   1989_MAMJJASO           kotido  0.240406
# 4   1989_MAMJJASO           moroto  0.368330
# 5   1989_MAMJJASO    nakapiripirit  0.422757
# 6   1989_MAMJJASO          kaabong  0.328922
# 7   1989_MAMJJASO          karenga  0.351722
# 8   1989_MAMJJASO           amudat  0.255446
# 9   1989_MAMJJASO    nab_nak_napak  0.191652
# 10  1989_MAMJJASO  abi_kar_kaboong  0.184655
# 11  1989_MAMJJASO   mor_kot_amudat  0.294888
# 12  1989_MAMJJASO         karamoja  0.222072
# []
# [{'year_month': '1990_MAMJJASO', 'bound_name': 'abim', 'mean': 0.19725311}, {'year_month': '1990_MAMJJASO', 'bound_name': 'napak', 'mean': 0.017029444}, {'year_month': '1990_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.004655503}, {'year_month': '1990_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.1064522}, {'year_month': '1990_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.031326238}, {'year_month': '1990_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.12363275}, {'year_month': '1990_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.13542333}, {'year_month': '1990_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.05318026}, {'year_month': '1990_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.12662156}, {'year_month': '1990_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.024463978}, {'year_month': '1990_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.02110457}, {'year_month': '1990_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.007723256}, {'year_month': '1990_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.012970199}]
#        year_month       bound_name      mean
# 0   1990_MAMJJASO             abim  0.197253
# 1   1990_MAMJJASO            napak  0.017029
# 2   1990_MAMJJASO        nabilatuk  0.004656
# 3   1990_MAMJJASO           kotido  0.106452
# 4   1990_MAMJJASO           moroto -0.031326
# 5   1990_MAMJJASO    nakapiripirit -0.123633
# 6   1990_MAMJJASO          kaabong -0.135423
# 7   1990_MAMJJASO          karenga -0.053180
# 8   1990_MAMJJASO           amudat -0.126622
# 9   1990_MAMJJASO    nab_nak_napak -0.024464
# 10  1990_MAMJJASO  abi_kar_kaboong -0.021105
# 11  1990_MAMJJASO   mor_kot_amudat  0.007723
# 12  1990_MAMJJASO         karamoja -0.012970
# []
# [{'year_month': '1991_MAMJJASO', 'bound_name': 'abim', 'mean': 0.4891699}, {'year_month': '1991_MAMJJASO', 'bound_name': 'napak', 'mean': 0.54662824}, {'year_month': '1991_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.4794726}, {'year_month': '1991_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.3384259}, {'year_month': '1991_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.28504556}, {'year_month': '1991_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.5503246}, {'year_month': '1991_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.3704254}, {'year_month': '1991_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.26475328}, {'year_month': '1991_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.4483806}, {'year_month': '1991_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.5333259}, {'year_month': '1991_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.37768015}, {'year_month': '1991_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.33715576}, {'year_month': '1991_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.4142588}]
#        year_month       bound_name      mean
# 0   1991_MAMJJASO             abim  0.489170
# 1   1991_MAMJJASO            napak  0.546628
# 2   1991_MAMJJASO        nabilatuk  0.479473
# 3   1991_MAMJJASO           kotido  0.338426
# 4   1991_MAMJJASO           moroto  0.285046
# 5   1991_MAMJJASO    nakapiripirit  0.550325
# 6   1991_MAMJJASO          kaabong  0.370425
# 7   1991_MAMJJASO          karenga  0.264753
# 8   1991_MAMJJASO           amudat  0.448381
# 9   1991_MAMJJASO    nab_nak_napak  0.533326
# 10  1991_MAMJJASO  abi_kar_kaboong  0.377680
# 11  1991_MAMJJASO   mor_kot_amudat  0.337156
# 12  1991_MAMJJASO         karamoja  0.414259
# []
# [{'year_month': '1992_MAMJJASO', 'bound_name': 'abim', 'mean': -0.37138617}, {'year_month': '1992_MAMJJASO', 'bound_name': 'napak', 'mean': -0.61117953}, {'year_month': '1992_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.73281497}, {'year_month': '1992_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.43448225}, {'year_month': '1992_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.6135989}, {'year_month': '1992_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.5766463}, {'year_month': '1992_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.4384816}, {'year_month': '1992_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.4184896}, {'year_month': '1992_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.27751535}, {'year_month': '1992_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.6275839}, {'year_month': '1992_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.41457933}, {'year_month': '1992_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.4778909}, {'year_month': '1992_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.5025546}]
#        year_month       bound_name      mean
# 0   1992_MAMJJASO             abim -0.371386
# 1   1992_MAMJJASO            napak -0.611180
# 2   1992_MAMJJASO        nabilatuk -0.732815
# 3   1992_MAMJJASO           kotido -0.434482
# 4   1992_MAMJJASO           moroto -0.613599
# 5   1992_MAMJJASO    nakapiripirit -0.576646
# 6   1992_MAMJJASO          kaabong -0.438482
# 7   1992_MAMJJASO          karenga -0.418490
# 8   1992_MAMJJASO           amudat -0.277515
# 9   1992_MAMJJASO    nab_nak_napak -0.627584
# 10  1992_MAMJJASO  abi_kar_kaboong -0.414579
# 11  1992_MAMJJASO   mor_kot_amudat -0.477891
# 12  1992_MAMJJASO         karamoja -0.502555
# []
# [{'year_month': '1993_MAMJJASO', 'bound_name': 'abim', 'mean': -0.43636972}, {'year_month': '1993_MAMJJASO', 'bound_name': 'napak', 'mean': -0.49562287}, {'year_month': '1993_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.3457623}, {'year_month': '1993_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.6214988}, {'year_month': '1993_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.4216202}, {'year_month': '1993_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.243564}, {'year_month': '1993_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.8267704}, {'year_month': '1993_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.93228555}, {'year_month': '1993_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.40349165}, {'year_month': '1993_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.39403498}, {'year_month': '1993_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.74281293}, {'year_month': '1993_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.50045246}, {'year_month': '1993_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.5544838}]
#        year_month       bound_name      mean
# 0   1993_MAMJJASO             abim -0.436370
# 1   1993_MAMJJASO            napak -0.495623
# 2   1993_MAMJJASO        nabilatuk -0.345762
# 3   1993_MAMJJASO           kotido -0.621499
# 4   1993_MAMJJASO           moroto -0.421620
# 5   1993_MAMJJASO    nakapiripirit -0.243564
# 6   1993_MAMJJASO          kaabong -0.826770
# 7   1993_MAMJJASO          karenga -0.932286
# 8   1993_MAMJJASO           amudat -0.403492
# 9   1993_MAMJJASO    nab_nak_napak -0.394035
# 10  1993_MAMJJASO  abi_kar_kaboong -0.742813
# 11  1993_MAMJJASO   mor_kot_amudat -0.500452
# 12  1993_MAMJJASO         karamoja -0.554484
# []
# [{'year_month': '1994_MAMJJASO', 'bound_name': 'abim', 'mean': 0.07131303}, {'year_month': '1994_MAMJJASO', 'bound_name': 'napak', 'mean': 0.040107243}, {'year_month': '1994_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.04152834}, {'year_month': '1994_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.10648839}, {'year_month': '1994_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.015142246}, {'year_month': '1994_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.07356165}, {'year_month': '1994_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.3036035}, {'year_month': '1994_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.31047544}, {'year_month': '1994_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.26671726}, {'year_month': '1994_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.049651247}, {'year_month': '1994_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.23975663}, {'year_month': '1994_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.09915731}, {'year_month': '1994_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.13439272}]
#        year_month       bound_name      mean
# 0   1994_MAMJJASO             abim  0.071313
# 1   1994_MAMJJASO            napak  0.040107
# 2   1994_MAMJJASO        nabilatuk  0.041528
# 3   1994_MAMJJASO           kotido  0.106488
# 4   1994_MAMJJASO           moroto  0.015142
# 5   1994_MAMJJASO    nakapiripirit  0.073562
# 6   1994_MAMJJASO          kaabong  0.303604
# 7   1994_MAMJJASO          karenga  0.310475
# 8   1994_MAMJJASO           amudat  0.266717
# 9   1994_MAMJJASO    nab_nak_napak  0.049651
# 10  1994_MAMJJASO  abi_kar_kaboong  0.239757
# 11  1994_MAMJJASO   mor_kot_amudat  0.099157
# 12  1994_MAMJJASO         karamoja  0.134393
# []
# [{'year_month': '1995_MAMJJASO', 'bound_name': 'abim', 'mean': 0.10341584}, {'year_month': '1995_MAMJJASO', 'bound_name': 'napak', 'mean': 0.11558796}, {'year_month': '1995_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.017297445}, {'year_month': '1995_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.04412517}, {'year_month': '1995_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.067284614}, {'year_month': '1995_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.07296834}, {'year_month': '1995_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.13495032}, {'year_month': '1995_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.22373669}, {'year_month': '1995_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.0740674}, {'year_month': '1995_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.04254016}, {'year_month': '1995_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.08974176}, {'year_month': '1995_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.0046248334}, {'year_month': '1995_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.020485718}]
#        year_month       bound_name      mean
# 0   1995_MAMJJASO             abim  0.103416
# 1   1995_MAMJJASO            napak  0.115588
# 2   1995_MAMJJASO        nabilatuk  0.017297
# 3   1995_MAMJJASO           kotido -0.044125
# 4   1995_MAMJJASO           moroto  0.067285
# 5   1995_MAMJJASO    nakapiripirit -0.072968
# 6   1995_MAMJJASO          kaabong -0.134950
# 7   1995_MAMJJASO          karenga -0.223737
# 8   1995_MAMJJASO           amudat -0.074067
# 9   1995_MAMJJASO    nab_nak_napak  0.042540
# 10  1995_MAMJJASO  abi_kar_kaboong -0.089742
# 11  1995_MAMJJASO   mor_kot_amudat -0.004625
# 12  1995_MAMJJASO         karamoja -0.020486
# []
# [{'year_month': '1996_MAMJJASO', 'bound_name': 'abim', 'mean': 0.44681025}, {'year_month': '1996_MAMJJASO', 'bound_name': 'napak', 'mean': 0.40826935}, {'year_month': '1996_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.32156414}, {'year_month': '1996_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.38226014}, {'year_month': '1996_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.4065627}, {'year_month': '1996_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.45139185}, {'year_month': '1996_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.27848002}, {'year_month': '1996_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.19406685}, {'year_month': '1996_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.42889893}, {'year_month': '1996_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.40168777}, {'year_month': '1996_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.30501044}, {'year_month': '1996_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.40069553}, {'year_month': '1996_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.36631337}]
#        year_month       bound_name      mean
# 0   1996_MAMJJASO             abim  0.446810
# 1   1996_MAMJJASO            napak  0.408269
# 2   1996_MAMJJASO        nabilatuk  0.321564
# 3   1996_MAMJJASO           kotido  0.382260
# 4   1996_MAMJJASO           moroto  0.406563
# 5   1996_MAMJJASO    nakapiripirit  0.451392
# 6   1996_MAMJJASO          kaabong  0.278480
# 7   1996_MAMJJASO          karenga  0.194067
# 8   1996_MAMJJASO           amudat  0.428899
# 9   1996_MAMJJASO    nab_nak_napak  0.401688
# 10  1996_MAMJJASO  abi_kar_kaboong  0.305010
# 11  1996_MAMJJASO   mor_kot_amudat  0.400696
# 12  1996_MAMJJASO         karamoja  0.366313
# []
# [{'year_month': '1997_MAMJJASO', 'bound_name': 'abim', 'mean': -0.4837587}, {'year_month': '1997_MAMJJASO', 'bound_name': 'napak', 'mean': -0.44967535}, {'year_month': '1997_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.44260094}, {'year_month': '1997_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.14628002}, {'year_month': '1997_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.07155074}, {'year_month': '1997_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.40372404}, {'year_month': '1997_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.0059349136}, {'year_month': '1997_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.02753739}, {'year_month': '1997_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.06457252}, {'year_month': '1997_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.43547365}, {'year_month': '1997_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.14614837}, {'year_month': '1997_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.043148097}, {'year_month': '1997_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.20530958}]
#        year_month       bound_name      mean
# 0   1997_MAMJJASO             abim -0.483759
# 1   1997_MAMJJASO            napak -0.449675
# 2   1997_MAMJJASO        nabilatuk -0.442601
# 3   1997_MAMJJASO           kotido -0.146280
# 4   1997_MAMJJASO           moroto  0.071551
# 5   1997_MAMJJASO    nakapiripirit -0.403724
# 6   1997_MAMJJASO          kaabong -0.005935
# 7   1997_MAMJJASO          karenga -0.027537
# 8   1997_MAMJJASO           amudat -0.064573
# 9   1997_MAMJJASO    nab_nak_napak -0.435474
# 10  1997_MAMJJASO  abi_kar_kaboong -0.146148
# 11  1997_MAMJJASO   mor_kot_amudat -0.043148
# 12  1997_MAMJJASO         karamoja -0.205310
# []
# [{'year_month': '1998_MAMJJASO', 'bound_name': 'abim', 'mean': -0.23924549}, {'year_month': '1998_MAMJJASO', 'bound_name': 'napak', 'mean': -0.059560183}, {'year_month': '1998_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.031523157}, {'year_month': '1998_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.046340555}, {'year_month': '1998_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.117748044}, {'year_month': '1998_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.19832912}, {'year_month': '1998_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.0754168}, {'year_month': '1998_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.15324764}, {'year_month': '1998_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.15790488}, {'year_month': '1998_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.09191155}, {'year_month': '1998_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.070199}, {'year_month': '1998_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.037484337}, {'year_month': '1998_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.042729218}]
#        year_month       bound_name      mean
# 0   1998_MAMJJASO             abim -0.239245
# 1   1998_MAMJJASO            napak -0.059560
# 2   1998_MAMJJASO        nabilatuk -0.031523
# 3   1998_MAMJJASO           kotido  0.046341
# 4   1998_MAMJJASO           moroto  0.117748
# 5   1998_MAMJJASO    nakapiripirit -0.198329
# 6   1998_MAMJJASO          kaabong  0.075417
# 7   1998_MAMJJASO          karenga -0.153248
# 8   1998_MAMJJASO           amudat -0.157905
# 9   1998_MAMJJASO    nab_nak_napak -0.091912
# 10  1998_MAMJJASO  abi_kar_kaboong -0.070199
# 11  1998_MAMJJASO   mor_kot_amudat  0.037484
# 12  1998_MAMJJASO         karamoja -0.042729
# []
# [{'year_month': '1999_MAMJJASO', 'bound_name': 'abim', 'mean': 0.061178416}, {'year_month': '1999_MAMJJASO', 'bound_name': 'napak', 'mean': -0.22628689}, {'year_month': '1999_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.29487118}, {'year_month': '1999_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.15124518}, {'year_month': '1999_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.39102343}, {'year_month': '1999_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.22419803}, {'year_month': '1999_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.23821849}, {'year_month': '1999_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.2018372}, {'year_month': '1999_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.52461725}, {'year_month': '1999_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.24033801}, {'year_month': '1999_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.1446866}, {'year_month': '1999_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.31710923}, {'year_month': '1999_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.2301611}]
#        year_month       bound_name      mean
# 0   1999_MAMJJASO             abim  0.061178
# 1   1999_MAMJJASO            napak -0.226287
# 2   1999_MAMJJASO        nabilatuk -0.294871
# 3   1999_MAMJJASO           kotido -0.151245
# 4   1999_MAMJJASO           moroto -0.391023
# 5   1999_MAMJJASO    nakapiripirit -0.224198
# 6   1999_MAMJJASO          kaabong -0.238218
# 7   1999_MAMJJASO          karenga -0.201837
# 8   1999_MAMJJASO           amudat -0.524617
# 9   1999_MAMJJASO    nab_nak_napak -0.240338
# 10  1999_MAMJJASO  abi_kar_kaboong -0.144687
# 11  1999_MAMJJASO   mor_kot_amudat -0.317109
# 12  1999_MAMJJASO         karamoja -0.230161
# []
# [{'year_month': '2000_MAMJJASO', 'bound_name': 'abim', 'mean': 0.32598245}, {'year_month': '2000_MAMJJASO', 'bound_name': 'napak', 'mean': 0.08035646}, {'year_month': '2000_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.14845364}, {'year_month': '2000_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.121028826}, {'year_month': '2000_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.34321958}, {'year_month': '2000_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.23393995}, {'year_month': '2000_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.41928917}, {'year_month': '2000_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.167182}, {'year_month': '2000_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.310583}, {'year_month': '2000_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.05526183}, {'year_month': '2000_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.14632697}, {'year_month': '2000_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.14631699}, {'year_month': '2000_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.11735312}]
#        year_month       bound_name      mean
# 0   2000_MAMJJASO             abim  0.325982
# 1   2000_MAMJJASO            napak  0.080356
# 2   2000_MAMJJASO        nabilatuk -0.148454
# 3   2000_MAMJJASO           kotido  0.121029
# 4   2000_MAMJJASO           moroto -0.343220
# 5   2000_MAMJJASO    nakapiripirit -0.233940
# 6   2000_MAMJJASO          kaabong -0.419289
# 7   2000_MAMJJASO          karenga -0.167182
# 8   2000_MAMJJASO           amudat -0.310583
# 9   2000_MAMJJASO    nab_nak_napak -0.055262
# 10  2000_MAMJJASO  abi_kar_kaboong -0.146327
# 11  2000_MAMJJASO   mor_kot_amudat -0.146317
# 12  2000_MAMJJASO         karamoja -0.117353
# []
# [{'year_month': '2001_MAMJJASO', 'bound_name': 'abim', 'mean': 0.43175}, {'year_month': '2001_MAMJJASO', 'bound_name': 'napak', 'mean': 0.58520037}, {'year_month': '2001_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.695118}, {'year_month': '2001_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.3986913}, {'year_month': '2001_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.27818865}, {'year_month': '2001_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.6126967}, {'year_month': '2001_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.21646518}, {'year_month': '2001_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.3371628}, {'year_month': '2001_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.49251753}, {'year_month': '2001_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.6162395}, {'year_month': '2001_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.30720967}, {'year_month': '2001_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.36731318}, {'year_month': '2001_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.4247094}]
#        year_month       bound_name      mean
# 0   2001_MAMJJASO             abim  0.431750
# 1   2001_MAMJJASO            napak  0.585200
# 2   2001_MAMJJASO        nabilatuk  0.695118
# 3   2001_MAMJJASO           kotido  0.398691
# 4   2001_MAMJJASO           moroto  0.278189
# 5   2001_MAMJJASO    nakapiripirit  0.612697
# 6   2001_MAMJJASO          kaabong  0.216465
# 7   2001_MAMJJASO          karenga  0.337163
# 8   2001_MAMJJASO           amudat  0.492518
# 9   2001_MAMJJASO    nab_nak_napak  0.616239
# 10  2001_MAMJJASO  abi_kar_kaboong  0.307210
# 11  2001_MAMJJASO   mor_kot_amudat  0.367313
# 12  2001_MAMJJASO         karamoja  0.424709
# []
# [{'year_month': '2002_MAMJJASO', 'bound_name': 'abim', 'mean': -0.75473416}, {'year_month': '2002_MAMJJASO', 'bound_name': 'napak', 'mean': -0.7001281}, {'year_month': '2002_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.7032124}, {'year_month': '2002_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.7650912}, {'year_month': '2002_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.40088707}, {'year_month': '2002_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.77670145}, {'year_month': '2002_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.42756015}, {'year_month': '2002_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.40021497}, {'year_month': '2002_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.60502726}, {'year_month': '2002_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.7219373}, {'year_month': '2002_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.51309717}, {'year_month': '2002_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.5883279}, {'year_month': '2002_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.60355264}]
#        year_month       bound_name      mean
# 0   2002_MAMJJASO             abim -0.754734
# 1   2002_MAMJJASO            napak -0.700128
# 2   2002_MAMJJASO        nabilatuk -0.703212
# 3   2002_MAMJJASO           kotido -0.765091
# 4   2002_MAMJJASO           moroto -0.400887
# 5   2002_MAMJJASO    nakapiripirit -0.776701
# 6   2002_MAMJJASO          kaabong -0.427560
# 7   2002_MAMJJASO          karenga -0.400215
# 8   2002_MAMJJASO           amudat -0.605027
# 9   2002_MAMJJASO    nab_nak_napak -0.721937
# 10  2002_MAMJJASO  abi_kar_kaboong -0.513097
# 11  2002_MAMJJASO   mor_kot_amudat -0.588328
# 12  2002_MAMJJASO         karamoja -0.603553
# []
# [{'year_month': '2003_MAMJJASO', 'bound_name': 'abim', 'mean': 0.16055606}, {'year_month': '2003_MAMJJASO', 'bound_name': 'napak', 'mean': 0.19111167}, {'year_month': '2003_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.46273512}, {'year_month': '2003_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.08171996}, {'year_month': '2003_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.31962475}, {'year_month': '2003_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.35687593}, {'year_month': '2003_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.2047027}, {'year_month': '2003_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.08941552}, {'year_month': '2003_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.4592569}, {'year_month': '2003_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.29483333}, {'year_month': '2003_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.16359918}, {'year_month': '2003_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.24759598}, {'year_month': '2003_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.23216431}]
#        year_month       bound_name      mean
# 0   2003_MAMJJASO             abim  0.160556
# 1   2003_MAMJJASO            napak  0.191112
# 2   2003_MAMJJASO        nabilatuk  0.462735
# 3   2003_MAMJJASO           kotido  0.081720
# 4   2003_MAMJJASO           moroto  0.319625
# 5   2003_MAMJJASO    nakapiripirit  0.356876
# 6   2003_MAMJJASO          kaabong  0.204703
# 7   2003_MAMJJASO          karenga  0.089416
# 8   2003_MAMJJASO           amudat  0.459257
# 9   2003_MAMJJASO    nab_nak_napak  0.294833
# 10  2003_MAMJJASO  abi_kar_kaboong  0.163599
# 11  2003_MAMJJASO   mor_kot_amudat  0.247596
# 12  2003_MAMJJASO         karamoja  0.232164
# []
# [{'year_month': '2004_MAMJJASO', 'bound_name': 'abim', 'mean': -0.24557604}, {'year_month': '2004_MAMJJASO', 'bound_name': 'napak', 'mean': -0.16925418}, {'year_month': '2004_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.42753464}, {'year_month': '2004_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.10660183}, {'year_month': '2004_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.10987941}, {'year_month': '2004_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.6210881}, {'year_month': '2004_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.070224054}, {'year_month': '2004_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.07932592}, {'year_month': '2004_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.5488955}, {'year_month': '2004_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.34914926}, {'year_month': '2004_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.0825518}, {'year_month': '2004_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.18960448}, {'year_month': '2004_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.20154063}]
#        year_month       bound_name      mean
# 0   2004_MAMJJASO             abim -0.245576
# 1   2004_MAMJJASO            napak -0.169254
# 2   2004_MAMJJASO        nabilatuk -0.427535
# 3   2004_MAMJJASO           kotido -0.106602
# 4   2004_MAMJJASO           moroto -0.109879
# 5   2004_MAMJJASO    nakapiripirit -0.621088
# 6   2004_MAMJJASO          kaabong -0.070224
# 7   2004_MAMJJASO          karenga  0.079326
# 8   2004_MAMJJASO           amudat -0.548895
# 9   2004_MAMJJASO    nab_nak_napak -0.349149
# 10  2004_MAMJJASO  abi_kar_kaboong -0.082552
# 11  2004_MAMJJASO   mor_kot_amudat -0.189604
# 12  2004_MAMJJASO         karamoja -0.201541
# []
# [{'year_month': '2005_MAMJJASO', 'bound_name': 'abim', 'mean': -0.28383666}, {'year_month': '2005_MAMJJASO', 'bound_name': 'napak', 'mean': -0.062163495}, {'year_month': '2005_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.0895911}, {'year_month': '2005_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.05225714}, {'year_month': '2005_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.21436046}, {'year_month': '2005_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.26703578}, {'year_month': '2005_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.26660773}, {'year_month': '2005_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.101637565}, {'year_month': '2005_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.174862}, {'year_month': '2005_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.12460404}, {'year_month': '2005_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.070278086}, {'year_month': '2005_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.032863382}, {'year_month': '2005_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.0036644177}]
#        year_month       bound_name      mean
# 0   2005_MAMJJASO             abim -0.283837
# 1   2005_MAMJJASO            napak -0.062163
# 2   2005_MAMJJASO        nabilatuk -0.089591
# 3   2005_MAMJJASO           kotido -0.052257
# 4   2005_MAMJJASO           moroto  0.214360
# 5   2005_MAMJJASO    nakapiripirit -0.267036
# 6   2005_MAMJJASO          kaabong  0.266608
# 7   2005_MAMJJASO          karenga  0.101638
# 8   2005_MAMJJASO           amudat -0.174862
# 9   2005_MAMJJASO    nab_nak_napak -0.124604
# 10  2005_MAMJJASO  abi_kar_kaboong  0.070278
# 11  2005_MAMJJASO   mor_kot_amudat  0.032863
# 12  2005_MAMJJASO         karamoja -0.003664
# []
# [{'year_month': '2006_MAMJJASO', 'bound_name': 'abim', 'mean': 0.45805278}, {'year_month': '2006_MAMJJASO', 'bound_name': 'napak', 'mean': 0.27056515}, {'year_month': '2006_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.27064732}, {'year_month': '2006_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.14771187}, {'year_month': '2006_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.12666859}, {'year_month': '2006_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.12651463}, {'year_month': '2006_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.094203465}, {'year_month': '2006_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.12830932}, {'year_month': '2006_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.08964772}, {'year_month': '2006_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.23079251}, {'year_month': '2006_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.20535901}, {'year_month': '2006_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.12848392}, {'year_month': '2006_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.18890832}]
#        year_month       bound_name      mean
# 0   2006_MAMJJASO             abim  0.458053
# 1   2006_MAMJJASO            napak  0.270565
# 2   2006_MAMJJASO        nabilatuk  0.270647
# 3   2006_MAMJJASO           kotido  0.147712
# 4   2006_MAMJJASO           moroto  0.126669
# 5   2006_MAMJJASO    nakapiripirit  0.126515
# 6   2006_MAMJJASO          kaabong  0.094203
# 7   2006_MAMJJASO          karenga  0.128309
# 8   2006_MAMJJASO           amudat  0.089648
# 9   2006_MAMJJASO    nab_nak_napak  0.230793
# 10  2006_MAMJJASO  abi_kar_kaboong  0.205359
# 11  2006_MAMJJASO   mor_kot_amudat  0.128484
# 12  2006_MAMJJASO         karamoja  0.188908
# []
# [{'year_month': '2007_MAMJJASO', 'bound_name': 'abim', 'mean': 0.85319036}, {'year_month': '2007_MAMJJASO', 'bound_name': 'napak', 'mean': 1.0046761}, {'year_month': '2007_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.9188364}, {'year_month': '2007_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.9931117}, {'year_month': '2007_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.196479}, {'year_month': '2007_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.8420179}, {'year_month': '2007_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.0922817}, {'year_month': '2007_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.956805}, {'year_month': '2007_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.0047371}, {'year_month': '2007_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.9414376}, {'year_month': '2007_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.9911466}, {'year_month': '2007_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 1.0774559}, {'year_month': '2007_MAMJJASO', 'bound_name': 'karamoja', 'mean': 1.0028864}]
#        year_month       bound_name      mean
# 0   2007_MAMJJASO             abim  0.853190
# 1   2007_MAMJJASO            napak  1.004676
# 2   2007_MAMJJASO        nabilatuk  0.918836
# 3   2007_MAMJJASO           kotido  0.993112
# 4   2007_MAMJJASO           moroto  1.196479
# 5   2007_MAMJJASO    nakapiripirit  0.842018
# 6   2007_MAMJJASO          kaabong  1.092282
# 7   2007_MAMJJASO          karenga  0.956805
# 8   2007_MAMJJASO           amudat  1.004737
# 9   2007_MAMJJASO    nab_nak_napak  0.941438
# 10  2007_MAMJJASO  abi_kar_kaboong  0.991147
# 11  2007_MAMJJASO   mor_kot_amudat  1.077456
# 12  2007_MAMJJASO         karamoja  1.002886
# []
# [{'year_month': '2008_MAMJJASO', 'bound_name': 'abim', 'mean': -0.20052716}, {'year_month': '2008_MAMJJASO', 'bound_name': 'napak', 'mean': -0.22026694}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.06497494}, {'year_month': '2008_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.3668224}, {'year_month': '2008_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.45305762}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.04287085}, {'year_month': '2008_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.4804437}, {'year_month': '2008_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.41527867}, {'year_month': '2008_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.14113316}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.13814422}, {'year_month': '2008_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.38525754}, {'year_month': '2008_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.35999924}, {'year_month': '2008_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.2985795}]
#        year_month       bound_name      mean
# 0   2008_MAMJJASO             abim -0.200527
# 1   2008_MAMJJASO            napak -0.220267
# 2   2008_MAMJJASO        nabilatuk -0.064975
# 3   2008_MAMJJASO           kotido -0.366822
# 4   2008_MAMJJASO           moroto -0.453058
# 5   2008_MAMJJASO    nakapiripirit -0.042871
# 6   2008_MAMJJASO          kaabong -0.480444
# 7   2008_MAMJJASO          karenga -0.415279
# 8   2008_MAMJJASO           amudat -0.141133
# 9   2008_MAMJJASO    nab_nak_napak -0.138144
# 10  2008_MAMJJASO  abi_kar_kaboong -0.385258
# 11  2008_MAMJJASO   mor_kot_amudat -0.359999
# 12  2008_MAMJJASO         karamoja -0.298580
# []
# [{'year_month': '2009_MAMJJASO', 'bound_name': 'abim', 'mean': -0.74062145}, {'year_month': '2009_MAMJJASO', 'bound_name': 'napak', 'mean': -0.67129755}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': -0.61402315}, {'year_month': '2009_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.7760849}, {'year_month': '2009_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.83410597}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': -0.54811865}, {'year_month': '2009_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.82569}, {'year_month': '2009_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.79357845}, {'year_month': '2009_MAMJJASO', 'bound_name': 'amudat', 'mean': -0.5198674}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': -0.6250567}, {'year_month': '2009_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.79370433}, {'year_month': '2009_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.7522206}, {'year_month': '2009_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.72680885}]
#        year_month       bound_name      mean
# ...
#        year_month       bound_name      mean
# 0   2007_MAMJJASO             abim  0.099552
# 1   2007_MAMJJASO            napak  0.549404
# 2   2007_MAMJJASO        nabilatuk  0.490065
# 3   2007_MAMJJASO           kotido  0.322147
# 4   2007_MAMJJASO           moroto  0.937343
# 5   2007_MAMJJASO    nakapiripirit  0.155825
# 6   2007_MAMJJASO          kaabong  0.802921
# 7   2007_MAMJJASO          karenga  0.519673
# 8   2007_MAMJJASO           amudat  0.466556
# 9   2007_MAMJJASO    nab_nak_napak  0.428032
# 10  2007_MAMJJASO  abi_kar_kaboong  0.534047
# 11  2007_MAMJJASO   mor_kot_amudat  0.597465
# 12  2007_MAMJJASO         karamoja  0.520566
# []
# [{'year_month': '2008_MAMJJASO', 'bound_name': 'abim', 'mean': 0.4267815}, {'year_month': '2008_MAMJJASO', 'bound_name': 'napak', 'mean': 0.8086544}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.63437355}, {'year_month': '2008_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.83034515}, {'year_month': '2008_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.2771176}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.37219766}, {'year_month': '2008_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.3407602}, {'year_month': '2008_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.97683185}, {'year_month': '2008_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.73626447}, {'year_month': '2008_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.6509229}, {'year_month': '2008_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.9924036}, {'year_month': '2008_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.99354833}, {'year_month': '2008_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.8841334}]
#        year_month       bound_name      mean
# 0   2008_MAMJJASO             abim  0.426782
# 1   2008_MAMJJASO            napak  0.808654
# 2   2008_MAMJJASO        nabilatuk  0.634374
# 3   2008_MAMJJASO           kotido  0.830345
# 4   2008_MAMJJASO           moroto  1.277118
# 5   2008_MAMJJASO    nakapiripirit  0.372198
# 6   2008_MAMJJASO          kaabong  1.340760
# 7   2008_MAMJJASO          karenga  0.976832
# 8   2008_MAMJJASO           amudat  0.736264
# 9   2008_MAMJJASO    nab_nak_napak  0.650923
# 10  2008_MAMJJASO  abi_kar_kaboong  0.992404
# 11  2008_MAMJJASO   mor_kot_amudat  0.993548
# 12  2008_MAMJJASO         karamoja  0.884133
# []
# [{'year_month': '2009_MAMJJASO', 'bound_name': 'abim', 'mean': 0.22451474}, {'year_month': '2009_MAMJJASO', 'bound_name': 'napak', 'mean': 0.64181876}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.70961916}, {'year_month': '2009_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.40598765}, {'year_month': '2009_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.81174433}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.584572}, {'year_month': '2009_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.8766209}, {'year_month': '2009_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.50813615}, {'year_month': '2009_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.76202244}, {'year_month': '2009_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.6404668}, {'year_month': '2009_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.60103494}, {'year_month': '2009_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.63573545}, {'year_month': '2009_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.62465733}]
#        year_month       bound_name      mean
# 0   2009_MAMJJASO             abim  0.224515
# 1   2009_MAMJJASO            napak  0.641819
# 2   2009_MAMJJASO        nabilatuk  0.709619
# 3   2009_MAMJJASO           kotido  0.405988
# 4   2009_MAMJJASO           moroto  0.811744
# 5   2009_MAMJJASO    nakapiripirit  0.584572
# 6   2009_MAMJJASO          kaabong  0.876621
# 7   2009_MAMJJASO          karenga  0.508136
# 8   2009_MAMJJASO           amudat  0.762022
# 9   2009_MAMJJASO    nab_nak_napak  0.640467
# 10  2009_MAMJJASO  abi_kar_kaboong  0.601035
# 11  2009_MAMJJASO   mor_kot_amudat  0.635735
# 12  2009_MAMJJASO         karamoja  0.624657
# []
# [{'year_month': '2010_MAMJJASO', 'bound_name': 'abim', 'mean': 0.5289155}, {'year_month': '2010_MAMJJASO', 'bound_name': 'napak', 'mean': 1.0383937}, {'year_month': '2010_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.1141648}, {'year_month': '2010_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.632219}, {'year_month': '2010_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.3035755}, {'year_month': '2010_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 1.0498288}, {'year_month': '2010_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.1184633}, {'year_month': '2010_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.68718535}, {'year_month': '2010_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.2667232}, {'year_month': '2010_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 1.0577133}, {'year_month': '2010_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.8449298}, {'year_month': '2010_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 1.0207418}, {'year_month': '2010_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.9687498}]
#        year_month       bound_name      mean
# 0   2010_MAMJJASO             abim  0.528916
# 1   2010_MAMJJASO            napak  1.038394
# 2   2010_MAMJJASO        nabilatuk  1.114165
# 3   2010_MAMJJASO           kotido  0.632219
# 4   2010_MAMJJASO           moroto  1.303576
# 5   2010_MAMJJASO    nakapiripirit  1.049829
# 6   2010_MAMJJASO          kaabong  1.118463
# 7   2010_MAMJJASO          karenga  0.687185
# 8   2010_MAMJJASO           amudat  1.266723
# 9   2010_MAMJJASO    nab_nak_napak  1.057713
# 10  2010_MAMJJASO  abi_kar_kaboong  0.844930
# 11  2010_MAMJJASO   mor_kot_amudat  1.020742
# 12  2010_MAMJJASO         karamoja  0.968750
# []
# [{'year_month': '2011_MAMJJASO', 'bound_name': 'abim', 'mean': -0.49721912}, {'year_month': '2011_MAMJJASO', 'bound_name': 'napak', 'mean': 0.26483795}, {'year_month': '2011_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 0.47743022}, {'year_month': '2011_MAMJJASO', 'bound_name': 'kotido', 'mean': -0.49684805}, {'year_month': '2011_MAMJJASO', 'bound_name': 'moroto', 'mean': -0.09472044}, {'year_month': '2011_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.49904263}, {'year_month': '2011_MAMJJASO', 'bound_name': 'kaabong', 'mean': -0.2294807}, {'year_month': '2011_MAMJJASO', 'bound_name': 'karenga', 'mean': -0.45254657}, {'year_month': '2011_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.34403855}, {'year_month': '2011_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.374874}, {'year_month': '2011_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': -0.36046308}, {'year_month': '2011_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': -0.17902997}, {'year_month': '2011_MAMJJASO', 'bound_name': 'karamoja', 'mean': -0.06860802}]
#        year_month       bound_name      mean
# 0   2011_MAMJJASO             abim -0.497219
# 1   2011_MAMJJASO            napak  0.264838
# 2   2011_MAMJJASO        nabilatuk  0.477430
# 3   2011_MAMJJASO           kotido -0.496848
# 4   2011_MAMJJASO           moroto -0.094720
# 5   2011_MAMJJASO    nakapiripirit  0.499043
# 6   2011_MAMJJASO          kaabong -0.229481
# 7   2011_MAMJJASO          karenga -0.452547
# 8   2011_MAMJJASO           amudat  0.344039
# 9   2011_MAMJJASO    nab_nak_napak  0.374874
# 10  2011_MAMJJASO  abi_kar_kaboong -0.360463
# 11  2011_MAMJJASO   mor_kot_amudat -0.179030
# 12  2011_MAMJJASO         karamoja -0.068608
# []
# [{'year_month': '2012_MAMJJASO', 'bound_name': 'abim', 'mean': 0.27624023}, {'year_month': '2012_MAMJJASO', 'bound_name': 'napak', 'mean': 0.90361845}, {'year_month': '2012_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.0151262}, {'year_month': '2012_MAMJJASO', 'bound_name': 'kotido', 'mean': 0.31813496}, {'year_month': '2012_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.8985039}, {'year_month': '2012_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 0.9961776}, {'year_month': '2012_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.63778543}, {'year_month': '2012_MAMJJASO', 'bound_name': 'karenga', 'mean': 0.5650149}, {'year_month': '2012_MAMJJASO', 'bound_name': 'amudat', 'mean': 0.98837435}, {'year_month': '2012_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 0.95296866}, {'year_month': '2012_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 0.51767325}, {'year_month': '2012_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.6764816}, {'year_month': '2012_MAMJJASO', 'bound_name': 'karamoja', 'mean': 0.70685285}]
#        year_month       bound_name      mean
# 0   2012_MAMJJASO             abim  0.276240
# 1   2012_MAMJJASO            napak  0.903618
# 2   2012_MAMJJASO        nabilatuk  1.015126
# 3   2012_MAMJJASO           kotido  0.318135
# 4   2012_MAMJJASO           moroto  0.898504
# 5   2012_MAMJJASO    nakapiripirit  0.996178
# 6   2012_MAMJJASO          kaabong  0.637785
# 7   2012_MAMJJASO          karenga  0.565015
# 8   2012_MAMJJASO           amudat  0.988374
# 9   2012_MAMJJASO    nab_nak_napak  0.952969
# 10  2012_MAMJJASO  abi_kar_kaboong  0.517673
# 11  2012_MAMJJASO   mor_kot_amudat  0.676482
# 12  2012_MAMJJASO         karamoja  0.706853
# []
# [{'year_month': '2013_MAMJJASO', 'bound_name': 'abim', 'mean': 1.6223656}, {'year_month': '2013_MAMJJASO', 'bound_name': 'napak', 'mean': 1.8202176}, {'year_month': '2013_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.8222839}, {'year_month': '2013_MAMJJASO', 'bound_name': 'kotido', 'mean': 1.6250925}, {'year_month': '2013_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.878494}, {'year_month': '2013_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 1.8252027}, {'year_month': '2013_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.6710653}, {'year_month': '2013_MAMJJASO', 'bound_name': 'karenga', 'mean': 1.6662979}, {'year_month': '2013_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.8750389}, {'year_month': '2013_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 1.8220354}, {'year_month': '2013_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6561372}, {'year_month': '2013_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 1.7736698}, {'year_month': '2013_MAMJJASO', 'bound_name': 'karamoja', 'mean': 1.7464362}]
#        year_month       bound_name      mean
# 0   2013_MAMJJASO             abim  1.622366
# 1   2013_MAMJJASO            napak  1.820218
# 2   2013_MAMJJASO        nabilatuk  1.822284
# 3   2013_MAMJJASO           kotido  1.625093
# 4   2013_MAMJJASO           moroto  1.878494
# 5   2013_MAMJJASO    nakapiripirit  1.825203
# 6   2013_MAMJJASO          kaabong  1.671065
# 7   2013_MAMJJASO          karenga  1.666298
# 8   2013_MAMJJASO           amudat  1.875039
# 9   2013_MAMJJASO    nab_nak_napak  1.822035
# 10  2013_MAMJJASO  abi_kar_kaboong  1.656137
# 11  2013_MAMJJASO   mor_kot_amudat  1.773670
# 12  2013_MAMJJASO         karamoja  1.746436
# []
# [{'year_month': '2014_MAMJJASO', 'bound_name': 'abim', 'mean': 1.7326736}, {'year_month': '2014_MAMJJASO', 'bound_name': 'napak', 'mean': 1.5676856}, {'year_month': '2014_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.5049914}, {'year_month': '2014_MAMJJASO', 'bound_name': 'kotido', 'mean': 1.6379198}, {'year_month': '2014_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.3388885}, {'year_month': '2014_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 1.6186984}, {'year_month': '2014_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.517155}, {'year_month': '2014_MAMJJASO', 'bound_name': 'karenga', 'mean': 1.7208405}, {'year_month': '2014_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.5505627}, {'year_month': '2014_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 1.5684048}, {'year_month': '2014_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6285851}, {'year_month': '2014_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 1.500925}, {'year_month': '2014_MAMJJASO', 'bound_name': 'karamoja', 'mean': 1.5686853}]
#        year_month       bound_name      mean
# 0   2014_MAMJJASO             abim  1.732674
# 1   2014_MAMJJASO            napak  1.567686
# 2   2014_MAMJJASO        nabilatuk  1.504991
# 3   2014_MAMJJASO           kotido  1.637920
# 4   2014_MAMJJASO           moroto  1.338889
# 5   2014_MAMJJASO    nakapiripirit  1.618698
# 6   2014_MAMJJASO          kaabong  1.517155
# 7   2014_MAMJJASO          karenga  1.720840
# 8   2014_MAMJJASO           amudat  1.550563
# 9   2014_MAMJJASO    nab_nak_napak  1.568405
# 10  2014_MAMJJASO  abi_kar_kaboong  1.628585
# 11  2014_MAMJJASO   mor_kot_amudat  1.500925
# 12  2014_MAMJJASO         karamoja  1.568685
# []
# [{'year_month': '2015_MAMJJASO', 'bound_name': 'abim', 'mean': 1.7595173}, {'year_month': '2015_MAMJJASO', 'bound_name': 'napak', 'mean': 1.6505989}, {'year_month': '2015_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.5166912}, {'year_month': '2015_MAMJJASO', 'bound_name': 'kotido', 'mean': 1.7668964}, {'year_month': '2015_MAMJJASO', 'bound_name': 'moroto', 'mean': 1.4153892}, {'year_month': '2015_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 1.5699666}, {'year_month': '2015_MAMJJASO', 'bound_name': 'kaabong', 'mean': 1.5480385}, {'year_month': '2015_MAMJJASO', 'bound_name': 'karenga', 'mean': 1.7467586}, {'year_month': '2015_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.5945972}, {'year_month': '2015_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 1.5997654}, {'year_month': '2015_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6570947}, {'year_month': '2015_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 1.5930054}, {'year_month': '2015_MAMJJASO', 'bound_name': 'karamoja', 'mean': 1.6183964}]
#        year_month       bound_name      mean
# 0   2015_MAMJJASO             abim  1.759517
# 1   2015_MAMJJASO            napak  1.650599
# 2   2015_MAMJJASO        nabilatuk  1.516691
# 3   2015_MAMJJASO           kotido  1.766896
# 4   2015_MAMJJASO           moroto  1.415389
# 5   2015_MAMJJASO    nakapiripirit  1.569967
# 6   2015_MAMJJASO          kaabong  1.548038
# 7   2015_MAMJJASO          karenga  1.746759
# 8   2015_MAMJJASO           amudat  1.594597
# 9   2015_MAMJJASO    nab_nak_napak  1.599765
# 10  2015_MAMJJASO  abi_kar_kaboong  1.657095
# 11  2015_MAMJJASO   mor_kot_amudat  1.593005
# 12  2015_MAMJJASO         karamoja  1.618396
# []
# [{'year_month': '2016_MAMJJASO', 'bound_name': 'abim', 'mean': 1.5084578}, {'year_month': '2016_MAMJJASO', 'bound_name': 'napak', 'mean': 1.3936077}, {'year_month': '2016_MAMJJASO', 'bound_name': 'nabilatuk', 'mean': 1.3720183}, {'year_month': '2016_MAMJJASO', 'bound_name': 'kotido', 'mean': 1.075465}, {'year_month': '2016_MAMJJASO', 'bound_name': 'moroto', 'mean': 0.54110295}, {'year_month': '2016_MAMJJASO', 'bound_name': 'nakapiripirit', 'mean': 1.4603115}, {'year_month': '2016_MAMJJASO', 'bound_name': 'kaabong', 'mean': 0.8461924}, {'year_month': '2016_MAMJJASO', 'bound_name': 'karenga', 'mean': 1.1795043}, {'year_month': '2016_MAMJJASO', 'bound_name': 'amudat', 'mean': 1.2410821}, {'year_month': '2016_MAMJJASO', 'bound_name': 'nab_nak_napak', 'mean': 1.4074281}, {'year_month': '2016_MAMJJASO', 'bound_name': 'abi_kar_kaboong', 'mean': 1.1159062}, {'year_month': '2016_MAMJJASO', 'bound_name': 'mor_kot_amudat', 'mean': 0.89007026}, {'year_month': '2016_MAMJJASO', 'bound_name': 'karamoja', 'mean': 1.1365517}]
#        year_month       bound_name      mean
# 0   2016_MAMJJASO             abim  1.508458
# 1   2016_MAMJJASO            napak  1.393608
# 2   2016_MAMJJASO        nabilatuk  1.372018
# 3   2016_MAMJJASO           kotido  1.075465
# 4   2016_MAMJJASO           moroto  0.541103
# 5   2016_MAMJJASO    nakapiripirit  1.460312
# 6   2016_MAMJJASO          kaabong  0.846192
# 7   2016_MAMJJASO          karenga  1.179504
# 8   2016_MAMJJASO           amudat  1.241082
# 9   2016_MAMJJASO    nab_nak_napak  1.407428
# 10  2016_MAMJJASO  abi_kar_kaboong  1.115906
# 11  2016_MAMJJASO   mor_kot_amudat  0.890070
# 12  2016_MAMJJASO         karamoja  1.136552

# %%
ncfile_list=['spei01','spei03','spei06','spei09','spei12','spei24','spei48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for JJAS
start_month_index=5
end_month_index=8

var_str='spei'

for ncfilename in ncfile_list:
    make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index)
# Out:
# []
# [{'year_month': '1981_JJAS', 'bound_name': 'abim', 'mean': 0.55818623}, {'year_month': '1981_JJAS', 'bound_name': 'napak', 'mean': 0.78212136}, {'year_month': '1981_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.6151881}, {'year_month': '1981_JJAS', 'bound_name': 'kotido', 'mean': 0.7966658}, {'year_month': '1981_JJAS', 'bound_name': 'moroto', 'mean': 0.7946417}, {'year_month': '1981_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.28234264}, {'year_month': '1981_JJAS', 'bound_name': 'kaabong', 'mean': 0.6858148}, {'year_month': '1981_JJAS', 'bound_name': 'karenga', 'mean': 0.5820157}, {'year_month': '1981_JJAS', 'bound_name': 'amudat', 'mean': -0.011519474}, {'year_month': '1981_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.608466}, {'year_month': '1981_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.62400633}, {'year_month': '1981_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.6466009}, {'year_month': '1981_JJAS', 'bound_name': 'karamoja', 'mean': 0.6262756}]
#    year_month       bound_name      mean
# 0   1981_JJAS             abim  0.558186
# 1   1981_JJAS            napak  0.782121
# 2   1981_JJAS        nabilatuk  0.615188
# 3   1981_JJAS           kotido  0.796666
# 4   1981_JJAS           moroto  0.794642
# 5   1981_JJAS    nakapiripirit  0.282343
# 6   1981_JJAS          kaabong  0.685815
# 7   1981_JJAS          karenga  0.582016
# 8   1981_JJAS           amudat -0.011519
# 9   1981_JJAS    nab_nak_napak  0.608466
# 10  1981_JJAS  abi_kar_kaboong  0.624006
# 11  1981_JJAS   mor_kot_amudat  0.646601
# 12  1981_JJAS         karamoja  0.626276
# []
# [{'year_month': '1982_JJAS', 'bound_name': 'abim', 'mean': -0.071601816}, {'year_month': '1982_JJAS', 'bound_name': 'napak', 'mean': -0.39166462}, {'year_month': '1982_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.6715312}, {'year_month': '1982_JJAS', 'bound_name': 'kotido', 'mean': -0.073914126}, {'year_month': '1982_JJAS', 'bound_name': 'moroto', 'mean': -0.4736221}, {'year_month': '1982_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.74259114}, {'year_month': '1982_JJAS', 'bound_name': 'kaabong', 'mean': -0.065871015}, {'year_month': '1982_JJAS', 'bound_name': 'karenga', 'mean': 0.12137738}, {'year_month': '1982_JJAS', 'bound_name': 'amudat', 'mean': -0.82454026}, {'year_month': '1982_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.54829067}, {'year_month': '1982_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.020963402}, {'year_month': '1982_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.37408596}, {'year_month': '1982_JJAS', 'bound_name': 'karamoja', 'mean': -0.30145478}]
#    year_month       bound_name      mean
# 0   1982_JJAS             abim -0.071602
# 1   1982_JJAS            napak -0.391665
# 2   1982_JJAS        nabilatuk -0.671531
# 3   1982_JJAS           kotido -0.073914
# 4   1982_JJAS           moroto -0.473622
# 5   1982_JJAS    nakapiripirit -0.742591
# 6   1982_JJAS          kaabong -0.065871
# 7   1982_JJAS          karenga  0.121377
# 8   1982_JJAS           amudat -0.824540
# 9   1982_JJAS    nab_nak_napak -0.548291
# 10  1982_JJAS  abi_kar_kaboong -0.020963
# 11  1982_JJAS   mor_kot_amudat -0.374086
# 12  1982_JJAS         karamoja -0.301455
# []
# [{'year_month': '1983_JJAS', 'bound_name': 'abim', 'mean': 0.103604704}, {'year_month': '1983_JJAS', 'bound_name': 'napak', 'mean': 0.27916917}, {'year_month': '1983_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.095634975}, {'year_month': '1983_JJAS', 'bound_name': 'kotido', 'mean': 0.6805932}, {'year_month': '1983_JJAS', 'bound_name': 'moroto', 'mean': 0.7441598}, {'year_month': '1983_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.13585779}, {'year_month': '1983_JJAS', 'bound_name': 'kaabong', 'mean': 0.940905}, {'year_month': '1983_JJAS', 'bound_name': 'karenga', 'mean': 0.7653531}, {'year_month': '1983_JJAS', 'bound_name': 'amudat', 'mean': 0.085359745}, {'year_month': '1983_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.12538345}, {'year_month': '1983_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.6609929}, {'year_month': '1983_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.59636444}, {'year_month': '1983_JJAS', 'bound_name': 'karamoja', 'mean': 0.4699666}]
#    year_month       bound_name      mean
# 0   1983_JJAS             abim  0.103605
# 1   1983_JJAS            napak  0.279169
# 2   1983_JJAS        nabilatuk  0.095635
# 3   1983_JJAS           kotido  0.680593
# 4   1983_JJAS           moroto  0.744160
# 5   1983_JJAS    nakapiripirit -0.135858
# 6   1983_JJAS          kaabong  0.940905
# 7   1983_JJAS          karenga  0.765353
# 8   1983_JJAS           amudat  0.085360
# 9   1983_JJAS    nab_nak_napak  0.125383
# 10  1983_JJAS  abi_kar_kaboong  0.660993
# 11  1983_JJAS   mor_kot_amudat  0.596364
# 12  1983_JJAS         karamoja  0.469967
# []
# [{'year_month': '1984_JJAS', 'bound_name': 'abim', 'mean': -0.49210507}, {'year_month': '1984_JJAS', 'bound_name': 'napak', 'mean': -0.8690555}, {'year_month': '1984_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.8505661}, {'year_month': '1984_JJAS', 'bound_name': 'kotido', 'mean': -1.1819559}, {'year_month': '1984_JJAS', 'bound_name': 'moroto', 'mean': -1.2478302}, {'year_month': '1984_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.8887016}, {'year_month': '1984_JJAS', 'bound_name': 'kaabong', 'mean': -1.3669001}, {'year_month': '1984_JJAS', 'bound_name': 'karenga', 'mean': -1.5765122}, {'year_month': '1984_JJAS', 'bound_name': 'amudat', 'mean': -1.1022931}, {'year_month': '1984_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.8705388}, {'year_month': '1984_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -1.172107}, {'year_month': '1984_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -1.1938698}, {'year_month': '1984_JJAS', 'bound_name': 'karamoja', 'mean': -1.0831163}]
#    year_month       bound_name      mean
# 0   1984_JJAS             abim -0.492105
# 1   1984_JJAS            napak -0.869056
# 2   1984_JJAS        nabilatuk -0.850566
# 3   1984_JJAS           kotido -1.181956
# 4   1984_JJAS           moroto -1.247830
# 5   1984_JJAS    nakapiripirit -0.888702
# 6   1984_JJAS          kaabong -1.366900
# 7   1984_JJAS          karenga -1.576512
# 8   1984_JJAS           amudat -1.102293
# 9   1984_JJAS    nab_nak_napak -0.870539
# 10  1984_JJAS  abi_kar_kaboong -1.172107
# 11  1984_JJAS   mor_kot_amudat -1.193870
# 12  1984_JJAS         karamoja -1.083116
# []
# [{'year_month': '1985_JJAS', 'bound_name': 'abim', 'mean': -0.1028304}, {'year_month': '1985_JJAS', 'bound_name': 'napak', 'mean': -0.33774316}, {'year_month': '1985_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.26300547}, {'year_month': '1985_JJAS', 'bound_name': 'kotido', 'mean': -0.21753955}, {'year_month': '1985_JJAS', 'bound_name': 'moroto', 'mean': -0.19592011}, {'year_month': '1985_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.15689535}, {'year_month': '1985_JJAS', 'bound_name': 'kaabong', 'mean': -0.037784733}, {'year_month': '1985_JJAS', 'bound_name': 'karenga', 'mean': 0.09972265}, {'year_month': '1985_JJAS', 'bound_name': 'amudat', 'mean': -0.14954025}, {'year_month': '1985_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.18517168}, {'year_month': '1985_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.02197523}, {'year_month': '1985_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.19624403}, {'year_month': '1985_JJAS', 'bound_name': 'karamoja', 'mean': -0.12952732}]
#    year_month       bound_name      mean
# 0   1985_JJAS             abim -0.102830
# 1   1985_JJAS            napak -0.337743
# 2   1985_JJAS        nabilatuk -0.263005
# 3   1985_JJAS           kotido -0.217540
# 4   1985_JJAS           moroto -0.195920
# 5   1985_JJAS    nakapiripirit  0.156895
# 6   1985_JJAS          kaabong -0.037785
# 7   1985_JJAS          karenga  0.099723
# 8   1985_JJAS           amudat -0.149540
# 9   1985_JJAS    nab_nak_napak -0.185172
# 10  1985_JJAS  abi_kar_kaboong -0.021975
# 11  1985_JJAS   mor_kot_amudat -0.196244
# 12  1985_JJAS         karamoja -0.129527
# []
# [{'year_month': '1986_JJAS', 'bound_name': 'abim', 'mean': -1.1376653}, {'year_month': '1986_JJAS', 'bound_name': 'napak', 'mean': -0.8830448}, {'year_month': '1986_JJAS', 'bound_name': 'nabilatuk', 'mean': -1.0842164}, {'year_month': '1986_JJAS', 'bound_name': 'kotido', 'mean': -0.43343896}, {'year_month': '1986_JJAS', 'bound_name': 'moroto', 'mean': -0.45342386}, {'year_month': '1986_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.9515865}, {'year_month': '1986_JJAS', 'bound_name': 'kaabong', 'mean': -0.07008629}, {'year_month': '1986_JJAS', 'bound_name': 'karenga', 'mean': -0.23838432}, {'year_month': '1986_JJAS', 'bound_name': 'amudat', 'mean': -0.6637435}, {'year_month': '1986_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.94488484}, {'year_month': '1986_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.41318262}, {'year_month': '1986_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.48404658}, {'year_month': '1986_JJAS', 'bound_name': 'karamoja', 'mean': -0.6049567}]
#    year_month       bound_name      mean
# 0   1986_JJAS             abim -1.137665
# 1   1986_JJAS            napak -0.883045
# 2   1986_JJAS        nabilatuk -1.084216
# 3   1986_JJAS           kotido -0.433439
# 4   1986_JJAS           moroto -0.453424
# 5   1986_JJAS    nakapiripirit -0.951586
# 6   1986_JJAS          kaabong -0.070086
# 7   1986_JJAS          karenga -0.238384
# 8   1986_JJAS           amudat -0.663743
# 9   1986_JJAS    nab_nak_napak -0.944885
# 10  1986_JJAS  abi_kar_kaboong -0.413183
# 11  1986_JJAS   mor_kot_amudat -0.484047
# 12  1986_JJAS         karamoja -0.604957
# []
# [{'year_month': '1987_JJAS', 'bound_name': 'abim', 'mean': -0.21031559}, {'year_month': '1987_JJAS', 'bound_name': 'napak', 'mean': -0.30935118}, {'year_month': '1987_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.017378636}, {'year_month': '1987_JJAS', 'bound_name': 'kotido', 'mean': -0.42904603}, {'year_month': '1987_JJAS', 'bound_name': 'moroto', 'mean': -0.074883886}, {'year_month': '1987_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.07335191}, {'year_month': '1987_JJAS', 'bound_name': 'kaabong', 'mean': -0.6013355}, {'year_month': '1987_JJAS', 'bound_name': 'karenga', 'mean': -0.54816467}, {'year_month': '1987_JJAS', 'bound_name': 'amudat', 'mean': -0.20870064}, {'year_month': '1987_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.1818887}, {'year_month': '1987_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.47777516}, {'year_month': '1987_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.24520946}, {'year_month': '1987_JJAS', 'bound_name': 'karamoja', 'mean': -0.3093993}]
#    year_month       bound_name      mean
# 0   1987_JJAS             abim -0.210316
# 1   1987_JJAS            napak -0.309351
# 2   1987_JJAS        nabilatuk -0.017379
# 3   1987_JJAS           kotido -0.429046
# 4   1987_JJAS           moroto -0.074884
# 5   1987_JJAS    nakapiripirit -0.073352
# 6   1987_JJAS          kaabong -0.601336
# 7   1987_JJAS          karenga -0.548165
# 8   1987_JJAS           amudat -0.208701
# 9   1987_JJAS    nab_nak_napak -0.181889
# 10  1987_JJAS  abi_kar_kaboong -0.477775
# 11  1987_JJAS   mor_kot_amudat -0.245209
# 12  1987_JJAS         karamoja -0.309399
# []
# [{'year_month': '1988_JJAS', 'bound_name': 'abim', 'mean': 0.3104232}, {'year_month': '1988_JJAS', 'bound_name': 'napak', 'mean': 0.55701303}, {'year_month': '1988_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.0417672}, {'year_month': '1988_JJAS', 'bound_name': 'kotido', 'mean': 0.687394}, {'year_month': '1988_JJAS', 'bound_name': 'moroto', 'mean': 0.90899396}, {'year_month': '1988_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.131327}, {'year_month': '1988_JJAS', 'bound_name': 'kaabong', 'mean': 0.98191285}, {'year_month': '1988_JJAS', 'bound_name': 'karenga', 'mean': 0.72170043}, {'year_month': '1988_JJAS', 'bound_name': 'amudat', 'mean': 1.0016546}, {'year_month': '1988_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.8190439}, {'year_month': '1988_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.72775877}, {'year_month': '1988_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.8349948}, {'year_month': '1988_JJAS', 'bound_name': 'karamoja', 'mean': 0.79103374}]
#    year_month       bound_name      mean
# 0   1988_JJAS             abim  0.310423
# 1   1988_JJAS            napak  0.557013
# 2   1988_JJAS        nabilatuk  1.041767
# 3   1988_JJAS           kotido  0.687394
# 4   1988_JJAS           moroto  0.908994
# 5   1988_JJAS    nakapiripirit  1.131327
# 6   1988_JJAS          kaabong  0.981913
# 7   1988_JJAS          karenga  0.721700
# 8   1988_JJAS           amudat  1.001655
# 9   1988_JJAS    nab_nak_napak  0.819044
# 10  1988_JJAS  abi_kar_kaboong  0.727759
# 11  1988_JJAS   mor_kot_amudat  0.834995
# 12  1988_JJAS         karamoja  0.791034
# []
# [{'year_month': '1989_JJAS', 'bound_name': 'abim', 'mean': -0.47874096}, {'year_month': '1989_JJAS', 'bound_name': 'napak', 'mean': -0.26792762}, {'year_month': '1989_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.14716776}, {'year_month': '1989_JJAS', 'bound_name': 'kotido', 'mean': 0.09128503}, {'year_month': '1989_JJAS', 'bound_name': 'moroto', 'mean': -0.008487937}, {'year_month': '1989_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.20497343}, {'year_month': '1989_JJAS', 'bound_name': 'kaabong', 'mean': -0.044590354}, {'year_month': '1989_JJAS', 'bound_name': 'karenga', 'mean': 0.16725558}, {'year_month': '1989_JJAS', 'bound_name': 'amudat', 'mean': -0.26232263}, {'year_month': '1989_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.11154463}, {'year_month': '1989_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.114474855}, {'year_month': '1989_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.014341663}, {'year_month': '1989_JJAS', 'bound_name': 'karamoja', 'mean': -0.0815758}]
#    year_month       bound_name      mean
# 0   1989_JJAS             abim -0.478741
# 1   1989_JJAS            napak -0.267928
# 2   1989_JJAS        nabilatuk -0.147168
# 3   1989_JJAS           kotido  0.091285
# 4   1989_JJAS           moroto -0.008488
# 5   1989_JJAS    nakapiripirit  0.204973
# 6   1989_JJAS          kaabong -0.044590
# 7   1989_JJAS          karenga  0.167256
# 8   1989_JJAS           amudat -0.262323
# 9   1989_JJAS    nab_nak_napak -0.111545
# 10  1989_JJAS  abi_kar_kaboong -0.114475
# 11  1989_JJAS   mor_kot_amudat -0.014342
# 12  1989_JJAS         karamoja -0.081576
# []
# [{'year_month': '1990_JJAS', 'bound_name': 'abim', 'mean': -0.111995265}, {'year_month': '1990_JJAS', 'bound_name': 'napak', 'mean': -0.42584932}, {'year_month': '1990_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.35787106}, {'year_month': '1990_JJAS', 'bound_name': 'kotido', 'mean': -0.21301329}, {'year_month': '1990_JJAS', 'bound_name': 'moroto', 'mean': -0.42856377}, {'year_month': '1990_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.544789}, {'year_month': '1990_JJAS', 'bound_name': 'kaabong', 'mean': -0.29330263}, {'year_month': '1990_JJAS', 'bound_name': 'karenga', 'mean': -0.34539092}, {'year_month': '1990_JJAS', 'bound_name': 'amudat', 'mean': -0.3298723}, {'year_month': '1990_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.44420442}, {'year_month': '1990_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.25507832}, {'year_month': '1990_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.32171497}, {'year_month': '1990_JJAS', 'bound_name': 'karamoja', 'mean': -0.3365186}]
#    year_month       bound_name      mean
# 0   1990_JJAS             abim -0.111995
# 1   1990_JJAS            napak -0.425849
# 2   1990_JJAS        nabilatuk -0.357871
# 3   1990_JJAS           kotido -0.213013
# 4   1990_JJAS           moroto -0.428564
# 5   1990_JJAS    nakapiripirit -0.544789
# 6   1990_JJAS          kaabong -0.293303
# 7   1990_JJAS          karenga -0.345391
# 8   1990_JJAS           amudat -0.329872
# 9   1990_JJAS    nab_nak_napak -0.444204
# 10  1990_JJAS  abi_kar_kaboong -0.255078
# 11  1990_JJAS   mor_kot_amudat -0.321715
# 12  1990_JJAS         karamoja -0.336519
# []
# [{'year_month': '1991_JJAS', 'bound_name': 'abim', 'mean': 0.7741453}, {'year_month': '1991_JJAS', 'bound_name': 'napak', 'mean': 0.79470897}, {'year_month': '1991_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.6035382}, {'year_month': '1991_JJAS', 'bound_name': 'kotido', 'mean': 0.65595615}, {'year_month': '1991_JJAS', 'bound_name': 'moroto', 'mean': 0.26968765}, {'year_month': '1991_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.7583005}, {'year_month': '1991_JJAS', 'bound_name': 'kaabong', 'mean': 0.49441004}, {'year_month': '1991_JJAS', 'bound_name': 'karenga', 'mean': 0.14515354}, {'year_month': '1991_JJAS', 'bound_name': 'amudat', 'mean': 0.68910074}, {'year_month': '1991_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.74387795}, {'year_month': '1991_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.48657528}, {'year_month': '1991_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.5059545}, {'year_month': '1991_JJAS', 'bound_name': 'karamoja', 'mean': 0.574618}]
#    year_month       bound_name      mean
# 0   1991_JJAS             abim  0.774145
# 1   1991_JJAS            napak  0.794709
# 2   1991_JJAS        nabilatuk  0.603538
# 3   1991_JJAS           kotido  0.655956
# 4   1991_JJAS           moroto  0.269688
# 5   1991_JJAS    nakapiripirit  0.758300
# 6   1991_JJAS          kaabong  0.494410
# 7   1991_JJAS          karenga  0.145154
# 8   1991_JJAS           amudat  0.689101
# 9   1991_JJAS    nab_nak_napak  0.743878
# 10  1991_JJAS  abi_kar_kaboong  0.486575
# 11  1991_JJAS   mor_kot_amudat  0.505955
# 12  1991_JJAS         karamoja  0.574618
# []
# [{'year_month': '1992_JJAS', 'bound_name': 'abim', 'mean': -0.16520363}, {'year_month': '1992_JJAS', 'bound_name': 'napak', 'mean': -0.5228833}, {'year_month': '1992_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.6456219}, {'year_month': '1992_JJAS', 'bound_name': 'kotido', 'mean': -0.36443985}, {'year_month': '1992_JJAS', 'bound_name': 'moroto', 'mean': -0.5683262}, {'year_month': '1992_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.29764852}, {'year_month': '1992_JJAS', 'bound_name': 'kaabong', 'mean': -0.31936276}, {'year_month': '1992_JJAS', 'bound_name': 'karenga', 'mean': -0.31507862}, {'year_month': '1992_JJAS', 'bound_name': 'amudat', 'mean': 0.15540378}, {'year_month': '1992_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.4868466}, {'year_month': '1992_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.27479327}, {'year_month': '1992_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.35084787}, {'year_month': '1992_JJAS', 'bound_name': 'karamoja', 'mean': -0.36653402}]
#    year_month       bound_name      mean
# 0   1992_JJAS             abim -0.165204
# 1   1992_JJAS            napak -0.522883
# 2   1992_JJAS        nabilatuk -0.645622
# 3   1992_JJAS           kotido -0.364440
# 4   1992_JJAS           moroto -0.568326
# 5   1992_JJAS    nakapiripirit -0.297649
# 6   1992_JJAS          kaabong -0.319363
# 7   1992_JJAS          karenga -0.315079
# 8   1992_JJAS           amudat  0.155404
# 9   1992_JJAS    nab_nak_napak -0.486847
# 10  1992_JJAS  abi_kar_kaboong -0.274793
# 11  1992_JJAS   mor_kot_amudat -0.350848
# 12  1992_JJAS         karamoja -0.366534
# []
# [{'year_month': '1993_JJAS', 'bound_name': 'abim', 'mean': -0.5613536}, {'year_month': '1993_JJAS', 'bound_name': 'napak', 'mean': -0.2528904}, {'year_month': '1993_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.21297376}, {'year_month': '1993_JJAS', 'bound_name': 'kotido', 'mean': -0.71710056}, {'year_month': '1993_JJAS', 'bound_name': 'moroto', 'mean': -0.29628277}, {'year_month': '1993_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.22007596}, {'year_month': '1993_JJAS', 'bound_name': 'kaabong', 'mean': -1.0445466}, {'year_month': '1993_JJAS', 'bound_name': 'karenga', 'mean': -1.2947642}, {'year_month': '1993_JJAS', 'bound_name': 'amudat', 'mean': -0.24844216}, {'year_month': '1993_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.022883212}, {'year_month': '1993_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.97035605}, {'year_month': '1993_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.46046725}, {'year_month': '1993_JJAS', 'bound_name': 'karamoja', 'mean': -0.5061566}]
#    year_month       bound_name      mean
# 0   1993_JJAS             abim -0.561354
# 1   1993_JJAS            napak -0.252890
# 2   1993_JJAS        nabilatuk  0.212974
# 3   1993_JJAS           kotido -0.717101
# 4   1993_JJAS           moroto -0.296283
# 5   1993_JJAS    nakapiripirit  0.220076
# 6   1993_JJAS          kaabong -1.044547
# 7   1993_JJAS          karenga -1.294764
# 8   1993_JJAS           amudat -0.248442
# 9   1993_JJAS    nab_nak_napak -0.022883
# 10  1993_JJAS  abi_kar_kaboong -0.970356
# 11  1993_JJAS   mor_kot_amudat -0.460467
# 12  1993_JJAS         karamoja -0.506157
# []
# [{'year_month': '1994_JJAS', 'bound_name': 'abim', 'mean': 0.40342894}, {'year_month': '1994_JJAS', 'bound_name': 'napak', 'mean': 0.27698082}, {'year_month': '1994_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.4089208}, {'year_month': '1994_JJAS', 'bound_name': 'kotido', 'mean': 0.6382743}, {'year_month': '1994_JJAS', 'bound_name': 'moroto', 'mean': 0.29001895}, {'year_month': '1994_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.57131135}, {'year_month': '1994_JJAS', 'bound_name': 'kaabong', 'mean': 0.88331485}, {'year_month': '1994_JJAS', 'bound_name': 'karenga', 'mean': 1.0500174}, {'year_month': '1994_JJAS', 'bound_name': 'amudat', 'mean': 0.8621384}, {'year_month': '1994_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.38642296}, {'year_month': '1994_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.7893069}, {'year_month': '1994_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.5388568}, {'year_month': '1994_JJAS', 'bound_name': 'karamoja', 'mean': 0.5811823}]
#    year_month       bound_name      mean
# 0   1994_JJAS             abim  0.403429
# 1   1994_JJAS            napak  0.276981
# 2   1994_JJAS        nabilatuk  0.408921
# 3   1994_JJAS           kotido  0.638274
# 4   1994_JJAS           moroto  0.290019
# 5   1994_JJAS    nakapiripirit  0.571311
# 6   1994_JJAS          kaabong  0.883315
# 7   1994_JJAS          karenga  1.050017
# 8   1994_JJAS           amudat  0.862138
# 9   1994_JJAS    nab_nak_napak  0.386423
# 10  1994_JJAS  abi_kar_kaboong  0.789307
# 11  1994_JJAS   mor_kot_amudat  0.538857
# 12  1994_JJAS         karamoja  0.581182
# []
# [{'year_month': '1995_JJAS', 'bound_name': 'abim', 'mean': 0.4598257}, {'year_month': '1995_JJAS', 'bound_name': 'napak', 'mean': 0.43498698}, {'year_month': '1995_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.19819945}, {'year_month': '1995_JJAS', 'bound_name': 'kotido', 'mean': 0.027618386}, {'year_month': '1995_JJAS', 'bound_name': 'moroto', 'mean': 0.1438701}, {'year_month': '1995_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.20183417}, {'year_month': '1995_JJAS', 'bound_name': 'kaabong', 'mean': -0.2435015}, {'year_month': '1995_JJAS', 'bound_name': 'karenga', 'mean': -0.38922468}, {'year_month': '1995_JJAS', 'bound_name': 'amudat', 'mean': 0.17180064}, {'year_month': '1995_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.32008103}, {'year_month': '1995_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.081223786}, {'year_month': '1995_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.10123113}, {'year_month': '1995_JJAS', 'bound_name': 'karamoja', 'mean': 0.104691364}]
#    year_month       bound_name      mean
# 0   1995_JJAS             abim  0.459826
# 1   1995_JJAS            napak  0.434987
# 2   1995_JJAS        nabilatuk  0.198199
# 3   1995_JJAS           kotido  0.027618
# 4   1995_JJAS           moroto  0.143870
# 5   1995_JJAS    nakapiripirit  0.201834
# 6   1995_JJAS          kaabong -0.243501
# 7   1995_JJAS          karenga -0.389225
# 8   1995_JJAS           amudat  0.171801
# 9   1995_JJAS    nab_nak_napak  0.320081
# 10  1995_JJAS  abi_kar_kaboong -0.081224
# 11  1995_JJAS   mor_kot_amudat  0.101231
# 12  1995_JJAS         karamoja  0.104691
# []
# [{'year_month': '1996_JJAS', 'bound_name': 'abim', 'mean': 0.54136485}, {'year_month': '1996_JJAS', 'bound_name': 'napak', 'mean': 0.6294943}, {'year_month': '1996_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.6082404}, {'year_month': '1996_JJAS', 'bound_name': 'kotido', 'mean': 0.70309377}, {'year_month': '1996_JJAS', 'bound_name': 'moroto', 'mean': 0.8444865}, {'year_month': '1996_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.6141578}, {'year_month': '1996_JJAS', 'bound_name': 'kaabong', 'mean': 0.8421414}, {'year_month': '1996_JJAS', 'bound_name': 'karenga', 'mean': 0.6168498}, {'year_month': '1996_JJAS', 'bound_name': 'amudat', 'mean': 0.6525805}, {'year_month': '1996_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.62072486}, {'year_month': '1996_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.7012823}, {'year_month': '1996_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.7509139}, {'year_month': '1996_JJAS', 'bound_name': 'karamoja', 'mean': 0.69149905}]
#    year_month       bound_name      mean
# 0   1996_JJAS             abim  0.541365
# 1   1996_JJAS            napak  0.629494
# 2   1996_JJAS        nabilatuk  0.608240
# 3   1996_JJAS           kotido  0.703094
# 4   1996_JJAS           moroto  0.844486
# 5   1996_JJAS    nakapiripirit  0.614158
# 6   1996_JJAS          kaabong  0.842141
# 7   1996_JJAS          karenga  0.616850
# 8   1996_JJAS           amudat  0.652580
# 9   1996_JJAS    nab_nak_napak  0.620725
# 10  1996_JJAS  abi_kar_kaboong  0.701282
# 11  1996_JJAS   mor_kot_amudat  0.750914
# 12  1996_JJAS         karamoja  0.691499
# []
# [{'year_month': '1997_JJAS', 'bound_name': 'abim', 'mean': -0.49069634}, {'year_month': '1997_JJAS', 'bound_name': 'napak', 'mean': -0.4323507}, {'year_month': '1997_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.33598474}, {'year_month': '1997_JJAS', 'bound_name': 'kotido', 'mean': -0.01670623}, {'year_month': '1997_JJAS', 'bound_name': 'moroto', 'mean': 0.22351609}, {'year_month': '1997_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.25839067}, {'year_month': '1997_JJAS', 'bound_name': 'kaabong', 'mean': -0.09188671}, {'year_month': '1997_JJAS', 'bound_name': 'karenga', 'mean': -0.0105744805}, {'year_month': '1997_JJAS', 'bound_name': 'amudat', 'mean': 0.154539}, {'year_month': '1997_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.36374524}, {'year_month': '1997_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.18423088}, {'year_month': '1997_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.11201081}, {'year_month': '1997_JJAS', 'bound_name': 'karamoja', 'mean': -0.14676674}]
#    year_month       bound_name      mean
# 0   1997_JJAS             abim -0.490696
# 1   1997_JJAS            napak -0.432351
# 2   1997_JJAS        nabilatuk -0.335985
# 3   1997_JJAS           kotido -0.016706
# 4   1997_JJAS           moroto  0.223516
# 5   1997_JJAS    nakapiripirit -0.258391
# 6   1997_JJAS          kaabong -0.091887
# 7   1997_JJAS          karenga -0.010574
# 8   1997_JJAS           amudat  0.154539
# 9   1997_JJAS    nab_nak_napak -0.363745
# 10  1997_JJAS  abi_kar_kaboong -0.184231
# 11  1997_JJAS   mor_kot_amudat  0.112011
# 12  1997_JJAS         karamoja -0.146767
# []
# [{'year_month': '1998_JJAS', 'bound_name': 'abim', 'mean': 0.2155895}, {'year_month': '1998_JJAS', 'bound_name': 'napak', 'mean': 0.28664404}, {'year_month': '1998_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.31330985}, {'year_month': '1998_JJAS', 'bound_name': 'kotido', 'mean': 0.67251813}, {'year_month': '1998_JJAS', 'bound_name': 'moroto', 'mean': 0.81441754}, {'year_month': '1998_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.018037563}, {'year_month': '1998_JJAS', 'bound_name': 'kaabong', 'mean': 0.834524}, {'year_month': '1998_JJAS', 'bound_name': 'karenga', 'mean': 0.7781877}, {'year_month': '1998_JJAS', 'bound_name': 'amudat', 'mean': 0.15260187}, {'year_month': '1998_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.20817123}, {'year_month': '1998_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.6458577}, {'year_month': '1998_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.6338588}, {'year_month': '1998_JJAS', 'bound_name': 'karamoja', 'mean': 0.5027853}]
#    year_month       bound_name      mean
# 0   1998_JJAS             abim  0.215589
# 1   1998_JJAS            napak  0.286644
# 2   1998_JJAS        nabilatuk  0.313310
# 3   1998_JJAS           kotido  0.672518
# 4   1998_JJAS           moroto  0.814418
# 5   1998_JJAS    nakapiripirit -0.018038
# 6   1998_JJAS          kaabong  0.834524
# 7   1998_JJAS          karenga  0.778188
# 8   1998_JJAS           amudat  0.152602
# 9   1998_JJAS    nab_nak_napak  0.208171
# 10  1998_JJAS  abi_kar_kaboong  0.645858
# 11  1998_JJAS   mor_kot_amudat  0.633859
# 12  1998_JJAS         karamoja  0.502785
# []
# [{'year_month': '1999_JJAS', 'bound_name': 'abim', 'mean': -0.0575174}, {'year_month': '1999_JJAS', 'bound_name': 'napak', 'mean': -0.41209683}, {'year_month': '1999_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.39839128}, {'year_month': '1999_JJAS', 'bound_name': 'kotido', 'mean': -0.38355505}, {'year_month': '1999_JJAS', 'bound_name': 'moroto', 'mean': -0.61475664}, {'year_month': '1999_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.08095866}, {'year_month': '1999_JJAS', 'bound_name': 'kaabong', 'mean': -0.50866836}, {'year_month': '1999_JJAS', 'bound_name': 'karenga', 'mean': -0.5086601}, {'year_month': '1999_JJAS', 'bound_name': 'amudat', 'mean': -0.6548308}, {'year_month': '1999_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.3177054}, {'year_month': '1999_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.3813477}, {'year_month': '1999_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.5270986}, {'year_month': '1999_JJAS', 'bound_name': 'karamoja', 'mean': -0.4076311}]
#    year_month       bound_name      mean
# 0   1999_JJAS             abim -0.057517
# 1   1999_JJAS            napak -0.412097
# 2   1999_JJAS        nabilatuk -0.398391
# 3   1999_JJAS           kotido -0.383555
# 4   1999_JJAS           moroto -0.614757
# 5   1999_JJAS    nakapiripirit -0.080959
# 6   1999_JJAS          kaabong -0.508668
# 7   1999_JJAS          karenga -0.508660
# 8   1999_JJAS           amudat -0.654831
# 9   1999_JJAS    nab_nak_napak -0.317705
# 10  1999_JJAS  abi_kar_kaboong -0.381348
# 11  1999_JJAS   mor_kot_amudat -0.527099
# 12  1999_JJAS         karamoja -0.407631
# []
# [{'year_month': '2000_JJAS', 'bound_name': 'abim', 'mean': 0.8230761}, {'year_month': '2000_JJAS', 'bound_name': 'napak', 'mean': 0.37056395}, {'year_month': '2000_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.023214204}, {'year_month': '2000_JJAS', 'bound_name': 'kotido', 'mean': 0.558633}, {'year_month': '2000_JJAS', 'bound_name': 'moroto', 'mean': 0.021767529}, {'year_month': '2000_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.12240084}, {'year_month': '2000_JJAS', 'bound_name': 'kaabong', 'mean': -0.017237253}, {'year_month': '2000_JJAS', 'bound_name': 'karenga', 'mean': 0.17197613}, {'year_month': '2000_JJAS', 'bound_name': 'amudat', 'mean': 0.021687394}, {'year_month': '2000_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.16031025}, {'year_month': '2000_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.26691952}, {'year_month': '2000_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.24248491}, {'year_month': '2000_JJAS', 'bound_name': 'karamoja', 'mean': 0.22520319}]
#    year_month       bound_name      mean
# 0   2000_JJAS             abim  0.823076
# 1   2000_JJAS            napak  0.370564
# 2   2000_JJAS        nabilatuk  0.023214
# 3   2000_JJAS           kotido  0.558633
# 4   2000_JJAS           moroto  0.021768
# 5   2000_JJAS    nakapiripirit -0.122401
# 6   2000_JJAS          kaabong -0.017237
# 7   2000_JJAS          karenga  0.171976
# 8   2000_JJAS           amudat  0.021687
# 9   2000_JJAS    nab_nak_napak  0.160310
# 10  2000_JJAS  abi_kar_kaboong  0.266920
# 11  2000_JJAS   mor_kot_amudat  0.242485
# 12  2000_JJAS         karamoja  0.225203
# []
# [{'year_month': '2001_JJAS', 'bound_name': 'abim', 'mean': 0.6094}, {'year_month': '2001_JJAS', 'bound_name': 'napak', 'mean': 1.0209523}, {'year_month': '2001_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.0847842}, {'year_month': '2001_JJAS', 'bound_name': 'kotido', 'mean': 0.44857264}, {'year_month': '2001_JJAS', 'bound_name': 'moroto', 'mean': 0.51646894}, {'year_month': '2001_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.982862}, {'year_month': '2001_JJAS', 'bound_name': 'kaabong', 'mean': 0.27453092}, {'year_month': '2001_JJAS', 'bound_name': 'karenga', 'mean': 0.3383263}, {'year_month': '2001_JJAS', 'bound_name': 'amudat', 'mean': 0.82423264}, {'year_month': '2001_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.0240453}, {'year_month': '2001_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.3848849}, {'year_month': '2001_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.5453878}, {'year_month': '2001_JJAS', 'bound_name': 'karamoja', 'mean': 0.63946134}]
#    year_month       bound_name      mean
# 0   2001_JJAS             abim  0.609400
# 1   2001_JJAS            napak  1.020952
# 2   2001_JJAS        nabilatuk  1.084784
# 3   2001_JJAS           kotido  0.448573
# 4   2001_JJAS           moroto  0.516469
# 5   2001_JJAS    nakapiripirit  0.982862
# 6   2001_JJAS          kaabong  0.274531
# 7   2001_JJAS          karenga  0.338326
# 8   2001_JJAS           amudat  0.824233
# 9   2001_JJAS    nab_nak_napak  1.024045
# 10  2001_JJAS  abi_kar_kaboong  0.384885
# 11  2001_JJAS   mor_kot_amudat  0.545388
# 12  2001_JJAS         karamoja  0.639461
# []
# [{'year_month': '2002_JJAS', 'bound_name': 'abim', 'mean': -0.9308138}, {'year_month': '2002_JJAS', 'bound_name': 'napak', 'mean': -0.9648383}, {'year_month': '2002_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.9623508}, {'year_month': '2002_JJAS', 'bound_name': 'kotido', 'mean': -1.1044811}, {'year_month': '2002_JJAS', 'bound_name': 'moroto', 'mean': -0.8887176}, {'year_month': '2002_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.9531625}, {'year_month': '2002_JJAS', 'bound_name': 'kaabong', 'mean': -0.95802003}, {'year_month': '2002_JJAS', 'bound_name': 'karenga', 'mean': -0.8331605}, {'year_month': '2002_JJAS', 'bound_name': 'amudat', 'mean': -0.8785127}, {'year_month': '2002_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.96108264}, {'year_month': '2002_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.91931885}, {'year_month': '2002_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.9755441}, {'year_month': '2002_JJAS', 'bound_name': 'karamoja', 'mean': -0.9505548}]
#    year_month       bound_name      mean
# 0   2002_JJAS             abim -0.930814
# 1   2002_JJAS            napak -0.964838
# 2   2002_JJAS        nabilatuk -0.962351
# 3   2002_JJAS           kotido -1.104481
# 4   2002_JJAS           moroto -0.888718
# 5   2002_JJAS    nakapiripirit -0.953162
# 6   2002_JJAS          kaabong -0.958020
# 7   2002_JJAS          karenga -0.833161
# 8   2002_JJAS           amudat -0.878513
# 9   2002_JJAS    nab_nak_napak -0.961083
# 10  2002_JJAS  abi_kar_kaboong -0.919319
# 11  2002_JJAS   mor_kot_amudat -0.975544
# 12  2002_JJAS         karamoja -0.950555
# []
# [{'year_month': '2003_JJAS', 'bound_name': 'abim', 'mean': 0.48193988}, {'year_month': '2003_JJAS', 'bound_name': 'napak', 'mean': 0.5748678}, {'year_month': '2003_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.892058}, {'year_month': '2003_JJAS', 'bound_name': 'kotido', 'mean': 0.27412966}, {'year_month': '2003_JJAS', 'bound_name': 'moroto', 'mean': 0.33041638}, {'year_month': '2003_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.75700676}, {'year_month': '2003_JJAS', 'bound_name': 'kaabong', 'mean': 0.15354663}, {'year_month': '2003_JJAS', 'bound_name': 'karenga', 'mean': -0.0039024667}, {'year_month': '2003_JJAS', 'bound_name': 'amudat', 'mean': 0.76701826}, {'year_month': '2003_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.69283134}, {'year_month': '2003_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.20710123}, {'year_month': '2003_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.38790095}, {'year_month': '2003_JJAS', 'bound_name': 'karamoja', 'mean': 0.41934633}]
#    year_month       bound_name      mean
# 0   2003_JJAS             abim  0.481940
# 1   2003_JJAS            napak  0.574868
# 2   2003_JJAS        nabilatuk  0.892058
# 3   2003_JJAS           kotido  0.274130
# 4   2003_JJAS           moroto  0.330416
# 5   2003_JJAS    nakapiripirit  0.757007
# 6   2003_JJAS          kaabong  0.153547
# 7   2003_JJAS          karenga -0.003902
# 8   2003_JJAS           amudat  0.767018
# 9   2003_JJAS    nab_nak_napak  0.692831
# 10  2003_JJAS  abi_kar_kaboong  0.207101
# 11  2003_JJAS   mor_kot_amudat  0.387901
# 12  2003_JJAS         karamoja  0.419346
# []
# [{'year_month': '2004_JJAS', 'bound_name': 'abim', 'mean': -0.36246988}, {'year_month': '2004_JJAS', 'bound_name': 'napak', 'mean': -0.26140845}, {'year_month': '2004_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.66520053}, {'year_month': '2004_JJAS', 'bound_name': 'kotido', 'mean': -0.39539695}, {'year_month': '2004_JJAS', 'bound_name': 'moroto', 'mean': -0.584581}, {'year_month': '2004_JJAS', 'bound_name': 'nakapiripirit', 'mean': -1.0030949}, {'year_month': '2004_JJAS', 'bound_name': 'kaabong', 'mean': -0.4738649}, {'year_month': '2004_JJAS', 'bound_name': 'karenga', 'mean': -0.15345962}, {'year_month': '2004_JJAS', 'bound_name': 'amudat', 'mean': -0.9158918}, {'year_month': '2004_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.55240333}, {'year_month': '2004_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.36281833}, {'year_month': '2004_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.5679809}, {'year_month': '2004_JJAS', 'bound_name': 'karamoja', 'mean': -0.48862815}]
#    year_month       bound_name      mean
# 0   2004_JJAS             abim -0.362470
# 1   2004_JJAS            napak -0.261408
# 2   2004_JJAS        nabilatuk -0.665201
# 3   2004_JJAS           kotido -0.395397
# 4   2004_JJAS           moroto -0.584581
# 5   2004_JJAS    nakapiripirit -1.003095
# 6   2004_JJAS          kaabong -0.473865
# 7   2004_JJAS          karenga -0.153460
# 8   2004_JJAS           amudat -0.915892
# 9   2004_JJAS    nab_nak_napak -0.552403
# 10  2004_JJAS  abi_kar_kaboong -0.362818
# 11  2004_JJAS   mor_kot_amudat -0.567981
# 12  2004_JJAS         karamoja -0.488628
# []
# [{'year_month': '2005_JJAS', 'bound_name': 'abim', 'mean': -1.1176031}, {'year_month': '2005_JJAS', 'bound_name': 'napak', 'mean': -0.6967665}, {'year_month': '2005_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.503583}, {'year_month': '2005_JJAS', 'bound_name': 'kotido', 'mean': -0.7674777}, {'year_month': '2005_JJAS', 'bound_name': 'moroto', 'mean': -0.20233075}, {'year_month': '2005_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.62776333}, {'year_month': '2005_JJAS', 'bound_name': 'kaabong', 'mean': -0.26272705}, {'year_month': '2005_JJAS', 'bound_name': 'karenga', 'mean': -0.4794963}, {'year_month': '2005_JJAS', 'bound_name': 'amudat', 'mean': -0.6399396}, {'year_month': '2005_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.6365027}, {'year_month': '2005_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.55784017}, {'year_month': '2005_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.5155036}, {'year_month': '2005_JJAS', 'bound_name': 'karamoja', 'mean': -0.5693495}]
#    year_month       bound_name      mean
# 0   2005_JJAS             abim -1.117603
# 1   2005_JJAS            napak -0.696766
# 2   2005_JJAS        nabilatuk -0.503583
# 3   2005_JJAS           kotido -0.767478
# 4   2005_JJAS           moroto -0.202331
# 5   2005_JJAS    nakapiripirit -0.627763
# 6   2005_JJAS          kaabong -0.262727
# 7   2005_JJAS          karenga -0.479496
# 8   2005_JJAS           amudat -0.639940
# 9   2005_JJAS    nab_nak_napak -0.636503
# 10  2005_JJAS  abi_kar_kaboong -0.557840
# 11  2005_JJAS   mor_kot_amudat -0.515504
# 12  2005_JJAS         karamoja -0.569350
# []
# [{'year_month': '2006_JJAS', 'bound_name': 'abim', 'mean': -0.20946379}, {'year_month': '2006_JJAS', 'bound_name': 'napak', 'mean': -0.54904836}, {'year_month': '2006_JJAS', 'bound_name': 'nabilatuk', 'mean': -0.5848754}, {'year_month': '2006_JJAS', 'bound_name': 'kotido', 'mean': -0.20823134}, {'year_month': '2006_JJAS', 'bound_name': 'moroto', 'mean': -0.19028628}, {'year_month': '2006_JJAS', 'bound_name': 'nakapiripirit', 'mean': -0.81316197}, {'year_month': '2006_JJAS', 'bound_name': 'kaabong', 'mean': -0.09679213}, {'year_month': '2006_JJAS', 'bound_name': 'karenga', 'mean': -0.007197109}, {'year_month': '2006_JJAS', 'bound_name': 'amudat', 'mean': -0.44076163}, {'year_month': '2006_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -0.6296443}, {'year_month': '2006_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.106327735}, {'year_month': '2006_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.2439194}, {'year_month': '2006_JJAS', 'bound_name': 'karamoja', 'mean': -0.31673637}]
#    year_month       bound_name      mean
# 0   2006_JJAS             abim -0.209464
# 1   2006_JJAS            napak -0.549048
# 2   2006_JJAS        nabilatuk -0.584875
# 3   2006_JJAS           kotido -0.208231
# 4   2006_JJAS           moroto -0.190286
# 5   2006_JJAS    nakapiripirit -0.813162
# 6   2006_JJAS          kaabong -0.096792
# 7   2006_JJAS          karenga -0.007197
# 8   2006_JJAS           amudat -0.440762
# 9   2006_JJAS    nab_nak_napak -0.629644
# 10  2006_JJAS  abi_kar_kaboong -0.106328
# 11  2006_JJAS   mor_kot_amudat -0.243919
# 12  2006_JJAS         karamoja -0.316736
# []
# [{'year_month': '2007_JJAS', 'bound_name': 'abim', 'mean': 1.0972846}, {'year_month': '2007_JJAS', 'bound_name': 'napak', 'mean': 1.42385}, {'year_month': '2007_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.3163087}, {'year_month': '2007_JJAS', 'bound_name': 'kotido', 'mean': 1.4313208}, {'year_month': '2007_JJAS', 'bound_name': 'moroto', 'mean': 1.6974097}, {'year_month': '2007_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.2074482}, {'year_month': '2007_JJAS', 'bound_name': 'kaabong', 'mean': 1.6030327}, {'year_month': '2007_JJAS', 'bound_name': 'karenga', 'mean': 1.4333264}, {'year_month': '2007_JJAS', 'bound_name': 'amudat', 'mean': 1.4057571}, {'year_month': '2007_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.3411375}, {'year_month': '2007_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.4181398}, {'year_month': '2007_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.5341482}, {'year_month': '2007_JJAS', 'bound_name': 'karamoja', 'mean': 1.4306779}]
#    year_month       bound_name      mean
# 0   2007_JJAS             abim  1.097285
# 1   2007_JJAS            napak  1.423850
# 2   2007_JJAS        nabilatuk  1.316309
# 3   2007_JJAS           kotido  1.431321
# 4   2007_JJAS           moroto  1.697410
# 5   2007_JJAS    nakapiripirit  1.207448
# 6   2007_JJAS          kaabong  1.603033
# 7   2007_JJAS          karenga  1.433326
# 8   2007_JJAS           amudat  1.405757
# 9   2007_JJAS    nab_nak_napak  1.341138
# 10  2007_JJAS  abi_kar_kaboong  1.418140
# 11  2007_JJAS   mor_kot_amudat  1.534148
# 12  2007_JJAS         karamoja  1.430678
# []
# [{'year_month': '2008_JJAS', 'bound_name': 'abim', 'mean': 0.24886997}, {'year_month': '2008_JJAS', 'bound_name': 'napak', 'mean': 0.27142876}, {'year_month': '2008_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.50084317}, {'year_month': '2008_JJAS', 'bound_name': 'kotido', 'mean': 0.114626564}, {'year_month': '2008_JJAS', 'bound_name': 'moroto', 'mean': -0.06404627}, {'year_month': '2008_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.46546036}, {'year_month': '2008_JJAS', 'bound_name': 'kaabong', 'mean': -0.28997406}, {'year_month': '2008_JJAS', 'bound_name': 'karenga', 'mean': -0.209607}, {'year_month': '2008_JJAS', 'bound_name': 'amudat', 'mean': 0.32573962}, {'year_month': '2008_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.37395594}, {'year_month': '2008_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.11793917}, {'year_month': '2008_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.0813964}, {'year_month': '2008_JJAS', 'bound_name': 'karamoja', 'mean': 0.102184646}]
#    year_month       bound_name      mean
# 0   2008_JJAS             abim  0.248870
# 1   2008_JJAS            napak  0.271429
# 2   2008_JJAS        nabilatuk  0.500843
# 3   2008_JJAS           kotido  0.114627
# 4   2008_JJAS           moroto -0.064046
# 5   2008_JJAS    nakapiripirit  0.465460
# 6   2008_JJAS          kaabong -0.289974
# 7   2008_JJAS          karenga -0.209607
# 8   2008_JJAS           amudat  0.325740
# 9   2008_JJAS    nab_nak_napak  0.373956
# 10  2008_JJAS  abi_kar_kaboong -0.117939
# 11  2008_JJAS   mor_kot_amudat  0.081396
# 12  2008_JJAS         karamoja  0.102185
# []
# [{'year_month': '2009_JJAS', 'bound_name': 'abim', 'mean': -1.4343257}, {'year_month': '2009_JJAS', 'bound_name': 'napak', 'mean': -1.6145493}, {'year_month': '2009_JJAS', 'bound_name': 'nabilatuk', 'mean': -1.3378967}, {'year_month': '2009_JJAS', 'bound_name': 'kotido', 'mean': -1.6500604}, {'year_month': '2009_JJAS', 'bound_name': 'moroto', 'mean': -1.5312968}, {'year_month': '2009_JJAS', 'bound_name': 'nakapiripirit', 'mean': -1.1985152}, {'year_month': '2009_JJAS', 'bound_name': 'kaabong', 'mean': -1.4111723}, {'year_month': '2009_JJAS', 'bound_name': 'karenga', 'mean': -1.4094654}, {'year_month': '2009_JJAS', 'bound_name': 'amudat', 'mean': -1.140839}, {'year_month': '2009_JJAS', 'bound_name': 'nab_nak_napak', 'mean': -1.4406246}, {'year_month': '2009_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -1.4172822}, {'year_month': '2009_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -1.508021}, {'year_month': '2009_JJAS', 'bound_name': 'karamoja', 'mean': -1.4536759}]
#    year_month       bound_name      mean
# 0   2009_JJAS             abim -1.434326
# 1   2009_JJAS            napak -1.614549
# 2   2009_JJAS        nabilatuk -1.337897
# 3   2009_JJAS           kotido -1.650060
# 4   2009_JJAS           moroto -1.531297
# 5   2009_JJAS    nakapiripirit -1.198515
# 6   2009_JJAS          kaabong -1.411172
# 7   2009_JJAS          karenga -1.409465
# 8   2009_JJAS           amudat -1.140839
# 9   2009_JJAS    nab_nak_napak -1.440625
# 10  2009_JJAS  abi_kar_kaboong -1.417282
# 11  2009_JJAS   mor_kot_amudat -1.508021
# 12  2009_JJAS         karamoja -1.453676
# []
# [{'year_month': '2010_JJAS', 'bound_name': 'abim', 'mean': -0.2623152}, {'year_month': '2010_JJAS', 'bound_name': 'napak', 'mean': -0.045353204}, {'year_month': '2010_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.12170491}, {'year_month': '2010_JJAS', 'bound_name': 'kotido', 'mean': -0.3183658}, {'year_month': '2010_JJAS', 'bound_name': 'moroto', 'mean': 0.10594224}, {'year_month': '2010_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.19436708}, {'year_month': '2010_JJAS', 'bound_name': 'kaabong', 'mean': -0.28459603}, {'year_month': '2010_JJAS', 'bound_name': 'karenga', 'mean': -0.30027285}, {'year_month': '2010_JJAS', 'bound_name': 'amudat', 'mean': 0.21739624}, {'year_month': '2010_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.05649452}, {'year_month': '2010_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.28220338}, {'year_month': '2010_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.04792983}, {'year_month': '2010_JJAS', 'bound_name': 'karamoja', 'mean': -0.09966267}]
#    year_month       bound_name      mean
# 0   2010_JJAS             abim -0.262315
# 1   2010_JJAS            napak -0.045353
# 2   2010_JJAS        nabilatuk  0.121705
# 3   2010_JJAS           kotido -0.318366
# 4   2010_JJAS           moroto  0.105942
# 5   2010_JJAS    nakapiripirit  0.194367
# 6   2010_JJAS          kaabong -0.284596
# 7   2010_JJAS          karenga -0.300273
# 8   2010_JJAS           amudat  0.217396
# 9   2010_JJAS    nab_nak_napak  0.056495
# 10  2010_JJAS  abi_kar_kaboong -0.282203
# 11  2010_JJAS   mor_kot_amudat -0.047930
# 12  2010_JJAS         karamoja -0.099663
# []
# [{'year_month': '2011_JJAS', 'bound_name': 'abim', 'mean': 0.7979424}, {'year_month': '2011_JJAS', 'bound_name': 'napak', 'mean': 1.0691295}, {'year_month': '2011_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.9999995}, {'year_month': '2011_JJAS', 'bound_name': 'kotido', 'mean': 0.8903929}, {'year_month': '2011_JJAS', 'bound_name': 'moroto', 'mean': 0.9495894}, {'year_month': '2011_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.8625422}, {'year_month': '2011_JJAS', 'bound_name': 'kaabong', 'mean': 1.007778}, {'year_month': '2011_JJAS', 'bound_name': 'karenga', 'mean': 0.98524773}, {'year_month': '2011_JJAS', 'bound_name': 'amudat', 'mean': 0.9025257}, {'year_month': '2011_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.99732065}, {'year_month': '2011_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.9429625}, {'year_month': '2011_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.91655964}, {'year_month': '2011_JJAS', 'bound_name': 'karamoja', 'mean': 0.9518265}]
#    year_month       bound_name      mean
# 0   2011_JJAS             abim  0.797942
# ...
# 2   2006_JJAS        nabilatuk -0.263508
# 3   2006_JJAS           kotido -1.027269
# 4   2006_JJAS           moroto -0.481827
# 5   2006_JJAS    nakapiripirit -0.556287
# 6   2006_JJAS          kaabong -0.878387
# 7   2006_JJAS          karenga -1.117114
# 8   2006_JJAS           amudat -0.580269
# 9   2006_JJAS    nab_nak_napak -0.476297
# 10  2006_JJAS  abi_kar_kaboong -1.004741
# 11  2006_JJAS   mor_kot_amudat -0.724265
# 12  2006_JJAS         karamoja -0.747086
# []
# [{'year_month': '2007_JJAS', 'bound_name': 'abim', 'mean': 0.182375}, {'year_month': '2007_JJAS', 'bound_name': 'napak', 'mean': 0.654065}, {'year_month': '2007_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.50678027}, {'year_month': '2007_JJAS', 'bound_name': 'kotido', 'mean': 0.6004588}, {'year_month': '2007_JJAS', 'bound_name': 'moroto', 'mean': 1.2358302}, {'year_month': '2007_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.14341603}, {'year_month': '2007_JJAS', 'bound_name': 'kaabong', 'mean': 1.2163951}, {'year_month': '2007_JJAS', 'bound_name': 'karenga', 'mean': 0.9290017}, {'year_month': '2007_JJAS', 'bound_name': 'amudat', 'mean': 0.51812327}, {'year_month': '2007_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.48159778}, {'year_month': '2007_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.85317826}, {'year_month': '2007_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.84205914}, {'year_month': '2007_JJAS', 'bound_name': 'karamoja', 'mean': 0.7314172}]
#    year_month       bound_name      mean
# 0   2007_JJAS             abim  0.182375
# 1   2007_JJAS            napak  0.654065
# 2   2007_JJAS        nabilatuk  0.506780
# 3   2007_JJAS           kotido  0.600459
# 4   2007_JJAS           moroto  1.235830
# 5   2007_JJAS    nakapiripirit  0.143416
# 6   2007_JJAS          kaabong  1.216395
# 7   2007_JJAS          karenga  0.929002
# 8   2007_JJAS           amudat  0.518123
# 9   2007_JJAS    nab_nak_napak  0.481598
# 10  2007_JJAS  abi_kar_kaboong  0.853178
# 11  2007_JJAS   mor_kot_amudat  0.842059
# 12  2007_JJAS         karamoja  0.731417
# []
# [{'year_month': '2008_JJAS', 'bound_name': 'abim', 'mean': 0.5079221}, {'year_month': '2008_JJAS', 'bound_name': 'napak', 'mean': 0.8298947}, {'year_month': '2008_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.6751437}, {'year_month': '2008_JJAS', 'bound_name': 'kotido', 'mean': 0.8715141}, {'year_month': '2008_JJAS', 'bound_name': 'moroto', 'mean': 1.2690669}, {'year_month': '2008_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.4423515}, {'year_month': '2008_JJAS', 'bound_name': 'kaabong', 'mean': 1.3443806}, {'year_month': '2008_JJAS', 'bound_name': 'karenga', 'mean': 0.9755144}, {'year_month': '2008_JJAS', 'bound_name': 'amudat', 'mean': 0.79130507}, {'year_month': '2008_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.68983966}, {'year_month': '2008_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.016674}, {'year_month': '2008_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.0173854}, {'year_month': '2008_JJAS', 'bound_name': 'karamoja', 'mean': 0.9129249}]
#    year_month       bound_name      mean
# 0   2008_JJAS             abim  0.507922
# 1   2008_JJAS            napak  0.829895
# 2   2008_JJAS        nabilatuk  0.675144
# 3   2008_JJAS           kotido  0.871514
# 4   2008_JJAS           moroto  1.269067
# 5   2008_JJAS    nakapiripirit  0.442351
# 6   2008_JJAS          kaabong  1.344381
# 7   2008_JJAS          karenga  0.975514
# 8   2008_JJAS           amudat  0.791305
# 9   2008_JJAS    nab_nak_napak  0.689840
# 10  2008_JJAS  abi_kar_kaboong  1.016674
# 11  2008_JJAS   mor_kot_amudat  1.017385
# 12  2008_JJAS         karamoja  0.912925
# []
# [{'year_month': '2009_JJAS', 'bound_name': 'abim', 'mean': 0.142804}, {'year_month': '2009_JJAS', 'bound_name': 'napak', 'mean': 0.58963585}, {'year_month': '2009_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.6854656}, {'year_month': '2009_JJAS', 'bound_name': 'kotido', 'mean': 0.31468108}, {'year_month': '2009_JJAS', 'bound_name': 'moroto', 'mean': 0.72010714}, {'year_month': '2009_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.57681817}, {'year_month': '2009_JJAS', 'bound_name': 'kaabong', 'mean': 0.7953327}, {'year_month': '2009_JJAS', 'bound_name': 'karenga', 'mean': 0.44129878}, {'year_month': '2009_JJAS', 'bound_name': 'amudat', 'mean': 0.73677546}, {'year_month': '2009_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.60653454}, {'year_month': '2009_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.523218}, {'year_month': '2009_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.5564945}, {'year_month': '2009_JJAS', 'bound_name': 'karamoja', 'mean': 0.56034684}]
#    year_month       bound_name      mean
# 0   2009_JJAS             abim  0.142804
# 1   2009_JJAS            napak  0.589636
# 2   2009_JJAS        nabilatuk  0.685466
# 3   2009_JJAS           kotido  0.314681
# 4   2009_JJAS           moroto  0.720107
# 5   2009_JJAS    nakapiripirit  0.576818
# 6   2009_JJAS          kaabong  0.795333
# 7   2009_JJAS          karenga  0.441299
# 8   2009_JJAS           amudat  0.736775
# 9   2009_JJAS    nab_nak_napak  0.606535
# 10  2009_JJAS  abi_kar_kaboong  0.523218
# 11  2009_JJAS   mor_kot_amudat  0.556494
# 12  2009_JJAS         karamoja  0.560347
# []
# [{'year_month': '2010_JJAS', 'bound_name': 'abim', 'mean': 0.5316297}, {'year_month': '2010_JJAS', 'bound_name': 'napak', 'mean': 1.1183828}, {'year_month': '2010_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.2045573}, {'year_month': '2010_JJAS', 'bound_name': 'kotido', 'mean': 0.66850734}, {'year_month': '2010_JJAS', 'bound_name': 'moroto', 'mean': 1.4167391}, {'year_month': '2010_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.1545063}, {'year_month': '2010_JJAS', 'bound_name': 'kaabong', 'mean': 1.1770512}, {'year_month': '2010_JJAS', 'bound_name': 'karenga', 'mean': 0.7325016}, {'year_month': '2010_JJAS', 'bound_name': 'amudat', 'mean': 1.3784931}, {'year_month': '2010_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.1467409}, {'year_month': '2010_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.88445216}, {'year_month': '2010_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.1020409}, {'year_month': '2010_JJAS', 'bound_name': 'karamoja', 'mean': 1.0373582}]
#    year_month       bound_name      mean
# 0   2010_JJAS             abim  0.531630
# 1   2010_JJAS            napak  1.118383
# 2   2010_JJAS        nabilatuk  1.204557
# 3   2010_JJAS           kotido  0.668507
# 4   2010_JJAS           moroto  1.416739
# 5   2010_JJAS    nakapiripirit  1.154506
# 6   2010_JJAS          kaabong  1.177051
# 7   2010_JJAS          karenga  0.732502
# 8   2010_JJAS           amudat  1.378493
# 9   2010_JJAS    nab_nak_napak  1.146741
# 10  2010_JJAS  abi_kar_kaboong  0.884452
# 11  2010_JJAS   mor_kot_amudat  1.102041
# 12  2010_JJAS         karamoja  1.037358
# []
# [{'year_month': '2011_JJAS', 'bound_name': 'abim', 'mean': -0.6222848}, {'year_month': '2011_JJAS', 'bound_name': 'napak', 'mean': 0.15032876}, {'year_month': '2011_JJAS', 'bound_name': 'nabilatuk', 'mean': 0.4161628}, {'year_month': '2011_JJAS', 'bound_name': 'kotido', 'mean': -0.7614706}, {'year_month': '2011_JJAS', 'bound_name': 'moroto', 'mean': -0.4751989}, {'year_month': '2011_JJAS', 'bound_name': 'nakapiripirit', 'mean': 0.47167763}, {'year_month': '2011_JJAS', 'bound_name': 'kaabong', 'mean': -0.65322894}, {'year_month': '2011_JJAS', 'bound_name': 'karenga', 'mean': -0.8637008}, {'year_month': '2011_JJAS', 'bound_name': 'amudat', 'mean': 0.22634777}, {'year_month': '2011_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 0.29579186}, {'year_month': '2011_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': -0.69679147}, {'year_month': '2011_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': -0.46334556}, {'year_month': '2011_JJAS', 'bound_name': 'karamoja', 'mean': -0.30649355}]
#    year_month       bound_name      mean
# 0   2011_JJAS             abim -0.622285
# 1   2011_JJAS            napak  0.150329
# 2   2011_JJAS        nabilatuk  0.416163
# 3   2011_JJAS           kotido -0.761471
# 4   2011_JJAS           moroto -0.475199
# 5   2011_JJAS    nakapiripirit  0.471678
# 6   2011_JJAS          kaabong -0.653229
# 7   2011_JJAS          karenga -0.863701
# 8   2011_JJAS           amudat  0.226348
# 9   2011_JJAS    nab_nak_napak  0.295792
# 10  2011_JJAS  abi_kar_kaboong -0.696791
# 11  2011_JJAS   mor_kot_amudat -0.463346
# 12  2011_JJAS         karamoja -0.306494
# []
# [{'year_month': '2012_JJAS', 'bound_name': 'abim', 'mean': 0.43110326}, {'year_month': '2012_JJAS', 'bound_name': 'napak', 'mean': 1.0425117}, {'year_month': '2012_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.1191803}, {'year_month': '2012_JJAS', 'bound_name': 'kotido', 'mean': 0.5710347}, {'year_month': '2012_JJAS', 'bound_name': 'moroto', 'mean': 1.2076823}, {'year_month': '2012_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.0723932}, {'year_month': '2012_JJAS', 'bound_name': 'kaabong', 'mean': 0.9651944}, {'year_month': '2012_JJAS', 'bound_name': 'karenga', 'mean': 0.9076066}, {'year_month': '2012_JJAS', 'bound_name': 'amudat', 'mean': 1.1262969}, {'year_month': '2012_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.067118}, {'year_month': '2012_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.80016065}, {'year_month': '2012_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.9308954}, {'year_month': '2012_JJAS', 'bound_name': 'karamoja', 'mean': 0.9268243}]
#    year_month       bound_name      mean
# 0   2012_JJAS             abim  0.431103
# 1   2012_JJAS            napak  1.042512
# 2   2012_JJAS        nabilatuk  1.119180
# 3   2012_JJAS           kotido  0.571035
# 4   2012_JJAS           moroto  1.207682
# 5   2012_JJAS    nakapiripirit  1.072393
# 6   2012_JJAS          kaabong  0.965194
# 7   2012_JJAS          karenga  0.907607
# 8   2012_JJAS           amudat  1.126297
# 9   2012_JJAS    nab_nak_napak  1.067118
# 10  2012_JJAS  abi_kar_kaboong  0.800161
# 11  2012_JJAS   mor_kot_amudat  0.930895
# 12  2012_JJAS         karamoja  0.926824
# []
# [{'year_month': '2013_JJAS', 'bound_name': 'abim', 'mean': 1.7240837}, {'year_month': '2013_JJAS', 'bound_name': 'napak', 'mean': 1.8647608}, {'year_month': '2013_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.8449761}, {'year_month': '2013_JJAS', 'bound_name': 'kotido', 'mean': 1.7690847}, {'year_month': '2013_JJAS', 'bound_name': 'moroto', 'mean': 1.9273385}, {'year_month': '2013_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.842063}, {'year_month': '2013_JJAS', 'bound_name': 'kaabong', 'mean': 1.7742153}, {'year_month': '2013_JJAS', 'bound_name': 'karenga', 'mean': 1.7849852}, {'year_month': '2013_JJAS', 'bound_name': 'amudat', 'mean': 1.9052744}, {'year_month': '2013_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.854271}, {'year_month': '2013_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.7627437}, {'year_month': '2013_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.8581978}, {'year_month': '2013_JJAS', 'bound_name': 'karamoja', 'mean': 1.8223346}]
#    year_month       bound_name      mean
# 0   2013_JJAS             abim  1.724084
# 1   2013_JJAS            napak  1.864761
# 2   2013_JJAS        nabilatuk  1.844976
# 3   2013_JJAS           kotido  1.769085
# 4   2013_JJAS           moroto  1.927338
# 5   2013_JJAS    nakapiripirit  1.842063
# 6   2013_JJAS          kaabong  1.774215
# 7   2013_JJAS          karenga  1.784985
# 8   2013_JJAS           amudat  1.905274
# 9   2013_JJAS    nab_nak_napak  1.854271
# 10  2013_JJAS  abi_kar_kaboong  1.762744
# 11  2013_JJAS   mor_kot_amudat  1.858198
# 12  2013_JJAS         karamoja  1.822335
# []
# [{'year_month': '2014_JJAS', 'bound_name': 'abim', 'mean': 1.7869276}, {'year_month': '2014_JJAS', 'bound_name': 'napak', 'mean': 1.5330673}, {'year_month': '2014_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.4681305}, {'year_month': '2014_JJAS', 'bound_name': 'kotido', 'mean': 1.630208}, {'year_month': '2014_JJAS', 'bound_name': 'moroto', 'mean': 1.2201301}, {'year_month': '2014_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.5809819}, {'year_month': '2014_JJAS', 'bound_name': 'kaabong', 'mean': 1.4647448}, {'year_month': '2014_JJAS', 'bound_name': 'karenga', 'mean': 1.7131313}, {'year_month': '2014_JJAS', 'bound_name': 'amudat', 'mean': 1.4611396}, {'year_month': '2014_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.5324523}, {'year_month': '2014_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6173832}, {'year_month': '2014_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.4332404}, {'year_month': '2014_JJAS', 'bound_name': 'karamoja', 'mean': 1.5315777}]
#    year_month       bound_name      mean
# 0   2014_JJAS             abim  1.786928
# 1   2014_JJAS            napak  1.533067
# 2   2014_JJAS        nabilatuk  1.468130
# 3   2014_JJAS           kotido  1.630208
# 4   2014_JJAS           moroto  1.220130
# 5   2014_JJAS    nakapiripirit  1.580982
# 6   2014_JJAS          kaabong  1.464745
# 7   2014_JJAS          karenga  1.713131
# 8   2014_JJAS           amudat  1.461140
# 9   2014_JJAS    nab_nak_napak  1.532452
# 10  2014_JJAS  abi_kar_kaboong  1.617383
# 11  2014_JJAS   mor_kot_amudat  1.433240
# 12  2014_JJAS         karamoja  1.531578
# []
# [{'year_month': '2015_JJAS', 'bound_name': 'abim', 'mean': 1.7709928}, {'year_month': '2015_JJAS', 'bound_name': 'napak', 'mean': 1.6660633}, {'year_month': '2015_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.5296344}, {'year_month': '2015_JJAS', 'bound_name': 'kotido', 'mean': 1.7635587}, {'year_month': '2015_JJAS', 'bound_name': 'moroto', 'mean': 1.4189281}, {'year_month': '2015_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.5892875}, {'year_month': '2015_JJAS', 'bound_name': 'kaabong', 'mean': 1.5232316}, {'year_month': '2015_JJAS', 'bound_name': 'karenga', 'mean': 1.7371321}, {'year_month': '2015_JJAS', 'bound_name': 'amudat', 'mean': 1.6103666}, {'year_month': '2015_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.6157573}, {'year_month': '2015_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6462989}, {'year_month': '2015_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 1.5959756}, {'year_month': '2015_JJAS', 'bound_name': 'karamoja', 'mean': 1.6205173}]
#    year_month       bound_name      mean
# 0   2015_JJAS             abim  1.770993
# 1   2015_JJAS            napak  1.666063
# 2   2015_JJAS        nabilatuk  1.529634
# 3   2015_JJAS           kotido  1.763559
# 4   2015_JJAS           moroto  1.418928
# 5   2015_JJAS    nakapiripirit  1.589288
# 6   2015_JJAS          kaabong  1.523232
# 7   2015_JJAS          karenga  1.737132
# 8   2015_JJAS           amudat  1.610367
# 9   2015_JJAS    nab_nak_napak  1.615757
# 10  2015_JJAS  abi_kar_kaboong  1.646299
# 11  2015_JJAS   mor_kot_amudat  1.595976
# 12  2015_JJAS         karamoja  1.620517
# []
# [{'year_month': '2016_JJAS', 'bound_name': 'abim', 'mean': 1.3955797}, {'year_month': '2016_JJAS', 'bound_name': 'napak', 'mean': 1.3544729}, {'year_month': '2016_JJAS', 'bound_name': 'nabilatuk', 'mean': 1.3654945}, {'year_month': '2016_JJAS', 'bound_name': 'kotido', 'mean': 0.94331324}, {'year_month': '2016_JJAS', 'bound_name': 'moroto', 'mean': 0.46172845}, {'year_month': '2016_JJAS', 'bound_name': 'nakapiripirit', 'mean': 1.4624393}, {'year_month': '2016_JJAS', 'bound_name': 'kaabong', 'mean': 0.7238347}, {'year_month': '2016_JJAS', 'bound_name': 'karenga', 'mean': 1.066293}, {'year_month': '2016_JJAS', 'bound_name': 'amudat', 'mean': 1.2217774}, {'year_month': '2016_JJAS', 'bound_name': 'nab_nak_napak', 'mean': 1.3866465}, {'year_month': '2016_JJAS', 'bound_name': 'abi_kar_kaboong', 'mean': 0.9984962}, {'year_month': '2016_JJAS', 'bound_name': 'mor_kot_amudat', 'mean': 0.8000894}, {'year_month': '2016_JJAS', 'bound_name': 'karamoja', 'mean': 1.0586388}]
#    year_month       bound_name      mean
# 0   2016_JJAS             abim  1.395580
# 1   2016_JJAS            napak  1.354473
# 2   2016_JJAS        nabilatuk  1.365494
# 3   2016_JJAS           kotido  0.943313
# 4   2016_JJAS           moroto  0.461728
# 5   2016_JJAS    nakapiripirit  1.462439
# 6   2016_JJAS          kaabong  0.723835
# 7   2016_JJAS          karenga  1.066293
# 8   2016_JJAS           amudat  1.221777
# 9   2016_JJAS    nab_nak_napak  1.386647
# 10  2016_JJAS  abi_kar_kaboong  0.998496
# 11  2016_JJAS   mor_kot_amudat  0.800089
# 12  2016_JJAS         karamoja  1.058639

# %%
ncfile_list=['spei01','spei03','spei06','spei09','spei12','spei24','spei48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for MAM
start_month_index=2
end_month_index=4

var_str='spei'

for ncfilename in ncfile_list:
    make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index)
# Out:
# []
# [{'year_month': '1981_MAM', 'bound_name': 'abim', 'mean': 0.5713331}, {'year_month': '1981_MAM', 'bound_name': 'napak', 'mean': 0.4011164}, {'year_month': '1981_MAM', 'bound_name': 'nabilatuk', 'mean': 0.59878933}, {'year_month': '1981_MAM', 'bound_name': 'kotido', 'mean': 0.54121524}, {'year_month': '1981_MAM', 'bound_name': 'moroto', 'mean': 0.3982526}, {'year_month': '1981_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.84307593}, {'year_month': '1981_MAM', 'bound_name': 'kaabong', 'mean': 0.78124154}, {'year_month': '1981_MAM', 'bound_name': 'karenga', 'mean': 0.80075496}, {'year_month': '1981_MAM', 'bound_name': 'amudat', 'mean': 0.9013349}, {'year_month': '1981_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.5653572}, {'year_month': '1981_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.726852}, {'year_month': '1981_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.54993534}, {'year_month': '1981_MAM', 'bound_name': 'karamoja', 'mean': 0.61899596}]
#    year_month       bound_name      mean
# 0    1981_MAM             abim  0.571333
# 1    1981_MAM            napak  0.401116
# 2    1981_MAM        nabilatuk  0.598789
# 3    1981_MAM           kotido  0.541215
# 4    1981_MAM           moroto  0.398253
# 5    1981_MAM    nakapiripirit  0.843076
# 6    1981_MAM          kaabong  0.781242
# 7    1981_MAM          karenga  0.800755
# 8    1981_MAM           amudat  0.901335
# 9    1981_MAM    nab_nak_napak  0.565357
# 10   1981_MAM  abi_kar_kaboong  0.726852
# 11   1981_MAM   mor_kot_amudat  0.549935
# 12   1981_MAM         karamoja  0.618996
# []
# [{'year_month': '1982_MAM', 'bound_name': 'abim', 'mean': -0.10481413}, {'year_month': '1982_MAM', 'bound_name': 'napak', 'mean': -0.3216921}, {'year_month': '1982_MAM', 'bound_name': 'nabilatuk', 'mean': -0.3526467}, {'year_month': '1982_MAM', 'bound_name': 'kotido', 'mean': -0.101669066}, {'year_month': '1982_MAM', 'bound_name': 'moroto', 'mean': -0.25545305}, {'year_month': '1982_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.21740252}, {'year_month': '1982_MAM', 'bound_name': 'kaabong', 'mean': -0.108661115}, {'year_month': '1982_MAM', 'bound_name': 'karenga', 'mean': -0.02932963}, {'year_month': '1982_MAM', 'bound_name': 'amudat', 'mean': -0.23988585}, {'year_month': '1982_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.29948702}, {'year_month': '1982_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.087864265}, {'year_month': '1982_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.18935001}, {'year_month': '1982_MAM', 'bound_name': 'karamoja', 'mean': -0.18758677}]
#    year_month       bound_name      mean
# 0    1982_MAM             abim -0.104814
# 1    1982_MAM            napak -0.321692
# 2    1982_MAM        nabilatuk -0.352647
# 3    1982_MAM           kotido -0.101669
# 4    1982_MAM           moroto -0.255453
# 5    1982_MAM    nakapiripirit -0.217403
# 6    1982_MAM          kaabong -0.108661
# 7    1982_MAM          karenga -0.029330
# 8    1982_MAM           amudat -0.239886
# 9    1982_MAM    nab_nak_napak -0.299487
# 10   1982_MAM  abi_kar_kaboong -0.087864
# 11   1982_MAM   mor_kot_amudat -0.189350
# 12   1982_MAM         karamoja -0.187587
# []
# [{'year_month': '1983_MAM', 'bound_name': 'abim', 'mean': -0.861044}, {'year_month': '1983_MAM', 'bound_name': 'napak', 'mean': -0.6901291}, {'year_month': '1983_MAM', 'bound_name': 'nabilatuk', 'mean': -1.0161614}, {'year_month': '1983_MAM', 'bound_name': 'kotido', 'mean': -0.97464144}, {'year_month': '1983_MAM', 'bound_name': 'moroto', 'mean': -1.1717387}, {'year_month': '1983_MAM', 'bound_name': 'nakapiripirit', 'mean': -1.1468651}, {'year_month': '1983_MAM', 'bound_name': 'kaabong', 'mean': -1.3367974}, {'year_month': '1983_MAM', 'bound_name': 'karenga', 'mean': -1.236345}, {'year_month': '1983_MAM', 'bound_name': 'amudat', 'mean': -1.0075245}, {'year_month': '1983_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.88582885}, {'year_month': '1983_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -1.1775768}, {'year_month': '1983_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -1.060377}, {'year_month': '1983_MAM', 'bound_name': 'karamoja', 'mean': -1.0473474}]
#    year_month       bound_name      mean
# 0    1983_MAM             abim -0.861044
# 1    1983_MAM            napak -0.690129
# 2    1983_MAM        nabilatuk -1.016161
# 3    1983_MAM           kotido -0.974641
# 4    1983_MAM           moroto -1.171739
# 5    1983_MAM    nakapiripirit -1.146865
# 6    1983_MAM          kaabong -1.336797
# 7    1983_MAM          karenga -1.236345
# 8    1983_MAM           amudat -1.007524
# 9    1983_MAM    nab_nak_napak -0.885829
# 10   1983_MAM  abi_kar_kaboong -1.177577
# 11   1983_MAM   mor_kot_amudat -1.060377
# 12   1983_MAM         karamoja -1.047347
# []
# [{'year_month': '1984_MAM', 'bound_name': 'abim', 'mean': -0.39383042}, {'year_month': '1984_MAM', 'bound_name': 'napak', 'mean': -0.32956505}, {'year_month': '1984_MAM', 'bound_name': 'nabilatuk', 'mean': -0.56076634}, {'year_month': '1984_MAM', 'bound_name': 'kotido', 'mean': -0.6601479}, {'year_month': '1984_MAM', 'bound_name': 'moroto', 'mean': -0.673697}, {'year_month': '1984_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.7474449}, {'year_month': '1984_MAM', 'bound_name': 'kaabong', 'mean': -0.9653751}, {'year_month': '1984_MAM', 'bound_name': 'karenga', 'mean': -0.97295505}, {'year_month': '1984_MAM', 'bound_name': 'amudat', 'mean': -0.72568685}, {'year_month': '1984_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.49430558}, {'year_month': '1984_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.80596364}, {'year_month': '1984_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.67772716}, {'year_month': '1984_MAM', 'bound_name': 'karamoja', 'mean': -0.6658768}]
#    year_month       bound_name      mean
# 0    1984_MAM             abim -0.393830
# 1    1984_MAM            napak -0.329565
# 2    1984_MAM        nabilatuk -0.560766
# 3    1984_MAM           kotido -0.660148
# 4    1984_MAM           moroto -0.673697
# 5    1984_MAM    nakapiripirit -0.747445
# 6    1984_MAM          kaabong -0.965375
# 7    1984_MAM          karenga -0.972955
# 8    1984_MAM           amudat -0.725687
# 9    1984_MAM    nab_nak_napak -0.494306
# 10   1984_MAM  abi_kar_kaboong -0.805964
# 11   1984_MAM   mor_kot_amudat -0.677727
# 12   1984_MAM         karamoja -0.665877
# []
# [{'year_month': '1985_MAM', 'bound_name': 'abim', 'mean': 0.8380032}, {'year_month': '1985_MAM', 'bound_name': 'napak', 'mean': 0.7592606}, {'year_month': '1985_MAM', 'bound_name': 'nabilatuk', 'mean': 0.6429139}, {'year_month': '1985_MAM', 'bound_name': 'kotido', 'mean': 0.8592957}, {'year_month': '1985_MAM', 'bound_name': 'moroto', 'mean': 0.85004914}, {'year_month': '1985_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.7607373}, {'year_month': '1985_MAM', 'bound_name': 'kaabong', 'mean': 1.0669352}, {'year_month': '1985_MAM', 'bound_name': 'karenga', 'mean': 1.0912635}, {'year_month': '1985_MAM', 'bound_name': 'amudat', 'mean': 0.8584283}, {'year_month': '1985_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.7348534}, {'year_month': '1985_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.0083734}, {'year_month': '1985_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.85539824}, {'year_month': '1985_MAM', 'bound_name': 'karamoja', 'mean': 0.8725218}]
#    year_month       bound_name      mean
# 0    1985_MAM             abim  0.838003
# 1    1985_MAM            napak  0.759261
# 2    1985_MAM        nabilatuk  0.642914
# 3    1985_MAM           kotido  0.859296
# 4    1985_MAM           moroto  0.850049
# 5    1985_MAM    nakapiripirit  0.760737
# 6    1985_MAM          kaabong  1.066935
# 7    1985_MAM          karenga  1.091264
# 8    1985_MAM           amudat  0.858428
# 9    1985_MAM    nab_nak_napak  0.734853
# 10   1985_MAM  abi_kar_kaboong  1.008373
# 11   1985_MAM   mor_kot_amudat  0.855398
# 12   1985_MAM         karamoja  0.872522
# []
# [{'year_month': '1986_MAM', 'bound_name': 'abim', 'mean': 0.055424992}, {'year_month': '1986_MAM', 'bound_name': 'napak', 'mean': 0.15064625}, {'year_month': '1986_MAM', 'bound_name': 'nabilatuk', 'mean': 0.38659668}, {'year_month': '1986_MAM', 'bound_name': 'kotido', 'mean': -0.08171822}, {'year_month': '1986_MAM', 'bound_name': 'moroto', 'mean': 0.4268474}, {'year_month': '1986_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.5570735}, {'year_month': '1986_MAM', 'bound_name': 'kaabong', 'mean': 0.21602905}, {'year_month': '1986_MAM', 'bound_name': 'karenga', 'mean': -0.05777286}, {'year_month': '1986_MAM', 'bound_name': 'amudat', 'mean': 0.7800916}, {'year_month': '1986_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.31323618}, {'year_month': '1986_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.10267471}, {'year_month': '1986_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.28298396}, {'year_month': '1986_MAM', 'bound_name': 'karamoja', 'mean': 0.22722347}]
#    year_month       bound_name      mean
# 0    1986_MAM             abim  0.055425
# 1    1986_MAM            napak  0.150646
# 2    1986_MAM        nabilatuk  0.386597
# 3    1986_MAM           kotido -0.081718
# 4    1986_MAM           moroto  0.426847
# 5    1986_MAM    nakapiripirit  0.557073
# 6    1986_MAM          kaabong  0.216029
# 7    1986_MAM          karenga -0.057773
# 8    1986_MAM           amudat  0.780092
# 9    1986_MAM    nab_nak_napak  0.313236
# 10   1986_MAM  abi_kar_kaboong  0.102675
# 11   1986_MAM   mor_kot_amudat  0.282984
# 12   1986_MAM         karamoja  0.227223
# []
# [{'year_month': '1987_MAM', 'bound_name': 'abim', 'mean': -0.14379728}, {'year_month': '1987_MAM', 'bound_name': 'napak', 'mean': -0.21828252}, {'year_month': '1987_MAM', 'bound_name': 'nabilatuk', 'mean': -0.15253033}, {'year_month': '1987_MAM', 'bound_name': 'kotido', 'mean': -0.4192496}, {'year_month': '1987_MAM', 'bound_name': 'moroto', 'mean': -0.16216163}, {'year_month': '1987_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.15121076}, {'year_month': '1987_MAM', 'bound_name': 'kaabong', 'mean': -0.6037984}, {'year_month': '1987_MAM', 'bound_name': 'karenga', 'mean': -0.7774031}, {'year_month': '1987_MAM', 'bound_name': 'amudat', 'mean': 0.028576417}, {'year_month': '1987_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.18573165}, {'year_month': '1987_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.51711696}, {'year_month': '1987_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.23263991}, {'year_month': '1987_MAM', 'bound_name': 'karamoja', 'mean': -0.32087547}]
#    year_month       bound_name      mean
# 0    1987_MAM             abim -0.143797
# 1    1987_MAM            napak -0.218283
# 2    1987_MAM        nabilatuk -0.152530
# 3    1987_MAM           kotido -0.419250
# 4    1987_MAM           moroto -0.162162
# 5    1987_MAM    nakapiripirit -0.151211
# 6    1987_MAM          kaabong -0.603798
# 7    1987_MAM          karenga -0.777403
# 8    1987_MAM           amudat  0.028576
# 9    1987_MAM    nab_nak_napak -0.185732
# 10   1987_MAM  abi_kar_kaboong -0.517117
# 11   1987_MAM   mor_kot_amudat -0.232640
# 12   1987_MAM         karamoja -0.320875
# []
# [{'year_month': '1988_MAM', 'bound_name': 'abim', 'mean': 0.121539116}, {'year_month': '1988_MAM', 'bound_name': 'napak', 'mean': 0.023930797}, {'year_month': '1988_MAM', 'bound_name': 'nabilatuk', 'mean': 0.39235246}, {'year_month': '1988_MAM', 'bound_name': 'kotido', 'mean': 0.27381438}, {'year_month': '1988_MAM', 'bound_name': 'moroto', 'mean': 0.14566511}, {'year_month': '1988_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.5406102}, {'year_month': '1988_MAM', 'bound_name': 'kaabong', 'mean': 0.07345459}, {'year_month': '1988_MAM', 'bound_name': 'karenga', 'mean': -0.24555682}, {'year_month': '1988_MAM', 'bound_name': 'amudat', 'mean': 0.59527636}, {'year_month': '1988_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.2452294}, {'year_month': '1988_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.0077609196}, {'year_month': '1988_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.28138292}, {'year_month': '1988_MAM', 'bound_name': 'karamoja', 'mean': 0.17065911}]
#    year_month       bound_name      mean
# 0    1988_MAM             abim  0.121539
# 1    1988_MAM            napak  0.023931
# 2    1988_MAM        nabilatuk  0.392352
# 3    1988_MAM           kotido  0.273814
# 4    1988_MAM           moroto  0.145665
# 5    1988_MAM    nakapiripirit  0.540610
# 6    1988_MAM          kaabong  0.073455
# 7    1988_MAM          karenga -0.245557
# 8    1988_MAM           amudat  0.595276
# 9    1988_MAM    nab_nak_napak  0.245229
# 10   1988_MAM  abi_kar_kaboong  0.007761
# 11   1988_MAM   mor_kot_amudat  0.281383
# 12   1988_MAM         karamoja  0.170659
# []
# [{'year_month': '1989_MAM', 'bound_name': 'abim', 'mean': 0.5691375}, {'year_month': '1989_MAM', 'bound_name': 'napak', 'mean': 0.84771466}, {'year_month': '1989_MAM', 'bound_name': 'nabilatuk', 'mean': 0.82840323}, {'year_month': '1989_MAM', 'bound_name': 'kotido', 'mean': 0.7894288}, {'year_month': '1989_MAM', 'bound_name': 'moroto', 'mean': 0.7670091}, {'year_month': '1989_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.80398226}, {'year_month': '1989_MAM', 'bound_name': 'kaabong', 'mean': 0.6521297}, {'year_month': '1989_MAM', 'bound_name': 'karenga', 'mean': 0.8941395}, {'year_month': '1989_MAM', 'bound_name': 'amudat', 'mean': 0.5777047}, {'year_month': '1989_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.8315159}, {'year_month': '1989_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.6888399}, {'year_month': '1989_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.74126834}, {'year_month': '1989_MAM', 'bound_name': 'karamoja', 'mean': 0.7509671}]
#    year_month       bound_name      mean
# 0    1989_MAM             abim  0.569138
# 1    1989_MAM            napak  0.847715
# 2    1989_MAM        nabilatuk  0.828403
# 3    1989_MAM           kotido  0.789429
# 4    1989_MAM           moroto  0.767009
# 5    1989_MAM    nakapiripirit  0.803982
# 6    1989_MAM          kaabong  0.652130
# 7    1989_MAM          karenga  0.894140
# 8    1989_MAM           amudat  0.577705
# 9    1989_MAM    nab_nak_napak  0.831516
# 10   1989_MAM  abi_kar_kaboong  0.688840
# 11   1989_MAM   mor_kot_amudat  0.741268
# 12   1989_MAM         karamoja  0.750967
# []
# [{'year_month': '1990_MAM', 'bound_name': 'abim', 'mean': 0.8600305}, {'year_month': '1990_MAM', 'bound_name': 'napak', 'mean': 0.8158798}, {'year_month': '1990_MAM', 'bound_name': 'nabilatuk', 'mean': 0.80871385}, {'year_month': '1990_MAM', 'bound_name': 'kotido', 'mean': 0.5768674}, {'year_month': '1990_MAM', 'bound_name': 'moroto', 'mean': 0.45988363}, {'year_month': '1990_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.65623546}, {'year_month': '1990_MAM', 'bound_name': 'kaabong', 'mean': 0.08769087}, {'year_month': '1990_MAM', 'bound_name': 'karenga', 'mean': 0.47813207}, {'year_month': '1990_MAM', 'bound_name': 'amudat', 'mean': 0.41483963}, {'year_month': '1990_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.77025384}, {'year_month': '1990_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.4026632}, {'year_month': '1990_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.49966323}, {'year_month': '1990_MAM', 'bound_name': 'karamoja', 'mean': 0.55057186}]
#    year_month       bound_name      mean
# 0    1990_MAM             abim  0.860030
# 1    1990_MAM            napak  0.815880
# 2    1990_MAM        nabilatuk  0.808714
# 3    1990_MAM           kotido  0.576867
# 4    1990_MAM           moroto  0.459884
# 5    1990_MAM    nakapiripirit  0.656235
# 6    1990_MAM          kaabong  0.087691
# 7    1990_MAM          karenga  0.478132
# 8    1990_MAM           amudat  0.414840
# 9    1990_MAM    nab_nak_napak  0.770254
# 10   1990_MAM  abi_kar_kaboong  0.402663
# 11   1990_MAM   mor_kot_amudat  0.499663
# 12   1990_MAM         karamoja  0.550572
# []
# [{'year_month': '1991_MAM', 'bound_name': 'abim', 'mean': -0.5610364}, {'year_month': '1991_MAM', 'bound_name': 'napak', 'mean': -0.7634678}, {'year_month': '1991_MAM', 'bound_name': 'nabilatuk', 'mean': -0.37449342}, {'year_month': '1991_MAM', 'bound_name': 'kotido', 'mean': -0.5781746}, {'year_month': '1991_MAM', 'bound_name': 'moroto', 'mean': -0.56173235}, {'year_month': '1991_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.13819559}, {'year_month': '1991_MAM', 'bound_name': 'kaabong', 'mean': -0.22287022}, {'year_month': '1991_MAM', 'bound_name': 'karenga', 'mean': -0.18839014}, {'year_month': '1991_MAM', 'bound_name': 'amudat', 'mean': -0.2162}, {'year_month': '1991_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.50778973}, {'year_month': '1991_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.30973655}, {'year_month': '1991_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.5046835}, {'year_month': '1991_MAM', 'bound_name': 'karamoja', 'mean': -0.434979}]
#    year_month       bound_name      mean
# 0    1991_MAM             abim -0.561036
# 1    1991_MAM            napak -0.763468
# 2    1991_MAM        nabilatuk -0.374493
# 3    1991_MAM           kotido -0.578175
# 4    1991_MAM           moroto -0.561732
# 5    1991_MAM    nakapiripirit -0.138196
# 6    1991_MAM          kaabong -0.222870
# 7    1991_MAM          karenga -0.188390
# 8    1991_MAM           amudat -0.216200
# 9    1991_MAM    nab_nak_napak -0.507790
# 10   1991_MAM  abi_kar_kaboong -0.309737
# 11   1991_MAM   mor_kot_amudat -0.504683
# 12   1991_MAM         karamoja -0.434979
# []
# [{'year_month': '1992_MAM', 'bound_name': 'abim', 'mean': -0.74532884}, {'year_month': '1992_MAM', 'bound_name': 'napak', 'mean': -0.647215}, {'year_month': '1992_MAM', 'bound_name': 'nabilatuk', 'mean': -0.6496451}, {'year_month': '1992_MAM', 'bound_name': 'kotido', 'mean': -0.75490254}, {'year_month': '1992_MAM', 'bound_name': 'moroto', 'mean': -0.6204121}, {'year_month': '1992_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.5613177}, {'year_month': '1992_MAM', 'bound_name': 'kaabong', 'mean': -0.71186274}, {'year_month': '1992_MAM', 'bound_name': 'karenga', 'mean': -0.8150599}, {'year_month': '1992_MAM', 'bound_name': 'amudat', 'mean': -0.35181415}, {'year_month': '1992_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.62400645}, {'year_month': '1992_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.7469482}, {'year_month': '1992_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.6261061}, {'year_month': '1992_MAM', 'bound_name': 'karamoja', 'mean': -0.6692585}]
#    year_month       bound_name      mean
# 0    1992_MAM             abim -0.745329
# 1    1992_MAM            napak -0.647215
# 2    1992_MAM        nabilatuk -0.649645
# 3    1992_MAM           kotido -0.754903
# 4    1992_MAM           moroto -0.620412
# 5    1992_MAM    nakapiripirit -0.561318
# 6    1992_MAM          kaabong -0.711863
# 7    1992_MAM          karenga -0.815060
# 8    1992_MAM           amudat -0.351814
# 9    1992_MAM    nab_nak_napak -0.624006
# 10   1992_MAM  abi_kar_kaboong -0.746948
# 11   1992_MAM   mor_kot_amudat -0.626106
# 12   1992_MAM         karamoja -0.669258
# []
# [{'year_month': '1993_MAM', 'bound_name': 'abim', 'mean': -0.9835989}, {'year_month': '1993_MAM', 'bound_name': 'napak', 'mean': -1.0528226}, {'year_month': '1993_MAM', 'bound_name': 'nabilatuk', 'mean': -1.2146829}, {'year_month': '1993_MAM', 'bound_name': 'kotido', 'mean': -0.98004746}, {'year_month': '1993_MAM', 'bound_name': 'moroto', 'mean': -1.232853}, {'year_month': '1993_MAM', 'bound_name': 'nakapiripirit', 'mean': -1.2320799}, {'year_month': '1993_MAM', 'bound_name': 'kaabong', 'mean': -1.1442984}, {'year_month': '1993_MAM', 'bound_name': 'karenga', 'mean': -0.9219912}, {'year_month': '1993_MAM', 'bound_name': 'amudat', 'mean': -1.3349274}, {'year_month': '1993_MAM', 'bound_name': 'nab_nak_napak', 'mean': -1.1368604}, {'year_month': '1993_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -1.0437119}, {'year_month': '1993_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -1.1477621}, {'year_month': '1993_MAM', 'bound_name': 'karamoja', 'mean': -1.1065626}]
#    year_month       bound_name      mean
# 0    1993_MAM             abim -0.983599
# 1    1993_MAM            napak -1.052823
# 2    1993_MAM        nabilatuk -1.214683
# 3    1993_MAM           kotido -0.980047
# 4    1993_MAM           moroto -1.232853
# 5    1993_MAM    nakapiripirit -1.232080
# 6    1993_MAM          kaabong -1.144298
# 7    1993_MAM          karenga -0.921991
# 8    1993_MAM           amudat -1.334927
# 9    1993_MAM    nab_nak_napak -1.136860
# 10   1993_MAM  abi_kar_kaboong -1.043712
# 11   1993_MAM   mor_kot_amudat -1.147762
# 12   1993_MAM         karamoja -1.106563
# []
# [{'year_month': '1994_MAM', 'bound_name': 'abim', 'mean': -0.08382933}, {'year_month': '1994_MAM', 'bound_name': 'napak', 'mean': 0.1623541}, {'year_month': '1994_MAM', 'bound_name': 'nabilatuk', 'mean': -0.02681312}, {'year_month': '1994_MAM', 'bound_name': 'kotido', 'mean': -0.053895336}, {'year_month': '1994_MAM', 'bound_name': 'moroto', 'mean': -0.1746763}, {'year_month': '1994_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.0020329077}, {'year_month': '1994_MAM', 'bound_name': 'kaabong', 'mean': 0.083439544}, {'year_month': '1994_MAM', 'bound_name': 'karenga', 'mean': 0.28593823}, {'year_month': '1994_MAM', 'bound_name': 'amudat', 'mean': -0.08441697}, {'year_month': '1994_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.07772271}, {'year_month': '1994_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.086548924}, {'year_month': '1994_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.10834912}, {'year_month': '1994_MAM', 'bound_name': 'karamoja', 'mean': 0.021521091}]
#    year_month       bound_name      mean
# 0    1994_MAM             abim -0.083829
# 1    1994_MAM            napak  0.162354
# 2    1994_MAM        nabilatuk -0.026813
# 3    1994_MAM           kotido -0.053895
# 4    1994_MAM           moroto -0.174676
# 5    1994_MAM    nakapiripirit  0.002033
# 6    1994_MAM          kaabong  0.083440
# 7    1994_MAM          karenga  0.285938
# 8    1994_MAM           amudat -0.084417
# 9    1994_MAM    nab_nak_napak  0.077723
# 10   1994_MAM  abi_kar_kaboong  0.086549
# 11   1994_MAM   mor_kot_amudat -0.108349
# 12   1994_MAM         karamoja  0.021521
# []
# [{'year_month': '1995_MAM', 'bound_name': 'abim', 'mean': -0.21500053}, {'year_month': '1995_MAM', 'bound_name': 'napak', 'mean': -0.23918115}, {'year_month': '1995_MAM', 'bound_name': 'nabilatuk', 'mean': -0.2528541}, {'year_month': '1995_MAM', 'bound_name': 'kotido', 'mean': -0.22806108}, {'year_month': '1995_MAM', 'bound_name': 'moroto', 'mean': -0.07694699}, {'year_month': '1995_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.19528101}, {'year_month': '1995_MAM', 'bound_name': 'kaabong', 'mean': -0.321849}, {'year_month': '1995_MAM', 'bound_name': 'karenga', 'mean': -0.4518914}, {'year_month': '1995_MAM', 'bound_name': 'amudat', 'mean': -0.21278961}, {'year_month': '1995_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.22997116}, {'year_month': '1995_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.3240066}, {'year_month': '1995_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.16416341}, {'year_month': '1995_MAM', 'bound_name': 'karamoja', 'mean': -0.24306206}]
#    year_month       bound_name      mean
# 0    1995_MAM             abim -0.215001
# 1    1995_MAM            napak -0.239181
# 2    1995_MAM        nabilatuk -0.252854
# 3    1995_MAM           kotido -0.228061
# 4    1995_MAM           moroto -0.076947
# 5    1995_MAM    nakapiripirit -0.195281
# 6    1995_MAM          kaabong -0.321849
# 7    1995_MAM          karenga -0.451891
# 8    1995_MAM           amudat -0.212790
# 9    1995_MAM    nab_nak_napak -0.229971
# 10   1995_MAM  abi_kar_kaboong -0.324007
# 11   1995_MAM   mor_kot_amudat -0.164163
# 12   1995_MAM         karamoja -0.243062
# []
# [{'year_month': '1996_MAM', 'bound_name': 'abim', 'mean': 0.4698734}, {'year_month': '1996_MAM', 'bound_name': 'napak', 'mean': 0.45602813}, {'year_month': '1996_MAM', 'bound_name': 'nabilatuk', 'mean': 0.27630904}, {'year_month': '1996_MAM', 'bound_name': 'kotido', 'mean': 0.21304873}, {'year_month': '1996_MAM', 'bound_name': 'moroto', 'mean': 0.22688662}, {'year_month': '1996_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.6172943}, {'year_month': '1996_MAM', 'bound_name': 'kaabong', 'mean': 0.024197709}, {'year_month': '1996_MAM', 'bound_name': 'karenga', 'mean': 0.1045963}, {'year_month': '1996_MAM', 'bound_name': 'amudat', 'mean': 0.61774904}, {'year_month': '1996_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.46224198}, {'year_month': '1996_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.16994755}, {'year_month': '1996_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.2933774}, {'year_month': '1996_MAM', 'bound_name': 'karamoja', 'mean': 0.3023397}]
#    year_month       bound_name      mean
# 0    1996_MAM             abim  0.469873
# 1    1996_MAM            napak  0.456028
# 2    1996_MAM        nabilatuk  0.276309
# 3    1996_MAM           kotido  0.213049
# 4    1996_MAM           moroto  0.226887
# 5    1996_MAM    nakapiripirit  0.617294
# 6    1996_MAM          kaabong  0.024198
# 7    1996_MAM          karenga  0.104596
# 8    1996_MAM           amudat  0.617749
# 9    1996_MAM    nab_nak_napak  0.462242
# 10   1996_MAM  abi_kar_kaboong  0.169948
# 11   1996_MAM   mor_kot_amudat  0.293377
# 12   1996_MAM         karamoja  0.302340
# []
# [{'year_month': '1997_MAM', 'bound_name': 'abim', 'mean': 0.6242538}, {'year_month': '1997_MAM', 'bound_name': 'napak', 'mean': 0.24781606}, {'year_month': '1997_MAM', 'bound_name': 'nabilatuk', 'mean': 0.3122041}, {'year_month': '1997_MAM', 'bound_name': 'kotido', 'mean': 0.8089665}, {'year_month': '1997_MAM', 'bound_name': 'moroto', 'mean': 0.6331866}, {'year_month': '1997_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.45703927}, {'year_month': '1997_MAM', 'bound_name': 'kaabong', 'mean': 0.9409846}, {'year_month': '1997_MAM', 'bound_name': 'karenga', 'mean': 0.9388567}, {'year_month': '1997_MAM', 'bound_name': 'amudat', 'mean': 0.8240085}, {'year_month': '1997_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.31934163}, {'year_month': '1997_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.8510718}, {'year_month': '1997_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.7406974}, {'year_month': '1997_MAM', 'bound_name': 'karamoja', 'mean': 0.64667547}]
#    year_month       bound_name      mean
# 0    1997_MAM             abim  0.624254
# 1    1997_MAM            napak  0.247816
# 2    1997_MAM        nabilatuk  0.312204
# 3    1997_MAM           kotido  0.808967
# 4    1997_MAM           moroto  0.633187
# 5    1997_MAM    nakapiripirit  0.457039
# 6    1997_MAM          kaabong  0.940985
# 7    1997_MAM          karenga  0.938857
# 8    1997_MAM           amudat  0.824009
# 9    1997_MAM    nab_nak_napak  0.319342
# 10   1997_MAM  abi_kar_kaboong  0.851072
# 11   1997_MAM   mor_kot_amudat  0.740697
# 12   1997_MAM         karamoja  0.646675
# []
# [{'year_month': '1998_MAM', 'bound_name': 'abim', 'mean': -0.8767179}, {'year_month': '1998_MAM', 'bound_name': 'napak', 'mean': -1.0609417}, {'year_month': '1998_MAM', 'bound_name': 'nabilatuk', 'mean': -1.009245}, {'year_month': '1998_MAM', 'bound_name': 'kotido', 'mean': -0.803869}, {'year_month': '1998_MAM', 'bound_name': 'moroto', 'mean': -1.1142033}, {'year_month': '1998_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.87023735}, {'year_month': '1998_MAM', 'bound_name': 'kaabong', 'mean': -0.6916474}, {'year_month': '1998_MAM', 'bound_name': 'karenga', 'mean': -1.0628494}, {'year_month': '1998_MAM', 'bound_name': 'amudat', 'mean': -0.872534}, {'year_month': '1998_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.99723846}, {'year_month': '1998_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.83610713}, {'year_month': '1998_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.94198066}, {'year_month': '1998_MAM', 'bound_name': 'karamoja', 'mean': -0.9211675}]
#    year_month       bound_name      mean
# 0    1998_MAM             abim -0.876718
# 1    1998_MAM            napak -1.060942
# 2    1998_MAM        nabilatuk -1.009245
# 3    1998_MAM           kotido -0.803869
# 4    1998_MAM           moroto -1.114203
# 5    1998_MAM    nakapiripirit -0.870237
# 6    1998_MAM          kaabong -0.691647
# 7    1998_MAM          karenga -1.062849
# 8    1998_MAM           amudat -0.872534
# 9    1998_MAM    nab_nak_napak -0.997238
# 10   1998_MAM  abi_kar_kaboong -0.836107
# 11   1998_MAM   mor_kot_amudat -0.941981
# 12   1998_MAM         karamoja -0.921167
# []
# [{'year_month': '1999_MAM', 'bound_name': 'abim', 'mean': 0.80555326}, {'year_month': '1999_MAM', 'bound_name': 'napak', 'mean': 0.7928668}, {'year_month': '1999_MAM', 'bound_name': 'nabilatuk', 'mean': 0.6525508}, {'year_month': '1999_MAM', 'bound_name': 'kotido', 'mean': 0.92266566}, {'year_month': '1999_MAM', 'bound_name': 'moroto', 'mean': 0.9405504}, {'year_month': '1999_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.38697088}, {'year_month': '1999_MAM', 'bound_name': 'kaabong', 'mean': 0.6119373}, {'year_month': '1999_MAM', 'bound_name': 'karenga', 'mean': 0.5048488}, {'year_month': '1999_MAM', 'bound_name': 'amudat', 'mean': 0.4306585}, {'year_month': '1999_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.65082115}, {'year_month': '1999_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.6399694}, {'year_month': '1999_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.8390359}, {'year_month': '1999_MAM', 'bound_name': 'karamoja', 'mean': 0.70697236}]
#    year_month       bound_name      mean
# 0    1999_MAM             abim  0.805553
# 1    1999_MAM            napak  0.792867
# 2    1999_MAM        nabilatuk  0.652551
# 3    1999_MAM           kotido  0.922666
# 4    1999_MAM           moroto  0.940550
# 5    1999_MAM    nakapiripirit  0.386971
# 6    1999_MAM          kaabong  0.611937
# 7    1999_MAM          karenga  0.504849
# 8    1999_MAM           amudat  0.430658
# 9    1999_MAM    nab_nak_napak  0.650821
# 10   1999_MAM  abi_kar_kaboong  0.639969
# 11   1999_MAM   mor_kot_amudat  0.839036
# 12   1999_MAM         karamoja  0.706972
# []
# [{'year_month': '2000_MAM', 'bound_name': 'abim', 'mean': -0.76134723}, {'year_month': '2000_MAM', 'bound_name': 'napak', 'mean': -0.73077947}, {'year_month': '2000_MAM', 'bound_name': 'nabilatuk', 'mean': -0.8170279}, {'year_month': '2000_MAM', 'bound_name': 'kotido', 'mean': -0.6401716}, {'year_month': '2000_MAM', 'bound_name': 'moroto', 'mean': -0.9786897}, {'year_month': '2000_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.8011728}, {'year_month': '2000_MAM', 'bound_name': 'kaabong', 'mean': -1.0545816}, {'year_month': '2000_MAM', 'bound_name': 'karenga', 'mean': -0.6059093}, {'year_month': '2000_MAM', 'bound_name': 'amudat', 'mean': -1.0299735}, {'year_month': '2000_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.7686194}, {'year_month': '2000_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.86034846}, {'year_month': '2000_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.8489786}, {'year_month': '2000_MAM', 'bound_name': 'karamoja', 'mean': -0.82753676}]
#    year_month       bound_name      mean
# 0    2000_MAM             abim -0.761347
# 1    2000_MAM            napak -0.730779
# 2    2000_MAM        nabilatuk -0.817028
# 3    2000_MAM           kotido -0.640172
# 4    2000_MAM           moroto -0.978690
# 5    2000_MAM    nakapiripirit -0.801173
# 6    2000_MAM          kaabong -1.054582
# 7    2000_MAM          karenga -0.605909
# 8    2000_MAM           amudat -1.029974
# 9    2000_MAM    nab_nak_napak -0.768619
# 10   2000_MAM  abi_kar_kaboong -0.860348
# 11   2000_MAM   mor_kot_amudat -0.848979
# 12   2000_MAM         karamoja -0.827537
# []
# [{'year_month': '2001_MAM', 'bound_name': 'abim', 'mean': 0.69812715}, {'year_month': '2001_MAM', 'bound_name': 'napak', 'mean': 0.5210343}, {'year_month': '2001_MAM', 'bound_name': 'nabilatuk', 'mean': 0.5956148}, {'year_month': '2001_MAM', 'bound_name': 'kotido', 'mean': 0.5751462}, {'year_month': '2001_MAM', 'bound_name': 'moroto', 'mean': 0.55695087}, {'year_month': '2001_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.39397907}, {'year_month': '2001_MAM', 'bound_name': 'kaabong', 'mean': 0.44441697}, {'year_month': '2001_MAM', 'bound_name': 'karenga', 'mean': 0.66137904}, {'year_month': '2001_MAM', 'bound_name': 'amudat', 'mean': 0.39956602}, {'year_month': '2001_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.50184566}, {'year_month': '2001_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.56992394}, {'year_month': '2001_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.5353678}, {'year_month': '2001_MAM', 'bound_name': 'karamoja', 'mean': 0.53723425}]
#    year_month       bound_name      mean
# 0    2001_MAM             abim  0.698127
# 1    2001_MAM            napak  0.521034
# 2    2001_MAM        nabilatuk  0.595615
# 3    2001_MAM           kotido  0.575146
# 4    2001_MAM           moroto  0.556951
# 5    2001_MAM    nakapiripirit  0.393979
# 6    2001_MAM          kaabong  0.444417
# 7    2001_MAM          karenga  0.661379
# 8    2001_MAM           amudat  0.399566
# 9    2001_MAM    nab_nak_napak  0.501846
# 10   2001_MAM  abi_kar_kaboong  0.569924
# 11   2001_MAM   mor_kot_amudat  0.535368
# 12   2001_MAM         karamoja  0.537234
# []
# [{'year_month': '2002_MAM', 'bound_name': 'abim', 'mean': -0.4921299}, {'year_month': '2002_MAM', 'bound_name': 'napak', 'mean': -0.30348387}, {'year_month': '2002_MAM', 'bound_name': 'nabilatuk', 'mean': -0.060222138}, {'year_month': '2002_MAM', 'bound_name': 'kotido', 'mean': -0.19532755}, {'year_month': '2002_MAM', 'bound_name': 'moroto', 'mean': 0.3355655}, {'year_month': '2002_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.27842847}, {'year_month': '2002_MAM', 'bound_name': 'kaabong', 'mean': 0.39983988}, {'year_month': '2002_MAM', 'bound_name': 'karenga', 'mean': 0.30874568}, {'year_month': '2002_MAM', 'bound_name': 'amudat', 'mean': -0.046601877}, {'year_month': '2002_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.24467853}, {'year_month': '2002_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.12548448}, {'year_month': '2002_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.04671445}, {'year_month': '2002_MAM', 'bound_name': 'karamoja', 'mean': -0.017422736}]
#    year_month       bound_name      mean
# 0    2002_MAM             abim -0.492130
# 1    2002_MAM            napak -0.303484
# 2    2002_MAM        nabilatuk -0.060222
# 3    2002_MAM           kotido -0.195328
# 4    2002_MAM           moroto  0.335566
# 5    2002_MAM    nakapiripirit -0.278428
# 6    2002_MAM          kaabong  0.399840
# 7    2002_MAM          karenga  0.308746
# 8    2002_MAM           amudat -0.046602
# 9    2002_MAM    nab_nak_napak -0.244679
# 10   2002_MAM  abi_kar_kaboong  0.125484
# 11   2002_MAM   mor_kot_amudat  0.046714
# 12   2002_MAM         karamoja -0.017423
# []
# [{'year_month': '2003_MAM', 'bound_name': 'abim', 'mean': -0.1275902}, {'year_month': '2003_MAM', 'bound_name': 'napak', 'mean': 0.061352063}, {'year_month': '2003_MAM', 'bound_name': 'nabilatuk', 'mean': 0.36886314}, {'year_month': '2003_MAM', 'bound_name': 'kotido', 'mean': 0.076547496}, {'year_month': '2003_MAM', 'bound_name': 'moroto', 'mean': 0.61964613}, {'year_month': '2003_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.4330734}, {'year_month': '2003_MAM', 'bound_name': 'kaabong', 'mean': 0.53449214}, {'year_month': '2003_MAM', 'bound_name': 'karenga', 'mean': 0.25340438}, {'year_month': '2003_MAM', 'bound_name': 'amudat', 'mean': 0.59790283}, {'year_month': '2003_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.22961837}, {'year_month': '2003_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.27780595}, {'year_month': '2003_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.39233592}, {'year_month': '2003_MAM', 'bound_name': 'karamoja', 'mean': 0.29903898}]
#    year_month       bound_name      mean
# 0    2003_MAM             abim -0.127590
# 1    2003_MAM            napak  0.061352
# 2    2003_MAM        nabilatuk  0.368863
# 3    2003_MAM           kotido  0.076547
# 4    2003_MAM           moroto  0.619646
# 5    2003_MAM    nakapiripirit  0.433073
# 6    2003_MAM          kaabong  0.534492
# 7    2003_MAM          karenga  0.253404
# 8    2003_MAM           amudat  0.597903
# 9    2003_MAM    nab_nak_napak  0.229618
# 10   2003_MAM  abi_kar_kaboong  0.277806
# 11   2003_MAM   mor_kot_amudat  0.392336
# 12   2003_MAM         karamoja  0.299039
# []
# [{'year_month': '2004_MAM', 'bound_name': 'abim', 'mean': -0.52409506}, {'year_month': '2004_MAM', 'bound_name': 'napak', 'mean': -0.32289687}, {'year_month': '2004_MAM', 'bound_name': 'nabilatuk', 'mean': -0.19984426}, {'year_month': '2004_MAM', 'bound_name': 'kotido', 'mean': -0.27345642}, {'year_month': '2004_MAM', 'bound_name': 'moroto', 'mean': -0.009699525}, {'year_month': '2004_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.12890123}, {'year_month': '2004_MAM', 'bound_name': 'kaabong', 'mean': -0.23724933}, {'year_month': '2004_MAM', 'bound_name': 'karenga', 'mean': -0.21761492}, {'year_month': '2004_MAM', 'bound_name': 'amudat', 'mean': -0.06325661}, {'year_month': '2004_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.24306525}, {'year_month': '2004_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.31332117}, {'year_month': '2004_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.12803341}, {'year_month': '2004_MAM', 'bound_name': 'karamoja', 'mean': -0.23181862}]
#    year_month       bound_name      mean
# 0    2004_MAM             abim -0.524095
# 1    2004_MAM            napak -0.322897
# 2    2004_MAM        nabilatuk -0.199844
# 3    2004_MAM           kotido -0.273456
# 4    2004_MAM           moroto -0.009700
# 5    2004_MAM    nakapiripirit -0.128901
# 6    2004_MAM          kaabong -0.237249
# 7    2004_MAM          karenga -0.217615
# 8    2004_MAM           amudat -0.063257
# 9    2004_MAM    nab_nak_napak -0.243065
# 10   2004_MAM  abi_kar_kaboong -0.313321
# 11   2004_MAM   mor_kot_amudat -0.128033
# 12   2004_MAM         karamoja -0.231819
# []
# [{'year_month': '2005_MAM', 'bound_name': 'abim', 'mean': -0.65682393}, {'year_month': '2005_MAM', 'bound_name': 'napak', 'mean': -0.43678153}, {'year_month': '2005_MAM', 'bound_name': 'nabilatuk', 'mean': -0.6241278}, {'year_month': '2005_MAM', 'bound_name': 'kotido', 'mean': -0.58607835}, {'year_month': '2005_MAM', 'bound_name': 'moroto', 'mean': -0.60927796}, {'year_month': '2005_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.7749284}, {'year_month': '2005_MAM', 'bound_name': 'kaabong', 'mean': -0.18272288}, {'year_month': '2005_MAM', 'bound_name': 'karenga', 'mean': -0.10549013}, {'year_month': '2005_MAM', 'bound_name': 'amudat', 'mean': -0.9864397}, {'year_month': '2005_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.57014424}, {'year_month': '2005_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.29732856}, {'year_month': '2005_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.66938955}, {'year_month': '2005_MAM', 'bound_name': 'karamoja', 'mean': -0.5028978}]
#    year_month       bound_name      mean
# 0    2005_MAM             abim -0.656824
# 1    2005_MAM            napak -0.436782
# 2    2005_MAM        nabilatuk -0.624128
# 3    2005_MAM           kotido -0.586078
# 4    2005_MAM           moroto -0.609278
# 5    2005_MAM    nakapiripirit -0.774928
# 6    2005_MAM          kaabong -0.182723
# 7    2005_MAM          karenga -0.105490
# 8    2005_MAM           amudat -0.986440
# 9    2005_MAM    nab_nak_napak -0.570144
# 10   2005_MAM  abi_kar_kaboong -0.297329
# 11   2005_MAM   mor_kot_amudat -0.669390
# 12   2005_MAM         karamoja -0.502898
# []
# [{'year_month': '2006_MAM', 'bound_name': 'abim', 'mean': 1.3183957}, {'year_month': '2006_MAM', 'bound_name': 'napak', 'mean': 1.4725338}, {'year_month': '2006_MAM', 'bound_name': 'nabilatuk', 'mean': 1.4346524}, {'year_month': '2006_MAM', 'bound_name': 'kotido', 'mean': 0.9099902}, {'year_month': '2006_MAM', 'bound_name': 'moroto', 'mean': 0.75838923}, {'year_month': '2006_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.2200032}, {'year_month': '2006_MAM', 'bound_name': 'kaabong', 'mean': 0.57435626}, {'year_month': '2006_MAM', 'bound_name': 'karenga', 'mean': 0.60453457}, {'year_month': '2006_MAM', 'bound_name': 'amudat', 'mean': 0.81752455}, {'year_month': '2006_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.3946992}, {'year_month': '2006_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.7918288}, {'year_month': '2006_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.8316404}, {'year_month': '2006_MAM', 'bound_name': 'karamoja', 'mean': 0.9963304}]
#    year_month       bound_name      mean
# 0    2006_MAM             abim  1.318396
# 1    2006_MAM            napak  1.472534
# 2    2006_MAM        nabilatuk  1.434652
# 3    2006_MAM           kotido  0.909990
# 4    2006_MAM           moroto  0.758389
# 5    2006_MAM    nakapiripirit  1.220003
# 6    2006_MAM          kaabong  0.574356
# 7    2006_MAM          karenga  0.604535
# 8    2006_MAM           amudat  0.817525
# 9    2006_MAM    nab_nak_napak  1.394699
# 10   2006_MAM  abi_kar_kaboong  0.791829
# 11   2006_MAM   mor_kot_amudat  0.831640
# 12   2006_MAM         karamoja  0.996330
# []
# [{'year_month': '2007_MAM', 'bound_name': 'abim', 'mean': -0.008145664}, {'year_month': '2007_MAM', 'bound_name': 'napak', 'mean': -0.1599298}, {'year_month': '2007_MAM', 'bound_name': 'nabilatuk', 'mean': -0.21061967}, {'year_month': '2007_MAM', 'bound_name': 'kotido', 'mean': -0.20236528}, {'year_month': '2007_MAM', 'bound_name': 'moroto', 'mean': 0.024361182}, {'year_month': '2007_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.29339874}, {'year_month': '2007_MAM', 'bound_name': 'kaabong', 'mean': 0.0451807}, {'year_month': '2007_MAM', 'bound_name': 'karenga', 'mean': -0.15052344}, {'year_month': '2007_MAM', 'bound_name': 'amudat', 'mean': -0.15508018}, {'year_month': '2007_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.20760857}, {'year_month': '2007_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.01849433}, {'year_month': '2007_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.1019946}, {'year_month': '2007_MAM', 'bound_name': 'karamoja', 'mean': -0.10531441}]
#    year_month       bound_name      mean
# 0    2007_MAM             abim -0.008146
# 1    2007_MAM            napak -0.159930
# 2    2007_MAM        nabilatuk -0.210620
# 3    2007_MAM           kotido -0.202365
# 4    2007_MAM           moroto  0.024361
# 5    2007_MAM    nakapiripirit -0.293399
# 6    2007_MAM          kaabong  0.045181
# 7    2007_MAM          karenga -0.150523
# 8    2007_MAM           amudat -0.155080
# 9    2007_MAM    nab_nak_napak -0.207609
# 10   2007_MAM  abi_kar_kaboong -0.018494
# 11   2007_MAM   mor_kot_amudat -0.101995
# 12   2007_MAM         karamoja -0.105314
# []
# [{'year_month': '2008_MAM', 'bound_name': 'abim', 'mean': -0.7126592}, {'year_month': '2008_MAM', 'bound_name': 'napak', 'mean': -0.71894896}, {'year_month': '2008_MAM', 'bound_name': 'nabilatuk', 'mean': -0.8040532}, {'year_month': '2008_MAM', 'bound_name': 'kotido', 'mean': -0.589505}, {'year_month': '2008_MAM', 'bound_name': 'moroto', 'mean': -0.68517417}, {'year_month': '2008_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.8762494}, {'year_month': '2008_MAM', 'bound_name': 'kaabong', 'mean': -0.57156146}, {'year_month': '2008_MAM', 'bound_name': 'karenga', 'mean': -0.40590367}, {'year_month': '2008_MAM', 'bound_name': 'amudat', 'mean': -0.77355945}, {'year_month': '2008_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.7805507}, {'year_month': '2008_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.5702201}, {'year_month': '2008_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.6621618}, {'year_month': '2008_MAM', 'bound_name': 'karamoja', 'mean': -0.66648465}]
#    year_month       bound_name      mean
# 0    2008_MAM             abim -0.712659
# 1    2008_MAM            napak -0.718949
# 2    2008_MAM        nabilatuk -0.804053
# 3    2008_MAM           kotido -0.589505
# 4    2008_MAM           moroto -0.685174
# 5    2008_MAM    nakapiripirit -0.876249
# 6    2008_MAM          kaabong -0.571561
# 7    2008_MAM          karenga -0.405904
# 8    2008_MAM           amudat -0.773559
# 9    2008_MAM    nab_nak_napak -0.780551
# 10   2008_MAM  abi_kar_kaboong -0.570220
# 11   2008_MAM   mor_kot_amudat -0.662162
# 12   2008_MAM         karamoja -0.666485
# []
# [{'year_month': '2009_MAM', 'bound_name': 'abim', 'mean': -0.37375492}, {'year_month': '2009_MAM', 'bound_name': 'napak', 'mean': -0.3018952}, {'year_month': '2009_MAM', 'bound_name': 'nabilatuk', 'mean': -0.35082868}, {'year_month': '2009_MAM', 'bound_name': 'kotido', 'mean': -0.43319067}, {'year_month': '2009_MAM', 'bound_name': 'moroto', 'mean': -0.69659656}, {'year_month': '2009_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.32811457}, {'year_month': '2009_MAM', 'bound_name': 'kaabong', 'mean': -0.78461343}, {'year_month': '2009_MAM', 'bound_name': 'karenga', 'mean': -0.68824136}, {'year_month': '2009_MAM', 'bound_name': 'amudat', 'mean': -0.54812926}, {'year_month': '2009_MAM', 'bound_name': 'nab_nak_napak', 'mean': -0.31957448}, {'year_month': '2009_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.6447204}, {'year_month': '2009_MAM', 'bound_name': 'mor_kot_amudat', 'mean': -0.56087995}, {'year_month': '2009_MAM', 'bound_name': 'karamoja', 'mean': -0.51451576}]
#    year_month       bound_name      mean
# 0    2009_MAM             abim -0.373755
# 1    2009_MAM            napak -0.301895
# 2    2009_MAM        nabilatuk -0.350829
# 3    2009_MAM           kotido -0.433191
# 4    2009_MAM           moroto -0.696597
# 5    2009_MAM    nakapiripirit -0.328115
# 6    2009_MAM          kaabong -0.784613
# 7    2009_MAM          karenga -0.688241
# 8    2009_MAM           amudat -0.548129
# 9    2009_MAM    nab_nak_napak -0.319574
# 10   2009_MAM  abi_kar_kaboong -0.644720
# 11   2009_MAM   mor_kot_amudat -0.560880
# 12   2009_MAM         karamoja -0.514516
# []
# [{'year_month': '2010_MAM', 'bound_name': 'abim', 'mean': 0.6325462}, {'year_month': '2010_MAM', 'bound_name': 'napak', 'mean': 0.69726753}, {'year_month': '2010_MAM', 'bound_name': 'nabilatuk', 'mean': 0.7026918}, {'year_month': '2010_MAM', 'bound_name': 'kotido', 'mean': 0.6672734}, {'year_month': '2010_MAM', 'bound_name': 'moroto', 'mean': 1.0104039}, {'year_month': '2010_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.54843736}, {'year_month': '2010_MAM', 'bound_name': 'kaabong', 'mean': 0.84914446}, {'year_month': '2010_MAM', 'bound_name': 'karenga', 'mean': 0.6413988}, {'year_month': '2010_MAM', 'bound_name': 'amudat', 'mean': 0.75848395}, {'year_month': '2010_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.65731394}, {'year_month': '2010_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.7364008}, {'year_month': '2010_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.822804}, {'year_month': '2010_MAM', 'bound_name': 'karamoja', 'mean': 0.7388244}]
#    year_month       bound_name      mean
# 0    2010_MAM             abim  0.632546
# 1    2010_MAM            napak  0.697268
# 2    2010_MAM        nabilatuk  0.702692
# 3    2010_MAM           kotido  0.667273
# 4    2010_MAM           moroto  1.010404
# 5    2010_MAM    nakapiripirit  0.548437
# 6    2010_MAM          kaabong  0.849144
# 7    2010_MAM          karenga  0.641399
# 8    2010_MAM           amudat  0.758484
# 9    2010_MAM    nab_nak_napak  0.657314
# 10   2010_MAM  abi_kar_kaboong  0.736401
# 11   2010_MAM   mor_kot_amudat  0.822804
# 12   2010_MAM         karamoja  0.738824
# []
# [{'year_month': '2011_MAM', 'bound_name': 'abim', 'mean': 0.118701026}, {'year_month': '2011_MAM', 'bound_name': 'napak', 'mean': 0.14056507}, {'year_month': '2011_MAM', 'bound_name': 'nabilatuk', 'mean': 0.118249185}, {'year_month': '2011_MAM', 'bound_name': 'kotido', 'mean': 0.22533527}, {'year_month': '2011_MAM', 'bound_name': 'moroto', 'mean': 0.0628155}, {'year_month': '2011_MAM', 'bound_name': 'nakapiripirit', 'mean': -0.023154391}, {'year_month': '2011_MAM', 'bound_name': 'kaabong', 'mean': 0.26479998}, {'year_month': '2011_MAM', 'bound_name': 'karenga', 'mean': 0.21725366}, {'year_month': '2011_MAM', 'bound_name': 'amudat', 'mean': -0.37227166}, {'year_month': '2011_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.09058215}, {'year_month': '2011_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.21175586}, {'year_month': '2011_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.04928839}, {'year_month': '2011_MAM', 'bound_name': 'karamoja', 'mean': 0.121340066}]
#    year_month       bound_name      mean
# 0    2011_MAM             abim  0.118701
# 1    2011_MAM            napak  0.140565
# 2    2011_MAM        nabilatuk  0.118249
# 3    2011_MAM           kotido  0.225335
# 4    2011_MAM           moroto  0.062816
# 5    2011_MAM    nakapiripirit -0.023154
# 6    2011_MAM          kaabong  0.264800
# 7    2011_MAM          karenga  0.217254
# 8    2011_MAM           amudat -0.372272
# 9    2011_MAM    nab_nak_napak  0.090582
# 10   2011_MAM  abi_kar_kaboong  0.211756
# ...
#    year_month       bound_name      mean
# 0    2006_MAM             abim -1.582896
# 1    2006_MAM            napak -0.707412
# 2    2006_MAM        nabilatuk -0.465873
# 3    2006_MAM           kotido -1.238663
# 4    2006_MAM           moroto -0.403161
# 5    2006_MAM    nakapiripirit -0.740784
# 6    2006_MAM          kaabong -0.868441
# 7    2006_MAM          karenga -1.053823
# 8    2006_MAM           amudat -0.604534
# 9    2006_MAM    nab_nak_napak -0.665113
# 10   2006_MAM  abi_kar_kaboong -1.116127
# 11   2006_MAM   mor_kot_amudat -0.783865
# 12   2006_MAM         karamoja -0.866573
# []
# [{'year_month': '2007_MAM', 'bound_name': 'abim', 'mean': -0.1528826}, {'year_month': '2007_MAM', 'bound_name': 'napak', 'mean': 0.2699281}, {'year_month': '2007_MAM', 'bound_name': 'nabilatuk', 'mean': 0.36779755}, {'year_month': '2007_MAM', 'bound_name': 'kotido', 'mean': -0.20179196}, {'year_month': '2007_MAM', 'bound_name': 'moroto', 'mean': 0.42677715}, {'year_month': '2007_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.038722783}, {'year_month': '2007_MAM', 'bound_name': 'kaabong', 'mean': 0.14226405}, {'year_month': '2007_MAM', 'bound_name': 'karenga', 'mean': -0.12749568}, {'year_month': '2007_MAM', 'bound_name': 'amudat', 'mean': 0.27375}, {'year_month': '2007_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.22693793}, {'year_month': '2007_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.008055062}, {'year_month': '2007_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.1400817}, {'year_month': '2007_MAM', 'bound_name': 'karamoja', 'mean': 0.11399528}]
#    year_month       bound_name      mean
# 0    2007_MAM             abim -0.152883
# 1    2007_MAM            napak  0.269928
# 2    2007_MAM        nabilatuk  0.367798
# 3    2007_MAM           kotido -0.201792
# 4    2007_MAM           moroto  0.426777
# 5    2007_MAM    nakapiripirit  0.038723
# 6    2007_MAM          kaabong  0.142264
# 7    2007_MAM          karenga -0.127496
# 8    2007_MAM           amudat  0.273750
# 9    2007_MAM    nab_nak_napak  0.226938
# 10   2007_MAM  abi_kar_kaboong -0.008055
# 11   2007_MAM   mor_kot_amudat  0.140082
# 12   2007_MAM         karamoja  0.113995
# []
# [{'year_month': '2008_MAM', 'bound_name': 'abim', 'mean': 0.4136859}, {'year_month': '2008_MAM', 'bound_name': 'napak', 'mean': 0.86218804}, {'year_month': '2008_MAM', 'bound_name': 'nabilatuk', 'mean': 0.597232}, {'year_month': '2008_MAM', 'bound_name': 'kotido', 'mean': 0.9336318}, {'year_month': '2008_MAM', 'bound_name': 'moroto', 'mean': 1.3871973}, {'year_month': '2008_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.26869366}, {'year_month': '2008_MAM', 'bound_name': 'kaabong', 'mean': 1.4357442}, {'year_month': '2008_MAM', 'bound_name': 'karenga', 'mean': 1.1188734}, {'year_month': '2008_MAM', 'bound_name': 'amudat', 'mean': 0.67592365}, {'year_month': '2008_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.64173913}, {'year_month': '2008_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.0685788}, {'year_month': '2008_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.0693637}, {'year_month': '2008_MAM', 'bound_name': 'karamoja', 'mean': 0.9330384}]
#    year_month       bound_name      mean
# 0    2008_MAM             abim  0.413686
# 1    2008_MAM            napak  0.862188
# 2    2008_MAM        nabilatuk  0.597232
# 3    2008_MAM           kotido  0.933632
# 4    2008_MAM           moroto  1.387197
# 5    2008_MAM    nakapiripirit  0.268694
# 6    2008_MAM          kaabong  1.435744
# 7    2008_MAM          karenga  1.118873
# 8    2008_MAM           amudat  0.675924
# 9    2008_MAM    nab_nak_napak  0.641739
# 10   2008_MAM  abi_kar_kaboong  1.068579
# 11   2008_MAM   mor_kot_amudat  1.069364
# 12   2008_MAM         karamoja  0.933038
# []
# [{'year_month': '2009_MAM', 'bound_name': 'abim', 'mean': 0.42180052}, {'year_month': '2009_MAM', 'bound_name': 'napak', 'mean': 0.7779288}, {'year_month': '2009_MAM', 'bound_name': 'nabilatuk', 'mean': 0.7912582}, {'year_month': '2009_MAM', 'bound_name': 'kotido', 'mean': 0.64409184}, {'year_month': '2009_MAM', 'bound_name': 'moroto', 'mean': 1.0954034}, {'year_month': '2009_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.62535256}, {'year_month': '2009_MAM', 'bound_name': 'kaabong', 'mean': 1.1047658}, {'year_month': '2009_MAM', 'bound_name': 'karenga', 'mean': 0.69421726}, {'year_month': '2009_MAM', 'bound_name': 'amudat', 'mean': 0.86027175}, {'year_month': '2009_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.7386266}, {'year_month': '2009_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.8100197}, {'year_month': '2009_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.8664253}, {'year_month': '2009_MAM', 'bound_name': 'karamoja', 'mean': 0.8053144}]
#    year_month       bound_name      mean
# 0    2009_MAM             abim  0.421801
# 1    2009_MAM            napak  0.777929
# 2    2009_MAM        nabilatuk  0.791258
# 3    2009_MAM           kotido  0.644092
# 4    2009_MAM           moroto  1.095403
# 5    2009_MAM    nakapiripirit  0.625353
# 6    2009_MAM          kaabong  1.104766
# 7    2009_MAM          karenga  0.694217
# 8    2009_MAM           amudat  0.860272
# 9    2009_MAM    nab_nak_napak  0.738627
# 10   2009_MAM  abi_kar_kaboong  0.810020
# 11   2009_MAM   mor_kot_amudat  0.866425
# 12   2009_MAM         karamoja  0.805314
# []
# [{'year_month': '2010_MAM', 'bound_name': 'abim', 'mean': 0.60310274}, {'year_month': '2010_MAM', 'bound_name': 'napak', 'mean': 0.91753525}, {'year_month': '2010_MAM', 'bound_name': 'nabilatuk', 'mean': 0.96601224}, {'year_month': '2010_MAM', 'bound_name': 'kotido', 'mean': 0.61288476}, {'year_month': '2010_MAM', 'bound_name': 'moroto', 'mean': 1.0852091}, {'year_month': '2010_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.88565063}, {'year_month': '2010_MAM', 'bound_name': 'kaabong', 'mean': 1.0188457}, {'year_month': '2010_MAM', 'bound_name': 'karenga', 'mean': 0.64142036}, {'year_month': '2010_MAM', 'bound_name': 'amudat', 'mean': 1.0639632}, {'year_month': '2010_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.9190675}, {'year_month': '2010_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.80774206}, {'year_month': '2010_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.88708955}, {'year_month': '2010_MAM', 'bound_name': 'karamoja', 'mean': 0.86848927}]
#    year_month       bound_name      mean
# 0    2010_MAM             abim  0.603103
# 1    2010_MAM            napak  0.917535
# 2    2010_MAM        nabilatuk  0.966012
# 3    2010_MAM           kotido  0.612885
# 4    2010_MAM           moroto  1.085209
# 5    2010_MAM    nakapiripirit  0.885651
# 6    2010_MAM          kaabong  1.018846
# 7    2010_MAM          karenga  0.641420
# 8    2010_MAM           amudat  1.063963
# 9    2010_MAM    nab_nak_napak  0.919068
# 10   2010_MAM  abi_kar_kaboong  0.807742
# 11   2010_MAM   mor_kot_amudat  0.887090
# 12   2010_MAM         karamoja  0.868489
# []
# [{'year_month': '2011_MAM', 'bound_name': 'abim', 'mean': -0.17897446}, {'year_month': '2011_MAM', 'bound_name': 'napak', 'mean': 0.5938706}, {'year_month': '2011_MAM', 'bound_name': 'nabilatuk', 'mean': 0.7254368}, {'year_month': '2011_MAM', 'bound_name': 'kotido', 'mean': 0.030964838}, {'year_month': '2011_MAM', 'bound_name': 'moroto', 'mean': 0.6375293}, {'year_month': '2011_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.718562}, {'year_month': '2011_MAM', 'bound_name': 'kaabong', 'mean': 0.49965492}, {'year_month': '2011_MAM', 'bound_name': 'karenga', 'mean': 0.18918087}, {'year_month': '2011_MAM', 'bound_name': 'amudat', 'mean': 0.71789616}, {'year_month': '2011_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.65637463}, {'year_month': '2011_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 0.23099755}, {'year_month': '2011_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.40298176}, {'year_month': '2011_MAM', 'bound_name': 'karamoja', 'mean': 0.4212281}]
#    year_month       bound_name      mean
# 0    2011_MAM             abim -0.178974
# 1    2011_MAM            napak  0.593871
# 2    2011_MAM        nabilatuk  0.725437
# 3    2011_MAM           kotido  0.030965
# 4    2011_MAM           moroto  0.637529
# 5    2011_MAM    nakapiripirit  0.718562
# 6    2011_MAM          kaabong  0.499655
# 7    2011_MAM          karenga  0.189181
# 8    2011_MAM           amudat  0.717896
# 9    2011_MAM    nab_nak_napak  0.656375
# 10   2011_MAM  abi_kar_kaboong  0.230998
# 11   2011_MAM   mor_kot_amudat  0.402982
# 12   2011_MAM         karamoja  0.421228
# []
# [{'year_month': '2012_MAM', 'bound_name': 'abim', 'mean': -0.1775739}, {'year_month': '2012_MAM', 'bound_name': 'napak', 'mean': 0.4659883}, {'year_month': '2012_MAM', 'bound_name': 'nabilatuk', 'mean': 0.6656795}, {'year_month': '2012_MAM', 'bound_name': 'kotido', 'mean': -0.34705973}, {'year_month': '2012_MAM', 'bound_name': 'moroto', 'mean': 0.12031724}, {'year_month': '2012_MAM', 'bound_name': 'nakapiripirit', 'mean': 0.7118443}, {'year_month': '2012_MAM', 'bound_name': 'kaabong', 'mean': -0.12223038}, {'year_month': '2012_MAM', 'bound_name': 'karenga', 'mean': -0.21713087}, {'year_month': '2012_MAM', 'bound_name': 'amudat', 'mean': 0.55456793}, {'year_month': '2012_MAM', 'bound_name': 'nab_nak_napak', 'mean': 0.57649106}, {'year_month': '2012_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': -0.16142838}, {'year_month': '2012_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 0.0083479}, {'year_month': '2012_MAM', 'bound_name': 'karamoja', 'mean': 0.12752686}]
#    year_month       bound_name      mean
# 0    2012_MAM             abim -0.177574
# 1    2012_MAM            napak  0.465988
# 2    2012_MAM        nabilatuk  0.665680
# 3    2012_MAM           kotido -0.347060
# 4    2012_MAM           moroto  0.120317
# 5    2012_MAM    nakapiripirit  0.711844
# 6    2012_MAM          kaabong -0.122230
# 7    2012_MAM          karenga -0.217131
# 8    2012_MAM           amudat  0.554568
# 9    2012_MAM    nab_nak_napak  0.576491
# 10   2012_MAM  abi_kar_kaboong -0.161428
# 11   2012_MAM   mor_kot_amudat  0.008348
# 12   2012_MAM         karamoja  0.127527
# []
# [{'year_month': '2013_MAM', 'bound_name': 'abim', 'mean': 1.419256}, {'year_month': '2013_MAM', 'bound_name': 'napak', 'mean': 1.7088071}, {'year_month': '2013_MAM', 'bound_name': 'nabilatuk', 'mean': 1.7371795}, {'year_month': '2013_MAM', 'bound_name': 'kotido', 'mean': 1.3591729}, {'year_month': '2013_MAM', 'bound_name': 'moroto', 'mean': 1.7554966}, {'year_month': '2013_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.7421893}, {'year_month': '2013_MAM', 'bound_name': 'kaabong', 'mean': 1.4615046}, {'year_month': '2013_MAM', 'bound_name': 'karenga', 'mean': 1.4444802}, {'year_month': '2013_MAM', 'bound_name': 'amudat', 'mean': 1.7715008}, {'year_month': '2013_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.7240795}, {'year_month': '2013_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.4453517}, {'year_month': '2013_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.5955037}, {'year_month': '2013_MAM', 'bound_name': 'karamoja', 'mean': 1.5819588}]
#    year_month       bound_name      mean
# 0    2013_MAM             abim  1.419256
# 1    2013_MAM            napak  1.708807
# 2    2013_MAM        nabilatuk  1.737180
# 3    2013_MAM           kotido  1.359173
# 4    2013_MAM           moroto  1.755497
# 5    2013_MAM    nakapiripirit  1.742189
# 6    2013_MAM          kaabong  1.461505
# 7    2013_MAM          karenga  1.444480
# 8    2013_MAM           amudat  1.771501
# 9    2013_MAM    nab_nak_napak  1.724079
# 10   2013_MAM  abi_kar_kaboong  1.445352
# 11   2013_MAM   mor_kot_amudat  1.595504
# 12   2013_MAM         karamoja  1.581959
# []
# [{'year_month': '2014_MAM', 'bound_name': 'abim', 'mean': 1.6354989}, {'year_month': '2014_MAM', 'bound_name': 'napak', 'mean': 1.6436743}, {'year_month': '2014_MAM', 'bound_name': 'nabilatuk', 'mean': 1.6086468}, {'year_month': '2014_MAM', 'bound_name': 'kotido', 'mean': 1.6314979}, {'year_month': '2014_MAM', 'bound_name': 'moroto', 'mean': 1.589357}, {'year_month': '2014_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.7151487}, {'year_month': '2014_MAM', 'bound_name': 'kaabong', 'mean': 1.6110461}, {'year_month': '2014_MAM', 'bound_name': 'karenga', 'mean': 1.7206752}, {'year_month': '2014_MAM', 'bound_name': 'amudat', 'mean': 1.7545491}, {'year_month': '2014_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.6559464}, {'year_month': '2014_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6451862}, {'year_month': '2014_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.6371889}, {'year_month': '2014_MAM', 'bound_name': 'karamoja', 'mean': 1.646056}]
#    year_month       bound_name      mean
# 0    2014_MAM             abim  1.635499
# 1    2014_MAM            napak  1.643674
# 2    2014_MAM        nabilatuk  1.608647
# 3    2014_MAM           kotido  1.631498
# 4    2014_MAM           moroto  1.589357
# 5    2014_MAM    nakapiripirit  1.715149
# 6    2014_MAM          kaabong  1.611046
# 7    2014_MAM          karenga  1.720675
# 8    2014_MAM           amudat  1.754549
# 9    2014_MAM    nab_nak_napak  1.655946
# 10   2014_MAM  abi_kar_kaboong  1.645186
# 11   2014_MAM   mor_kot_amudat  1.637189
# 12   2014_MAM         karamoja  1.646056
# []
# [{'year_month': '2015_MAM', 'bound_name': 'abim', 'mean': 1.7593116}, {'year_month': '2015_MAM', 'bound_name': 'napak', 'mean': 1.6441153}, {'year_month': '2015_MAM', 'bound_name': 'nabilatuk', 'mean': 1.5215753}, {'year_month': '2015_MAM', 'bound_name': 'kotido', 'mean': 1.797481}, {'year_month': '2015_MAM', 'bound_name': 'moroto', 'mean': 1.4534417}, {'year_month': '2015_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.5690342}, {'year_month': '2015_MAM', 'bound_name': 'kaabong', 'mean': 1.6046513}, {'year_month': '2015_MAM', 'bound_name': 'karenga', 'mean': 1.8015088}, {'year_month': '2015_MAM', 'bound_name': 'amudat', 'mean': 1.6047189}, {'year_month': '2015_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.59724}, {'year_month': '2015_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.6972101}, {'year_month': '2015_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.6228296}, {'year_month': '2015_MAM', 'bound_name': 'karamoja', 'mean': 1.641661}]
#    year_month       bound_name      mean
# 0    2015_MAM             abim  1.759312
# 1    2015_MAM            napak  1.644115
# 2    2015_MAM        nabilatuk  1.521575
# 3    2015_MAM           kotido  1.797481
# 4    2015_MAM           moroto  1.453442
# 5    2015_MAM    nakapiripirit  1.569034
# 6    2015_MAM          kaabong  1.604651
# 7    2015_MAM          karenga  1.801509
# 8    2015_MAM           amudat  1.604719
# 9    2015_MAM    nab_nak_napak  1.597240
# 10   2015_MAM  abi_kar_kaboong  1.697210
# 11   2015_MAM   mor_kot_amudat  1.622830
# 12   2015_MAM         karamoja  1.641661
# []
# [{'year_month': '2016_MAM', 'bound_name': 'abim', 'mean': 1.819175}, {'year_month': '2016_MAM', 'bound_name': 'napak', 'mean': 1.6097052}, {'year_month': '2016_MAM', 'bound_name': 'nabilatuk', 'mean': 1.5379114}, {'year_month': '2016_MAM', 'bound_name': 'kotido', 'mean': 1.460181}, {'year_month': '2016_MAM', 'bound_name': 'moroto', 'mean': 0.91871077}, {'year_month': '2016_MAM', 'bound_name': 'nakapiripirit', 'mean': 1.5975025}, {'year_month': '2016_MAM', 'bound_name': 'kaabong', 'mean': 1.1940402}, {'year_month': '2016_MAM', 'bound_name': 'karenga', 'mean': 1.4951779}, {'year_month': '2016_MAM', 'bound_name': 'amudat', 'mean': 1.4281586}, {'year_month': '2016_MAM', 'bound_name': 'nab_nak_napak', 'mean': 1.5910219}, {'year_month': '2016_MAM', 'bound_name': 'abi_kar_kaboong', 'mean': 1.445281}, {'year_month': '2016_MAM', 'bound_name': 'mor_kot_amudat', 'mean': 1.2354153}, {'year_month': '2016_MAM', 'bound_name': 'karamoja', 'mean': 1.4246475}]
#    year_month       bound_name      mean
# 0    2016_MAM             abim  1.819175
# 1    2016_MAM            napak  1.609705
# 2    2016_MAM        nabilatuk  1.537911
# 3    2016_MAM           kotido  1.460181
# 4    2016_MAM           moroto  0.918711
# 5    2016_MAM    nakapiripirit  1.597502
# 6    2016_MAM          kaabong  1.194040
# 7    2016_MAM          karenga  1.495178
# 8    2016_MAM           amudat  1.428159
# 9    2016_MAM    nab_nak_napak  1.591022
# 10   2016_MAM  abi_kar_kaboong  1.445281
# 11   2016_MAM   mor_kot_amudat  1.235415
# 12   2016_MAM         karamoja  1.424647

# %%
ncfile_list=['spei01','spei03','spei06','spei09','spei12','spei24','spei48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for OND
start_month_index=9
end_month_index=11

var_str='spei'

for ncfilename in ncfile_list:
    make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index)
# Out:
# []
# [{'year_month': '1981_OND', 'bound_name': 'abim', 'mean': -1.3463771}, {'year_month': '1981_OND', 'bound_name': 'napak', 'mean': -1.0769845}, {'year_month': '1981_OND', 'bound_name': 'nabilatuk', 'mean': -0.9950992}, {'year_month': '1981_OND', 'bound_name': 'kotido', 'mean': -1.2608128}, {'year_month': '1981_OND', 'bound_name': 'moroto', 'mean': -1.2177956}, {'year_month': '1981_OND', 'bound_name': 'nakapiripirit', 'mean': -0.94372714}, {'year_month': '1981_OND', 'bound_name': 'kaabong', 'mean': -1.264595}, {'year_month': '1981_OND', 'bound_name': 'karenga', 'mean': -1.2557241}, {'year_month': '1981_OND', 'bound_name': 'amudat', 'mean': -0.8829339}, {'year_month': '1981_OND', 'bound_name': 'nab_nak_napak', 'mean': -1.0227107}, {'year_month': '1981_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -1.2854705}, {'year_month': '1981_OND', 'bound_name': 'mor_kot_amudat', 'mean': -1.1736436}, {'year_month': '1981_OND', 'bound_name': 'karamoja', 'mean': -1.1661783}]
#    year_month       bound_name      mean
# 0    1981_OND             abim -1.346377
# 1    1981_OND            napak -1.076985
# 2    1981_OND        nabilatuk -0.995099
# 3    1981_OND           kotido -1.260813
# 4    1981_OND           moroto -1.217796
# 5    1981_OND    nakapiripirit -0.943727
# 6    1981_OND          kaabong -1.264595
# 7    1981_OND          karenga -1.255724
# 8    1981_OND           amudat -0.882934
# 9    1981_OND    nab_nak_napak -1.022711
# 10   1981_OND  abi_kar_kaboong -1.285470
# 11   1981_OND   mor_kot_amudat -1.173644
# 12   1981_OND         karamoja -1.166178
# []
# [{'year_month': '1982_OND', 'bound_name': 'abim', 'mean': 0.48083645}, {'year_month': '1982_OND', 'bound_name': 'napak', 'mean': 0.53939867}, {'year_month': '1982_OND', 'bound_name': 'nabilatuk', 'mean': 0.66357785}, {'year_month': '1982_OND', 'bound_name': 'kotido', 'mean': 0.76745206}, {'year_month': '1982_OND', 'bound_name': 'moroto', 'mean': 1.0245707}, {'year_month': '1982_OND', 'bound_name': 'nakapiripirit', 'mean': 0.66018987}, {'year_month': '1982_OND', 'bound_name': 'kaabong', 'mean': 1.2116009}, {'year_month': '1982_OND', 'bound_name': 'karenga', 'mean': 1.1027964}, {'year_month': '1982_OND', 'bound_name': 'amudat', 'mean': 0.695084}, {'year_month': '1982_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.59924984}, {'year_month': '1982_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.9783387}, {'year_month': '1982_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.8580104}, {'year_month': '1982_OND', 'bound_name': 'karamoja', 'mean': 0.8193246}]
#    year_month       bound_name      mean
# 0    1982_OND             abim  0.480836
# 1    1982_OND            napak  0.539399
# 2    1982_OND        nabilatuk  0.663578
# 3    1982_OND           kotido  0.767452
# 4    1982_OND           moroto  1.024571
# 5    1982_OND    nakapiripirit  0.660190
# 6    1982_OND          kaabong  1.211601
# 7    1982_OND          karenga  1.102796
# 8    1982_OND           amudat  0.695084
# 9    1982_OND    nab_nak_napak  0.599250
# 10   1982_OND  abi_kar_kaboong  0.978339
# 11   1982_OND   mor_kot_amudat  0.858010
# 12   1982_OND         karamoja  0.819325
# []
# [{'year_month': '1983_OND', 'bound_name': 'abim', 'mean': -0.17391522}, {'year_month': '1983_OND', 'bound_name': 'napak', 'mean': -0.26907533}, {'year_month': '1983_OND', 'bound_name': 'nabilatuk', 'mean': -0.04438115}, {'year_month': '1983_OND', 'bound_name': 'kotido', 'mean': -0.3763411}, {'year_month': '1983_OND', 'bound_name': 'moroto', 'mean': -0.15453361}, {'year_month': '1983_OND', 'bound_name': 'nakapiripirit', 'mean': -0.13831897}, {'year_month': '1983_OND', 'bound_name': 'kaabong', 'mean': -0.08107157}, {'year_month': '1983_OND', 'bound_name': 'karenga', 'mean': -0.14284445}, {'year_month': '1983_OND', 'bound_name': 'amudat', 'mean': -0.38963962}, {'year_month': '1983_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.18503304}, {'year_month': '1983_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.12262131}, {'year_month': '1983_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.2891465}, {'year_month': '1983_OND', 'bound_name': 'karamoja', 'mean': -0.19563854}]
#    year_month       bound_name      mean
# 0    1983_OND             abim -0.173915
# 1    1983_OND            napak -0.269075
# 2    1983_OND        nabilatuk -0.044381
# 3    1983_OND           kotido -0.376341
# 4    1983_OND           moroto -0.154534
# 5    1983_OND    nakapiripirit -0.138319
# 6    1983_OND          kaabong -0.081072
# 7    1983_OND          karenga -0.142844
# 8    1983_OND           amudat -0.389640
# 9    1983_OND    nab_nak_napak -0.185033
# 10   1983_OND  abi_kar_kaboong -0.122621
# 11   1983_OND   mor_kot_amudat -0.289147
# 12   1983_OND         karamoja -0.195639
# []
# [{'year_month': '1984_OND', 'bound_name': 'abim', 'mean': -0.7952461}, {'year_month': '1984_OND', 'bound_name': 'napak', 'mean': -0.6915137}, {'year_month': '1984_OND', 'bound_name': 'nabilatuk', 'mean': -0.86185485}, {'year_month': '1984_OND', 'bound_name': 'kotido', 'mean': -0.864236}, {'year_month': '1984_OND', 'bound_name': 'moroto', 'mean': -0.44331074}, {'year_month': '1984_OND', 'bound_name': 'nakapiripirit', 'mean': -0.8410031}, {'year_month': '1984_OND', 'bound_name': 'kaabong', 'mean': -0.8531275}, {'year_month': '1984_OND', 'bound_name': 'karenga', 'mean': -1.2220876}, {'year_month': '1984_OND', 'bound_name': 'amudat', 'mean': -0.54414344}, {'year_month': '1984_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.76913774}, {'year_month': '1984_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.928467}, {'year_month': '1984_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.63499475}, {'year_month': '1984_OND', 'bound_name': 'karamoja', 'mean': -0.7840903}]
#    year_month       bound_name      mean
# 0    1984_OND             abim -0.795246
# 1    1984_OND            napak -0.691514
# 2    1984_OND        nabilatuk -0.861855
# 3    1984_OND           kotido -0.864236
# 4    1984_OND           moroto -0.443311
# 5    1984_OND    nakapiripirit -0.841003
# 6    1984_OND          kaabong -0.853127
# 7    1984_OND          karenga -1.222088
# 8    1984_OND           amudat -0.544143
# 9    1984_OND    nab_nak_napak -0.769138
# 10   1984_OND  abi_kar_kaboong -0.928467
# 11   1984_OND   mor_kot_amudat -0.634995
# 12   1984_OND         karamoja -0.784090
# []
# [{'year_month': '1985_OND', 'bound_name': 'abim', 'mean': -0.20262553}, {'year_month': '1985_OND', 'bound_name': 'napak', 'mean': -0.5719768}, {'year_month': '1985_OND', 'bound_name': 'nabilatuk', 'mean': -0.4552451}, {'year_month': '1985_OND', 'bound_name': 'kotido', 'mean': -0.44689152}, {'year_month': '1985_OND', 'bound_name': 'moroto', 'mean': -0.7618332}, {'year_month': '1985_OND', 'bound_name': 'nakapiripirit', 'mean': -0.38486648}, {'year_month': '1985_OND', 'bound_name': 'kaabong', 'mean': -0.96467364}, {'year_month': '1985_OND', 'bound_name': 'karenga', 'mean': -0.81945497}, {'year_month': '1985_OND', 'bound_name': 'amudat', 'mean': -0.51646036}, {'year_month': '1985_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.49539503}, {'year_month': '1985_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.71353513}, {'year_month': '1985_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.5870322}, {'year_month': '1985_OND', 'bound_name': 'karamoja', 'mean': -0.60375273}]
#    year_month       bound_name      mean
# 0    1985_OND             abim -0.202626
# 1    1985_OND            napak -0.571977
# 2    1985_OND        nabilatuk -0.455245
# 3    1985_OND           kotido -0.446892
# 4    1985_OND           moroto -0.761833
# 5    1985_OND    nakapiripirit -0.384866
# 6    1985_OND          kaabong -0.964674
# 7    1985_OND          karenga -0.819455
# 8    1985_OND           amudat -0.516460
# 9    1985_OND    nab_nak_napak -0.495395
# 10   1985_OND  abi_kar_kaboong -0.713535
# 11   1985_OND   mor_kot_amudat -0.587032
# 12   1985_OND         karamoja -0.603753
# []
# [{'year_month': '1986_OND', 'bound_name': 'abim', 'mean': -0.71226084}, {'year_month': '1986_OND', 'bound_name': 'napak', 'mean': -0.6886743}, {'year_month': '1986_OND', 'bound_name': 'nabilatuk', 'mean': -0.7553647}, {'year_month': '1986_OND', 'bound_name': 'kotido', 'mean': -0.66973174}, {'year_month': '1986_OND', 'bound_name': 'moroto', 'mean': -0.56278795}, {'year_month': '1986_OND', 'bound_name': 'nakapiripirit', 'mean': -0.7390987}, {'year_month': '1986_OND', 'bound_name': 'kaabong', 'mean': -0.8528991}, {'year_month': '1986_OND', 'bound_name': 'karenga', 'mean': -0.86370003}, {'year_month': '1986_OND', 'bound_name': 'amudat', 'mean': -0.92894524}, {'year_month': '1986_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.716827}, {'year_month': '1986_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.8158935}, {'year_month': '1986_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.6743757}, {'year_month': '1986_OND', 'bound_name': 'karamoja', 'mean': -0.7391986}]
#    year_month       bound_name      mean
# 0    1986_OND             abim -0.712261
# 1    1986_OND            napak -0.688674
# 2    1986_OND        nabilatuk -0.755365
# 3    1986_OND           kotido -0.669732
# 4    1986_OND           moroto -0.562788
# 5    1986_OND    nakapiripirit -0.739099
# 6    1986_OND          kaabong -0.852899
# 7    1986_OND          karenga -0.863700
# 8    1986_OND           amudat -0.928945
# 9    1986_OND    nab_nak_napak -0.716827
# 10   1986_OND  abi_kar_kaboong -0.815893
# 11   1986_OND   mor_kot_amudat -0.674376
# 12   1986_OND         karamoja -0.739199
# []
# [{'year_month': '1987_OND', 'bound_name': 'abim', 'mean': -0.10733313}, {'year_month': '1987_OND', 'bound_name': 'napak', 'mean': -0.4118185}, {'year_month': '1987_OND', 'bound_name': 'nabilatuk', 'mean': -0.5379738}, {'year_month': '1987_OND', 'bound_name': 'kotido', 'mean': -0.4478127}, {'year_month': '1987_OND', 'bound_name': 'moroto', 'mean': -0.22195606}, {'year_month': '1987_OND', 'bound_name': 'nakapiripirit', 'mean': -0.2823918}, {'year_month': '1987_OND', 'bound_name': 'kaabong', 'mean': -0.67395}, {'year_month': '1987_OND', 'bound_name': 'karenga', 'mean': -0.7297759}, {'year_month': '1987_OND', 'bound_name': 'amudat', 'mean': 0.042610377}, {'year_month': '1987_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.40297502}, {'year_month': '1987_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.5279167}, {'year_month': '1987_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.26595974}, {'year_month': '1987_OND', 'bound_name': 'karamoja', 'mean': -0.40454075}]
#    year_month       bound_name      mean
# 0    1987_OND             abim -0.107333
# 1    1987_OND            napak -0.411819
# 2    1987_OND        nabilatuk -0.537974
# 3    1987_OND           kotido -0.447813
# 4    1987_OND           moroto -0.221956
# 5    1987_OND    nakapiripirit -0.282392
# 6    1987_OND          kaabong -0.673950
# 7    1987_OND          karenga -0.729776
# 8    1987_OND           amudat  0.042610
# 9    1987_OND    nab_nak_napak -0.402975
# 10   1987_OND  abi_kar_kaboong -0.527917
# 11   1987_OND   mor_kot_amudat -0.265960
# 12   1987_OND         karamoja -0.404541
# []
# [{'year_month': '1988_OND', 'bound_name': 'abim', 'mean': -0.3049495}, {'year_month': '1988_OND', 'bound_name': 'napak', 'mean': -0.15602954}, {'year_month': '1988_OND', 'bound_name': 'nabilatuk', 'mean': -0.18796557}, {'year_month': '1988_OND', 'bound_name': 'kotido', 'mean': -0.08013515}, {'year_month': '1988_OND', 'bound_name': 'moroto', 'mean': -0.15416981}, {'year_month': '1988_OND', 'bound_name': 'nakapiripirit', 'mean': -0.02511587}, {'year_month': '1988_OND', 'bound_name': 'kaabong', 'mean': 0.14672388}, {'year_month': '1988_OND', 'bound_name': 'karenga', 'mean': 0.3295617}, {'year_month': '1988_OND', 'bound_name': 'amudat', 'mean': -0.14979339}, {'year_month': '1988_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.12667958}, {'year_month': '1988_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.06468678}, {'year_month': '1988_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.12292225}, {'year_month': '1988_OND', 'bound_name': 'karamoja', 'mean': -0.056085844}]
#    year_month       bound_name      mean
# 0    1988_OND             abim -0.304949
# 1    1988_OND            napak -0.156030
# 2    1988_OND        nabilatuk -0.187966
# 3    1988_OND           kotido -0.080135
# 4    1988_OND           moroto -0.154170
# 5    1988_OND    nakapiripirit -0.025116
# 6    1988_OND          kaabong  0.146724
# 7    1988_OND          karenga  0.329562
# 8    1988_OND           amudat -0.149793
# 9    1988_OND    nab_nak_napak -0.126680
# 10   1988_OND  abi_kar_kaboong  0.064687
# 11   1988_OND   mor_kot_amudat -0.122922
# 12   1988_OND         karamoja -0.056086
# []
# [{'year_month': '1989_OND', 'bound_name': 'abim', 'mean': -0.03976577}, {'year_month': '1989_OND', 'bound_name': 'napak', 'mean': 0.21657155}, {'year_month': '1989_OND', 'bound_name': 'nabilatuk', 'mean': 0.11249181}, {'year_month': '1989_OND', 'bound_name': 'kotido', 'mean': 0.107963145}, {'year_month': '1989_OND', 'bound_name': 'moroto', 'mean': 0.21673405}, {'year_month': '1989_OND', 'bound_name': 'nakapiripirit', 'mean': -0.16856834}, {'year_month': '1989_OND', 'bound_name': 'kaabong', 'mean': -0.25460228}, {'year_month': '1989_OND', 'bound_name': 'karenga', 'mean': -0.19299011}, {'year_month': '1989_OND', 'bound_name': 'amudat', 'mean': -0.24340282}, {'year_month': '1989_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.08798795}, {'year_month': '1989_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.17866503}, {'year_month': '1989_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.08703989}, {'year_month': '1989_OND', 'bound_name': 'karamoja', 'mean': -0.009009814}]
#    year_month       bound_name      mean
# 0    1989_OND             abim -0.039766
# 1    1989_OND            napak  0.216572
# 2    1989_OND        nabilatuk  0.112492
# 3    1989_OND           kotido  0.107963
# 4    1989_OND           moroto  0.216734
# 5    1989_OND    nakapiripirit -0.168568
# 6    1989_OND          kaabong -0.254602
# 7    1989_OND          karenga -0.192990
# 8    1989_OND           amudat -0.243403
# 9    1989_OND    nab_nak_napak  0.087988
# 10   1989_OND  abi_kar_kaboong -0.178665
# 11   1989_OND   mor_kot_amudat  0.087040
# 12   1989_OND         karamoja -0.009010
# []
# [{'year_month': '1990_OND', 'bound_name': 'abim', 'mean': -0.15733205}, {'year_month': '1990_OND', 'bound_name': 'napak', 'mean': -0.4305483}, {'year_month': '1990_OND', 'bound_name': 'nabilatuk', 'mean': -0.5180894}, {'year_month': '1990_OND', 'bound_name': 'kotido', 'mean': -0.004506321}, {'year_month': '1990_OND', 'bound_name': 'moroto', 'mean': -0.21411511}, {'year_month': '1990_OND', 'bound_name': 'nakapiripirit', 'mean': -0.5750304}, {'year_month': '1990_OND', 'bound_name': 'kaabong', 'mean': -0.48079872}, {'year_month': '1990_OND', 'bound_name': 'karenga', 'mean': -0.29516482}, {'year_month': '1990_OND', 'bound_name': 'amudat', 'mean': -0.6099811}, {'year_month': '1990_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.489129}, {'year_month': '1990_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.3433899}, {'year_month': '1990_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.20103866}, {'year_month': '1990_OND', 'bound_name': 'karamoja', 'mean': -0.34430933}]
#    year_month       bound_name      mean
# 0    1990_OND             abim -0.157332
# 1    1990_OND            napak -0.430548
# 2    1990_OND        nabilatuk -0.518089
# 3    1990_OND           kotido -0.004506
# 4    1990_OND           moroto -0.214115
# 5    1990_OND    nakapiripirit -0.575030
# 6    1990_OND          kaabong -0.480799
# 7    1990_OND          karenga -0.295165
# 8    1990_OND           amudat -0.609981
# 9    1990_OND    nab_nak_napak -0.489129
# 10   1990_OND  abi_kar_kaboong -0.343390
# 11   1990_OND   mor_kot_amudat -0.201039
# 12   1990_OND         karamoja -0.344309
# []
# [{'year_month': '1991_OND', 'bound_name': 'abim', 'mean': 0.40488318}, {'year_month': '1991_OND', 'bound_name': 'napak', 'mean': 0.49293768}, {'year_month': '1991_OND', 'bound_name': 'nabilatuk', 'mean': 0.54003274}, {'year_month': '1991_OND', 'bound_name': 'kotido', 'mean': 0.7525809}, {'year_month': '1991_OND', 'bound_name': 'moroto', 'mean': 0.54611164}, {'year_month': '1991_OND', 'bound_name': 'nakapiripirit', 'mean': 0.21444432}, {'year_month': '1991_OND', 'bound_name': 'kaabong', 'mean': 1.0559225}, {'year_month': '1991_OND', 'bound_name': 'karenga', 'mean': 0.97663575}, {'year_month': '1991_OND', 'bound_name': 'amudat', 'mean': 0.15960754}, {'year_month': '1991_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.42605594}, {'year_month': '1991_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.8524936}, {'year_month': '1991_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.55962616}, {'year_month': '1991_OND', 'bound_name': 'karamoja', 'mean': 0.62333435}]
#    year_month       bound_name      mean
# 0    1991_OND             abim  0.404883
# 1    1991_OND            napak  0.492938
# 2    1991_OND        nabilatuk  0.540033
# 3    1991_OND           kotido  0.752581
# 4    1991_OND           moroto  0.546112
# 5    1991_OND    nakapiripirit  0.214444
# 6    1991_OND          kaabong  1.055923
# 7    1991_OND          karenga  0.976636
# 8    1991_OND           amudat  0.159608
# 9    1991_OND    nab_nak_napak  0.426056
# 10   1991_OND  abi_kar_kaboong  0.852494
# 11   1991_OND   mor_kot_amudat  0.559626
# 12   1991_OND         karamoja  0.623334
# []
# [{'year_month': '1992_OND', 'bound_name': 'abim', 'mean': 0.7163494}, {'year_month': '1992_OND', 'bound_name': 'napak', 'mean': 0.36989352}, {'year_month': '1992_OND', 'bound_name': 'nabilatuk', 'mean': 0.2431631}, {'year_month': '1992_OND', 'bound_name': 'kotido', 'mean': 0.4942839}, {'year_month': '1992_OND', 'bound_name': 'moroto', 'mean': 0.131462}, {'year_month': '1992_OND', 'bound_name': 'nakapiripirit', 'mean': 0.16003355}, {'year_month': '1992_OND', 'bound_name': 'kaabong', 'mean': 0.39907876}, {'year_month': '1992_OND', 'bound_name': 'karenga', 'mean': 0.74142766}, {'year_month': '1992_OND', 'bound_name': 'amudat', 'mean': -0.06041321}, {'year_month': '1992_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.28489527}, {'year_month': '1992_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.5736775}, {'year_month': '1992_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.24520278}, {'year_month': '1992_OND', 'bound_name': 'karamoja', 'mean': 0.37694332}]
#    year_month       bound_name      mean
# 0    1992_OND             abim  0.716349
# 1    1992_OND            napak  0.369894
# 2    1992_OND        nabilatuk  0.243163
# 3    1992_OND           kotido  0.494284
# 4    1992_OND           moroto  0.131462
# 5    1992_OND    nakapiripirit  0.160034
# 6    1992_OND          kaabong  0.399079
# 7    1992_OND          karenga  0.741428
# 8    1992_OND           amudat -0.060413
# 9    1992_OND    nab_nak_napak  0.284895
# 10   1992_OND  abi_kar_kaboong  0.573677
# 11   1992_OND   mor_kot_amudat  0.245203
# 12   1992_OND         karamoja  0.376943
# []
# [{'year_month': '1993_OND', 'bound_name': 'abim', 'mean': -0.33943042}, {'year_month': '1993_OND', 'bound_name': 'napak', 'mean': -0.49431333}, {'year_month': '1993_OND', 'bound_name': 'nabilatuk', 'mean': -0.75811154}, {'year_month': '1993_OND', 'bound_name': 'kotido', 'mean': -0.3787877}, {'year_month': '1993_OND', 'bound_name': 'moroto', 'mean': -0.4851207}, {'year_month': '1993_OND', 'bound_name': 'nakapiripirit', 'mean': -1.0094075}, {'year_month': '1993_OND', 'bound_name': 'kaabong', 'mean': -0.7719774}, {'year_month': '1993_OND', 'bound_name': 'karenga', 'mean': -0.6578888}, {'year_month': '1993_OND', 'bound_name': 'amudat', 'mean': -0.64927834}, {'year_month': '1993_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.6928592}, {'year_month': '1993_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.6215618}, {'year_month': '1993_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.47171673}, {'year_month': '1993_OND', 'bound_name': 'karamoja', 'mean': -0.5964067}]
#    year_month       bound_name      mean
# 0    1993_OND             abim -0.339430
# 1    1993_OND            napak -0.494313
# 2    1993_OND        nabilatuk -0.758112
# 3    1993_OND           kotido -0.378788
# 4    1993_OND           moroto -0.485121
# 5    1993_OND    nakapiripirit -1.009408
# 6    1993_OND          kaabong -0.771977
# 7    1993_OND          karenga -0.657889
# 8    1993_OND           amudat -0.649278
# 9    1993_OND    nab_nak_napak -0.692859
# 10   1993_OND  abi_kar_kaboong -0.621562
# 11   1993_OND   mor_kot_amudat -0.471717
# 12   1993_OND         karamoja -0.596407
# []
# [{'year_month': '1994_OND', 'bound_name': 'abim', 'mean': -0.10313532}, {'year_month': '1994_OND', 'bound_name': 'napak', 'mean': -0.13981237}, {'year_month': '1994_OND', 'bound_name': 'nabilatuk', 'mean': 0.08345411}, {'year_month': '1994_OND', 'bound_name': 'kotido', 'mean': -0.20952372}, {'year_month': '1994_OND', 'bound_name': 'moroto', 'mean': -0.12169527}, {'year_month': '1994_OND', 'bound_name': 'nakapiripirit', 'mean': 0.12553543}, {'year_month': '1994_OND', 'bound_name': 'kaabong', 'mean': -0.046781067}, {'year_month': '1994_OND', 'bound_name': 'karenga', 'mean': -0.08003209}, {'year_month': '1994_OND', 'bound_name': 'amudat', 'mean': 0.016978318}, {'year_month': '1994_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.01889721}, {'year_month': '1994_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.07094649}, {'year_month': '1994_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.13219717}, {'year_month': '1994_OND', 'bound_name': 'karamoja', 'mean': -0.07394189}]
#    year_month       bound_name      mean
# 0    1994_OND             abim -0.103135
# 1    1994_OND            napak -0.139812
# 2    1994_OND        nabilatuk  0.083454
# 3    1994_OND           kotido -0.209524
# 4    1994_OND           moroto -0.121695
# 5    1994_OND    nakapiripirit  0.125535
# 6    1994_OND          kaabong -0.046781
# 7    1994_OND          karenga -0.080032
# 8    1994_OND           amudat  0.016978
# 9    1994_OND    nab_nak_napak -0.018897
# 10   1994_OND  abi_kar_kaboong -0.070946
# 11   1994_OND   mor_kot_amudat -0.132197
# 12   1994_OND         karamoja -0.073942
# []
# [{'year_month': '1995_OND', 'bound_name': 'abim', 'mean': -0.13223425}, {'year_month': '1995_OND', 'bound_name': 'napak', 'mean': -0.18887055}, {'year_month': '1995_OND', 'bound_name': 'nabilatuk', 'mean': -0.07397623}, {'year_month': '1995_OND', 'bound_name': 'kotido', 'mean': -0.51010084}, {'year_month': '1995_OND', 'bound_name': 'moroto', 'mean': -0.471797}, {'year_month': '1995_OND', 'bound_name': 'nakapiripirit', 'mean': 0.009172783}, {'year_month': '1995_OND', 'bound_name': 'kaabong', 'mean': -0.53667516}, {'year_month': '1995_OND', 'bound_name': 'karenga', 'mean': -0.4067296}, {'year_month': '1995_OND', 'bound_name': 'amudat', 'mean': -0.0010886771}, {'year_month': '1995_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.109660834}, {'year_month': '1995_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.3902514}, {'year_month': '1995_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.4006204}, {'year_month': '1995_OND', 'bound_name': 'karamoja', 'mean': -0.30429703}]
#    year_month       bound_name      mean
# 0    1995_OND             abim -0.132234
# 1    1995_OND            napak -0.188871
# 2    1995_OND        nabilatuk -0.073976
# 3    1995_OND           kotido -0.510101
# 4    1995_OND           moroto -0.471797
# 5    1995_OND    nakapiripirit  0.009173
# 6    1995_OND          kaabong -0.536675
# 7    1995_OND          karenga -0.406730
# 8    1995_OND           amudat -0.001089
# 9    1995_OND    nab_nak_napak -0.109661
# 10   1995_OND  abi_kar_kaboong -0.390251
# 11   1995_OND   mor_kot_amudat -0.400620
# 12   1995_OND         karamoja -0.304297
# []
# [{'year_month': '1996_OND', 'bound_name': 'abim', 'mean': -0.12131685}, {'year_month': '1996_OND', 'bound_name': 'napak', 'mean': 0.002590075}, {'year_month': '1996_OND', 'bound_name': 'nabilatuk', 'mean': -0.26411313}, {'year_month': '1996_OND', 'bound_name': 'kotido', 'mean': -0.11081021}, {'year_month': '1996_OND', 'bound_name': 'moroto', 'mean': -0.26752627}, {'year_month': '1996_OND', 'bound_name': 'nakapiripirit', 'mean': -0.5714303}, {'year_month': '1996_OND', 'bound_name': 'kaabong', 'mean': -0.5872343}, {'year_month': '1996_OND', 'bound_name': 'karenga', 'mean': -0.46264508}, {'year_month': '1996_OND', 'bound_name': 'amudat', 'mean': -0.27765095}, {'year_month': '1996_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.21285227}, {'year_month': '1996_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.42479214}, {'year_month': '1996_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.2049622}, {'year_month': '1996_OND', 'bound_name': 'karamoja', 'mean': -0.28718817}]
#    year_month       bound_name      mean
# 0    1996_OND             abim -0.121317
# 1    1996_OND            napak  0.002590
# 2    1996_OND        nabilatuk -0.264113
# 3    1996_OND           kotido -0.110810
# 4    1996_OND           moroto -0.267526
# 5    1996_OND    nakapiripirit -0.571430
# 6    1996_OND          kaabong -0.587234
# 7    1996_OND          karenga -0.462645
# 8    1996_OND           amudat -0.277651
# 9    1996_OND    nab_nak_napak -0.212852
# 10   1996_OND  abi_kar_kaboong -0.424792
# 11   1996_OND   mor_kot_amudat -0.204962
# 12   1996_OND         karamoja -0.287188
# []
# [{'year_month': '1997_OND', 'bound_name': 'abim', 'mean': 0.9311739}, {'year_month': '1997_OND', 'bound_name': 'napak', 'mean': 1.2927692}, {'year_month': '1997_OND', 'bound_name': 'nabilatuk', 'mean': 1.0765878}, {'year_month': '1997_OND', 'bound_name': 'kotido', 'mean': 1.2985411}, {'year_month': '1997_OND', 'bound_name': 'moroto', 'mean': 1.6670961}, {'year_month': '1997_OND', 'bound_name': 'nakapiripirit', 'mean': 0.7494923}, {'year_month': '1997_OND', 'bound_name': 'kaabong', 'mean': 1.2793671}, {'year_month': '1997_OND', 'bound_name': 'karenga', 'mean': 1.0658481}, {'year_month': '1997_OND', 'bound_name': 'amudat', 'mean': 1.003552}, {'year_month': '1997_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.0965946}, {'year_month': '1997_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.1280516}, {'year_month': '1997_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.3930287}, {'year_month': '1997_OND', 'bound_name': 'karamoja', 'mean': 1.2026365}]
#    year_month       bound_name      mean
# 0    1997_OND             abim  0.931174
# 1    1997_OND            napak  1.292769
# 2    1997_OND        nabilatuk  1.076588
# 3    1997_OND           kotido  1.298541
# 4    1997_OND           moroto  1.667096
# 5    1997_OND    nakapiripirit  0.749492
# 6    1997_OND          kaabong  1.279367
# 7    1997_OND          karenga  1.065848
# 8    1997_OND           amudat  1.003552
# 9    1997_OND    nab_nak_napak  1.096595
# 10   1997_OND  abi_kar_kaboong  1.128052
# 11   1997_OND   mor_kot_amudat  1.393029
# 12   1997_OND         karamoja  1.202636
# []
# [{'year_month': '1998_OND', 'bound_name': 'abim', 'mean': 0.7546571}, {'year_month': '1998_OND', 'bound_name': 'napak', 'mean': 0.2718637}, {'year_month': '1998_OND', 'bound_name': 'nabilatuk', 'mean': 0.0641}, {'year_month': '1998_OND', 'bound_name': 'kotido', 'mean': 0.7027275}, {'year_month': '1998_OND', 'bound_name': 'moroto', 'mean': 0.1718013}, {'year_month': '1998_OND', 'bound_name': 'nakapiripirit', 'mean': 0.24339241}, {'year_month': '1998_OND', 'bound_name': 'kaabong', 'mean': 0.5125327}, {'year_month': '1998_OND', 'bound_name': 'karenga', 'mean': 0.54577833}, {'year_month': '1998_OND', 'bound_name': 'amudat', 'mean': 0.08219905}, {'year_month': '1998_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.219686}, {'year_month': '1998_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.5891228}, {'year_month': '1998_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.37354478}, {'year_month': '1998_OND', 'bound_name': 'karamoja', 'mean': 0.40277144}]
#    year_month       bound_name      mean
# 0    1998_OND             abim  0.754657
# 1    1998_OND            napak  0.271864
# 2    1998_OND        nabilatuk  0.064100
# 3    1998_OND           kotido  0.702727
# 4    1998_OND           moroto  0.171801
# 5    1998_OND    nakapiripirit  0.243392
# 6    1998_OND          kaabong  0.512533
# 7    1998_OND          karenga  0.545778
# 8    1998_OND           amudat  0.082199
# 9    1998_OND    nab_nak_napak  0.219686
# 10   1998_OND  abi_kar_kaboong  0.589123
# 11   1998_OND   mor_kot_amudat  0.373545
# 12   1998_OND         karamoja  0.402771
# []
# [{'year_month': '1999_OND', 'bound_name': 'abim', 'mean': -0.31449455}, {'year_month': '1999_OND', 'bound_name': 'napak', 'mean': -0.7347209}, {'year_month': '1999_OND', 'bound_name': 'nabilatuk', 'mean': -0.51762044}, {'year_month': '1999_OND', 'bound_name': 'kotido', 'mean': -0.20152716}, {'year_month': '1999_OND', 'bound_name': 'moroto', 'mean': -0.38476247}, {'year_month': '1999_OND', 'bound_name': 'nakapiripirit', 'mean': 0.13712977}, {'year_month': '1999_OND', 'bound_name': 'kaabong', 'mean': -0.3494059}, {'year_month': '1999_OND', 'bound_name': 'karenga', 'mean': 0.014185211}, {'year_month': '1999_OND', 'bound_name': 'amudat', 'mean': 0.02462452}, {'year_month': '1999_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.44759032}, {'year_month': '1999_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.24921349}, {'year_month': '1999_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.23382425}, {'year_month': '1999_OND', 'bound_name': 'karamoja', 'mean': -0.30741045}]
#    year_month       bound_name      mean
# 0    1999_OND             abim -0.314495
# 1    1999_OND            napak -0.734721
# 2    1999_OND        nabilatuk -0.517620
# 3    1999_OND           kotido -0.201527
# 4    1999_OND           moroto -0.384762
# 5    1999_OND    nakapiripirit  0.137130
# 6    1999_OND          kaabong -0.349406
# 7    1999_OND          karenga  0.014185
# 8    1999_OND           amudat  0.024625
# 9    1999_OND    nab_nak_napak -0.447590
# 10   1999_OND  abi_kar_kaboong -0.249213
# 11   1999_OND   mor_kot_amudat -0.233824
# 12   1999_OND         karamoja -0.307410
# []
# [{'year_month': '2000_OND', 'bound_name': 'abim', 'mean': 0.53318536}, {'year_month': '2000_OND', 'bound_name': 'napak', 'mean': 0.6604658}, {'year_month': '2000_OND', 'bound_name': 'nabilatuk', 'mean': 0.61274916}, {'year_month': '2000_OND', 'bound_name': 'kotido', 'mean': 0.6133763}, {'year_month': '2000_OND', 'bound_name': 'moroto', 'mean': 0.6697681}, {'year_month': '2000_OND', 'bound_name': 'nakapiripirit', 'mean': 0.5532747}, {'year_month': '2000_OND', 'bound_name': 'kaabong', 'mean': 0.52431566}, {'year_month': '2000_OND', 'bound_name': 'karenga', 'mean': 0.38806665}, {'year_month': '2000_OND', 'bound_name': 'amudat', 'mean': 0.48935854}, {'year_month': '2000_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.62067974}, {'year_month': '2000_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.49296552}, {'year_month': '2000_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.6132665}, {'year_month': '2000_OND', 'bound_name': 'karamoja', 'mean': 0.5720007}]
#    year_month       bound_name      mean
# 0    2000_OND             abim  0.533185
# 1    2000_OND            napak  0.660466
# 2    2000_OND        nabilatuk  0.612749
# 3    2000_OND           kotido  0.613376
# 4    2000_OND           moroto  0.669768
# 5    2000_OND    nakapiripirit  0.553275
# 6    2000_OND          kaabong  0.524316
# 7    2000_OND          karenga  0.388067
# 8    2000_OND           amudat  0.489359
# 9    2000_OND    nab_nak_napak  0.620680
# 10   2000_OND  abi_kar_kaboong  0.492966
# 11   2000_OND   mor_kot_amudat  0.613267
# 12   2000_OND         karamoja  0.572001
# []
# [{'year_month': '2001_OND', 'bound_name': 'abim', 'mean': 1.0702293}, {'year_month': '2001_OND', 'bound_name': 'napak', 'mean': 1.0277746}, {'year_month': '2001_OND', 'bound_name': 'nabilatuk', 'mean': 0.81150323}, {'year_month': '2001_OND', 'bound_name': 'kotido', 'mean': 1.1274835}, {'year_month': '2001_OND', 'bound_name': 'moroto', 'mean': 0.9075396}, {'year_month': '2001_OND', 'bound_name': 'nakapiripirit', 'mean': 0.9325714}, {'year_month': '2001_OND', 'bound_name': 'kaabong', 'mean': 0.99638295}, {'year_month': '2001_OND', 'bound_name': 'karenga', 'mean': 1.0736895}, {'year_month': '2001_OND', 'bound_name': 'amudat', 'mean': 0.859467}, {'year_month': '2001_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.9553495}, {'year_month': '2001_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.0364311}, {'year_month': '2001_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.98909193}, {'year_month': '2001_OND', 'bound_name': 'karamoja', 'mean': 0.9955238}]
#    year_month       bound_name      mean
# 0    2001_OND             abim  1.070229
# 1    2001_OND            napak  1.027775
# 2    2001_OND        nabilatuk  0.811503
# 3    2001_OND           kotido  1.127483
# 4    2001_OND           moroto  0.907540
# 5    2001_OND    nakapiripirit  0.932571
# 6    2001_OND          kaabong  0.996383
# 7    2001_OND          karenga  1.073689
# 8    2001_OND           amudat  0.859467
# 9    2001_OND    nab_nak_napak  0.955350
# 10   2001_OND  abi_kar_kaboong  1.036431
# 11   2001_OND   mor_kot_amudat  0.989092
# 12   2001_OND         karamoja  0.995524
# []
# [{'year_month': '2002_OND', 'bound_name': 'abim', 'mean': 0.094444565}, {'year_month': '2002_OND', 'bound_name': 'napak', 'mean': 0.076590754}, {'year_month': '2002_OND', 'bound_name': 'nabilatuk', 'mean': 0.22794344}, {'year_month': '2002_OND', 'bound_name': 'kotido', 'mean': -0.044192374}, {'year_month': '2002_OND', 'bound_name': 'moroto', 'mean': -0.24891897}, {'year_month': '2002_OND', 'bound_name': 'nakapiripirit', 'mean': 0.45446327}, {'year_month': '2002_OND', 'bound_name': 'kaabong', 'mean': -0.27164054}, {'year_month': '2002_OND', 'bound_name': 'karenga', 'mean': -0.28364444}, {'year_month': '2002_OND', 'bound_name': 'amudat', 'mean': 0.16101979}, {'year_month': '2002_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.21324964}, {'year_month': '2002_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.17131075}, {'year_month': '2002_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.08904269}, {'year_month': '2002_OND', 'bound_name': 'karamoja', 'mean': -0.02270651}]
#    year_month       bound_name      mean
# 0    2002_OND             abim  0.094445
# 1    2002_OND            napak  0.076591
# 2    2002_OND        nabilatuk  0.227943
# 3    2002_OND           kotido -0.044192
# 4    2002_OND           moroto -0.248919
# 5    2002_OND    nakapiripirit  0.454463
# 6    2002_OND          kaabong -0.271641
# 7    2002_OND          karenga -0.283644
# 8    2002_OND           amudat  0.161020
# 9    2002_OND    nab_nak_napak  0.213250
# 10   2002_OND  abi_kar_kaboong -0.171311
# 11   2002_OND   mor_kot_amudat -0.089043
# 12   2002_OND         karamoja -0.022707
# []
# [{'year_month': '2003_OND', 'bound_name': 'abim', 'mean': -0.73578966}, {'year_month': '2003_OND', 'bound_name': 'napak', 'mean': -0.73865}, {'year_month': '2003_OND', 'bound_name': 'nabilatuk', 'mean': -0.6649221}, {'year_month': '2003_OND', 'bound_name': 'kotido', 'mean': -0.7528067}, {'year_month': '2003_OND', 'bound_name': 'moroto', 'mean': -0.84441423}, {'year_month': '2003_OND', 'bound_name': 'nakapiripirit', 'mean': -0.62312025}, {'year_month': '2003_OND', 'bound_name': 'kaabong', 'mean': -0.7379604}, {'year_month': '2003_OND', 'bound_name': 'karenga', 'mean': -0.5824679}, {'year_month': '2003_OND', 'bound_name': 'amudat', 'mean': -0.73271227}, {'year_month': '2003_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.6910128}, {'year_month': '2003_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.69871324}, {'year_month': '2003_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.7861219}, {'year_month': '2003_OND', 'bound_name': 'karamoja', 'mean': -0.72416806}]
#    year_month       bound_name      mean
# 0    2003_OND             abim -0.735790
# 1    2003_OND            napak -0.738650
# 2    2003_OND        nabilatuk -0.664922
# 3    2003_OND           kotido -0.752807
# 4    2003_OND           moroto -0.844414
# 5    2003_OND    nakapiripirit -0.623120
# 6    2003_OND          kaabong -0.737960
# 7    2003_OND          karenga -0.582468
# 8    2003_OND           amudat -0.732712
# 9    2003_OND    nab_nak_napak -0.691013
# 10   2003_OND  abi_kar_kaboong -0.698713
# 11   2003_OND   mor_kot_amudat -0.786122
# 12   2003_OND         karamoja -0.724168
# []
# [{'year_month': '2004_OND', 'bound_name': 'abim', 'mean': -0.2719337}, {'year_month': '2004_OND', 'bound_name': 'napak', 'mean': -0.09822738}, {'year_month': '2004_OND', 'bound_name': 'nabilatuk', 'mean': -0.047620475}, {'year_month': '2004_OND', 'bound_name': 'kotido', 'mean': -0.0020423178}, {'year_month': '2004_OND', 'bound_name': 'moroto', 'mean': 0.16493317}, {'year_month': '2004_OND', 'bound_name': 'nakapiripirit', 'mean': 0.0131278215}, {'year_month': '2004_OND', 'bound_name': 'kaabong', 'mean': 0.21980785}, {'year_month': '2004_OND', 'bound_name': 'karenga', 'mean': 0.028972814}, {'year_month': '2004_OND', 'bound_name': 'amudat', 'mean': 0.25969055}, {'year_month': '2004_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.056674637}, {'year_month': '2004_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.033618063}, {'year_month': '2004_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.113779955}, {'year_month': '2004_OND', 'bound_name': 'karamoja', 'mean': 0.030484345}]
#    year_month       bound_name      mean
# 0    2004_OND             abim -0.271934
# 1    2004_OND            napak -0.098227
# 2    2004_OND        nabilatuk -0.047620
# 3    2004_OND           kotido -0.002042
# 4    2004_OND           moroto  0.164933
# 5    2004_OND    nakapiripirit  0.013128
# 6    2004_OND          kaabong  0.219808
# 7    2004_OND          karenga  0.028973
# 8    2004_OND           amudat  0.259691
# 9    2004_OND    nab_nak_napak -0.056675
# 10   2004_OND  abi_kar_kaboong  0.033618
# 11   2004_OND   mor_kot_amudat  0.113780
# 12   2004_OND         karamoja  0.030484
# []
# [{'year_month': '2005_OND', 'bound_name': 'abim', 'mean': -1.3199707}, {'year_month': '2005_OND', 'bound_name': 'napak', 'mean': -1.1540726}, {'year_month': '2005_OND', 'bound_name': 'nabilatuk', 'mean': -0.85221726}, {'year_month': '2005_OND', 'bound_name': 'kotido', 'mean': -1.2601687}, {'year_month': '2005_OND', 'bound_name': 'moroto', 'mean': -0.9602768}, {'year_month': '2005_OND', 'bound_name': 'nakapiripirit', 'mean': -0.58521205}, {'year_month': '2005_OND', 'bound_name': 'kaabong', 'mean': -1.0897458}, {'year_month': '2005_OND', 'bound_name': 'karenga', 'mean': -1.1039476}, {'year_month': '2005_OND', 'bound_name': 'amudat', 'mean': -0.6397934}, {'year_month': '2005_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.93255806}, {'year_month': '2005_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -1.1582458}, {'year_month': '2005_OND', 'bound_name': 'mor_kot_amudat', 'mean': -1.0243939}, {'year_month': '2005_OND', 'bound_name': 'karamoja', 'mean': -1.0437161}]
#    year_month       bound_name      mean
# 0    2005_OND             abim -1.319971
# 1    2005_OND            napak -1.154073
# 2    2005_OND        nabilatuk -0.852217
# 3    2005_OND           kotido -1.260169
# 4    2005_OND           moroto -0.960277
# 5    2005_OND    nakapiripirit -0.585212
# 6    2005_OND          kaabong -1.089746
# 7    2005_OND          karenga -1.103948
# 8    2005_OND           amudat -0.639793
# 9    2005_OND    nab_nak_napak -0.932558
# 10   2005_OND  abi_kar_kaboong -1.158246
# 11   2005_OND   mor_kot_amudat -1.024394
# 12   2005_OND         karamoja -1.043716
# []
# [{'year_month': '2006_OND', 'bound_name': 'abim', 'mean': 1.299062}, {'year_month': '2006_OND', 'bound_name': 'napak', 'mean': 1.4052404}, {'year_month': '2006_OND', 'bound_name': 'nabilatuk', 'mean': 1.3406451}, {'year_month': '2006_OND', 'bound_name': 'kotido', 'mean': 1.3821245}, {'year_month': '2006_OND', 'bound_name': 'moroto', 'mean': 1.5968964}, {'year_month': '2006_OND', 'bound_name': 'nakapiripirit', 'mean': 1.1078341}, {'year_month': '2006_OND', 'bound_name': 'kaabong', 'mean': 1.5519562}, {'year_month': '2006_OND', 'bound_name': 'karenga', 'mean': 1.1720395}, {'year_month': '2006_OND', 'bound_name': 'amudat', 'mean': 1.3497274}, {'year_month': '2006_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.3093125}, {'year_month': '2006_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.3861908}, {'year_month': '2006_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.4629486}, {'year_month': '2006_OND', 'bound_name': 'karamoja', 'mean': 1.3862379}]
#    year_month       bound_name      mean
# 0    2006_OND             abim  1.299062
# 1    2006_OND            napak  1.405240
# 2    2006_OND        nabilatuk  1.340645
# 3    2006_OND           kotido  1.382125
# 4    2006_OND           moroto  1.596896
# 5    2006_OND    nakapiripirit  1.107834
# 6    2006_OND          kaabong  1.551956
# 7    2006_OND          karenga  1.172040
# 8    2006_OND           amudat  1.349727
# 9    2006_OND    nab_nak_napak  1.309312
# 10   2006_OND  abi_kar_kaboong  1.386191
# 11   2006_OND   mor_kot_amudat  1.462949
# 12   2006_OND         karamoja  1.386238
# []
# [{'year_month': '2007_OND', 'bound_name': 'abim', 'mean': -1.5732697}, {'year_month': '2007_OND', 'bound_name': 'napak', 'mean': -1.3638805}, {'year_month': '2007_OND', 'bound_name': 'nabilatuk', 'mean': -1.3243648}, {'year_month': '2007_OND', 'bound_name': 'kotido', 'mean': -1.1043686}, {'year_month': '2007_OND', 'bound_name': 'moroto', 'mean': -1.0495026}, {'year_month': '2007_OND', 'bound_name': 'nakapiripirit', 'mean': -1.4156367}, {'year_month': '2007_OND', 'bound_name': 'kaabong', 'mean': -0.6050657}, {'year_month': '2007_OND', 'bound_name': 'karenga', 'mean': -0.7204061}, {'year_month': '2007_OND', 'bound_name': 'amudat', 'mean': -1.3237028}, {'year_month': '2007_OND', 'bound_name': 'nab_nak_napak', 'mean': -1.3697486}, {'year_month': '2007_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.9069594}, {'year_month': '2007_OND', 'bound_name': 'mor_kot_amudat', 'mean': -1.122697}, {'year_month': '2007_OND', 'bound_name': 'karamoja', 'mean': -1.12306}]
#    year_month       bound_name      mean
# 0    2007_OND             abim -1.573270
# 1    2007_OND            napak -1.363881
# 2    2007_OND        nabilatuk -1.324365
# 3    2007_OND           kotido -1.104369
# 4    2007_OND           moroto -1.049503
# 5    2007_OND    nakapiripirit -1.415637
# 6    2007_OND          kaabong -0.605066
# 7    2007_OND          karenga -0.720406
# 8    2007_OND           amudat -1.323703
# 9    2007_OND    nab_nak_napak -1.369749
# 10   2007_OND  abi_kar_kaboong -0.906959
# 11   2007_OND   mor_kot_amudat -1.122697
# 12   2007_OND         karamoja -1.123060
# []
# [{'year_month': '2008_OND', 'bound_name': 'abim', 'mean': -0.016709805}, {'year_month': '2008_OND', 'bound_name': 'napak', 'mean': 0.4745962}, {'year_month': '2008_OND', 'bound_name': 'nabilatuk', 'mean': 0.5640377}, {'year_month': '2008_OND', 'bound_name': 'kotido', 'mean': 0.24981014}, {'year_month': '2008_OND', 'bound_name': 'moroto', 'mean': 0.71021074}, {'year_month': '2008_OND', 'bound_name': 'nakapiripirit', 'mean': 0.59539115}, {'year_month': '2008_OND', 'bound_name': 'kaabong', 'mean': 0.62761116}, {'year_month': '2008_OND', 'bound_name': 'karenga', 'mean': 0.41193584}, {'year_month': '2008_OND', 'bound_name': 'amudat', 'mean': 0.8485905}, {'year_month': '2008_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.52703935}, {'year_month': '2008_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.3921902}, {'year_month': '2008_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.5464716}, {'year_month': '2008_OND', 'bound_name': 'karamoja', 'mean': 0.48434323}]
#    year_month       bound_name      mean
# 0    2008_OND             abim -0.016710
# 1    2008_OND            napak  0.474596
# 2    2008_OND        nabilatuk  0.564038
# 3    2008_OND           kotido  0.249810
# 4    2008_OND           moroto  0.710211
# 5    2008_OND    nakapiripirit  0.595391
# 6    2008_OND          kaabong  0.627611
# 7    2008_OND          karenga  0.411936
# 8    2008_OND           amudat  0.848590
# 9    2008_OND    nab_nak_napak  0.527039
# 10   2008_OND  abi_kar_kaboong  0.392190
# 11   2008_OND   mor_kot_amudat  0.546472
# 12   2008_OND         karamoja  0.484343
# []
# [{'year_month': '2009_OND', 'bound_name': 'abim', 'mean': -0.29797336}, {'year_month': '2009_OND', 'bound_name': 'napak', 'mean': -0.14419316}, {'year_month': '2009_OND', 'bound_name': 'nabilatuk', 'mean': -0.12899014}, {'year_month': '2009_OND', 'bound_name': 'kotido', 'mean': -0.6835462}, {'year_month': '2009_OND', 'bound_name': 'moroto', 'mean': -0.4134177}, {'year_month': '2009_OND', 'bound_name': 'nakapiripirit', 'mean': -0.20636457}, {'year_month': '2009_OND', 'bound_name': 'kaabong', 'mean': -0.12069672}, {'year_month': '2009_OND', 'bound_name': 'karenga', 'mean': -0.47537404}, {'year_month': '2009_OND', 'bound_name': 'amudat', 'mean': -0.3848755}, {'year_month': '2009_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.15812378}, {'year_month': '2009_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.25885108}, {'year_month': '2009_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.5192101}, {'year_month': '2009_OND', 'bound_name': 'karamoja', 'mean': -0.30992454}]
#    year_month       bound_name      mean
# 0    2009_OND             abim -0.297973
# 1    2009_OND            napak -0.144193
# 2    2009_OND        nabilatuk -0.128990
# 3    2009_OND           kotido -0.683546
# 4    2009_OND           moroto -0.413418
# 5    2009_OND    nakapiripirit -0.206365
# 6    2009_OND          kaabong -0.120697
# 7    2009_OND          karenga -0.475374
# 8    2009_OND           amudat -0.384876
# 9    2009_OND    nab_nak_napak -0.158124
# 10   2009_OND  abi_kar_kaboong -0.258851
# 11   2009_OND   mor_kot_amudat -0.519210
# 12   2009_OND         karamoja -0.309925
# []
# [{'year_month': '2010_OND', 'bound_name': 'abim', 'mean': -0.43848422}, {'year_month': '2010_OND', 'bound_name': 'napak', 'mean': -0.69844615}, {'year_month': '2010_OND', 'bound_name': 'nabilatuk', 'mean': -0.6221172}, {'year_month': '2010_OND', 'bound_name': 'kotido', 'mean': -0.9884962}, {'year_month': '2010_OND', 'bound_name': 'moroto', 'mean': -1.0969608}, {'year_month': '2010_OND', 'bound_name': 'nakapiripirit', 'mean': -0.4018861}, {'year_month': '2010_OND', 'bound_name': 'kaabong', 'mean': -0.5741617}, {'year_month': '2010_OND', 'bound_name': 'karenga', 'mean': -0.6198105}, {'year_month': '2010_OND', 'bound_name': 'amudat', 'mean': -0.5734245}, {'year_month': '2010_OND', 'bound_name': 'nab_nak_napak', 'mean': -0.6002493}, {'year_month': '2010_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.5472146}, {'year_month': '2010_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.9556848}, {'year_month': '2010_OND', 'bound_name': 'karamoja', 'mean': -0.6944881}]
#    year_month       bound_name      mean
# 0    2010_OND             abim -0.438484
# 1    2010_OND            napak -0.698446
# 2    2010_OND        nabilatuk -0.622117
# 3    2010_OND           kotido -0.988496
# 4    2010_OND           moroto -1.096961
# 5    2010_OND    nakapiripirit -0.401886
# 6    2010_OND          kaabong -0.574162
# 7    2010_OND          karenga -0.619811
# 8    2010_OND           amudat -0.573425
# 9    2010_OND    nab_nak_napak -0.600249
# 10   2010_OND  abi_kar_kaboong -0.547215
# 11   2010_OND   mor_kot_amudat -0.955685
# 12   2010_OND         karamoja -0.694488
# []
# [{'year_month': '2011_OND', 'bound_name': 'abim', 'mean': 0.693}, {'year_month': '2011_OND', 'bound_name': 'napak', 'mean': 0.7541458}, {'year_month': '2011_OND', 'bound_name': 'nabilatuk', 'mean': 0.6243361}, {'year_month': '2011_OND', 'bound_name': 'kotido', 'mean': 0.82112026}, {'year_month': '2011_OND', 'bound_name': 'moroto', 'mean': 0.98844093}, {'year_month': '2011_OND', 'bound_name': 'nakapiripirit', 'mean': 0.61872774}, {'year_month': '2011_OND', 'bound_name': 'kaabong', 'mean': 1.0418864}, {'year_month': '2011_OND', 'bound_name': 'karenga', 'mean': 0.93721044}, {'year_month': '2011_OND', 'bound_name': 'amudat', 'mean': 0.65793484}, {'year_month': '2011_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.6890534}, {'year_month': '2011_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.91741925}, {'year_month': '2011_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.85861284}, {'year_month': '2011_OND', 'bound_name': 'karamoja', 'mean': 0.8259955}]
#    year_month       bound_name      mean
# 0    2011_OND             abim  0.693000
# 1    2011_OND            napak  0.754146
# 2    2011_OND        nabilatuk  0.624336
# 3    2011_OND           kotido  0.821120
# 4    2011_OND           moroto  0.988441
# 5    2011_OND    nakapiripirit  0.618728
# 6    2011_OND          kaabong  1.041886
# 7    2011_OND          karenga  0.937210
# 8    2011_OND           amudat  0.657935
# 9    2011_OND    nab_nak_napak  0.689053
# 10   2011_OND  abi_kar_kaboong  0.917419
# ...
#    year_month       bound_name      mean
# 0    2006_OND             abim -0.494799
# 1    2006_OND            napak  0.002523
# 2    2006_OND        nabilatuk  0.166947
# 3    2006_OND           kotido -0.360633
# 4    2006_OND           moroto  0.269161
# 5    2006_OND    nakapiripirit -0.191668
# 6    2006_OND          kaabong -0.085858
# 7    2006_OND          karenga -0.324252
# 8    2006_OND           amudat  0.022615
# 9    2006_OND    nab_nak_napak -0.016048
# 10   2006_OND  abi_kar_kaboong -0.260498
# 11   2006_OND   mor_kot_amudat -0.035308
# 12   2006_OND         karamoja -0.110840
# []
# [{'year_month': '2007_OND', 'bound_name': 'abim', 'mean': 0.4324935}, {'year_month': '2007_OND', 'bound_name': 'napak', 'mean': 0.91387874}, {'year_month': '2007_OND', 'bound_name': 'nabilatuk', 'mean': 0.7096599}, {'year_month': '2007_OND', 'bound_name': 'kotido', 'mean': 0.9557348}, {'year_month': '2007_OND', 'bound_name': 'moroto', 'mean': 1.4631293}, {'year_month': '2007_OND', 'bound_name': 'nakapiripirit', 'mean': 0.43899497}, {'year_month': '2007_OND', 'bound_name': 'kaabong', 'mean': 1.4590784}, {'year_month': '2007_OND', 'bound_name': 'karenga', 'mean': 1.1522025}, {'year_month': '2007_OND', 'bound_name': 'amudat', 'mean': 0.8174689}, {'year_month': '2007_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.73914737}, {'year_month': '2007_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.093119}, {'year_month': '2007_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.1352807}, {'year_month': '2007_OND', 'bound_name': 'karamoja', 'mean': 0.9939694}]
#    year_month       bound_name      mean
# 0    2007_OND             abim  0.432494
# 1    2007_OND            napak  0.913879
# 2    2007_OND        nabilatuk  0.709660
# 3    2007_OND           kotido  0.955735
# 4    2007_OND           moroto  1.463129
# 5    2007_OND    nakapiripirit  0.438995
# 6    2007_OND          kaabong  1.459078
# 7    2007_OND          karenga  1.152202
# 8    2007_OND           amudat  0.817469
# 9    2007_OND    nab_nak_napak  0.739147
# 10   2007_OND  abi_kar_kaboong  1.093119
# 11   2007_OND   mor_kot_amudat  1.135281
# 12   2007_OND         karamoja  0.993969
# []
# [{'year_month': '2008_OND', 'bound_name': 'abim', 'mean': 0.38367122}, {'year_month': '2008_OND', 'bound_name': 'napak', 'mean': 0.79076713}, {'year_month': '2008_OND', 'bound_name': 'nabilatuk', 'mean': 0.84636223}, {'year_month': '2008_OND', 'bound_name': 'kotido', 'mean': 0.6436636}, {'year_month': '2008_OND', 'bound_name': 'moroto', 'mean': 1.2008357}, {'year_month': '2008_OND', 'bound_name': 'nakapiripirit', 'mean': 0.6968386}, {'year_month': '2008_OND', 'bound_name': 'kaabong', 'mean': 1.1797287}, {'year_month': '2008_OND', 'bound_name': 'karenga', 'mean': 0.74577165}, {'year_month': '2008_OND', 'bound_name': 'amudat', 'mean': 0.9463329}, {'year_month': '2008_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.7766795}, {'year_month': '2008_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.8472507}, {'year_month': '2008_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.92475575}, {'year_month': '2008_OND', 'bound_name': 'karamoja', 'mean': 0.84954286}]
#    year_month       bound_name      mean
# 0    2008_OND             abim  0.383671
# 1    2008_OND            napak  0.790767
# 2    2008_OND        nabilatuk  0.846362
# 3    2008_OND           kotido  0.643664
# 4    2008_OND           moroto  1.200836
# 5    2008_OND    nakapiripirit  0.696839
# 6    2008_OND          kaabong  1.179729
# 7    2008_OND          karenga  0.745772
# 8    2008_OND           amudat  0.946333
# 9    2008_OND    nab_nak_napak  0.776680
# 10   2008_OND  abi_kar_kaboong  0.847251
# 11   2008_OND   mor_kot_amudat  0.924756
# 12   2008_OND         karamoja  0.849543
# []
# [{'year_month': '2009_OND', 'bound_name': 'abim', 'mean': 0.07254185}, {'year_month': '2009_OND', 'bound_name': 'napak', 'mean': 0.48073667}, {'year_month': '2009_OND', 'bound_name': 'nabilatuk', 'mean': 0.5302197}, {'year_month': '2009_OND', 'bound_name': 'kotido', 'mean': 0.11628686}, {'year_month': '2009_OND', 'bound_name': 'moroto', 'mean': 0.46001983}, {'year_month': '2009_OND', 'bound_name': 'nakapiripirit', 'mean': 0.38876396}, {'year_month': '2009_OND', 'bound_name': 'kaabong', 'mean': 0.615982}, {'year_month': '2009_OND', 'bound_name': 'karenga', 'mean': 0.2758599}, {'year_month': '2009_OND', 'bound_name': 'amudat', 'mean': 0.54887074}, {'year_month': '2009_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.46588567}, {'year_month': '2009_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.37810966}, {'year_month': '2009_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.33510208}, {'year_month': '2009_OND', 'bound_name': 'karamoja', 'mean': 0.3923041}]
#    year_month       bound_name      mean
# 0    2009_OND             abim  0.072542
# 1    2009_OND            napak  0.480737
# 2    2009_OND        nabilatuk  0.530220
# 3    2009_OND           kotido  0.116287
# 4    2009_OND           moroto  0.460020
# 5    2009_OND    nakapiripirit  0.388764
# 6    2009_OND          kaabong  0.615982
# 7    2009_OND          karenga  0.275860
# 8    2009_OND           amudat  0.548871
# 9    2009_OND    nab_nak_napak  0.465886
# 10   2009_OND  abi_kar_kaboong  0.378110
# 11   2009_OND   mor_kot_amudat  0.335102
# 12   2009_OND         karamoja  0.392304
# []
# [{'year_month': '2010_OND', 'bound_name': 'abim', 'mean': 0.03247935}, {'year_month': '2010_OND', 'bound_name': 'napak', 'mean': 0.74922264}, {'year_month': '2010_OND', 'bound_name': 'nabilatuk', 'mean': 0.89834756}, {'year_month': '2010_OND', 'bound_name': 'kotido', 'mean': 0.15319195}, {'year_month': '2010_OND', 'bound_name': 'moroto', 'mean': 0.9198315}, {'year_month': '2010_OND', 'bound_name': 'nakapiripirit', 'mean': 0.943386}, {'year_month': '2010_OND', 'bound_name': 'kaabong', 'mean': 0.7301909}, {'year_month': '2010_OND', 'bound_name': 'karenga', 'mean': 0.34059134}, {'year_month': '2010_OND', 'bound_name': 'amudat', 'mean': 1.046399}, {'year_month': '2010_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.83466154}, {'year_month': '2010_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.43648833}, {'year_month': '2010_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.6280008}, {'year_month': '2010_OND', 'bound_name': 'karamoja', 'mean': 0.6242988}]
#    year_month       bound_name      mean
# 0    2010_OND             abim  0.032479
# 1    2010_OND            napak  0.749223
# 2    2010_OND        nabilatuk  0.898348
# 3    2010_OND           kotido  0.153192
# 4    2010_OND           moroto  0.919832
# 5    2010_OND    nakapiripirit  0.943386
# 6    2010_OND          kaabong  0.730191
# 7    2010_OND          karenga  0.340591
# 8    2010_OND           amudat  1.046399
# 9    2010_OND    nab_nak_napak  0.834662
# 10   2010_OND  abi_kar_kaboong  0.436488
# 11   2010_OND   mor_kot_amudat  0.628001
# 12   2010_OND         karamoja  0.624299
# []
# [{'year_month': '2011_OND', 'bound_name': 'abim', 'mean': -0.4278538}, {'year_month': '2011_OND', 'bound_name': 'napak', 'mean': 0.18048938}, {'year_month': '2011_OND', 'bound_name': 'nabilatuk', 'mean': 0.37480572}, {'year_month': '2011_OND', 'bound_name': 'kotido', 'mean': -0.6020072}, {'year_month': '2011_OND', 'bound_name': 'moroto', 'mean': -0.25104958}, {'year_month': '2011_OND', 'bound_name': 'nakapiripirit', 'mean': 0.4037987}, {'year_month': '2011_OND', 'bound_name': 'kaabong', 'mean': -0.42088103}, {'year_month': '2011_OND', 'bound_name': 'karenga', 'mean': -0.49309814}, {'year_month': '2011_OND', 'bound_name': 'amudat', 'mean': 0.19115002}, {'year_month': '2011_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.28361782}, {'year_month': '2011_OND', 'bound_name': 'abi_kar_kaboong', 'mean': -0.44079235}, {'year_month': '2011_OND', 'bound_name': 'mor_kot_amudat', 'mean': -0.31368518}, {'year_month': '2011_OND', 'bound_name': 'karamoja', 'mean': -0.16975668}]
#    year_month       bound_name      mean
# 0    2011_OND             abim -0.427854
# 1    2011_OND            napak  0.180489
# 2    2011_OND        nabilatuk  0.374806
# 3    2011_OND           kotido -0.602007
# 4    2011_OND           moroto -0.251050
# 5    2011_OND    nakapiripirit  0.403799
# 6    2011_OND          kaabong -0.420881
# 7    2011_OND          karenga -0.493098
# 8    2011_OND           amudat  0.191150
# 9    2011_OND    nab_nak_napak  0.283618
# 10   2011_OND  abi_kar_kaboong -0.440792
# 11   2011_OND   mor_kot_amudat -0.313685
# 12   2011_OND         karamoja -0.169757
# []
# [{'year_month': '2012_OND', 'bound_name': 'abim', 'mean': 0.81238157}, {'year_month': '2012_OND', 'bound_name': 'napak', 'mean': 1.2834942}, {'year_month': '2012_OND', 'bound_name': 'nabilatuk', 'mean': 1.2958434}, {'year_month': '2012_OND', 'bound_name': 'kotido', 'mean': 0.8758868}, {'year_month': '2012_OND', 'bound_name': 'moroto', 'mean': 1.3574194}, {'year_month': '2012_OND', 'bound_name': 'nakapiripirit', 'mean': 1.293534}, {'year_month': '2012_OND', 'bound_name': 'kaabong', 'mean': 1.1818656}, {'year_month': '2012_OND', 'bound_name': 'karenga', 'mean': 1.196576}, {'year_month': '2012_OND', 'bound_name': 'amudat', 'mean': 1.3346226}, {'year_month': '2012_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.2889013}, {'year_month': '2012_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.081249}, {'year_month': '2012_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.1552275}, {'year_month': '2012_OND', 'bound_name': 'karamoja', 'mean': 1.1709269}]
#    year_month       bound_name      mean
# 0    2012_OND             abim  0.812382
# 1    2012_OND            napak  1.283494
# 2    2012_OND        nabilatuk  1.295843
# 3    2012_OND           kotido  0.875887
# 4    2012_OND           moroto  1.357419
# 5    2012_OND    nakapiripirit  1.293534
# 6    2012_OND          kaabong  1.181866
# 7    2012_OND          karenga  1.196576
# 8    2012_OND           amudat  1.334623
# 9    2012_OND    nab_nak_napak  1.288901
# 10   2012_OND  abi_kar_kaboong  1.081249
# 11   2012_OND   mor_kot_amudat  1.155228
# 12   2012_OND         karamoja  1.170927
# []
# [{'year_month': '2013_OND', 'bound_name': 'abim', 'mean': 2.0222018}, {'year_month': '2013_OND', 'bound_name': 'napak', 'mean': 2.0395408}, {'year_month': '2013_OND', 'bound_name': 'nabilatuk', 'mean': 2.0380542}, {'year_month': '2013_OND', 'bound_name': 'kotido', 'mean': 1.9487157}, {'year_month': '2013_OND', 'bound_name': 'moroto', 'mean': 2.0277708}, {'year_month': '2013_OND', 'bound_name': 'nakapiripirit', 'mean': 2.0788734}, {'year_month': '2013_OND', 'bound_name': 'kaabong', 'mean': 1.8522614}, {'year_month': '2013_OND', 'bound_name': 'karenga', 'mean': 1.8895122}, {'year_month': '2013_OND', 'bound_name': 'amudat', 'mean': 2.119685}, {'year_month': '2013_OND', 'bound_name': 'nab_nak_napak', 'mean': 2.0500884}, {'year_month': '2013_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.9094754}, {'year_month': '2013_OND', 'bound_name': 'mor_kot_amudat', 'mean': 2.0122411}, {'year_month': '2013_OND', 'bound_name': 'karamoja', 'mean': 1.987016}]
#    year_month       bound_name      mean
# 0    2013_OND             abim  2.022202
# 1    2013_OND            napak  2.039541
# 2    2013_OND        nabilatuk  2.038054
# 3    2013_OND           kotido  1.948716
# 4    2013_OND           moroto  2.027771
# 5    2013_OND    nakapiripirit  2.078873
# 6    2013_OND          kaabong  1.852261
# 7    2013_OND          karenga  1.889512
# 8    2013_OND           amudat  2.119685
# 9    2013_OND    nab_nak_napak  2.050088
# 10   2013_OND  abi_kar_kaboong  1.909475
# 11   2013_OND   mor_kot_amudat  2.012241
# 12   2013_OND         karamoja  1.987016
# []
# [{'year_month': '2014_OND', 'bound_name': 'abim', 'mean': 1.7967983}, {'year_month': '2014_OND', 'bound_name': 'napak', 'mean': 1.6656524}, {'year_month': '2014_OND', 'bound_name': 'nabilatuk', 'mean': 1.5776336}, {'year_month': '2014_OND', 'bound_name': 'kotido', 'mean': 1.8196476}, {'year_month': '2014_OND', 'bound_name': 'moroto', 'mean': 1.4651952}, {'year_month': '2014_OND', 'bound_name': 'nakapiripirit', 'mean': 1.6235429}, {'year_month': '2014_OND', 'bound_name': 'kaabong', 'mean': 1.6334292}, {'year_month': '2014_OND', 'bound_name': 'karenga', 'mean': 1.8314804}, {'year_month': '2014_OND', 'bound_name': 'amudat', 'mean': 1.5975169}, {'year_month': '2014_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.6352475}, {'year_month': '2014_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.7287424}, {'year_month': '2014_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.6353639}, {'year_month': '2014_OND', 'bound_name': 'karamoja', 'mean': 1.6691883}]
#    year_month       bound_name      mean
# 0    2014_OND             abim  1.796798
# 1    2014_OND            napak  1.665652
# 2    2014_OND        nabilatuk  1.577634
# 3    2014_OND           kotido  1.819648
# 4    2014_OND           moroto  1.465195
# 5    2014_OND    nakapiripirit  1.623543
# 6    2014_OND          kaabong  1.633429
# 7    2014_OND          karenga  1.831480
# 8    2014_OND           amudat  1.597517
# 9    2014_OND    nab_nak_napak  1.635247
# 10   2014_OND  abi_kar_kaboong  1.728742
# 11   2014_OND   mor_kot_amudat  1.635364
# 12   2014_OND         karamoja  1.669188
# []
# [{'year_month': '2015_OND', 'bound_name': 'abim', 'mean': 1.5831299}, {'year_month': '2015_OND', 'bound_name': 'napak', 'mean': 1.4295216}, {'year_month': '2015_OND', 'bound_name': 'nabilatuk', 'mean': 1.3372122}, {'year_month': '2015_OND', 'bound_name': 'kotido', 'mean': 1.297128}, {'year_month': '2015_OND', 'bound_name': 'moroto', 'mean': 0.85432893}, {'year_month': '2015_OND', 'bound_name': 'nakapiripirit', 'mean': 1.4140235}, {'year_month': '2015_OND', 'bound_name': 'kaabong', 'mean': 1.1169156}, {'year_month': '2015_OND', 'bound_name': 'karenga', 'mean': 1.411479}, {'year_month': '2015_OND', 'bound_name': 'amudat', 'mean': 1.2903142}, {'year_month': '2015_OND', 'bound_name': 'nab_nak_napak', 'mean': 1.4055523}, {'year_month': '2015_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 1.3216743}, {'year_month': '2015_OND', 'bound_name': 'mor_kot_amudat', 'mean': 1.1168985}, {'year_month': '2015_OND', 'bound_name': 'karamoja', 'mean': 1.2829852}]
#    year_month       bound_name      mean
# 0    2015_OND             abim  1.583130
# 1    2015_OND            napak  1.429522
# 2    2015_OND        nabilatuk  1.337212
# 3    2015_OND           kotido  1.297128
# 4    2015_OND           moroto  0.854329
# 5    2015_OND    nakapiripirit  1.414024
# 6    2015_OND          kaabong  1.116916
# 7    2015_OND          karenga  1.411479
# 8    2015_OND           amudat  1.290314
# 9    2015_OND    nab_nak_napak  1.405552
# 10   2015_OND  abi_kar_kaboong  1.321674
# 11   2015_OND   mor_kot_amudat  1.116899
# 12   2015_OND         karamoja  1.282985
# []
# [{'year_month': '2016_OND', 'bound_name': 'abim', 'mean': 0.7908989}, {'year_month': '2016_OND', 'bound_name': 'napak', 'mean': 0.7890924}, {'year_month': '2016_OND', 'bound_name': 'nabilatuk', 'mean': 0.7500263}, {'year_month': '2016_OND', 'bound_name': 'kotido', 'mean': 0.35225463}, {'year_month': '2016_OND', 'bound_name': 'moroto', 'mean': -0.1985905}, {'year_month': '2016_OND', 'bound_name': 'nakapiripirit', 'mean': 0.8273842}, {'year_month': '2016_OND', 'bound_name': 'kaabong', 'mean': 0.082166344}, {'year_month': '2016_OND', 'bound_name': 'karenga', 'mean': 0.41622096}, {'year_month': '2016_OND', 'bound_name': 'amudat', 'mean': 0.60193014}, {'year_month': '2016_OND', 'bound_name': 'nab_nak_napak', 'mean': 0.79133725}, {'year_month': '2016_OND', 'bound_name': 'abi_kar_kaboong', 'mean': 0.36517808}, {'year_month': '2016_OND', 'bound_name': 'mor_kot_amudat', 'mean': 0.17572072}, {'year_month': '2016_OND', 'bound_name': 'karamoja', 'mean': 0.4402696}]
#    year_month       bound_name      mean
# 0    2016_OND             abim  0.790899
# 1    2016_OND            napak  0.789092
# 2    2016_OND        nabilatuk  0.750026
# 3    2016_OND           kotido  0.352255
# 4    2016_OND           moroto -0.198591
# 5    2016_OND    nakapiripirit  0.827384
# 6    2016_OND          kaabong  0.082166
# 7    2016_OND          karenga  0.416221
# 8    2016_OND           amudat  0.601930
# 9    2016_OND    nab_nak_napak  0.791337
# 10   2016_OND  abi_kar_kaboong  0.365178
# 11   2016_OND   mor_kot_amudat  0.175721
# 12   2016_OND         karamoja  0.440270

# %%
import glob
import geopandas as gp
import pandas as pd
import numpy as np

import xarray as xr
import rioxarray

shpfiles=glob.glob('/home/data_folder/karamoja_shapefiles/*/*.shp')

dist_shp=gp.read_file(shpfiles[0])
#dist_shp.plot()
#dist_shp.info()

kara_shp=gp.read_file(shpfiles[1])
#kara_shp.plot()

lh_shp=gp.read_file(shpfiles[2])
#lh_shp.plot()

sc_shp=gp.read_file(shpfiles[3])
#sc_shp.plot()

dist_shp1=dist_shp[['admin2Name','geometry']]
dist_shp1.columns=['admin_name','geometry']
lh_shp1=lh_shp[['livelihood','geometry']]
lh_shp1.columns=['admin_name','geometry']
kara_shp1=kara_shp[['geometry']]
kara_shp1['admin_name']='karamoja'
#kara_shp1.columns=['admin_name','geometry']

geo_db=pd.concat([dist_shp1,lh_shp1,kara_shp1])
geo_db1=geo_db.reset_index()
geo_db2=geo_db1[['admin_name','geometry']]
geo_db2['admin_name1']=geo_db2['admin_name'].str.lower()
admin_bound_list=geo_db2['admin_name1'].tolist()
#admin_bound_list



def get_month_index_str(start_month_index,end_month_index):
    month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
    m_ind_list=np.arange(start_month_index,end_month_index+1,1)
    m_cnt=[]
    for m_ind in m_ind_list:
        mstr=month_index_dict[m_ind]
        m_cnt.append(mstr)
    jmstr=''.join(m_cnt)
    return jmstr



def region_shp_spei_averager_season(single_row_shp,xds,var_str,start_month_index,end_month_index):
    month_index_str=get_month_index_str(start_month_index,end_month_index)
    year_list=np.arange(1981,2016+1,1)
    xds_clipped = xds.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)
    print(xds_clipped)
    db_cont=[]
    for year_int in year_list[0:3]:
        xds_year=xds_clipped.sel(time=slice(str(year_int),str(year_int)))
        da1=xds_year[var_str]
        aa=da1.values
        aa1=aa[start_month_index:end_month_index,:,:]
        aa2=aa1.ravel()
        aa3 = aa2[(aa2 >=-9000)]
        cont_mean=np.mean(aa3)
        year_str=str(year_int)
        year_month_index_str=f'{year_str}_{month_index_str}'
        ab_dict={}
        ab_dict['year_month']=year_month_index_str
        ab_dict['bound_name']=ab_str
        ab_dict['mean']=cont_mean
        db_cont.append(ab_dict)
    db=pd.DataFrame(db_cont)
    db1=pd.pivot_table(db, values='mean', index=['year_month'], columns=['bound_name'])
    db2=db1.reset_index()
    return db2,month_index_str



def make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index):
    ncfile_path=f'/home/data_folder/ceda_spei/{ncfilename}.nc'
    xds=xr.open_dataset(ncfile_path)
    xds.rio.write_crs("epsg:4326", inplace=True)
    mdb_cont=[]
    for ab_str in admin_bound_list[0:1]:
        geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
        single_row_shp=geo_db3        
        db2,month_index_str=region_shp_spei_averager_season(single_row_shp,xds,var_str,start_month_index,end_month_index)
        mdb_cont.append(db2)
        db2=[]
    mdb1=pd.concat(mdb_cont,axis=0)
    mdb1.to_csv(f'/home/data_folder/spei_seasonal/{ncfilename}_{month_index_str}.csv',index=False)
    mdb1=[]
    #return db
# Out:
# /root/miniconda3/envs/climada_env/lib/python3.8/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
ncfile_list=['spei01','spei03','spei06','spei09','spei12','spei24','spei48']

#month_index_dict={0:'J',1:'F',2:'M',3:'A',4:'M',5:'J',6:'J',7:'A',8:'S',9:'O',10:'N',11:'D'}
#for mar to october
start_month_index=2
end_month_index=9

var_str='spei'

for ncfilename in ncfile_list[0:1]:
    make_spei_csv_season(geo_db2,admin_bound_list,ncfilename,var_str,start_month_index,end_month_index)

# %%
import xarray as xr

ncfile_path='/home/data_folder/ceda_spei/spei01.nc'

#xds = rioxarray.open_rasterio(ncfile_path)

xds=xr.open_dataset(ncfile_path)
xds.rio.write_crs("epsg:4326", inplace=True)
#xds_year=xds.loc[dict(time=slice(str(1991)))]

xds_year=xds.sel(time=slice('1991','1991'))

#xds_year['time']


ab_str=admin_bound_list[12]
print(ab_str)
geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
single_row_shp=geo_db3 

clipped = xds_year.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)
# year_xds=xds_year.indexes['time'].to_datetimeindex()
# year_str=str(year_xds[0].year)
# da=clipped.loc[dict(time=slice(year_str))]
# da1=da[var_str]
# aa=da1.values
# aa1=aa[start_month_index:end_month_index,:,:]
# aa2=aa1.ravel()
# aa3 = aa2[(aa2 >=-9000)]
# cont_mean=np.mean(aa3)
clipped
# Out:
# karamoja
# <xarray.Dataset>
# Dimensions:      (lat: 56, lon: 30, time: 12)
# Coordinates:
#   * lat          (lat) float32 4.175 4.125 4.075 4.025 ... 1.525 1.475 1.425
#   * lon          (lon) float32 33.53 33.58 33.62 33.67 ... 34.88 34.92 34.97
#   * time         (time) datetime64[ns] 1991-01-01 1991-02-01 ... 1991-12-01
#     spatial_ref  int64 0
# Data variables:
#     spei         (time, lat, lon) float32 nan nan nan nan ... nan nan nan nan
# Attributes:
#     title:                     High resolution Standardized Precipitation Eva...
#     institution:               School of Geography and the Environment, Unive...
#     version:                   1.0
#     creators:                  Jian Peng, Simon Dadson, Feyera Hirpa, Ellen D...
#     source:                    The dataset was produced using CHIRPS precipit...
#     comment:                   The dataset was produced as part of the UK Spa...
#     time_coverage:             1981.01-2016.12
#     time_coverage_resolution:  monthly
#     spatial_resolution:        5km

# %%
ncfile_path='/home/data_folder/icpac_data/data/IGAD_Standardized_Precipitation_Index_SPI1/CHIRPS/spg01_m_igad_200501_200512_m.nc'

xds = rioxarray.open_rasterio(ncfile_path)

#xds=xr.open_dataset(ncfile_path)
#xds.rio.write_crs("epsg:4326", inplace=True)
#xds_year=xds.loc[dict(time=slice(str(1991)))]

#xds_year=xds.sel(time=slice('1991','1991'))

#xds_year['time']


ab_str=admin_bound_list[12]
print(ab_str)
geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
single_row_shp=geo_db3 

clipped = xds.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)

clipped
# Out:
# karamoja
# <xarray.Dataset>
# Dimensions:             (time: 12, x: 30, y: 56)
# Coordinates:
#   * time                (time) object 2005-01-01 00:00:00 ... 2005-12-01 00:0...
#   * x                   (x) float64 33.52 33.58 33.62 ... 34.88 34.92 34.98
#   * y                   (y) float64 1.425 1.475 1.525 ... 4.075 4.125 4.175
#     spatial_ref         int64 0
#     latitude_longitude  int64 0
# Data variables:
#     spg01               (time, y, x) float32 -9.999e+03 ... -9.999e+03
# Attributes: (12/28)
#     lat#_FillValue:                                  nan
#     latitude_longitude#crs_wkt:                      GEOGCS["WGS 84",DATUM["W...
#     latitude_longitude#geographic_crs_name:          WGS 84
#     latitude_longitude#GeoTransform:                 21.85 0.05 0.0 -11.75 0....
#     latitude_longitude#grid_mapping_name:            latitude_longitude
#     latitude_longitude#inverse_flattening:           298.257223563
#     ...                                              ...
#     spg01#grid_mapping:                              latitude_longitude
#     spg01#units:                                     dimensionless
#     spg01#_FillValue:                                -9999
#     time#calendar:                                   proleptic_gregorian
#     time#standard_name:                              time
#     time#units:                                      days since 2005-01-01 00...

# %%
ncfile_path='/home/data_folder/icpac_data/data/IGAD_Standardized_Precipitation_Index_SPI1/CHIRPS/spg01_m_igad_200501_200512_m.nc'

#xds = rioxarray.open_rasterio(ncfile_path)

xds=xr.open_dataset(ncfile_path)
#xds.rio.write_crs("epsg:4326", inplace=True)
#xds_year=xds.loc[dict(time=slice(str(1991)))]

#xds_year=xds.sel(time=slice('1991','1991'))

#xds_year['time']


ab_str=admin_bound_list[6]
print(ab_str)
geo_db3=geo_db2[geo_db2['admin_name1']==ab_str]
single_row_shp=geo_db3 

#clipped = xds.rio.clip(single_row_shp.geometry.values, single_row_shp.crs)

#clipped
xds
# Out:
# kaabong
# <xarray.Dataset>
# Dimensions:             (lat: 698, lon: 591, time: 12)
# Coordinates:
#   * lat                 (lat) float64 -11.72 -11.68 -11.62 ... 23.02 23.07 23.12
#   * lon                 (lon) float64 21.88 21.93 21.98 ... 51.27 51.33 51.38
#   * time                (time) datetime64[ns] 2005-01-01 ... 2005-12-01
#     latitude_longitude  int64 ...
# Data variables:
#     spg01               (time, lat, lon) float32 ...
#     4326                float32 ...
# Attributes:
#     Source_Software:   netcdftonetcdfCF-1.6.py
#     creator_name:      Created by dbinterface.py
#     Conventions:       CF-1.6
#     _CoordSysBuilder:  ucar.nc2.dataset.conv.CF1Convention
#     date_created:      2021-12-05

# %%
xds_year1=xds_year.sel(x=slice(33.51,35.00))
xds_year2=xds_year1.sel(y=slice(1.36,4.23))
xds_year1
# Out:
# <xarray.DataArray 'spei' (time: 12, y: 1800, x: 1)>
# array([[[9.96921e+36],
#         [9.96921e+36],
#         ...,
#         [9.96921e+36],
#         [9.96921e+36]],
#
#        [[9.96921e+36],
#         [9.96921e+36],
#         ...,
#         [9.96921e+36],
#         [9.96921e+36]],
#
#        ...,
#
#        [[9.96921e+36],
#         [9.96921e+36],
#         ...,
#         [9.96921e+36],
#         [9.96921e+36]],
#
#        [[9.96921e+36],
#         [9.96921e+36],
#         ...,
#         [9.96921e+36],
#         [9.96921e+36]]], dtype=float32)
# Coordinates:
#   * time         (time) object 1991-01-01 00:00:00 ... 1991-12-01 00:00:00
#   * x            (x) float64 34.5
#   * y            (y) float64 0.5 1.5 2.5 3.5 ... 1.798e+03 1.798e+03 1.8e+03
#     spatial_ref  int64 0
# Attributes:
#     lat#standard_name:         latitude
#     lat#units:                 degrees_north
#     lon#standard_name:         longitude
#     lon#units:                 degrees_east
#     comment:                   The dataset was produced as part of the UK Spa...
#     creators:                  Jian Peng, Simon Dadson, Feyera Hirpa, Ellen D...
#     institution:               School of Geography and the Environment, Unive...
#     source:                    The dataset was produced using CHIRPS precipit...
#     spatial_resolution:        5km
#     time_coverage:             1981.01-2016.12
#     time_coverage_resolution:  monthly
#     title:                     High resolution Standardized Precipitation Eva...
#     version:                   1.0
#     NETCDF_DIM_EXTRA:          {time}
#     NETCDF_DIM_time_DEF:       [432.   6.]
#     NETCDF_DIM_time_VALUES:    [    0.    31.    59.    90.   120.   151.   1...
#     coordinates:               lat lon
#     long_name:                 Standardized Precipitation Evapotranspiration ...
#     units:                     ('z value', 'z value', 'z value', 'z value', '...
#     _FillValue:                9.96921e+36
#     scale_factor:              1.0
#     add_offset:                0.0

# %%
clipped
# Out:
# <xarray.DataArray 'spei' (time: 12, y: 1, x: 1)>
# array([[[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]],
#
#        [[9.96921e+36]]], dtype=float32)
# Coordinates:
#   * time         (time) object 1991-01-01 00:00:00 ... 1991-12-01 00:00:00
#   * x            (x) float64 34.5
#   * y            (y) float64 2.5
#     spatial_ref  int64 0
# Attributes:
#     lat#standard_name:         latitude
#     lat#units:                 degrees_north
#     lon#standard_name:         longitude
#     lon#units:                 degrees_east
#     comment:                   The dataset was produced as part of the UK Spa...
#     creators:                  Jian Peng, Simon Dadson, Feyera Hirpa, Ellen D...
#     institution:               School of Geography and the Environment, Unive...
#     source:                    The dataset was produced using CHIRPS precipit...
#     spatial_resolution:        5km
#     time_coverage:             1981.01-2016.12
#     time_coverage_resolution:  monthly
#     title:                     High resolution Standardized Precipitation Eva...
#     version:                   1.0
#     NETCDF_DIM_EXTRA:          {time}
#     NETCDF_DIM_time_DEF:       [432.   6.]
#     NETCDF_DIM_time_VALUES:    [    0.    31.    59.    90.   120.   151.   1...
#     coordinates:               lat lon
#     long_name:                 Standardized Precipitation Evapotranspiration ...
#     units:                     ('z value', 'z value', 'z value', 'z value', '...
#     scale_factor:              1.0
#     add_offset:                0.0
#     _FillValue:                9.96921e+36

# %%
xds
# Out:
# <xarray.DataArray 'spei' (time: 432, y: 1800, x: 2080)>
# [1617408000 values with dtype=float32]
# Coordinates:
#   * time         (time) object 1981-01-01 00:00:00 ... 2016-12-01 00:00:00
#   * x            (x) float64 0.5 1.5 2.5 3.5 ... 2.078e+03 2.078e+03 2.08e+03
#   * y            (y) float64 0.5 1.5 2.5 3.5 ... 1.798e+03 1.798e+03 1.8e+03
#     spatial_ref  int64 0
# Attributes:
#     lat#standard_name:         latitude
#     lat#units:                 degrees_north
#     lon#standard_name:         longitude
#     lon#units:                 degrees_east
#     comment:                   The dataset was produced as part of the UK Spa...
#     creators:                  Jian Peng, Simon Dadson, Feyera Hirpa, Ellen D...
#     institution:               School of Geography and the Environment, Unive...
#     source:                    The dataset was produced using CHIRPS precipit...
#     spatial_resolution:        5km
#     time_coverage:             1981.01-2016.12
#     time_coverage_resolution:  monthly
#     title:                     High resolution Standardized Precipitation Eva...
#     version:                   1.0
#     NETCDF_DIM_EXTRA:          {time}
#     NETCDF_DIM_time_DEF:       [432.   6.]
#     NETCDF_DIM_time_VALUES:    [    0.    31.    59.    90.   120.   151.   1...
#     coordinates:               lat lon
#     long_name:                 Standardized Precipitation Evapotranspiration ...
#     units:                     ('z value', 'z value', 'z value', 'z value', '...
#     _FillValue:                9.96921e+36
#     scale_factor:              1.0
#     add_offset:                0.0

# %%
import cf_xarray as cfxr
import xarray as xr

ncfile_path='/home/data_folder/ceda_spei/spei01.nc'

#xds = rioxarray.open_rasterio(ncfile_path)

xds=xr.open_dataset(ncfile_path)

xds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1800, lon: 2080, time: 432)
# Coordinates:
#   * lat      (lat) float32 47.97 47.92 47.88 47.83 ... -41.88 -41.92 -41.97
#   * lon      (lon) float32 -27.98 -27.92 -27.88 -27.83 ... 75.88 75.93 75.97
#   * time     (time) datetime64[ns] 1981-01-01 1981-02-01 ... 2016-12-01
# Data variables:
#     spei     (time, lat, lon) float32 ...
# Attributes:
#     title:                     High resolution Standardized Precipitation Eva...
#     institution:               School of Geography and the Environment, Unive...
#     version:                   1.0
#     creators:                  Jian Peng, Simon Dadson, Feyera Hirpa, Ellen D...
#     source:                    The dataset was produced using CHIRPS precipit...
#     comment:                   The dataset was produced as part of the UK Spa...
#     time_coverage:             1981.01-2016.12
#     time_coverage_resolution:  monthly
#     spatial_resolution:        5km

# %%
#"D:\docker_work\icpac_data\data\IGAD_Standardized_Precipitation_Index_SPI1\CHIRPS\spg01_m_igad_200501_200512_m.nc"
import rioxarray

ncfile_path='/home/data_folder/icpac_data/data/IGAD_Standardized_Precipitation_Index_SPI1/CHIRPS/spg01_m_igad_200501_200512_m.nc'
xds = rioxarray.open_rasterio(ncfile_path)

xds
# Out:
# <xarray.Dataset>
# Dimensions:             (time: 12, x: 591, y: 698)
# Coordinates:
#   * time                (time) object 2005-01-01 00:00:00 ... 2005-12-01 00:0...
#   * x                   (x) float64 21.88 21.93 21.98 ... 51.28 51.33 51.38
#   * y                   (y) float64 -11.72 -11.67 -11.62 ... 23.02 23.08 23.12
#     latitude_longitude  int64 0
# Data variables:
#     spg01               (time, y, x) float32 ...
# Attributes: (12/28)
#     lat#_FillValue:                                  nan
#     latitude_longitude#crs_wkt:                      GEOGCS["WGS 84",DATUM["W...
#     latitude_longitude#geographic_crs_name:          WGS 84
#     latitude_longitude#GeoTransform:                 21.85 0.05 0.0 -11.75 0....
#     latitude_longitude#grid_mapping_name:            latitude_longitude
#     latitude_longitude#inverse_flattening:           298.257223563
#     ...                                              ...
#     spg01#grid_mapping:                              latitude_longitude
#     spg01#units:                                     dimensionless
#     spg01#_FillValue:                                -9999
#     time#calendar:                                   proleptic_gregorian
#     time#standard_name:                              time
#     time#units:                                      days since 2005-01-01 00...

# %%
df=xr.open_dataset(ncfile_path)
df
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 698, lon: 591, time: 12)
# Coordinates:
#   * lat                 (lat) float64 -11.72 -11.68 -11.62 ... 23.02 23.07 23.12
#   * lon                 (lon) float64 21.88 21.93 21.98 ... 51.27 51.33 51.38
#   * time                (time) datetime64[ns] 2005-01-01 ... 2005-12-01
#     latitude_longitude  int64 ...
# Data variables:
#     spg01               (time, lat, lon) float32 ...
#     4326                float32 ...
# Attributes:
#     Source_Software:   netcdftonetcdfCF-1.6.py
#     creator_name:      Created by dbinterface.py
#     Conventions:       CF-1.6
#     _CoordSysBuilder:  ucar.nc2.dataset.conv.CF1Convention
#     date_created:      2021-12-05
